# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
import csv
#holawenasnoxes

# %% [markdown]
# Daaniiiiiiiiiiiiiiiiii     AQUI   poner brevemente que hace cada funcion

# %%
from ytmusicapi import YTMusic

yt = YTMusic()
#z8uyayN3RbE
searchMusic=yt.get_song("5g2hT4GmAGU")

#yt.get_artist("UCiY3z8HAGD6BlSNKVn2kSvQ")
search_results=yt.search("ptazeta")
#search_results
searchPlay=yt.get_playlist("PL4fGSI1pDJn4jhQB4kb9M36dvVmJQPt4T")

searcArtist=yt.get_artist('UCI9q5A6SUN37p0gM01E1R4Q')

searchMusic=yt.get_song("-XiCucQ4RCU")

searchchar=yt.get_charts()
#searchchar
#searchPlay
#searchMusic
#searcArtist
#search_results

# %% [markdown]
# A continuación empezamos cargando un array con todos los artistas que aparecen en el array de playlist. Recorreremos el array de playlist y extraeremos los datos de dichas playlists con las funciones de la appi ya mencionadas. Probamos a meter los diccionarios que nos da la funcion
# "get_playlist" en un array llamado 'artistas' para empezar a jugar con ello.
# Nos dimos cuenta que filtrando por clave/valor del diccionario se podia ver muchos datos. En este caso filtramos por "tracks" donde nos enseña todas las canciones de las playlist con informacion relevante de ellas. Con esto conseguimos informacion de los artistas que participan en esa canción. Esta información la metemos en el array de artistas para dividir dos diccionarios: diccionario de solos (en los que solo participa un artista )y diccionario de colaboraciones (en el que participa más de uno)

# %% [markdown]
#
#
# ### Array de playlist
# * **BIZARRAP SESSIONS**  RDCLAK5uy_mEXMsobutX4itJVd6YaCodxMgUV-mMtNo
#
# * **TOP 100**   PL4fGSI1pDJn4jhQB4kb9M36dvVmJQPt4T
# * **Pon Reggaeton**       RDCLAK5uy_ll_3x-AJOymCxeODF09ZjyXg7b6m7OBqs
# * **Al Millon**        RDCLAK5uy_lOAAW-PX5XUed76iQefCxkOXd6m6ZvyiM
# * **Lo esencial del reggaetón**    RDCLAK5uy_mFaoBNPmTUVcY51UGFuAYedXv4kXuqg5M
# * **Hot Reggaeton** RDCLAK5uy_kV0Nh-OIcnh8LppyiFE4lhhWZEvaPQEOY
# * **Reggaeton Hits 2022** RDCLAK5uy_nCwpBIEzaxNFjFj4iWH5JzdwEuGUTCgFM
# * **Reggaeton Playlist - Best Reggaeton Songs** PLPPgknP7IOwXmkAE99CdZ2h4baKNEvzev
# * **Reggaeton 2022 Playlist & Latin Music 2022** PL6Go6XFhidEAac3TgkP8EfLF1bA1odl4e
# * **Top Reggaeton 2021 - 2022 Playlist - Best New Reggaeton Songs 2021 - 2022**    PLq3UZa7STrbpinnTs3HuJY_n49qHUu6Ho
# * **Top Reggaeton Playlist - Best Reggaeton Songs of All Time**    PLo3pNg0eiPc8rRO3XqFnl1Je2GTu7am-F
# * **REGGAETON ROMANTICO 2022/ MEJORES REGGAETONES 2022. Reggaeton nuevos mas tocados**   PL8cNgJdjBpTABXO7i8nrifUJWcHia392H
# * **Reggaeton para bailar**    PLPPgknP7IOwUmPZqVP6oj_K2YPfYdU2DV

# %%
yt = YTMusic()
playlist=['PL4fGSI1pDJn4jhQB4kb9M36dvVmJQPt4T','RDCLAK5uy_ll_3x-AJOymCxeODF09ZjyXg7b6m7OBqs',
'RDCLAK5uy_lOAAW-PX5XUed76iQefCxkOXd6m6ZvyiM','RDCLAK5uy_mFaoBNPmTUVcY51UGFuAYedXv4kXuqg5M',
'RDCLAK5uy_kV0Nh-OIcnh8LppyiFE4lhhWZEvaPQEOY','RDCLAK5uy_nCwpBIEzaxNFjFj4iWH5JzdwEuGUTCgFM',
'PLPPgknP7IOwXmkAE99CdZ2h4baKNEvzev','PL6Go6XFhidEAac3TgkP8EfLF1bA1odl4e','PLq3UZa7STrbpinnTs3HuJY_n49qHUu6Ho',
'PLo3pNg0eiPc8rRO3XqFnl1Je2GTu7am-F','PL8cNgJdjBpTABXO7i8nrifUJWcHia392H','PLPPgknP7IOwUmPZqVP6oj_K2YPfYdU2DV']

artistas = []
diccSolo= {}
diccSolo.clear()
colabos=[]

infoPlayList = []
for p in playlist:
     infoPlayList.append(yt.get_playlist(p))
     
#para rellenar artistas
for r in infoPlayList:
     for a in r['tracks']:
      artistas.append(a['artists'])

#for r in searchPlay['tracks']:
#     artistas.append(r['artists'])

for a in artistas:#cargamos el diccionario con los artistas que van a cantar solos
   for b in a:
    if(len(a)==1):
        diccSolo[b['name']]={'idYTMusic':b['id'],'colaboracion':[]}

# %%
diccColabo= {}
diccColabo.clear()

for a in artistas:#aqui cargamos solo artistas que han aparecido con colaboraciones en la playlist
  if(len(a)>1):
      diccColabo[a[0]['name']]={'idYTMusic':a[0]['id'],'colaboracion':[],'subscriptores':None,'views':None}

      #if(len(a)==2):
          #dicc[b['id']]={'name':b['name']}

# %% [markdown]
# Nos quedamos con el diccionario de colaboraciones para empezar nuestro análisis. Y empezamos a meter los atributos que nos vendran en el estudio. En este caso, recorriendo otra vez los artistas, sacaremos las colaboraciones de cada uno y la añadiremos

# %%
#c[1]['name']
for c in artistas:#aqui les metemos en colaboraciones sus feats
    if(len(c)>1):
      # print(c[i+1]['name'])--> funcion que recorre artistas de las colaboraciones
      #añadimos artistas a las colabos
           for i in range(len(c)-1):
            diccColabo[c[0]['name']]['colaboracion'].append(c[i+1]['name'])
#diccColabo

# %% [markdown]
# Al proseguir creando la red , nos dimos cuenta que un atributo que seria importante como el id de cada artista; algunas veces no salia. Aparecia como vacío y nos daba fallo al no poder mostrar nada. Esto era o bien porque no tienen canal creado dentro de esta plataforma o porque a veces la aplicación falla ocasionalmente. Por eso en este código buscamos estos espacios vacío, y los rellenamos usando otra funcion de la appi que nos proporciona tambien el id del artista: "search". En el caso de que no nos encuentre nada ponemos que no tiene canal creado.

# %%
#para quitar los artistas que no tiene id ytMusic(fallo de la api)

for a in diccColabo:
   if(diccColabo[a]['idYTMusic']==None):
     idsvacios=yt.search(a)
     if('browseId'not in idsvacios[0]):#VER SI TIENE  ['browseId'] , SI NO LO TIENE SE PONE NO CHANNEL, SI TIENE SE PONE LO QUE ESTA EN EL ELSE  
      diccColabo[a]['idYTMusic']='No Channel'
     else:
      diccColabo[a]['idYTMusic']=idsvacios[0]['browseId']
   
#diccColabo

# %%
#numeramos con ids 
i=0
for keys in diccColabo:
    diccColabo[keys]['id']=i
    i=i+1

# %% [markdown]
# Una vez bien creado las bases del csv, procedemos a rellenar la información de cada artista. En este caso meteremos sus visitas y sus suscriptores. Como resultado obtenemos el diccionario al completo con el que podremos crear el csv.

# %%
#sacamos artistas , del diccionario por su id, sacamos los que tienen canal,y metemos su info de vistas y subscriptores
infoartista=[]
infoSubscribers=[]
infoViews=[]
for a in diccColabo:
   infoartista.append(diccColabo[a]['idYTMusic'])
  
for r in infoartista:
   if(r!='No Channel'):
      artista=yt.get_artist(r)
      infoSubscribers.append(artista['subscribers'])
      infoViews.append(artista['views'])
i=0
for keys in diccColabo:
    if(diccColabo[keys]['idYTMusic']!='No Channel'):
      diccColabo[keys]['subscriptores']=infoSubscribers[i]
      diccColabo[keys]['views']=infoViews[i]
      i=i+1    

diccColabo
# Out:
# {'Arcangel': {'idYTMusic': 'UCVcAt8IIKIeubRSigcYXgtA',
#   'colaboracion': ['Bad Bunny',
#    'Duki',
#    'Bizarrap',
#    'Myke Towers',
#    'YOVNGCHIMI',
#    'Bad Bunny',
#    'Sech'],
#   'subscriptores': '10.7M',
#   'views': '4,731,158,596 views',
#   'id': 0},
#  'Farruko': {'idYTMusic': 'UC6QXZsAOOweLfhVPbqMyG4g',
#   'colaboracion': ['Omar Montes',
#    'Rauw Alejandro',
#    'Natti Natasha',
#    'Justin Quiles',
#    'Sean Paul',
#    'Nicky Jam',
#    'Amenazzy',
#    'Don Omar',
#    'Myke Towers',
#    'Rvssian',
#    'J Balvin',
#    'Rauw Alejandro',
#    'El Alfa',
#    'Myke Towers',
#    'Chencho Corleone',
#    'Anuel AA',
#    'Zumbi',
#    'Rauw Alejandro',
#    'KEVVO',
#    'Chencho Corleone'],
#   'subscriptores': '18.3M',
#   'views': '8,903,747,439 views',
#   'id': 1},
#  'Quevedo': {'idYTMusic': 'UC7PL9aor5qNRhvhWWVXyOqA',
#   'colaboracion': ['Bizarrap',
#    'Bad Gyal',
#    'Ovy On The Drums',
#    'Mora',
#    'Mora',
#    'Polima Westcoast',
#    'Bizarrap',
#    'Mora',
#    'Polima Westcoast',
#    'Bizarrap',
#    'De La Ghetto',
#    'Duki'],
#   'subscriptores': '1.07M',
#   'views': '286,022,617 views',
#   'id': 2},
#  'Bizarrap': {'idYTMusic': 'UCONiUl5u7y2bMaVZJcuRDEQ',
#   'colaboracion': ['Duki', 'Duki'],
#   'subscriptores': '16.6M',
#   'views': '5,838,104,536 views',
#   'id': 3},
#  'Rauw Alejandro': {'idYTMusic': 'UCw_m17sBd4GHxuK83-AZtuA',
#   'colaboracion': ['Baby Rasta',
#    'Lyanno',
#    'Brray',
#    'Lyanno',
#    'Brray',
#    'Baby Rasta',
#    'Nio Garcia',
#    'Lenny Tavárez',
#    'Baby Rasta',
#    'Nio Garcia',
#    'Lenny Tavárez',
#    'Lyanno',
#    'Brray',
#    'Chencho Corleone',
#    'Mr. NaisGai',
#    'Lyanno',
#    'Brray',
#    'Chencho Corleone',
#    'Baby Rasta',
#    'Chencho Corleone',
#    'Lyanno',
#    'Brray',
#    'Álvaro Díaz',
#    'Baby Rasta',
#    'Chencho Corleone',
#    'Lyanno',
#    'Brray',
#    'Álvaro Díaz',
#    'Baby Rasta',
#    'Lyanno',
#    'Brray',
#    'Chencho Corleone',
#    'Chencho Corleone'],
#   'subscriptores': '12.3M',
#   'views': '10,146,076,858 views',
#   'id': 4},
#  'Aitana': {'idYTMusic': 'UCkyzcFsGWVYSUGaR7YB9OYQ',
#   'colaboracion': ['Sangiovanni'],
#   'subscriptores': '2.14M',
#   'views': None,
#   'id': 5},
#  'Shakira': {'idYTMusic': 'UCo6JijJGA3IvIiPsawDK3Ww',
#   'colaboracion': ['Ozuna',
#    'Rauw Alejandro',
#    'Ozuna',
#    'Ozuna',
#    'Rauw Alejandro',
#    'Ozuna',
#    'Rauw Alejandro',
#    'Anuel AA'],
#   'subscriptores': '39.2M',
#   'views': '25,000,454,458 views',
#   'id': 6},
#  'Melendi': {'idYTMusic': 'UCl4jq8XKq5X0ZL5p_xVMmZA',
#   'colaboracion': ['India Martínez'],
#   'subscriptores': '4.41M',
#   'views': '3,761,514,765 views',
#   'id': 7},
#  'Belinda': {'idYTMusic': 'UC8tw8d2POmc3Lt8t1bmgl9Q',
#   'colaboracion': ['Ana Mena', 'Ana Mena'],
#   'subscriptores': '869K',
#   'views': '351,904,966 views',
#   'id': 8},
#  'Anuel AA': {'idYTMusic': 'UCbBaYg2UToDaoOwo-R6xi4g',
#   'colaboracion': ['Bryant Myers',
#    'MVSIS',
#    'Foreign Teck',
#    'Chris Jedi',
#    'Gaby Music',
#    'Chris Jedi',
#    'Gaby Music',
#    'David Guetta',
#    'Chris Jedi',
#    'Ñengo Flow',
#    'Chencho Corleone',
#    'Tainy',
#    'Ozuna',
#    'Chris Jedi',
#    'Ñengo Flow',
#    'Chencho Corleone',
#    'Rauw Alejandro',
#    'Daddy Yankee',
#    'Ozuna',
#    'Sech',
#    'Chris Jedi',
#    'Ñengo Flow',
#    'Chencho Corleone',
#    'Chris Jedi',
#    'Gaby Music',
#    'Randy Nota Loca',
#    'Zion',
#    'Chris Jedi',
#    'Ñengo Flow',
#    'Chencho Corleone',
#    'Brytiago',
#    'Daddy Yankee',
#    'Darell',
#    'Ozuna',
#    'Daddy Yankee',
#    'Natti Natasha',
#    'Rauw Alejandro',
#    'Chris Jedi',
#    'Gaby Music',
#    'Chris Jedi',
#    'Ñengo Flow',
#    'Chencho Corleone',
#    'Rauw Alejandro',
#    'Ozuna',
#    'Tainy',
#    'Ozuna'],
#   'subscriptores': '23.3M',
#   'views': '12,648,082,818 views',
#   'id': 9},
#  'Abraham Mateo': {'idYTMusic': 'UCql3y41dHUh9JoPHMedvCbQ',
#   'colaboracion': ['Ana Mena'],
#   'subscriptores': '4.62M',
#   'views': '1,817,829,022 views',
#   'id': 10},
#  'KAROL G': {'idYTMusic': 'UC7n3gWRN0vQzgiOKc51aZ4w',
#   'colaboracion': ['Maldy',
#    'Ovy On The Drums',
#    'Maldy',
#    'Ovy On The Drums',
#    'Ovy On The Drums',
#    'Maldy',
#    'Maldy',
#    'Nicki Minaj',
#    'Anuel AA',
#    'Feid',
#    'Maldy',
#    'Maldy',
#    'Feid',
#    'Maldy',
#    'Anuel AA',
#    'Daddy Yankee',
#    'Anuel AA',
#    'Ovy On The Drums',
#    'Maldy',
#    'Feid',
#    'Nicki Minaj',
#    'Simone & Simaria',
#    'Anuel AA',
#    'Daddy Yankee'],
#   'subscriptores': '28.7M',
#   'views': '15,352,927,056 views',
#   'id': 11},
#  'Emilia': {'idYTMusic': 'UCvXoAG_trv-m2pv5_1HVFvA',
#   'colaboracion': ['Ptazeta', 'Aitana', 'Ptazeta', 'Aitana'],
#   'subscriptores': '1.28M',
#   'views': '642,761,569 views',
#   'id': 12},
#  'Sergio Ramos': {'idYTMusic': 'UC2MgeVTYErtkCzRMucgFyjQ',
#   'colaboracion': ['Niña Pastori', 'RedOne'],
#   'subscriptores': '558',
#   'views': '8,887 views',
#   'id': 13},
#  'Jairo deRemache': {'idYTMusic': 'UC0rxntgJfUecm5h_d6mY8eg',
#   'colaboracion': ['Farruquito', 'Omar Montes'],
#   'subscriptores': '193',
#   'views': None,
#   'id': 14},
#  'India Martínez': {'idYTMusic': 'UCJbpTwP22V6baVULM7-J4Bw',
#   'colaboracion': ['Andy Rivera'],
#   'subscriptores': '1.01M',
#   'views': '707,584,196 views',
#   'id': 15},
#  'Rema': {'idYTMusic': 'UCy6qn2oxmoXA4_gBA5Q7zPw',
#   'colaboracion': ['Selena Gomez'],
#   'subscriptores': '2.5M',
#   'views': '748,248,296 views',
#   'id': 16},
#  'Galvan Real': {'idYTMusic': 'UC0r04hp-02vxsjHBVlm4F3A',
#   'colaboracion': ['María Artés Lamorena'],
#   'subscriptores': '417K',
#   'views': None,
#   'id': 17},
#  'C. Tangana': {'idYTMusic': 'UCLuHOvsT_LbOGVjqmXudvBg',
#   'colaboracion': ['Omar Montes'],
#   'subscriptores': '2.23M',
#   'views': '1,371,396,778 views',
#   'id': 18},
#  'JC Reyes': {'idYTMusic': 'UCXGll6UzxbSdLO1_w7rP22g',
#   'colaboracion': ['Pablo Chill-E', 'Ecko', 'Pablo Chill-E', 'Ecko'],
#   'subscriptores': '17.6K',
#   'views': None,
#   'id': 19},
#  'Zion & Lennox': {'idYTMusic': 'UC8U7wOw_Hd7ltvcWOWAp21g',
#   'colaboracion': ['Feid', 'Feid'],
#   'subscriptores': '3.38M',
#   'views': '2,796,528,595 views',
#   'id': 20},
#  'ROSALÍA': {'idYTMusic': 'UCeYz6rzUGhVwqxRM37FUo8w',
#   'colaboracion': ['Romeo Santos', 'Romeo Santos', 'Romeo Santos'],
#   'subscriptores': '9.96M',
#   'views': '4,669,722,848 views',
#   'id': 21},
#  'Kidd Keo': {'idYTMusic': 'UCv7W2bEmNY7yl9XxSsn3NvQ',
#   'colaboracion': ['TALE$'],
#   'subscriptores': '4.69M',
#   'views': None,
#   'id': 22},
#  'Eladio Carrion': {'idYTMusic': 'UC7YJ69rJ9qtVh6SjYFs4cGg',
#   'colaboracion': ['Arcangel'],
#   'subscriptores': '3.2M',
#   'views': '1,753,945,014 views',
#   'id': 23},
#  'David Guetta': {'idYTMusic': 'UCh-4c1ZoBPNP1C8c-7iVvUQ',
#   'colaboracion': ['Bebe Rexha'],
#   'subscriptores': '24.8M',
#   'views': '16,576,392,235 views',
#   'id': 24},
#  'RVFV': {'idYTMusic': 'UCj6HoOP59UGegqUC-fu4Wlg',
#   'colaboracion': ['Duki'],
#   'subscriptores': '979K',
#   'views': None,
#   'id': 25},
#  'Cano': {'idYTMusic': 'UCumOUWYBPRw2pxGl7QGeiRw',
#   'colaboracion': ['El Jhota', 'Los del Control'],
#   'subscriptores': '181K',
#   'views': None,
#   'id': 26},
#  'Wiso Rivera': {'idYTMusic': 'UCwfvKaHqW4r64dOurVFzD9A',
#   'colaboracion': ['Cruz Cafuné', 'Juseph'],
#   'subscriptores': '174',
#   'views': None,
#   'id': 27},
#  'Subelo Neo': {'idYTMusic': 'UCYEfkGCYwm66_W3xj6zaD4Q',
#   'colaboracion': ['Rauw Alejandro'],
#   'subscriptores': '10',
#   'views': None,
#   'id': 28},
#  'Lola Indigo': {'idYTMusic': 'UCydg_dYqBrPZ4-X1MnxD37A',
#   'colaboracion': ['Maria Becerra'],
#   'subscriptores': '1.24M',
#   'views': '685,333,282 views',
#   'id': 29},
#  'RM': {'idYTMusic': 'UCJCAlMsCuld3v96t-9SffdA',
#   'colaboracion': ['조유진'],
#   'subscriptores': '1.4M',
#   'views': None,
#   'id': 30},
#  'Feid': {'idYTMusic': 'UCc3e8O2V5_7OA300ursDyFQ',
#   'colaboracion': ['DJ Premier', 'Justin Quiles'],
#   'subscriptores': '3.65M',
#   'views': '3,114,175,033 views',
#   'id': 31},
#  'Kiddo': {'idYTMusic': 'UCVLS_HdJZUDE-4_Yzcd1vAA',
#   'colaboracion': ['Pepe : Vizio', 'Delaossa'],
#   'subscriptores': '102',
#   'views': None,
#   'id': 32},
#  'Estopa': {'idYTMusic': 'UCd25mqkTos06xFf1RP9qFJA',
#   'colaboracion': ['Beret'],
#   'subscriptores': '646K',
#   'views': '733,025,298 views',
#   'id': 33},
#  'Sebastián Yatra': {'idYTMusic': 'UCXP8o4Xcws36pgpFNlGGBeg',
#   'colaboracion': ['Pablo Alborán'],
#   'subscriptores': '17.7M',
#   'views': None,
#   'id': 34},
#  'Ryan Castro': {'idYTMusic': 'UCDxiGGtBV3CQiE-NKLEFgUg',
#   'colaboracion': ['SOG',
#    'SOG',
#    'SOG',
#    'Feid',
#    'Feid',
#    'Blessd',
#    'Feid',
#    'Ñejo',
#    'Andy Rivera'],
#   'subscriptores': '2.33M',
#   'views': None,
#   'id': 35},
#  'De La Ghetto': {'idYTMusic': 'UCf3TsqO9Ysrw8k63aHg4O5A',
#   'colaboracion': ['Anuel AA',
#    'Jowell & Randy',
#    'Pailita',
#    'Polima Westcoast',
#    'Feid',
#    'Daddy Yankee',
#    'Ozuna',
#    'Anuel AA',
#    'Jowell & Randy',
#    'Rauw Alejandro',
#    'Pailita',
#    'Polima Westcoast',
#    'Feid'],
#   'subscriptores': '2.89M',
#   'views': '1,202,694,852 views',
#   'id': 36},
#  'Cris Mj': {'idYTMusic': 'UCOykHV9q0qb0vrBsxO_5fkQ',
#   'colaboracion': ['Tiago PZK'],
#   'subscriptores': '1.52M',
#   'views': None,
#   'id': 37},
#  'Jhayco': {'idYTMusic': 'UChZEzxer-QvRMbADJJGOMuQ',
#   'colaboracion': ['Feid',
#    'Sech',
#    'Myke Towers',
#    'Feid',
#    'Sech',
#    'Myke Towers',
#    'Anuel AA',
#    'Myke Towers',
#    'Mora',
#    'Sech',
#    'Feid',
#    'Sech',
#    'Myke Towers',
#    'Anuel AA',
#    'Myke Towers',
#    'Anuel AA',
#    'Mora',
#    'Anuel AA'],
#   'subscriptores': '4.74M',
#   'views': '3,727,432,171 views',
#   'id': 38},
#  'Yandel': {'idYTMusic': 'UCc1QpDE0iT0n6ZLckjflNHw',
#   'colaboracion': ['Tiago PZK',
#    'Arcangel',
#    'Tiago PZK',
#    'Arcangel',
#    'Rauw Alejandro',
#    'Anuel AA'],
#   'subscriptores': '5.43M',
#   'views': '3,794,679,764 views',
#   'id': 39},
#  'Myke Towers': {'idYTMusic': 'UCYPsIfSIEwWcoynHBP5k1dg',
#   'colaboracion': ['Daddy Yankee',
#    'Daddy Yankee',
#    'DJ Nelson',
#    'Jay Wheeler',
#    'Daddy Yankee',
#    'Tiago PZK',
#    'Tiago PZK',
#    'Juhn'],
#   'subscriptores': '9.57M',
#   'views': '6,543,986,913 views',
#   'id': 40},
#  'Lenny Tavárez': {'idYTMusic': 'UCpOtgk_uRB6PZK47wUXXlVQ',
#   'colaboracion': ['Beéle',
#    'Brytiago',
#    'Blessd',
#    'Justin Quiles',
#    'Blessd',
#    'Justin Quiles',
#    'Blessd',
#    'Justin Quiles',
#    'Justin Quiles',
#    'Blessd',
#    'Justin Quiles',
#    'Dalex',
#    'Rauw Alejandro',
#    'Dalex',
#    'Brytiago'],
#   'subscriptores': '3.07M',
#   'views': '844,315,989 views',
#   'id': 41},
#  'Mora': {'idYTMusic': 'UCgDpp8Ex8Yz6hhHjbl3W5mg',
#   'colaboracion': ['De La Ghetto',
#    'Feid',
#    'Sech',
#    'Feid',
#    'Bad Bunny',
#    'Sech',
#    'Feid',
#    'Bad Bunny'],
#   'subscriptores': '1.79M',
#   'views': '1,403,049,546 views',
#   'id': 42},
#  'Natti Natasha': {'idYTMusic': 'UCqMwRUFZ6APDCsz61zEdhKQ',
#   'colaboracion': ['Maria Becerra',
#    'Ozuna',
#    'Maria Becerra',
#    'Becky G',
#    'Thalía'],
#   'subscriptores': '11.9M',
#   'views': '7,569,156,362 views',
#   'id': 43},
#  'Blessd': {'idYTMusic': 'UC3vpYFFzqIzsXbMgneDTSeQ',
#   'colaboracion': ['De La Ghetto',
#    'Darell',
#    'De La Ghetto',
#    'Darell',
#    'De La Ghetto',
#    'Darell',
#    'Ryan Castro',
#    'Ryan Castro'],
#   'subscriptores': '1.99M',
#   'views': '1,405,935,189 views',
#   'id': 44},
#  'Fran C.': {'idYTMusic': 'UChKGa5uCEN3O9u0VNeDZ5yQ',
#   'colaboracion': ['Pablo Pesadilla',
#    'Polima Westcoast',
#    'Nickoog Clk',
#    'Pablo Pesadilla',
#    'Polima Westcoast',
#    'Nickoog Clk',
#    'Pablo Pesadilla',
#    'Polima Westcoast',
#    'Nickoog Clk',
#    'Pablo Pesadilla',
#    'Polima Westcoast',
#    'Nickoog Clk'],
#   'subscriptores': '17.5K',
#   'views': None,
#   'id': 45},
#  'Wisin & Yandel': {'idYTMusic': 'UCJ0-R-v3CaJNYMqfp9tivqA',
#   'colaboracion': ['Rauw Alejandro',
#    'Natti Natasha',
#    'Daddy Yankee',
#    'Daddy Yankee',
#    'Natti Natasha',
#    'Daddy Yankee',
#    'Natti Natasha',
#    'Daddy Yankee',
#    'Daddy Yankee',
#    'Daddy Yankee'],
#   'subscriptores': '7.02M',
#   'views': '5,845,336,468 views',
#   'id': 46},
#  'Standly': {'idYTMusic': 'UCmIeOVFFYF72643-4SspXWA',
#   'colaboracion': ['Stars Music Chile',
#    'Cris Mj',
#    'Stars Music Chile',
#    'Cris Mj'],
#   'subscriptores': '1.08M',
#   'views': None,
#   'id': 47},
#  'Maluma': {'idYTMusic': 'UCtKIuEMDzPlUmPgdwBhiGcg',
#   'colaboracion': ['Chencho Corleone',
#    'Chencho Corleone',
#    'Chencho Corleone',
#    'Blessd',
#    'Chencho Corleone',
#    'Chencho Corleone',
#    'Chencho Corleone',
#    'Jennifer Lopez',
#    'GIMS',
#    'Becky G'],
#   'subscriptores': '28.9M',
#   'views': '20,236,920,895 views',
#   'id': 48},
#  'The Rudeboyz': {'idYTMusic': 'UCOGP7HlRV6GctAaZGGy0RSQ',
#   'colaboracion': ['Maluma', 'Adam Levine'],
#   'subscriptores': '90.2K',
#   'views': None,
#   'id': 49},
#  'Manuel Turizo': {'idYTMusic': 'UCfh2j2Dq-aSeLhzuPOsnhVg',
#   'colaboracion': ['Maria Becerra',
#    'Ozuna',
#    'Feid',
#    'Arcangel',
#    'Myke Towers',
#    'Rauw Alejandro'],
#   'subscriptores': '9.07M',
#   'views': None,
#   'id': 50},
#  'Trueno': {'idYTMusic': 'UCEPYn7xbzvQwL9C21evFGDg',
#   'colaboracion': ['Tiago PZK'],
#   'subscriptores': '5.86M',
#   'views': '1,372,075,175 views',
#   'id': 51},
#  'Los Legendarios': {'idYTMusic': 'UCu9edbv_LWcPQTOmP4FpOtg',
#   'colaboracion': ['Wisin', 'Natti Natasha', 'Jhayco', 'Wisin', 'Myke Towers'],
#   'subscriptores': '54.1K',
#   'views': '162,137,468 views',
#   'id': 52},
#  'Reik': {'idYTMusic': 'UCJ3jO8eOeYGrKNJ-TmQoV3w',
#   'colaboracion': ['Sech', 'Maria Becerra', 'Morat'],
#   'subscriptores': '9.57M',
#   'views': '7,778,541,041 views',
#   'id': 53},
#  'Ozuna': {'idYTMusic': 'UCKEFjh4JL-OyMI8z3h5Coaw',
#   'colaboracion': ['Tiago PZK',
#    'Karol G',
#    'Myke Towers',
#    'Tiago PZK',
#    'Tiago PZK',
#    'Tiago PZK',
#    'Tokischa',
#    'Karol G',
#    'Myke Towers',
#    'Camilo',
#    'Daddy Yankee',
#    'ROSALÍA'],
#   'subscriptores': '35.7M',
#   'views': '22,008,921,820 views',
#   'id': 54},
#  'Bad Bunny': {'idYTMusic': 'UCiY3z8HAGD6BlSNKVn2kSvQ',
#   'colaboracion': ['Jhay Cortez',
#    'J Balvin',
#    'Jhay Cortez',
#    'Tainy',
#    'Jowell & Randy',
#    'Ñengo Flow',
#    'J Balvin',
#    'Jhay Cortez',
#    'Daddy Yankee',
#    'Daddy Yankee',
#    'Jhay Cortez',
#    'Jowell & Randy',
#    'Ñengo Flow',
#    'J Balvin',
#    'Jhay Cortez',
#    'Farruko',
#    'Natti Natasha',
#    'ROSALÍA',
#    'Tainy',
#    'Sech',
#    'J Balvin',
#    'ROSALÍA',
#    'Jhay Cortez',
#    'Anuel AA',
#    'Dua Lipa',
#    'Tainy',
#    'J Balvin',
#    'Daddy Yankee',
#    'YAVIAH',
#    'J Balvin',
#    'Jhay Cortez',
#    'Tainy',
#    'J Balvin'],
#   'subscriptores': '44.7M',
#   'views': '27,400,036,753 views',
#   'id': 55},
#  'Becky G': {'idYTMusic': 'UC3UkDuAQjoRvTH7OEWm3cHQ',
#   'colaboracion': ['Natti Natasha',
#    'Paulo Londra',
#    'KAROL G',
#    'KAROL G',
#    'Paulo Londra',
#    'Natti Natasha'],
#   'subscriptores': '20.7M',
#   'views': '9,939,022,254 views',
#   'id': 56},
#  'J Balvin': {'idYTMusic': 'UCWw-Guyr5ul9B-d5kJlHMng',
#   'colaboracion': ['Maria Becerra',
#    'Sech',
#    'Daddy Yankee',
#    'Sech',
#    'Daddy Yankee',
#    'Zion & Lennox',
#    'Jowell & Randy',
#    'Ozuna',
#    'Chencho Corleone',
#    'Sech',
#    'Black Eyed Peas'],
#   'subscriptores': '33.8M',
#   'views': '22,093,499,099 views',
#   'id': 57},
#  'Dimelo Flow': {'idYTMusic': 'UCFc1GajMRv1jh4BIDj_n93g',
#   'colaboracion': ['Arcangel', 'Lenny Tavárez', 'Wisin', 'Dalex', 'Arcangel'],
#   'subscriptores': '664K',
#   'views': '357,291,142 views',
#   'id': 58},
#  'Crissin': {'idYTMusic': 'UC_Q2Ob7v-SlNlOiqHNrWQLw',
#   'colaboracion': ['Natan & Shander',
#    'Totoy El Frio',
#    'Natan & Shander',
#    'Totoy El Frio'],
#   'subscriptores': '15.4K',
#   'views': None,
#   'id': 59},
#  'Lunay': {'idYTMusic': 'UCPJQHfMDWwUdrKPkZfZNA0Q',
#   'colaboracion': ['Bad Bunny',
#    'Daddy Yankee',
#    'Lenny Tavárez',
#    'Boza',
#    'Juhn',
#    'Lenny Tavárez',
#    'Boza',
#    'Juhn',
#    'Bad Bunny',
#    'Daddy Yankee',
#    'Bad Bunny',
#    'Daddy Yankee'],
#   'subscriptores': '5.12M',
#   'views': '2,333,238,849 views',
#   'id': 60},
#  'Nicky Jam': {'idYTMusic': 'UCMJ705HLB_EflTzWDAjcKSQ',
#   'colaboracion': ['Ozuna',
#    'Dalex',
#    'Justin Quiles',
#    'J Balvin',
#    'Ozuna',
#    'Anuel AA',
#    'J Balvin',
#    'Dalex',
#    'Justin Quiles',
#    'Sech',
#    'Mau y Ricky',
#    'Ozuna'],
#   'subscriptores': '23.3M',
#   'views': '15,347,051,998 views',
#   'id': 61},
#  'Nio Garcia': {'idYTMusic': 'UCSBeb5-yOlKqw1lS95ciqcA',
#   'colaboracion': ['Bad Bunny',
#    'J Balvin',
#    'Myke Towers',
#    'Anuel AA',
#    'Lenny Tavárez',
#    'Rauw Alejandro',
#    'Bad Bunny',
#    'J Balvin',
#    'Bad Bunny',
#    'J Balvin',
#    'Flow La Movie',
#    'Casper Magico'],
#   'subscriptores': '1.31M',
#   'views': None,
#   'id': 62},
#  'Brytiago': {'idYTMusic': 'UCoEnXQjMHQX-5EEjhDMMXtQ',
#   'colaboracion': ['Darell'],
#   'subscriptores': '5.27M',
#   'views': '3,132,061,874 views',
#   'id': 63},
#  'Dalex': {'idYTMusic': 'UCXTtAAlWYj1RCVPZ-PYWoqA',
#   'colaboracion': ['Sech', 'Rich Music, Ltd'],
#   'subscriptores': '6.11M',
#   'views': '3,965,840,819 views',
#   'id': 64},
#  'Robi': {'idYTMusic': 'UCpjGA1q99cLKEvKlULb1Llw',
#   'colaboracion': ['Alejo', 'Feid', 'Alejo', 'Feid', 'Alejo', 'Feid'],
#   'subscriptores': '32.3K',
#   'views': None,
#   'id': 65},
#  'Wisin': {'idYTMusic': 'UCFVg6y3fZO7OVFbmoGfNdhQ',
#   'colaboracion': ['Nicky Jam', 'Nicky Jam', 'Ozuna'],
#   'subscriptores': '7.41M',
#   'views': '6,123,087,905 views',
#   'id': 66},
#  'Aventura': {'idYTMusic': 'UCDaQK4nrsvz27YzufrhJfgg',
#   'colaboracion': ['Bad Bunny', 'Romeo Santos'],
#   'subscriptores': '6.1M',
#   'views': '6,593,978,752 views',
#   'id': 67},
#  'Young Miko': {'idYTMusic': 'UCJzwfOuHuaB6DuPfh6rrPoA',
#   'colaboracion': ['Lunay', 'Chris Jedi', 'Vf7'],
#   'subscriptores': '6.59K',
#   'views': None,
#   'id': 68},
#  'SOG': {'idYTMusic': 'UCfXiritC8HjvxbabC7hIJzA',
#   'colaboracion': ['Ryan Castro', 'Blessd'],
#   'subscriptores': '2.64K',
#   'views': None,
#   'id': 69},
#  'Tainy': {'idYTMusic': 'UCeN6GRz4bN054slorYxms0w',
#   'colaboracion': ['Bad Bunny', 'Julieta Venegas', 'J Balvin'],
#   'subscriptores': '2.16M',
#   'views': '1,760,284,074 views',
#   'id': 70},
#  'Tiago PZK': {'idYTMusic': 'UCjYEamX786QxvyO527ezaaw',
#   'colaboracion': ['Trueno',
#    'Trueno',
#    'LIT killah',
#    'Maria Becerra',
#    'Nicki Nicole'],
#   'subscriptores': '3.95M',
#   'views': '1,452,521,960 views',
#   'id': 71},
#  'Ovy On The Drums': {'idYTMusic': 'UCtfkGa4ie0BivwCPWCHalOw',
#   'colaboracion': ['Myke Towers', 'Blessd'],
#   'subscriptores': '1.08M',
#   'views': '641,379,159 views',
#   'id': 72},
#  'Sean Paul': {'idYTMusic': 'UCnCNNA05VZcH8wVJYtC-6ew',
#   'colaboracion': ['J Balvin'],
#   'subscriptores': '4.35M',
#   'views': '2,760,302,994 views',
#   'id': 73},
#  'DJ Luian': {'idYTMusic': 'UC5UPgDCYyAxG8Yjq-0I_xTw',
#   'colaboracion': ['Mambo Kingz',
#    'Nicky Jam',
#    'Anuel AA',
#    'Darell',
#    'Nicky Jam',
#    'Anuel AA',
#    'Darell'],
#   'subscriptores': '523K',
#   'views': None,
#   'id': 74},
#  'Marc Anthony': {'idYTMusic': 'UC22hscWzcVvD_CEPiuaOIbQ',
#   'colaboracion': ['Will Smith', 'Bad Bunny'],
#   'subscriptores': '6.65M',
#   'views': '6,052,715,118 views',
#   'id': 75},
#  'Piso 21': {'idYTMusic': 'UCpe8GCklSIBcxULLHbhQwpQ',
#   'colaboracion': ['Micro TDH'],
#   'subscriptores': '7.56M',
#   'views': '6,625,925,745 views',
#   'id': 76},
#  'DJ Snake': {'idYTMusic': 'UC0c4bK_92XYr0YtASqqWOJg',
#   'colaboracion': ['J Balvin', 'Tyga', 'J Balvin', 'Tyga'],
#   'subscriptores': '23.8M',
#   'views': '7,954,686,433 views',
#   'id': 77},
#  'ChocQuibTown': {'idYTMusic': 'UCZq8jIlmIqSeb079Hr80BEw',
#   'colaboracion': ['Becky G'],
#   'subscriptores': '1.15M',
#   'views': '789,107,597 views',
#   'id': 78},
#  'Sech': {'idYTMusic': 'UCXhOBsxGZ3TkeaYIW5LAHfA',
#   'colaboracion': ['Ozuna'],
#   'subscriptores': '9.73M',
#   'views': '5,518,729,653 views',
#   'id': 79},
#  'Trumpmoney': {'idYTMusic': 'UCcOz_kTFH_rrLF47WVphoXQ',
#   'colaboracion': ['andres yuma', 'Vadi'],
#   'subscriptores': '111K',
#   'views': None,
#   'id': 80},
#  'Almighty': {'idYTMusic': 'UCRDGcK3rFRn6VImxBUQVanA',
#   'colaboracion': ['Luar La L'],
#   'subscriptores': '3.09M',
#   'views': None,
#   'id': 81},
#  'El Alfa': {'idYTMusic': 'UCJMzvcg3QxvaTKfpaj57TyA',
#   'colaboracion': ['Black Eyed Peas', 'Anitta'],
#   'subscriptores': '8.56M',
#   'views': '4,130,592,127 views',
#   'id': 82},
#  'Abhir Hathi': {'idYTMusic': 'UCYqIXahUqVJHiF_7Ca9kMDA',
#   'colaboracion': ['EL IMA'],
#   'subscriptores': '15.1K',
#   'views': None,
#   'id': 83},
#  'Prince Royce': {'idYTMusic': 'UC1amDmVt3wHmB7zKpkmf3rg',
#   'colaboracion': ['Maria Becerra'],
#   'subscriptores': '10M',
#   'views': '5,846,551,297 views',
#   'id': 84},
#  'TINI': {'idYTMusic': 'UCBDXpukZYpWw54QCbEGdsZw',
#   'colaboracion': ['Becky G', 'Anitta'],
#   'subscriptores': '7.96M',
#   'views': '3,964,097,217 views',
#   'id': 85},
#  'Rei': {'idYTMusic': 'UCxj1FOny1CnD6_P5vIygG4w',
#   'colaboracion': ['Quevedo'],
#   'subscriptores': '866K',
#   'views': None,
#   'id': 86},
#  'Rusherking': {'idYTMusic': 'UC68p6YG34KOL19VezkzaLwA',
#   'colaboracion': ['Dread Mar I'],
#   'subscriptores': '2.11M',
#   'views': None,
#   'id': 87},
#  'Tokischa': {'idYTMusic': 'UC7oLm1CnGj0JwTdlOnQTfGg',
#   'colaboracion': ['Anuel AA', 'Ñengo Flow'],
#   'subscriptores': '1.42M',
#   'views': '288,122,302 views',
#   'id': 88},
#  'Travis Scott': {'idYTMusic': 'UCf_gP4AMRSgAfyzbkeS9k4g',
#   'colaboracion': ['ROSALÍA'],
#   'subscriptores': '16.3M',
#   'views': '7,484,057,870 views',
#   'id': 89},
#  'Pedro Capó': {'idYTMusic': 'UCel_aU5VwTOSWlunrQ89UBQ',
#   'colaboracion': ['Camilo'],
#   'subscriptores': '6.77M',
#   'views': '3,372,364,896 views',
#   'id': 90},
#  'Karol G': {'idYTMusic': 'UC7n3gWRN0vQzgiOKc51aZ4w',
#   'colaboracion': ['Anuel AA'],
#   'subscriptores': '28.7M',
#   'views': '15,352,927,056 views',
#   'id': 91},
#  'Darell': {'idYTMusic': 'UCVsfgFfzYNMJvcQLDYT7fHw',
#   'colaboracion': ['El Alfa', 'Noriel'],
#   'subscriptores': '3.11M',
#   'views': '1,184,688,718 views',
#   'id': 92},
#  'Sky Rompiendo': {'idYTMusic': 'UCSTtXdKn1Dmx28ufElKiaqQ',
#   'colaboracion': ['Myke Towers', 'Rauw Alejandro'],
#   'subscriptores': '359K',
#   'views': '178,294,048 views',
#   'id': 93},
#  'Luis Fonsi': {'idYTMusic': 'UCk91oFc2hY2CdHirU93baLg',
#   'colaboracion': ['Rauw Alejandro'],
#   'subscriptores': '31.1M',
#   'views': '14,726,510,634 views',
#   'id': 94},
#  'Chyno Miranda': {'idYTMusic': 'UCKIxJ-kUSqhXUL5H-9brFcg',
#   'colaboracion': ['Chino & Nacho', 'Nacho'],
#   'subscriptores': '807K',
#   'views': '290,333,820 views',
#   'id': 95},
#  'CNCO': {'idYTMusic': 'UCYkfG1iLz04t-X2WTsSO4Dw',
#   'colaboracion': ['Natti Natasha'],
#   'subscriptores': '11.9M',
#   'views': '7,026,244,179 views',
#   'id': 96},
#  'Rvssian': {'idYTMusic': 'UCNzGI8JyKXRgrgGIknRGalg',
#   'colaboracion': ['Anuel AA', 'Juice WRLD'],
#   'subscriptores': '28.2K',
#   'views': '76,519,706 views',
#   'id': 97},
#  'Evaluna Montaner': {'idYTMusic': 'UCvPUs3Cm_Ioeihsy7ASXwLQ',
#   'colaboracion': ['Camilo'],
#   'subscriptores': '3.72M',
#   'views': '625,040,386 views',
#   'id': 98}}

# %%
df = pd.DataFrame.from_dict(diccColabo, orient = "index",columns=['id','idYTMusic','colaboracion','subscriptores','views'])

df.to_csv('finished.csv')
df
# Out:
#                   id                 idYTMusic  \
# Arcangel           0  UCVcAt8IIKIeubRSigcYXgtA
# Farruko            1  UC6QXZsAOOweLfhVPbqMyG4g
# Quevedo            2  UC7PL9aor5qNRhvhWWVXyOqA
# Bizarrap           3  UCONiUl5u7y2bMaVZJcuRDEQ
# Rauw Alejandro     4  UCw_m17sBd4GHxuK83-AZtuA
# ...               ..                       ...
# Luis Fonsi        94  UCk91oFc2hY2CdHirU93baLg
# Chyno Miranda     95  UCKIxJ-kUSqhXUL5H-9brFcg
# CNCO              96  UCYkfG1iLz04t-X2WTsSO4Dw
# Rvssian           97  UCNzGI8JyKXRgrgGIknRGalg
# Evaluna Montaner  98  UCvPUs3Cm_Ioeihsy7ASXwLQ
#
#                                                        colaboracion  \
# Arcangel          [Bad Bunny, Duki, Bizarrap, Myke Towers, YOVNG...
# Farruko           [Omar Montes, Rauw Alejandro, Natti Natasha, J...
# Quevedo           [Bizarrap, Bad Gyal, Ovy On The Drums, Mora, M...
# Bizarrap                                               [Duki, Duki]
# Rauw Alejandro    [Baby Rasta, Lyanno, Brray, Lyanno, Brray, Bab...
# ...                                                             ...
# Luis Fonsi                                         [Rauw Alejandro]
# Chyno Miranda                                [Chino & Nacho, Nacho]
# CNCO                                                [Natti Natasha]
# Rvssian                                      [Anuel AA, Juice WRLD]
# Evaluna Montaner                                           [Camilo]
#
#                  subscriptores                 views
# Arcangel                 10.7M   4,731,158,596 views
# Farruko                  18.3M   8,903,747,439 views
# Quevedo                  1.07M     286,022,617 views
# Bizarrap                 16.6M   5,838,104,536 views
# Rauw Alejandro           12.3M  10,146,076,858 views
# ...                        ...                   ...
# Luis Fonsi               31.1M  14,726,510,634 views
# Chyno Miranda             807K     290,333,820 views
# CNCO                     11.9M   7,026,244,179 views
# Rvssian                  28.2K      76,519,706 views
# Evaluna Montaner         3.72M     625,040,386 views
#
# [99 rows x 5 columns]

# %%
header = ['nombre','id','idYTMusic','colaboracion','subscriptores','views']

with open('nodos.csv','w',encoding='utf-8',newline='') as f:
    writer= csv.writer(f)
    writer.writerow(header)
    for i in diccColabo:
        writer.writerow([i,diccColabo[i]['id'],diccColabo[i]['idYTMusic'],
        diccColabo[i]['colaboracion'],diccColabo[i]['subscriptores'],diccColabo[i]['views']])

# %%
#para rellenar si es explicito  para artistas con colabos       
duration = []
explicit = []
publicacion=[]
vistas=[]
videosIds=[]
artistasAristas=[]
for r in infoPlayList:
     for a in r['tracks']:
          if(len(a['artists'])>1):
            explicit.append(a['isExplicit'])

#para rellenar duracion seg   para artistas con colabos     
for r in infoPlayList:
     for a in r['tracks']:
           if(len(a['artists'])>1):
            duration.append(a['duration_seconds'])
#para los artistas del csv
for r in infoPlayList:
     for a in r['tracks']:
           if(len(a['artists'])>1):
            artistasAristas.append(a['artists'])


for r in infoPlayList:
     for a in r['tracks']:
           if(len(a['artists'])>1):
               searchMusic=yt.get_song(a['videoId'])
               publicacion.append(searchMusic['microformat']['microformatDataRenderer']['publishDate'])
               vistas.append(searchMusic['microformat']['microformatDataRenderer']['viewCount'])

# %% [markdown]
# En este momento, abrimos un csv para escribir la información de las aristas.En nuestro caso se van a unir los nodos segun sus colaboraciones.Si el nodo A ha colaborado con B y C se lanzará una arista desde A hasta B y desde A hasta C.
# Tambien hemos añadido atributos complementarios para su posterior estudio en Gephi, como la duracion de la cancion en cuestión en la que colaboran, si la letra de la cancion tiene contenido explicito o no y la fecha de la publicación de la cancion en ytMusic.

# %%
header = ['Source', 'Target','duracion','explicito','fecha_publicacion','visitas']
writedicc = {}
with open('aristas.csv','w',encoding='utf-8',newline='') as f:
    writer= csv.writer(f)
    writer.writerow(header)
    iter=0
    repe=0
    for r in artistasAristas:
        for i in range(len(r)-1):
            writer.writerow([r[0]['name'],r[i+1]['name'],duration[iter],explicit[iter],publicacion[iter],vistas[iter]])
        iter=iter+1
            
      # iter=iter+1

# %%
df = pd.read_csv('aristas.csv',names=['artista', 'colaboracion','duracion','explicito','fecha_publicacion','visitas'])

G=nx.from_pandas_edgelist(df,'artista','colaboracion')


plt.show() 
plt.figure(figsize=(13,10))
pos = nx.circular_layout(G)
nx.draw(G,pos,with_labels=True,alpha=0.7)
# Out:
# c:\Users\marco\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51312 (\N{HANGUL SYLLABLE JO}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\marco\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\marco\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51652 (\N{HANGUL SYLLABLE JIN}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\marco\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51312 (\N{HANGUL SYLLABLE JO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\marco\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\marco\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51652 (\N{HANGUL SYLLABLE JIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
