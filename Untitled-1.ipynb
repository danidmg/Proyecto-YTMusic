# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
import csv
#holawenasnoxes

# %% [markdown]
# Daaniiiiiiiiiiiiiiiiii     AQUI   poner brevemente que hace cada funcion

# %%
from ytmusicapi import YTMusic

yt = YTMusic()
#z8uyayN3RbE
searchMusic=yt.get_song("5g2hT4GmAGU")

#yt.get_artist("UCiY3z8HAGD6BlSNKVn2kSvQ")
search_results=yt.search("Duki")
#search_results
searchPlay=yt.get_playlist("PL4fGSI1pDJn4jhQB4kb9M36dvVmJQPt4T")

searcArtist=yt.get_artist('UCI9q5A6SUN37p0gM01E1R4Q')

searchMusic=yt.get_song("-XiCucQ4RCU")

searchchar=yt.get_charts()
#searchchar
#searchPlay
#searchMusic
#searcArtist
#search_results

# %% [markdown]
# A continuación empezamos cargando un array con todos los artistas que aparecen en el array de playlist. Recorreremos el array de playlist y extraeremos los datos de dichas playlists con las funciones de la appi ya mencionadas. Probamos a meter los diccionarios que nos da la funcion
# "get_playlist" en un array llamado 'artistas' para empezar a jugar con ello.
# Nos dimos cuenta que filtrando por clave/valor del diccionario se podia ver muchos datos. En este caso filtramos por "tracks" donde nos enseña todas las canciones de las playlist con informacion relevante de ellas. Con esto conseguimos informacion de los artistas que participan en esa canción. Esta información la metemos en el array de artistas para dividir dos diccionarios: diccionario de solos (en los que solo participa un artista )y diccionario de colaboraciones (en el que participa más de uno)

# %% [markdown]
#
#
# ### Array de playlist
#
# * **TOP 100**   PL4fGSI1pDJn4jhQB4kb9M36dvVmJQPt4T
# * **Pon Reggaeton**       RDCLAK5uy_ll_3x-AJOymCxeODF09ZjyXg7b6m7OBqs
# * **Lo esencial del reggaetón**    RDCLAK5uy_mFaoBNPmTUVcY51UGFuAYedXv4kXuqg5M
# * **Reggaeton Playlist - Best Reggaeton Songs** PLPPgknP7IOwXmkAE99CdZ2h4baKNEvzev
# * **Reggaeton 2022 Playlist & Latin Music 2022** PL6Go6XFhidEAac3TgkP8EfLF1bA1odl4e
# * **Top Reggaeton 2021 - 2022 Playlist - Best New Reggaeton Songs 2021 - 2022**    PLq3UZa7STrbpinnTs3HuJY_n49qHUu6Ho
# * **Top Reggaeton Playlist - Best Reggaeton Songs of All Time**    PLo3pNg0eiPc8rRO3XqFnl1Je2GTu7am-F
# * **REGGAETON ROMANTICO 2022/ MEJORES REGGAETONES 2022. Reggaeton nuevos mas tocados**   PL8cNgJdjBpTABXO7i8nrifUJWcHia392H
# * **Reggaeton para bailar**    PLPPgknP7IOwUmPZqVP6oj_K2YPfYdU2DV
# * **JET funk (brasileño)**    RDCLAK5uy_mrFf8MOdXpsgjmDPmy9UrarANZUJv4IOw
# * **Hotlist Tropical (internacional)**    RDCLAK5uy_myscvcqMWXNPLHUdrYQtE9iNU9Ko80opM
# * **Pura Lumbre(Mejico)**   RDCLAK5uy_mBG8rnC5wMKo61Jn5c18C6_NoYsuQ2HRI
# * **Directoria (Brasil)** RDCLAK5uy_kvnwY7lh8VQkr7uLLsFPB06mhIwKAljbE
# * **Topnejo ( sertanejo Brasil)**   RDCLAK5uy_k5faEHND0iXJljeASESqJ3A8UtRr2FL00
# * **Éxitos clásicos de la música latina(Exitos internacional)** RDCLAK5uy_m-H5tH6XKlmMxXlwyUSgwCdGC1dCpaQsk
# * **Salsa mix**  RDCLAK5uy_lc4yBYpywmmgjplkuzYxzUgLJ8UvDKUUk
# * **Merengue mix**    RDCLAK5uy_ktzilGfj9x7BUPWEvdzUQsUEijEB4zFbY
# * **Cumbia mix**    RDCLAK5uy_k6ACq4WNfG-uJSz_jML9ZkUEULUoCzWIw
# * **Dale Dembow**   RDCLAK5uy_mqyWrEinpkO47PY_Rlhl5zVu3U6dcFk5w
# * **Bachata Mix**  RDCLAK5uy_kLYyE7wnPy-CdtP7hzzpru0iPr-eY2ea4
# * **Beats de Funk Brasileño**   RDCLAK5uy_kGkR7V7cd7-CC6FkeYB1d-Jn9_4iWgZ4M
# * **Mix tropical**   RDCLAK5uy_k6SmD6lMGgRRy3HarGTlo5Kkd32v3kYAs
# * **Dembow 2021 2022** PLuDO3mcjhw22CS23tEElwzdg6cBxp1STf

# %%
yt = YTMusic()
playlist=['PL4fGSI1pDJn4jhQB4kb9M36dvVmJQPt4T','RDCLAK5uy_ll_3x-AJOymCxeODF09ZjyXg7b6m7OBqs','RDCLAK5uy_mFaoBNPmTUVcY51UGFuAYedXv4kXuqg5M',
'PLPPgknP7IOwXmkAE99CdZ2h4baKNEvzev','PL6Go6XFhidEAac3TgkP8EfLF1bA1odl4e','PLq3UZa7STrbpinnTs3HuJY_n49qHUu6Ho',
'PLo3pNg0eiPc8rRO3XqFnl1Je2GTu7am-F','PL8cNgJdjBpTABXO7i8nrifUJWcHia392H','PLPPgknP7IOwUmPZqVP6oj_K2YPfYdU2DV',
'RDCLAK5uy_mrFf8MOdXpsgjmDPmy9UrarANZUJv4IOw','RDCLAK5uy_myscvcqMWXNPLHUdrYQtE9iNU9Ko80opM','RDCLAK5uy_mBG8rnC5wMKo61Jn5c18C6_NoYsuQ2HRI',
'RDCLAK5uy_k5faEHND0iXJljeASESqJ3A8UtRr2FL00','RDCLAK5uy_kvnwY7lh8VQkr7uLLsFPB06mhIwKAljbE','RDCLAK5uy_m-H5tH6XKlmMxXlwyUSgwCdGC1dCpaQsk',
'RDCLAK5uy_lc4yBYpywmmgjplkuzYxzUgLJ8UvDKUUk','RDCLAK5uy_ktzilGfj9x7BUPWEvdzUQsUEijEB4zFbY','RDCLAK5uy_k6ACq4WNfG-uJSz_jML9ZkUEULUoCzWIw',
'RDCLAK5uy_mqyWrEinpkO47PY_Rlhl5zVu3U6dcFk5w','RDCLAK5uy_kLYyE7wnPy-CdtP7hzzpru0iPr-eY2ea4','RDCLAK5uy_kGkR7V7cd7-CC6FkeYB1d-Jn9_4iWgZ4M',
'RDCLAK5uy_k6SmD6lMGgRRy3HarGTlo5Kkd32v3kYAs','PLuDO3mcjhw22CS23tEElwzdg6cBxp1STf']

artistas = []
diccSolo= {}
diccSolo.clear()
colabos=[]

infoPlayList = []
for p in playlist:
     infoPlayList.append(yt.get_playlist(p))
     
#para rellenar artistas
for r in infoPlayList:
     for a in r['tracks']:
      artistas.append(a['artists'])

#for r in searchPlay['tracks']:
#     artistas.append(r['artists'])

for a in artistas:#cargamos el diccionario con los artistas que van a cantar solos
   for b in a:
    if(len(a)==1):
        diccSolo[b['name']]={'idYTMusic':b['id'],'colaboracion':[]}

# %%
diccColabo= {}
diccColabo.clear()

for a in artistas:#aqui cargamos solo artistas que han aparecido con colaboraciones en la playlist
  if(len(a)>1):
      diccColabo[a[0]['name']]={'idYTMusic':a[0]['id'],'colaboracion':[],'subscriptores':None,'views':None}

      #if(len(a)==2):
          #dicc[b['id']]={'name':b['name']}

# %% [markdown]
# Nos quedamos con el diccionario de colaboraciones para empezar nuestro análisis. Y empezamos a meter los atributos que nos vendran en el estudio. En este caso, recorriendo otra vez los artistas, sacaremos las colaboraciones de cada uno y la añadiremos

# %%
#c[1]['name']
for c in artistas:#aqui les metemos en colaboraciones sus feats
    if(len(c)>1):
      # print(c[i+1]['name'])--> funcion que recorre artistas de las colaboraciones
      #añadimos artistas a las colabos
           for i in range(len(c)-1):
            diccColabo[c[0]['name']]['colaboracion'].append(c[i+1]['name'])
#diccColabo

# %% [markdown]
# Al proseguir creando la red , nos dimos cuenta que un atributo que seria importante como el id de cada artista; algunas veces no salia. Aparecia como vacío y nos daba fallo al no poder mostrar nada. Esto era o bien porque no tienen canal creado dentro de esta plataforma o porque a veces la aplicación falla ocasionalmente. Por eso en este código buscamos estos espacios vacío, y los rellenamos usando otra funcion de la appi que nos proporciona tambien el id del artista: "search". En el caso de que no nos encuentre nada ponemos que no tiene canal creado.

# %%
#para quitar los artistas que no tiene id ytMusic(fallo de la api)

for a in diccColabo:
   if(diccColabo[a]['idYTMusic']==None):
     idsvacios=yt.search(a)
     if('browseId'not in idsvacios[0]):#VER SI TIENE  ['browseId'] , SI NO LO TIENE SE PONE NO CHANNEL, SI TIENE SE PONE LO QUE ESTA EN EL ELSE  
      diccColabo[a]['idYTMusic']='No Channel'
     else:
      diccColabo[a]['idYTMusic']=idsvacios[0]['browseId']
   
#diccColabo

# %%
#numeramos con ids 
i=0
for keys in diccColabo:
    diccColabo[keys]['id']=i
    i=i+1

# %% [markdown]
# Una vez bien creado las bases del csv, procedemos a rellenar la información de cada artista. En este caso meteremos sus visitas y sus suscriptores. Como resultado obtenemos el diccionario al completo con el que podremos crear el csv.

# %%
#sacamos artistas , del diccionario por su id, sacamos los que tienen canal,y metemos su info de vistas y subscriptores
infoartista=[]
infoSubscribers=[]
infoViews=[]
for a in diccColabo:
   infoartista.append(diccColabo[a]['idYTMusic'])
  
for r in infoartista:
   if(r!='No Channel'):
      artista=yt.get_artist(r)
      infoSubscribers.append(artista['subscribers'])
      if(artista['views']!=None):
         infoViews.append(artista['views'])
      else:
         infoViews.append("No info")
i=0
for keys in diccColabo:
    if(diccColabo[keys]['idYTMusic']!='No Channel'):
      diccColabo[keys]['subscriptores']=infoSubscribers[i]
      diccColabo[keys]['views']=infoViews[i]
      i=i+1

# %% [markdown]
# Con el diccionario obtenido arriba, tenemos colaboraciones completadas, pero no los nodos. El nodo a colabora con b y c, pero solo esta reconocido como nodo a , b y c no. Tenemos que crear nodos para los colaboradores tambien. Esta estructura nos viene bien para sacar los csv de aristas y de nodos para el análisis de gephi, porque solo tiene que tratar las colaboraciones una única vez. Es decir que va a tratar como 1 colaboración A-B. De la otra manera sería muy costoso porque trataría las colaboraciones 2 veces A-B y B-A

# %%
#para rellenar si es explicito  para artistas con colabos       
duration = []
explicit = []
publicacion=[]
vistas=[]
videosIds=[]
artistasAristas=[]
for r in infoPlayList:
     for a in r['tracks']:
          if(len(a['artists'])>1):
            explicit.append(a['isExplicit'])

#para rellenar duracion seg   para artistas con colabos     
for r in infoPlayList:
     for a in r['tracks']:
           if(len(a['artists'])>1):
            duration.append(a['duration_seconds'])
#para los artistas del csv
for r in infoPlayList:
     for a in r['tracks']:
           if(len(a['artists'])>1):
            artistasAristas.append(a['artists'])

#para las vistas de cada cancion
for r in infoPlayList:
     for a in r['tracks']:
           if(len(a['artists'])>1):
               searchMusic=yt.get_song(a['videoId'])
               publicacion.append(searchMusic['microformat']['microformatDataRenderer']['publishDate'])
               vistas.append(searchMusic['microformat']['microformatDataRenderer']['viewCount'])

# %% [markdown]
# Utilizamos la tabla de aristas para sacar los artistas que no han sido reconocidos como nodos y lo añadimos vacios

# %%
for r in artistasAristas:
   for i in range(len(r)-1):
        a=i+1
        if(r[a]['name'] not in diccColabo):
           diccColabo[r[a]['name']]={'idYTMusic':'None','colaboracion':[],'subscriptores':None,'views':None,'id':None}
           search_results=yt.search(r[a]['name'])
           
           if('browseId'in search_results[0]):
            if(search_results[0]['browseId'][0]=='U'):
               
                searcArtist=yt.get_artist(search_results[0]['browseId'])
                diccColabo[r[a]['name']]['idYTMusic']=search_results[0]['browseId']
                diccColabo[r[a]['name']]['subscriptores']=searcArtist['subscribers']
                if(searcArtist['views']==None):
                     diccColabo[r[a]['name']]['views']="No info"
                else:
                    diccColabo[r[a]['name']]['views']=searcArtist['views']
                for c in  diccColabo:
                    for i in range(len(diccColabo[c]['colaboracion'])):
                        if(r[a]['name'] in diccColabo[c]['colaboracion'][i]):
                            diccColabo[r[a]['name']]['colaboracion'].append(c)
i=0
for keys in diccColabo:
    if(diccColabo[keys]['id']==None):
        diccColabo[keys]['id']=i
    i=i+1

# %% [markdown]
# Asi quedaría el diccionario definitivo

# %%
diccColabo
# Out:
# {'Quevedo': {'idYTMusic': 'UC7PL9aor5qNRhvhWWVXyOqA',
#   'colaboracion': ['Myke Towers',
#    'Bizarrap',
#    'Ovy On The Drums',
#    'Mora',
#    'Bad Gyal',
#    'Mora',
#    'Polima Westcoast',
#    'Linton',
#    'Bizarrap',
#    'De La Ghetto',
#    'Duki'],
#   'subscriptores': '1.12M',
#   'views': '313,720,842 views',
#   'id': 0},
#  'Arcangel': {'idYTMusic': 'UCVcAt8IIKIeubRSigcYXgtA',
#   'colaboracion': ['Bad Bunny', 'Sech'],
#   'subscriptores': '10.7M',
#   'views': '4,800,073,660 views',
#   'id': 1},
#  'Farruko': {'idYTMusic': 'UC6QXZsAOOweLfhVPbqMyG4g',
#   'colaboracion': ['Omar Montes',
#    'Rauw Alejandro',
#    'Natti Natasha',
#    'Justin Quiles',
#    'Myke Towers',
#    'Sech',
#    'Sean Paul',
#    'Nicky Jam',
#    'Amenazzy',
#    'Don Omar',
#    'Myke Towers',
#    'Rvssian',
#    'J Balvin',
#    'Rauw Alejandro',
#    'Anuel AA',
#    'Zumbi',
#    'Rauw Alejandro',
#    'KEVVO',
#    'Chencho Corleone',
#    'Natti Natasha',
#    'Justin Quiles',
#    'Lenny Tavárez',
#    'Dalex',
#    'Natti Natasha',
#    'Rauw Alejandro',
#    'Nicky Jam',
#    'Amenazzy',
#    'Rvssian',
#    'J Balvin',
#    'Nicky Jam',
#    'Amenazzy',
#    'Lenier'],
#   'subscriptores': '18.3M',
#   'views': '8,941,155,292 views',
#   'id': 2},
#  'Aitana': {'idYTMusic': 'UCkyzcFsGWVYSUGaR7YB9OYQ',
#   'colaboracion': ['Sangiovanni'],
#   'subscriptores': '2.15M',
#   'views': 'No info',
#   'id': 3},
#  'Bizarrap': {'idYTMusic': 'UCONiUl5u7y2bMaVZJcuRDEQ',
#   'colaboracion': ['Duki'],
#   'subscriptores': '16.6M',
#   'views': '5,878,001,371 views',
#   'id': 4},
#  'Belinda': {'idYTMusic': 'UC8tw8d2POmc3Lt8t1bmgl9Q',
#   'colaboracion': ['Ana Mena',
#    'Ana Mena',
#    'Los Ángeles Azules',
#    'Lalo Ebratt'],
#   'subscriptores': '870K',
#   'views': '353,229,612 views',
#   'id': 5},
#  'Melendi': {'idYTMusic': 'UCl4jq8XKq5X0ZL5p_xVMmZA',
#   'colaboracion': ['India Martínez'],
#   'subscriptores': '4.42M',
#   'views': '3,776,913,159 views',
#   'id': 6},
#  'Rauw Alejandro': {'idYTMusic': 'UCw_m17sBd4GHxuK83-AZtuA',
#   'colaboracion': ['Baby Rasta',
#    'Lyanno',
#    'Brray',
#    'Lyanno',
#    'Brray',
#    'Baby Rasta',
#    'Nio Garcia',
#    'Lenny Tavárez',
#    'Chencho Corleone',
#    'Mr. NaisGai',
#    'Lyanno',
#    'Brray',
#    'Chencho Corleone',
#    'Baby Rasta',
#    'Lyanno',
#    'Brray',
#    'Chencho Corleone',
#    'Chencho Corleone',
#    'Chencho Corleone',
#    'Chencho Corleone'],
#   'subscriptores': '12.3M',
#   'views': '10,234,929,176 views',
#   'id': 7},
#  'Abraham Mateo': {'idYTMusic': 'UCql3y41dHUh9JoPHMedvCbQ',
#   'colaboracion': ['Ana Mena'],
#   'subscriptores': '4.63M',
#   'views': '1,822,893,452 views',
#   'id': 8},
#  'Shakira': {'idYTMusic': 'UCo6JijJGA3IvIiPsawDK3Ww',
#   'colaboracion': ['Ozuna',
#    'Rauw Alejandro',
#    'Ozuna',
#    'Rauw Alejandro',
#    'Anuel AA',
#    'Pedro Capó',
#    'Camilo',
#    'Ozuna',
#    'Ozuna'],
#   'subscriptores': '39.4M',
#   'views': '25,139,267,843 views',
#   'id': 9},
#  'KAROL G': {'idYTMusic': 'UC7n3gWRN0vQzgiOKc51aZ4w',
#   'colaboracion': ['Maldy',
#    'Ovy On The Drums',
#    'Ovy On The Drums',
#    'Maldy',
#    'Maldy',
#    'Nicki Minaj',
#    'Anuel AA',
#    'Feid',
#    'Maldy',
#    'Anuel AA',
#    'Daddy Yankee',
#    'Anuel AA',
#    'Ovy On The Drums',
#    'Maldy',
#    'Feid',
#    'Nicki Minaj',
#    'Simone & Simaria',
#    'Anuel AA',
#    'Daddy Yankee',
#    'Nicki Minaj',
#    'Anuel AA',
#    'Mariah Angeliq ',
#    'Feid',
#    'Nicki Minaj',
#    'Anuel AA',
#    'Daddy Yankee',
#    'Anuel AA',
#    'Anuel AA',
#    'Daddy Yankee',
#    'Anuel AA',
#    'Anuel AA'],
#   'subscriptores': '28.8M',
#   'views': '15,457,348,057 views',
#   'id': 10},
#  'Emilia': {'idYTMusic': 'UCvXoAG_trv-m2pv5_1HVFvA',
#   'colaboracion': ['Ptazeta',
#    'Aitana',
#    'Ptazeta',
#    'Aitana',
#    'Ptazeta',
#    'Aitana'],
#   'subscriptores': '1.28M',
#   'views': '650,911,958 views',
#   'id': 11},
#  'India Martínez': {'idYTMusic': 'UCJbpTwP22V6baVULM7-J4Bw',
#   'colaboracion': ['Andy Rivera'],
#   'subscriptores': '1.01M',
#   'views': '711,938,622 views',
#   'id': 12},
#  'Jairo deRemache': {'idYTMusic': 'UC0rxntgJfUecm5h_d6mY8eg',
#   'colaboracion': ['Omar Montes', 'Farruquito'],
#   'subscriptores': '193',
#   'views': 'No info',
#   'id': 13},
#  'María Artés Lamorena': {'idYTMusic': 'UCIor0JghnFIMBOjfstqWPyg',
#   'colaboracion': ['La Cebolla', 'MAKI'],
#   'subscriptores': '126K',
#   'views': 'No info',
#   'id': 14},
#  'Duki': {'idYTMusic': 'UCtLchRAZex11gn-ah1_1Pgw',
#   'colaboracion': ['Cris Mj', 'Nicki Nicole', 'Cris Mj', 'Nicki Nicole'],
#   'subscriptores': '6.59M',
#   'views': '2,591,697,983 views',
#   'id': 15},
#  'Selena Gomez': {'idYTMusic': 'UCeBYRgPhy8kcRmIGQWKuqdQ',
#   'colaboracion': ['Rema'],
#   'subscriptores': '32.1M',
#   'views': '12,106,923,499 views',
#   'id': 16},
#  'Cardi B': {'idYTMusic': 'UCoIp9Cj1l7k63B90hFg38Zw',
#   'colaboracion': ['ROSALÍA', 'ROSALÍA'],
#   'subscriptores': '18.7M',
#   'views': 'No info',
#   'id': 17},
#  'Myke Towers': {'idYTMusic': 'UCYPsIfSIEwWcoynHBP5k1dg',
#   'colaboracion': ['Tiago PZK',
#    'Daddy Yankee',
#    'Daddy Yankee',
#    'DJ Nelson',
#    'Jay Wheeler',
#    'Juhn'],
#   'subscriptores': '9.59M',
#   'views': 'No info',
#   'id': 18},
#  'SFDK': {'idYTMusic': 'UCSrdBG1Qstc6mc8ucFVn5Qw',
#   'colaboracion': ['Lía Kali'],
#   'subscriptores': '535K',
#   'views': 'No info',
#   'id': 19},
#  'Anuel AA': {'idYTMusic': 'UCbBaYg2UToDaoOwo-R6xi4g',
#   'colaboracion': ['Jowell & Randy',
#    'De La Ghetto',
#    'Yailin la Mas Viral',
#    'MVSIS',
#    'Foreign Teck',
#    'Chris Jedi',
#    'Gaby Music',
#    'Jowell & Randy',
#    'De La Ghetto',
#    'Yailin la Mas Viral',
#    'Chris Jedi',
#    'Gaby Music',
#    'Chris Jedi',
#    'Ñengo Flow',
#    'Chencho Corleone',
#    'Rauw Alejandro',
#    'Daddy Yankee',
#    'Brytiago',
#    'Daddy Yankee',
#    'Natti Natasha',
#    'Rauw Alejandro',
#    'Chris Jedi',
#    'Gaby Music',
#    'MVSIS',
#    'Chris Jedi',
#    'Ñengo Flow',
#    'Chencho Corleone',
#    'Rauw Alejandro',
#    'Ozuna',
#    'Chris Jedi',
#    'Gaby Music',
#    'Daddy Yankee'],
#   'subscriptores': '23.4M',
#   'views': '12,762,253,041 views',
#   'id': 20},
#  'Mora': {'idYTMusic': 'UCgDpp8Ex8Yz6hhHjbl3W5mg',
#   'colaboracion': ['Feid',
#    'De La Ghetto',
#    'Bad Bunny',
#    'Sech',
#    'Feid',
#    'Bad Bunny',
#    'Sech'],
#   'subscriptores': '1.81M',
#   'views': '1,431,607,037 views',
#   'id': 21},
#  'Ozuna': {'idYTMusic': 'UCKEFjh4JL-OyMI8z3h5Coaw',
#   'colaboracion': ['Generación Escogida',
#    'Karol G',
#    'Myke Towers',
#    'Tiago PZK',
#    'Sech',
#    'Sech',
#    'Tokischa',
#    'Karol G',
#    'Myke Towers',
#    'Camilo',
#    'Daddy Yankee',
#    'ROSALÍA'],
#   'subscriptores': '35.7M',
#   'views': '22,086,128,808 views',
#   'id': 22},
#  'Pedro Calderon': {'idYTMusic': 'UCyCOJ11XNKUXtFuf79kWvog',
#   'colaboracion': ['Ayax y Prok'],
#   'subscriptores': '6',
#   'views': 'No info',
#   'id': 23},
#  'JC Reyes': {'idYTMusic': 'UCXGll6UzxbSdLO1_w7rP22g',
#   'colaboracion': ['Pablo Chill-E', 'Ecko', 'Pablo Chill-E', 'Ecko'],
#   'subscriptores': '18K',
#   'views': 'No info',
#   'id': 24},
#  'David Guetta': {'idYTMusic': 'UCh-4c1ZoBPNP1C8c-7iVvUQ',
#   'colaboracion': ['Bebe Rexha'],
#   'subscriptores': '24.9M',
#   'views': '16,643,342,952 views',
#   'id': 25},
#  'Galvan Real': {'idYTMusic': 'UC0r04hp-02vxsjHBVlm4F3A',
#   'colaboracion': ['María Artés Lamorena'],
#   'subscriptores': '419K',
#   'views': 'No info',
#   'id': 26},
#  'Lola Indigo': {'idYTMusic': 'UCydg_dYqBrPZ4-X1MnxD37A',
#   'colaboracion': ['Maria Becerra'],
#   'subscriptores': '1.24M',
#   'views': '690,135,447 views',
#   'id': 27},
#  'Oliver Tree': {'idYTMusic': 'UCoOFEu6s0wk7CUljMh8wisw',
#   'colaboracion': ['Robin Schulz'],
#   'subscriptores': '4.39M',
#   'views': '1,290,893,094 views',
#   'id': 28},
#  'Alain Pérez': {'idYTMusic': 'UCyU8vQ_a9O7ErFoaEiuM4Cg',
#   'colaboracion': ['Original Elias', 'Big Lois'],
#   'subscriptores': '16.2K',
#   'views': 'No info',
#   'id': 29},
#  'Wiso Rivera': {'idYTMusic': 'UCwfvKaHqW4r64dOurVFzD9A',
#   'colaboracion': ['Cruz Cafuné', 'Juseph'],
#   'subscriptores': '175',
#   'views': 'No info',
#   'id': 30},
#  'Abhir Hathi': {'idYTMusic': 'UCYqIXahUqVJHiF_7Ca9kMDA',
#   'colaboracion': ['EL IMA', 'EL IMA'],
#   'subscriptores': '15.2K',
#   'views': 'No info',
#   'id': 31},
#  'C. Tangana': {'idYTMusic': 'UCLuHOvsT_LbOGVjqmXudvBg',
#   'colaboracion': ['Omar Montes', 'Becky G', 'Becky G'],
#   'subscriptores': '2.23M',
#   'views': '1,377,377,099 views',
#   'id': 32},
#  'Nicki Minaj': {'idYTMusic': 'UCTTcTeAszDGxALRSMkJH9FQ',
#   'colaboracion': ['Maluma', 'Myriam Fares', 'FIFA Sound'],
#   'subscriptores': '25.1M',
#   'views': '9,756,945,708 views',
#   'id': 33},
#  'ROSALÍA': {'idYTMusic': 'UCeYz6rzUGhVwqxRM37FUo8w',
#   'colaboracion': ['Romeo Santos',
#    'Romeo Santos',
#    'Romeo Santos',
#    'Romeo Santos'],
#   'subscriptores': '10M',
#   'views': '4,707,785,901 views',
#   'id': 34},
#  'Los del Control': {'idYTMusic': 'UCAYrx2AH-THEBcoFLvpTkBQ',
#   'colaboracion': ['RVFV', 'Kaydy Cain'],
#   'subscriptores': '3.83K',
#   'views': 'No info',
#   'id': 35},
#  'Cano': {'idYTMusic': 'UCumOUWYBPRw2pxGl7QGeiRw',
#   'colaboracion': ['El Jhota', 'Los del Control'],
#   'subscriptores': '183K',
#   'views': 'No info',
#   'id': 36},
#  'Kidd Keo': {'idYTMusic': 'UCv7W2bEmNY7yl9XxSsn3NvQ',
#   'colaboracion': ['TALE$'],
#   'subscriptores': '4.69M',
#   'views': 'No info',
#   'id': 37},
#  'Sergio Ramos': {'idYTMusic': 'UC2MgeVTYErtkCzRMucgFyjQ',
#   'colaboracion': ['Niña Pastori', 'RedOne'],
#   'subscriptores': '620',
#   'views': '9,215 views',
#   'id': 38},
#  'Bad Bunny': {'idYTMusic': 'UCiY3z8HAGD6BlSNKVn2kSvQ',
#   'colaboracion': ['Ñengo Flow',
#    'Jhay Cortez',
#    'J Balvin',
#    'Jhay Cortez',
#    'Tainy',
#    'Jowell & Randy',
#    'Ñengo Flow',
#    'J Balvin',
#    'Jhay Cortez',
#    'Jhay Cortez',
#    'Jowell & Randy',
#    'Ñengo Flow',
#    'J Balvin',
#    'Jhay Cortez',
#    'Farruko',
#    'Natti Natasha',
#    'ROSALÍA',
#    'Tainy',
#    'Sech',
#    'J Balvin',
#    'ROSALÍA',
#    'Jhay Cortez',
#    'Anuel AA',
#    'Dua Lipa',
#    'Tainy',
#    'J Balvin',
#    'Daddy Yankee',
#    'YAVIAH',
#    'Mora',
#    'J Balvin',
#    'Jhay Cortez',
#    'Tainy',
#    'J Balvin',
#    'J Balvin',
#    'Jhay Cortez',
#    'Jhay Cortez',
#    'Anuel AA',
#    'Jowell & Randy',
#    'Ñengo Flow',
#    'Tainy',
#    'ROSALÍA',
#    'Bomba Estéreo',
#    'J Balvin',
#    'Farruko',
#    'J Balvin',
#    'Jhay Cortez',
#    'Jhay Cortez',
#    'Jowell & Randy',
#    'Ñengo Flow',
#    'Jennifer Lopez',
#    'Wisin & Yandel',
#    'Wisin',
#    'Tainy',
#    'J Balvin'],
#   'subscriptores': '44.9M',
#   'views': '27,673,032,321 views',
#   'id': 39},
#  'Yandel': {'idYTMusic': 'UCc1QpDE0iT0n6ZLckjflNHw',
#   'colaboracion': ['Feid',
#    'Tiago PZK',
#    'Arcangel',
#    'Rauw Alejandro',
#    'Anuel AA'],
#   'subscriptores': '5.45M',
#   'views': '3,810,757,747 views',
#   'id': 40},
#  'Wisin': {'idYTMusic': 'UCFVg6y3fZO7OVFbmoGfNdhQ',
#   'colaboracion': ['Jowell & Randy',
#    'Nicky Jam',
#    'Nicky Jam',
#    'Ozuna',
#    'Don Omar',
#    'Gente de Zona'],
#   'subscriptores': '7.42M',
#   'views': '6,142,212,516 views',
#   'id': 41},
#  'Ryan Castro': {'idYTMusic': 'UCDxiGGtBV3CQiE-NKLEFgUg',
#   'colaboracion': ['SOG', 'Feid'],
#   'subscriptores': '2.35M',
#   'views': 'No info',
#   'id': 42},
#  'Cris Mj': {'idYTMusic': 'UCOykHV9q0qb0vrBsxO_5fkQ',
#   'colaboracion': ['Tiago PZK'],
#   'subscriptores': '1.55M',
#   'views': 'No info',
#   'id': 43},
#  'Jhayco': {'idYTMusic': 'UChZEzxer-QvRMbADJJGOMuQ',
#   'colaboracion': ['Feid',
#    'Sech',
#    'Myke Towers',
#    'Myke Towers',
#    'Anuel AA',
#    'Mora',
#    'Los Legendarios',
#    'Wisin',
#    'Anuel AA',
#    'Mora',
#    'Feid',
#    'Sech',
#    'Anuel AA'],
#   'subscriptores': '4.75M',
#   'views': '3,746,917,780 views',
#   'id': 44},
#  'Xyron': {'idYTMusic': 'UCq5W39BHJWSDbc_jLyvh_KQ',
#   'colaboracion': ['Nicky Jam', 'Rapeton Approved'],
#   'subscriptores': '1.27K',
#   'views': 'No info',
#   'id': 45},
#  'Natti Natasha': {'idYTMusic': 'UCqMwRUFZ6APDCsz61zEdhKQ',
#   'colaboracion': ['Maria Becerra',
#    'Ozuna',
#    'Becky G',
#    'Thalía',
#    'Maria Becerra',
#    'Ozuna',
#    'Thalía',
#    'Thalía',
#    'Daddy Yankee',
#    'Pitbull',
#    'Romeo Santos',
#    'Romeo Santos'],
#   'subscriptores': '12M',
#   'views': '7,591,587,354 views',
#   'id': 46},
#  'DJ Playero': {'idYTMusic': 'UCFjHL-3lmFa4t92H8EcWBRA',
#   'colaboracion': ['Rauw Alejandro'],
#   'subscriptores': '1.79K',
#   'views': 'No info',
#   'id': 47},
#  'Zion & Lennox': {'idYTMusic': 'UC8U7wOw_Hd7ltvcWOWAp21g',
#   'colaboracion': ['Feid'],
#   'subscriptores': '3.39M',
#   'views': '2,812,449,014 views',
#   'id': 48},
#  'Blessd': {'idYTMusic': 'UC3vpYFFzqIzsXbMgneDTSeQ',
#   'colaboracion': ['De La Ghetto', 'Darell', 'Ryan Castro'],
#   'subscriptores': '2.01M',
#   'views': '1,435,173,451 views',
#   'id': 49},
#  'Fran C.': {'idYTMusic': 'UChKGa5uCEN3O9u0VNeDZ5yQ',
#   'colaboracion': ['Pablo Pesadilla', 'Polima Westcoast', 'Nickoog Clk'],
#   'subscriptores': '17.7K',
#   'views': 'No info',
#   'id': 50},
#  'Wisin & Yandel': {'idYTMusic': 'UCJ0-R-v3CaJNYMqfp9tivqA',
#   'colaboracion': ['Rauw Alejandro',
#    'Daddy Yankee',
#    'Daddy Yankee',
#    'Daddy Yankee'],
#   'subscriptores': '7.03M',
#   'views': '5,861,505,753 views',
#   'id': 51},
#  'De La Ghetto': {'idYTMusic': 'UCf3TsqO9Ysrw8k63aHg4O5A',
#   'colaboracion': ['Pailita', 'Polima Westcoast', 'Feid', 'J Balvin'],
#   'subscriptores': '2.89M',
#   'views': '1,208,931,499 views',
#   'id': 52},
#  'Maluma': {'idYTMusic': 'UCtKIuEMDzPlUmPgdwBhiGcg',
#   'colaboracion': ['Chencho Corleone',
#    'Chencho Corleone',
#    'Blessd',
#    'Chencho Corleone',
#    'Jennifer Lopez',
#    'GIMS',
#    'Becky G',
#    'Farina',
#    'J Balvin',
#    'Wisin',
#    'De La Ghetto',
#    'Shakira',
#    'GIMS'],
#   'subscriptores': '28.9M',
#   'views': '20,288,783,175 views',
#   'id': 53},
#  'Becky G': {'idYTMusic': 'UC3UkDuAQjoRvTH7OEWm3cHQ',
#   'colaboracion': ['Natti Natasha',
#    'Paulo Londra',
#    'KAROL G',
#    'Paulo Londra',
#    'Natti Natasha',
#    'TINI',
#    'Anitta',
#    'KAROL G',
#    'Natti Natasha',
#    'Natti Natasha',
#    'Daviles de Novelda',
#    'Natti Natasha',
#    'Daviles de Novelda'],
#   'subscriptores': '20.8M',
#   'views': '9,967,580,310 views',
#   'id': 54},
#  'J Balvin': {'idYTMusic': 'UCWw-Guyr5ul9B-d5kJlHMng',
#   'colaboracion': ['Maria Becerra',
#    'Sech',
#    'Daddy Yankee',
#    'Zion & Lennox',
#    'Jowell & Randy',
#    'Ozuna',
#    'Chencho Corleone',
#    'Sech',
#    'Black Eyed Peas',
#    'Zion & Lennox',
#    'Zion & Lennox'],
#   'subscriptores': '33.8M',
#   'views': '22,145,372,889 views',
#   'id': 55},
#  'Dimelo Flow': {'idYTMusic': 'UCFc1GajMRv1jh4BIDj_n93g',
#   'colaboracion': ['Arcangel',
#    'Lenny Tavárez',
#    'Wisin',
#    'Dalex',
#    'Arcangel',
#    'Arcangel'],
#   'subscriptores': '665K',
#   'views': '358,404,763 views',
#   'id': 56},
#  'Tainy': {'idYTMusic': 'UCeN6GRz4bN054slorYxms0w',
#   'colaboracion': ['Anuel AA',
#    'Ozuna',
#    'Anuel AA',
#    'Ozuna',
#    'J Balvin',
#    'Anuel AA',
#    'Ozuna',
#    'J Balvin',
#    'Anuel AA',
#    'Ozuna'],
#   'subscriptores': '2.16M',
#   'views': '1,768,869,002 views',
#   'id': 57},
#  'Crissin': {'idYTMusic': 'UC_Q2Ob7v-SlNlOiqHNrWQLw',
#   'colaboracion': ['Natan & Shander', 'Totoy El Frio'],
#   'subscriptores': '15.5K',
#   'views': 'No info',
#   'id': 58},
#  'Lenny Tavárez': {'idYTMusic': 'UCpOtgk_uRB6PZK47wUXXlVQ',
#   'colaboracion': ['Blessd',
#    'Justin Quiles',
#    'Justin Quiles',
#    'Blessd',
#    'Justin Quiles',
#    'Dalex',
#    'Rauw Alejandro',
#    'Dalex',
#    'Brytiago'],
#   'subscriptores': '3.07M',
#   'views': '847,284,639 views',
#   'id': 59},
#  'Lunay': {'idYTMusic': 'UCPJQHfMDWwUdrKPkZfZNA0Q',
#   'colaboracion': ['Bad Bunny',
#    'Daddy Yankee',
#    'Bad Bunny',
#    'Daddy Yankee',
#    'Bad Bunny',
#    'Daddy Yankee',
#    'Bad Bunny',
#    'Daddy Yankee',
#    'Anuel AA',
#    'Ozuna',
#    'Bad Bunny',
#    'Daddy Yankee',
#    'Bad Bunny',
#    'Daddy Yankee'],
#   'subscriptores': '5.12M',
#   'views': '2,341,449,767 views',
#   'id': 60},
#  'Nicky Jam': {'idYTMusic': 'UCMJ705HLB_EflTzWDAjcKSQ',
#   'colaboracion': ['Ozuna',
#    'Rauw Alejandro',
#    'J Balvin',
#    'Ozuna',
#    'Anuel AA',
#    'J Balvin',
#    'Dalex',
#    'Justin Quiles',
#    'Sech',
#    'Mau y Ricky',
#    'Ozuna',
#    'J Balvin',
#    'Enrique Iglesias',
#    'Ozuna',
#    'Rauw Alejandro',
#    'Alex Sensation',
#    'J Balvin',
#    'Ozuna',
#    'Prince Royce',
#    'Jay Wheeler',
#    'Prince Royce',
#    'Jay Wheeler'],
#   'subscriptores': '23.3M',
#   'views': '15,375,098,042 views',
#   'id': 61},
#  'Nio Garcia': {'idYTMusic': 'UCSBeb5-yOlKqw1lS95ciqcA',
#   'colaboracion': ['Bad Bunny',
#    'J Balvin',
#    'Myke Towers',
#    'Anuel AA',
#    'Lenny Tavárez',
#    'Rauw Alejandro',
#    'Bad Bunny',
#    'J Balvin',
#    'Flow La Movie',
#    'Casper Magico',
#    'Bad Bunny',
#    'J Balvin'],
#   'subscriptores': '1.32M',
#   'views': 'No info',
#   'id': 62},
#  'Brytiago': {'idYTMusic': 'UCoEnXQjMHQX-5EEjhDMMXtQ',
#   'colaboracion': ['Darell'],
#   'subscriptores': '5.28M',
#   'views': '3,142,893,191 views',
#   'id': 63},
#  'Dalex': {'idYTMusic': 'UCXTtAAlWYj1RCVPZ-PYWoqA',
#   'colaboracion': ['Sech', 'Rich Music, Ltd'],
#   'subscriptores': '6.12M',
#   'views': '3,982,906,804 views',
#   'id': 64},
#  'Robi': {'idYTMusic': 'UCpjGA1q99cLKEvKlULb1Llw',
#   'colaboracion': ['Alejo', 'Feid'],
#   'subscriptores': '32.4K',
#   'views': 'No info',
#   'id': 65},
#  'Feid': {'idYTMusic': 'UCc3e8O2V5_7OA300ursDyFQ',
#   'colaboracion': ['Justin Quiles'],
#   'subscriptores': '3.7M',
#   'views': '3,200,729,527 views',
#   'id': 66},
#  'Sean Paul': {'idYTMusic': 'UCnCNNA05VZcH8wVJYtC-6ew',
#   'colaboracion': ['J Balvin', 'J Balvin', 'J Balvin'],
#   'subscriptores': '4.36M',
#   'views': '2,774,501,326 views',
#   'id': 67},
#  'DJ Luian': {'idYTMusic': 'UC5UPgDCYyAxG8Yjq-0I_xTw',
#   'colaboracion': ['Mambo Kingz',
#    'Nicky Jam',
#    'Darell',
#    'Anuel AA',
#    'Nicky Jam',
#    'Darell',
#    'Anuel AA',
#    'Mambo Kingz',
#    'Ozuna',
#    'Mambo Kingz'],
#   'subscriptores': '526K',
#   'views': 'No info',
#   'id': 68},
#  'Manuel Turizo': {'idYTMusic': 'UCfh2j2Dq-aSeLhzuPOsnhVg',
#   'colaboracion': ['Ozuna',
#    'Feid',
#    'Arcangel',
#    'Myke Towers',
#    'Rauw Alejandro',
#    'Ozuna',
#    'Mau y Ricky',
#    'Camilo',
#    'Anuel AA',
#    'Ozuna',
#    'Ozuna',
#    'Mau y Ricky',
#    'Camilo',
#    'Fuego',
#    'Duki'],
#   'subscriptores': '9.1M',
#   'views': 'No info',
#   'id': 69},
#  'Marc Anthony': {'idYTMusic': 'UC22hscWzcVvD_CEPiuaOIbQ',
#   'colaboracion': ['Will Smith', 'Bad Bunny'],
#   'subscriptores': '6.66M',
#   'views': '6,079,210,263 views',
#   'id': 70},
#  'Piso 21': {'idYTMusic': 'UCpe8GCklSIBcxULLHbhQwpQ',
#   'colaboracion': ['Micro TDH'],
#   'subscriptores': '7.56M',
#   'views': '6,649,204,233 views',
#   'id': 71},
#  'DJ Snake': {'idYTMusic': 'UC0c4bK_92XYr0YtASqqWOJg',
#   'colaboracion': ['J Balvin', 'Tyga', 'J Balvin', 'Tyga'],
#   'subscriptores': '23.8M',
#   'views': '7,980,886,835 views',
#   'id': 72},
#  'ChocQuibTown': {'idYTMusic': 'UCZq8jIlmIqSeb079Hr80BEw',
#   'colaboracion': ['Becky G', 'Farruko', 'Zion & Lennox'],
#   'subscriptores': '1.15M',
#   'views': '790,493,181 views',
#   'id': 73},
#  'Trumpmoney': {'idYTMusic': 'UCcOz_kTFH_rrLF47WVphoXQ',
#   'colaboracion': ['andres yuma', 'Vadi'],
#   'subscriptores': '111K',
#   'views': 'No info',
#   'id': 74},
#  'Almighty': {'idYTMusic': 'UCRDGcK3rFRn6VImxBUQVanA',
#   'colaboracion': ['Luar La L'],
#   'subscriptores': '3.1M',
#   'views': '695,966,637 views',
#   'id': 75},
#  'Randy': {'idYTMusic': 'UCq5lNggfaWwSiM_W032Ac5A',
#   'colaboracion': ['De La Ghetto', 'Cazzu'],
#   'subscriptores': '885K',
#   'views': 'No info',
#   'id': 76},
#  'Reik': {'idYTMusic': 'UCJ3jO8eOeYGrKNJ-TmQoV3w',
#   'colaboracion': ['Maria Becerra', 'Morat', 'Maluma', 'Maluma'],
#   'subscriptores': '9.58M',
#   'views': '7,809,916,288 views',
#   'id': 77},
#  'Tiago PZK': {'idYTMusic': 'UCjYEamX786QxvyO527ezaaw',
#   'colaboracion': ['Trueno', 'LIT killah', 'Maria Becerra', 'Nicki Nicole'],
#   'subscriptores': '3.96M',
#   'views': '1,467,650,729 views',
#   'id': 78},
#  'Prince Royce': {'idYTMusic': 'UC1amDmVt3wHmB7zKpkmf3rg',
#   'colaboracion': ['Maria Becerra',
#    'Maria Becerra',
#    'Elvis Martinez',
#    'Shakira'],
#   'subscriptores': '10M',
#   'views': '5,873,082,228 views',
#   'id': 79},
#  'Ñejo': {'idYTMusic': 'UC73Rz2XUqTynb5plO5g1e_w',
#   'colaboracion': ['Ryan Castro', 'Andy Rivera'],
#   'subscriptores': '2.52M',
#   'views': 'No info',
#   'id': 80},
#  'Rei': {'idYTMusic': 'UCxj1FOny1CnD6_P5vIygG4w',
#   'colaboracion': ['Quevedo', 'BANDIDO', 'Duki'],
#   'subscriptores': '883K',
#   'views': 'No info',
#   'id': 81},
#  'Rusherking': {'idYTMusic': 'UC68p6YG34KOL19VezkzaLwA',
#   'colaboracion': ['Dread Mar I'],
#   'subscriptores': '2.12M',
#   'views': 'No info',
#   'id': 82},
#  'Tokischa': {'idYTMusic': 'UC7oLm1CnGj0JwTdlOnQTfGg',
#   'colaboracion': ['Anuel AA',
#    'Ñengo Flow',
#    'ROSALÍA',
#    'Treintisiete',
#    'Secreto El Famoso Biberon'],
#   'subscriptores': '1.44M',
#   'views': '295,816,385 views',
#   'id': 83},
#  'Zhamira Zambrano': {'idYTMusic': 'UCGLtX9sThtyfV_pPhQy10SQ',
#   'colaboracion': ['Jay Wheeler'],
#   'subscriptores': '3.33K',
#   'views': 'No info',
#   'id': 84},
#  'Travis Scott': {'idYTMusic': 'UCf_gP4AMRSgAfyzbkeS9k4g',
#   'colaboracion': ['ROSALÍA'],
#   'subscriptores': '16.3M',
#   'views': '7,507,729,098 views',
#   'id': 85},
#  'Pedro Capó': {'idYTMusic': 'UCel_aU5VwTOSWlunrQ89UBQ',
#   'colaboracion': ['Camilo'],
#   'subscriptores': '6.78M',
#   'views': '3,380,957,339 views',
#   'id': 86},
#  'Karol G': {'idYTMusic': 'UC7n3gWRN0vQzgiOKc51aZ4w',
#   'colaboracion': ['Anuel AA'],
#   'subscriptores': '28.8M',
#   'views': '15,457,348,057 views',
#   'id': 87},
#  'El Alfa': {'idYTMusic': 'UCJMzvcg3QxvaTKfpaj57TyA',
#   'colaboracion': ['Darell', 'Noriel', 'Trueno', 'Noriel', 'Camilo'],
#   'subscriptores': '8.58M',
#   'views': '4,161,690,066 views',
#   'id': 88},
#  'Sky Rompiendo': {'idYTMusic': 'UCSTtXdKn1Dmx28ufElKiaqQ',
#   'colaboracion': ['Myke Towers', 'Rauw Alejandro'],
#   'subscriptores': '359K',
#   'views': '178,455,923 views',
#   'id': 89},
#  'Luis Fonsi': {'idYTMusic': 'UCk91oFc2hY2CdHirU93baLg',
#   'colaboracion': ['Rauw Alejandro',
#    'Demi Lovato',
#    'Nicky Jam',
#    'Sebastián Yatra',
#    'Ozuna'],
#   'subscriptores': '31.2M',
#   'views': '14,754,054,675 views',
#   'id': 90},
#  'Chino & Nacho': {'idYTMusic': 'UCM0is5a5RHVKMcyN8Xs5dQw',
#   'colaboracion': ['Chyno Miranda', 'Nacho'],
#   'subscriptores': '4.8M',
#   'views': '4,171,415,805 views',
#   'id': 91},
#  'CNCO': {'idYTMusic': 'UCYkfG1iLz04t-X2WTsSO4Dw',
#   'colaboracion': ['Natti Natasha'],
#   'subscriptores': '11.9M',
#   'views': '7,037,169,532 views',
#   'id': 92},
#  'Rvssian': {'idYTMusic': 'UCNzGI8JyKXRgrgGIknRGalg',
#   'colaboracion': ['Anuel AA', 'Juice WRLD'],
#   'subscriptores': '28.3K',
#   'views': '77,236,321 views',
#   'id': 93},
#  'Evaluna Montaner': {'idYTMusic': 'UCvPUs3Cm_Ioeihsy7ASXwLQ',
#   'colaboracion': ['Camilo'],
#   'subscriptores': '3.72M',
#   'views': '625,651,232 views',
#   'id': 94},
#  'Carlos Vives': {'idYTMusic': 'UC4mhBXLZXLSffhVsrSsTdCQ',
#   'colaboracion': ['Sebastián Yatra'],
#   'subscriptores': '5.71M',
#   'views': '5,152,463,264 views',
#   'id': 95},
#  'Sebastián Yatra': {'idYTMusic': 'UCXP8o4Xcws36pgpFNlGGBeg',
#   'colaboracion': ['Mau y Ricky', 'Mau y Ricky'],
#   'subscriptores': '17.7M',
#   'views': 'No info',
#   'id': 96},
#  'Chacal': {'idYTMusic': 'UCJt4IsSmUjqTaamhCJoKK_g',
#   'colaboracion': ['Lenier',
#    'El Micha',
#    'El Micha',
#    'Baby Lores',
#    'Los 4',
#    'Lenier'],
#   'subscriptores': '443K',
#   'views': '265,171,930 views',
#   'id': 97},
#  'Kim Loaiza': {'idYTMusic': 'UCtGHTwNL20Y3fY9bumjHDOw',
#   'colaboracion': ['Ovy On The Drums'],
#   'subscriptores': '14.3M',
#   'views': '1,308,707,732 views',
#   'id': 98},
#  'Tiësto': {'idYTMusic': 'UC8VSaPhuiHkjobAgNpRqLIA',
#   'colaboracion': ['KAROL G'],
#   'subscriptores': '6.34M',
#   'views': '3,172,475,521 views',
#   'id': 99},
#  'Aventura': {'idYTMusic': 'UCDaQK4nrsvz27YzufrhJfgg',
#   'colaboracion': ['Bad Bunny', 'Romeo Santos', 'Bad Bunny', 'Romeo Santos'],
#   'subscriptores': '6.13M',
#   'views': '6,648,924,863 views',
#   'id': 100},
#  'Lit Killah': {'idYTMusic': 'UC1qoOeueDduCF1S6xnXYmqA',
#   'colaboracion': ['Tiago PZK'],
#   'subscriptores': '5.63M',
#   'views': 'No info',
#   'id': 101},
#  'Skrillex': {'idYTMusic': 'UCibXKvuw5PoJVmyZJ4qhDIw',
#   'colaboracion': ['J Balvin'],
#   'subscriptores': '20M',
#   'views': '6,416,845,370 views',
#   'id': 102},
#  'Sech': {'idYTMusic': 'UCXhOBsxGZ3TkeaYIW5LAHfA',
#   'colaboracion': ['Daddy Yankee'],
#   'subscriptores': '9.74M',
#   'views': '5,538,820,745 views',
#   'id': 103},
#  'Descemer Bueno': {'idYTMusic': 'UCp0C7rQ8oJ5sn_7_mDbub8A',
#   'colaboracion': ['Andra'],
#   'subscriptores': '135K',
#   'views': '86,861,782 views',
#   'id': 104},
#  'Kendo Kaponi': {'idYTMusic': 'UCLsG7r1pfUddC5VUI8Ero4g',
#   'colaboracion': ['Farruko', 'Anuel AA'],
#   'subscriptores': '1.33M',
#   'views': '342,209,089 views',
#   'id': 105},
#  'El Kamel': {'idYTMusic': 'UCPnWcazEV7QM0H7qBx6NVXg',
#   'colaboracion': ['Juaco'],
#   'subscriptores': '108K',
#   'views': 'No info',
#   'id': 106},
#  'Boy Wonder CF': {'idYTMusic': 'UC3IgJrS1IQIA94o27aKo-8Q',
#   'colaboracion': ['Bryant Myers', 'Baby Rasta', 'Jon Z', 'Shootter Ledo'],
#   'subscriptores': '19.1K',
#   'views': 'No info',
#   'id': 107},
#  'J Menez': {'idYTMusic': 'UCARR0lfCeeMhwL4uiWVDC9w',
#   'colaboracion': ['Arcangel', 'Jon Z'],
#   'subscriptores': '34',
#   'views': 'No info',
#   'id': 108},
#  'KHEA': {'idYTMusic': 'UCtdeqcj1VRfkxCZ427miDMQ',
#   'colaboracion': ['Eladio Carrion', 'Noriel', 'Eladio Carrion', 'Noriel'],
#   'subscriptores': '4.84M',
#   'views': '1,639,941,255 views',
#   'id': 109},
#  'Chyno Miranda': {'idYTMusic': 'UCKIxJ-kUSqhXUL5H-9brFcg',
#   'colaboracion': ['J Balvin'],
#   'subscriptores': '807K',
#   'views': '290,630,734 views',
#   'id': 110},
#  'Pacho El Antifeka': {'idYTMusic': 'UCAv5hmBopmA80uNfPOQ4uYg',
#   'colaboracion': ['Daddy Yankee'],
#   'subscriptores': '319K',
#   'views': 'No info',
#   'id': 111},
#  'Santana The Golden Boy': {'idYTMusic': 'UC41R6sIP1KOZqxLONheeIWQ',
#   'colaboracion': ['Amenazzy', 'Noriel'],
#   'subscriptores': '6.86K',
#   'views': 'No info',
#   'id': 112},
#  'Silvestre Dangond': {'idYTMusic': 'UCHgCGCFOoCaY6IB3nJC17Yg',
#   'colaboracion': ['Natti Natasha', 'Reik', 'Boza'],
#   'subscriptores': '5.67M',
#   'views': 'No info',
#   'id': 113},
#  'Greeicy': {'idYTMusic': 'UCkurR0SHjTh55G-or6U-5xg',
#   'colaboracion': ['Anitta'],
#   'subscriptores': '5.55M',
#   'views': 'No info',
#   'id': 114},
#  'Lalo Ebratt': {'idYTMusic': 'UCFKMn3pbbaDwC0tuURgh9Eg',
#   'colaboracion': ['Trapical'],
#   'subscriptores': '918K',
#   'views': '496,737,799 views',
#   'id': 115},
#  'Plan B': {'idYTMusic': 'UCptlL_RcC46JkGIcjkNspnA',
#   'colaboracion': ['Justin Quiles'],
#   'subscriptores': '5.57M',
#   'views': '3,840,624,973 views',
#   'id': 116},
#  'MC MENOR HR': {'idYTMusic': 'UCTAQXxH14ygzlc0bPH7Jo7A',
#   'colaboracion': ['MC MENOR SG', 'DJ ESCOBAR', 'MC MENOR SG', 'DJ ESCOBAR'],
#   'subscriptores': '27.8K',
#   'views': 'No info',
#   'id': 117},
#  'MC Cabelinho': {'idYTMusic': 'UCuHcGlgGFESTD7kTsBgCG-A',
#   'colaboracion': ['Ariel Donato', 'Ariel Donato'],
#   'subscriptores': '2.16M',
#   'views': 'No info',
#   'id': 118},
#  'MC Livinho': {'idYTMusic': 'UC1oMv_rIbwb7KavdiN5EWvQ',
#   'colaboracion': ['Mc Paiva ZS', 'MC Ryan SP', 'MC Ryan SP'],
#   'subscriptores': '3M',
#   'views': 'No info',
#   'id': 119},
#  'Kotim': {'idYTMusic': 'UC-XxvSPMHf6vWhijl2_1c_g',
#   'colaboracion': ['Mc Paiva ZS',
#    'MC Ryan SP',
#    'Love Funk',
#    'Mc Paiva ZS',
#    'Mc Paiva ZS'],
#   'subscriptores': '2.68K',
#   'views': 'No info',
#   'id': 120},
#  'MC Ryan SP': {'idYTMusic': 'UCVRLEQf_wH8zFb4qCfXqDXw',
#   'colaboracion': ['Mc Daniel', 'Mc Kadu', 'MC Joãozinho VT', 'MC Magal'],
#   'subscriptores': '645K',
#   'views': 'No info',
#   'id': 121},
#  'MC Marks': {'idYTMusic': 'UCGT7CQV3ZO3YGtCtLHNkT2Q',
#   'colaboracion': ['Mc IG', 'Mc Davi'],
#   'subscriptores': '3.53M',
#   'views': 'No info',
#   'id': 122},
#  'Dj LK da Escócia': {'idYTMusic': 'UCgmiPii9xGO-xmp8rgN04tQ',
#   'colaboracion': ['Tchakabum',
#    'MC Ryan SP',
#    'DJ Breno',
#    'MC Livinho',
#    'Tchakabum',
#    'MC Ryan SP'],
#   'subscriptores': '19.9K',
#   'views': 'No info',
#   'id': 123},
#  'MC Don Juan': {'idYTMusic': 'UCEJrzcV4RkXIpzKUhTYX-Sg',
#   'colaboracion': ['MC Ryan SP',
#    'MC Hariel',
#    'Mc Paiva ZS',
#    'Mc Davi',
#    'MC G15',
#    'MC Ryan SP',
#    'MC Hariel'],
#   'subscriptores': '1.54M',
#   'views': 'No info',
#   'id': 124},
#  'Djonga': {'idYTMusic': 'UCh7u19KFpc6VMUyx_kQ_ErA',
#   'colaboracion': ['MC Hariel'],
#   'subscriptores': '2.23M',
#   'views': 'No info',
#   'id': 125},
#  'L7NNON': {'idYTMusic': 'UCPxwQAAQF-erZ8N83_mi22A',
#   'colaboracion': ['DJ Biel do Furduncinho',
#    'Bianca',
#    'DJ Bel da CDD',
#    'Os Hawaianos',
#    'DJ Biel do Furduncinho'],
#   'subscriptores': '3.19M',
#   'views': 'No info',
#   'id': 126},
#  'WIU': {'idYTMusic': 'UCq6oOchdrstuKgv8d3kV3Dw',
#   'colaboracion': ['MC Ryan SP', 'MC Ryan SP'],
#   'subscriptores': '84.4K',
#   'views': 'No info',
#   'id': 127},
#  'Mc Piedro': {'idYTMusic': 'UCOgmto9WYDbUIqMO-f6e7cw',
#   'colaboracion': ['Love Funk', 'MC Lemos', 'Mc Lipi '],
#   'subscriptores': '2.2K',
#   'views': 'No info',
#   'id': 128},
#  'Veigh': {'idYTMusic': 'UC7UjEC2p_CtXJXd_f48LI6w',
#   'colaboracion': ['MC Hariel', 'Mc Kitinho'],
#   'subscriptores': '16.6K',
#   'views': 'No info',
#   'id': 129},
#  'MC Teteu': {'idYTMusic': 'UCUUt7DS3x4VKdx8q9BDmveQ',
#   'colaboracion': ['JC NO BEAT', 'DJ F7', 'Dj Serpinha'],
#   'subscriptores': '133K',
#   'views': 'No info',
#   'id': 130},
#  'DJ GBR': {'idYTMusic': 'UCY5HngkMmxgt5lUYnnnM9nQ',
#   'colaboracion': ['Mc IG', 'MC Ryan SP', 'MC Marks'],
#   'subscriptores': '245K',
#   'views': 'No info',
#   'id': 131},
#  'DJ TAK VADIÃO': {'idYTMusic': 'UC3ejGvTLyAgo6OjnM3mVbyA',
#   'colaboracion': ['dj sv', 'Mc Gabzin'],
#   'subscriptores': '2.37K',
#   'views': 'No info',
#   'id': 132},
#  'Mc Paiva ZS': {'idYTMusic': 'UC1F9t_RXoETqKkI4mqLb3xw',
#   'colaboracion': ['Kotim', 'Gabb MC', 'Mc Kadu'],
#   'subscriptores': '134K',
#   'views': 'No info',
#   'id': 133},
#  'Luísa Sonza': {'idYTMusic': 'UCuPnO05OM95aA1kVQ2tEFPQ',
#   'colaboracion': ['Davi Kneip',
#    'Mc Frog e Mc Leozin',
#    'Dj Gabriel do Borel',
#    'Luan Santana'],
#   'subscriptores': '7.85M',
#   'views': '2,103,005,834 views',
#   'id': 134},
#  'MC Tairon': {'idYTMusic': 'UChfh_GSdDxrI_dVgtM2m-Ag',
#   'colaboracion': ['Mc Vitin da Igrejinha', 'Dj Win', 'MC Braz', 'Dj Win'],
#   'subscriptores': '50.3K',
#   'views': 'No info',
#   'id': 135},
#  'Mc Kako': {'idYTMusic': 'UC4pGi_gzx-ZlR1VVhFSrG8w',
#   'colaboracion': ['DJ Boy', 'MC V7'],
#   'subscriptores': '172K',
#   'views': 'No info',
#   'id': 136},
#  'Dyamante DJ ': {'idYTMusic': 'UCMXZrqW8g8V9KCkeYBUagFQ',
#   'colaboracion': ['MC GW'],
#   'subscriptores': '10.1K',
#   'views': 'No info',
#   'id': 137},
#  'Mc Pepeu': {'idYTMusic': 'UCIJANZ5WFKPIMRKcGNeGTdA',
#   'colaboracion': ['DJ Swat'],
#   'subscriptores': '62K',
#   'views': 'No info',
#   'id': 138},
#  'Mc IG': {'idYTMusic': 'UCy8mM-ay_amwlPoX2Vc6dBA',
#   'colaboracion': ['MC Ryan SP', 'DJ GBR', 'MC Joãozinho VT', 'MC Hariel'],
#   'subscriptores': '270K',
#   'views': 'No info',
#   'id': 139},
#  'MC Cebezinho': {'idYTMusic': 'UClOBniuDdn5Rwnr3mP--u2w',
#   'colaboracion': ['Mc Paiva ZS', 'MC Ryan SP'],
#   'subscriptores': '21.2K',
#   'views': 'No info',
#   'id': 140},
#  'MC Hariel': {'idYTMusic': 'UCZEu7IEubkJEBuNVIsCO3bg',
#   'colaboracion': ['Mc IG', 'MC Ryan SP', 'Mc Paiva ZS', 'Felipe Araújo'],
#   'subscriptores': '1.52M',
#   'views': 'No info',
#   'id': 141},
#  'MC Joãozinho VT': {'idYTMusic': 'UCEWsUvm0WtG5jFFgr9u5PXQ',
#   'colaboracion': ['MC Don Juan', 'MC Ryan SP'],
#   'subscriptores': '149K',
#   'views': 'No info',
#   'id': 142},
#  'MC Kelvinho': {'idYTMusic': 'UCJ1QZPoECRW-eTp0CEalvSQ',
#   'colaboracion': ['Mc Paiva ZS', 'MC Ryan SP'],
#   'subscriptores': '53.5K',
#   'views': 'No info',
#   'id': 143},
#  "Alexander Delgado (Gente D' Zona)": {'idYTMusic': 'UCb6I84uAdPiLw3A_ypU3gnA',
#   'colaboracion': ['Nesty'],
#   'subscriptores': '22',
#   'views': 'No info',
#   'id': 144},
#  'Puerto Rican Power': {'idYTMusic': 'UCTTxR9ar3n24tCV5cwfJTxQ',
#   'colaboracion': ['Olga Tañon'],
#   'subscriptores': '72.7K',
#   'views': '108,584,115 views',
#   'id': 145},
#  'Christian Alicea': {'idYTMusic': 'UCSOgRRwjSlsQzbNqZSNNeHQ',
#   'colaboracion': ['DJ Buddha'],
#   'subscriptores': '14.2K',
#   'views': 'No info',
#   'id': 146},
#  'Los Ángeles Azules': {'idYTMusic': 'UCbjHMB9FdaTig0UyrwGNYHA',
#   'colaboracion': ['Juanes',
#    'Guaynaa',
#    'Sofia Reyes',
#    'Esteman',
#    'Nicki Nicole',
#    'Guaynaa',
#    'Sofia Reyes',
#    'Esteman'],
#   'subscriptores': '8.47M',
#   'views': '10,656,939,811 views',
#   'id': 147},
#  'Camila Cabello': {'idYTMusic': 'UCsZIVNwBqtPBX-41kO_rQzQ',
#   'colaboracion': ['Camilo', 'Camilo'],
#   'subscriptores': '16.1M',
#   'views': '6,313,899,249 views',
#   'id': 148},
#  'Daddy Yankee': {'idYTMusic': 'UCXRloA7YFgCfd6sU2_Y12cA',
#   'colaboracion': ['Marc Anthony', 'Marc Anthony'],
#   'subscriptores': '37.4M',
#   'views': '21,512,140,286 views',
#   'id': 149},
#  'Don Omar': {'idYTMusic': 'UCTrIOPtBeAN2E0R-sgU9JxA',
#   'colaboracion': ['Lil Jon'],
#   'subscriptores': '9.76M',
#   'views': '8,445,821,449 views',
#   'id': 150},
#  'Antony Santos': {'idYTMusic': 'UCbYOXeuF-NfKAVp0ZqIaBnA',
#   'colaboracion': ['Ozuna'],
#   'subscriptores': '678K',
#   'views': '474,703,045 views',
#   'id': 151},
#  'Justin Timberlake': {'idYTMusic': 'UC6VwktUsQQDCkHG1h6YftAQ',
#   'colaboracion': ['Romeo Santos'],
#   'subscriptores': '10.1M',
#   'views': '6,804,430,221 views',
#   'id': 152},
#  'Maffio': {'idYTMusic': 'UCD2HJZjYy2rAUIVm7FdRDew',
#   'colaboracion': ['Gente de Zona'],
#   'subscriptores': '503K',
#   'views': '242,301,029 views',
#   'id': 153},
#  'Daniel Santacruz': {'idYTMusic': 'UCjvediIPs_e1uIBlHt0oT5Q',
#   'colaboracion': ['Manny Cruz', 'Nacho'],
#   'subscriptores': '618K',
#   'views': '364,192,624 views',
#   'id': 154},
#  'Leoni Torres': {'idYTMusic': 'UCnpUiBSTMe83OBKBwm2k2zA',
#   'colaboracion': ['Diana Fuentes'],
#   'subscriptores': '377K',
#   'views': 'No info',
#   'id': 155},
#  'Tito Nieves': {'idYTMusic': 'UCUy2SaC4ovXQ0Kej7Q7CvJA',
#   'colaboracion': ['Norbert', 'Daniela Darcourt', 'Norbert'],
#   'subscriptores': '291K',
#   'views': '213,858,904 views',
#   'id': 156},
#  'G combo': {'idYTMusic': 'UCCZtUmexZfpF-C_Lq-ym2Sw',
#   'colaboracion': ['Owem-G'],
#   'subscriptores': '116',
#   'views': 'No info',
#   'id': 157},
#  'Ángela Aguilar': {'idYTMusic': 'UC4cu15Vfy2VLuqV-pQSXSug',
#   'colaboracion': ['Yuridia'],
#   'subscriptores': '3.49M',
#   'views': '891,398,755 views',
#   'id': 158},
#  'Grupo Marca Registrada': {'idYTMusic': 'UCJrXHTk9F1cFhjc88PALfgA',
#   'colaboracion': ['Junior H'],
#   'subscriptores': '704K',
#   'views': '675,349,338 views',
#   'id': 159},
#  'Gabito Ballesteros': {'idYTMusic': 'UCYMm2JZ_mvXYr7vT9-8_thw',
#   'colaboracion': ['Junior H'],
#   'subscriptores': '7.82K',
#   'views': 'No info',
#   'id': 160},
#  'Fuerza Regida': {'idYTMusic': 'UC0kxNxFQCK6d2spPz5Sme7Q',
#   'colaboracion': ['Natanael Cano'],
#   'subscriptores': '1.21M',
#   'views': 'No info',
#   'id': 161},
#  'Edgardo Nuñez': {'idYTMusic': 'UCohgH17dyp4c_V7U9LoBLdA',
#   'colaboracion': ['Fuerza Regida', 'Fuerza Regida'],
#   'subscriptores': '227K',
#   'views': 'No info',
#   'id': 162},
#  'Junior H': {'idYTMusic': 'UCwA5HHGsAlpU1UlhwWD52uA',
#   'colaboracion': ['Edgardo Nuñez'],
#   'subscriptores': '412K',
#   'views': 'No info',
#   'id': 163},
#  'Grupo Frontera': {'idYTMusic': 'UCJa2FF4TUB13Mm0GurZAqog',
#   'colaboracion': ['Carin Leon', 'Fuerza Regida'],
#   'subscriptores': '723K',
#   'views': 'No info',
#   'id': 164},
#  'Luis Mexia': {'idYTMusic': 'UC_yp0Gk5J6QGP8yZXxNeEYg',
#   'colaboracion': ['Grupo Firme'],
#   'subscriptores': '5.59K',
#   'views': 'No info',
#   'id': 165},
#  'El Fantasma': {'idYTMusic': 'UCXfrOptKcBwWzjY0wBXjj8A',
#   'colaboracion': ['Pepe Aguilar'],
#   'subscriptores': '306K',
#   'views': '787,845,577 views',
#   'id': 166},
#  'Natanael Cano': {'idYTMusic': 'UC47k7qXysCBKeaYfc1zmkIA',
#   'colaboracion': ['Victor Cibrian'],
#   'subscriptores': '2.45M',
#   'views': '1,097,537,724 views',
#   'id': 167},
#  'Grupo Firme': {'idYTMusic': 'UCJKREB2c3dO8dgdo8FtdO_A',
#   'colaboracion': ['La Ventaja', 'Camilo', 'Los Elegantes de Jerez'],
#   'subscriptores': '7.02M',
#   'views': '5,607,729,306 views',
#   'id': 168},
#  'Luis Alfonso Partida "El Yaki"': {'idYTMusic': 'UC5Qqpo0QGvIbNmfmrMdQ9Vg',
#   'colaboracion': ['Grupo Firme'],
#   'subscriptores': '631K',
#   'views': 'No info',
#   'id': 169},
#  'Oscar Maydon': {'idYTMusic': 'UCxTyOt1nVVexDlQub6kvvNQ',
#   'colaboracion': ['El Padrinito Toys'],
#   'subscriptores': '19.5K',
#   'views': 'No info',
#   'id': 170},
#  'José Mejía': {'idYTMusic': 'UC4HuNHynT5dws3s2E_P9VSw',
#   'colaboracion': ['Nivel Codiciado', 'Legado 7'],
#   'subscriptores': '12K',
#   'views': 'No info',
#   'id': 171},
#  'Romeo Santos': {'idYTMusic': 'UCpB_98tUTs3zSiOxZuGPnOA',
#   'colaboracion': ['Christian Nodal'],
#   'subscriptores': '20.1M',
#   'views': '15,882,101,180 views',
#   'id': 172},
#  'Yahritza Y Su Esencia': {'idYTMusic': 'UC5oOy_NEadrnh0lXtJpzgjA',
#   'colaboracion': ['Ivan Cornejo'],
#   'subscriptores': '822K',
#   'views': 'No info',
#   'id': 173},
#  'Kany Garcia': {'idYTMusic': 'UCw3HhreALeqcDfqriN1u1vw',
#   'colaboracion': ['Christian Nodal'],
#   'subscriptores': '2.21M',
#   'views': '1,579,565,802 views',
#   'id': 174},
#  'Ivan Cornejo': {'idYTMusic': 'UCHuClD7xaYq8LYN9FbX2VLQ',
#   'colaboracion': ['Eslabón Armado'],
#   'subscriptores': '195K',
#   'views': '158,207,768 views',
#   'id': 175},
#  'Israel & Rodolffo': {'idYTMusic': 'UCB0234L7RQAClP1BZjn-r5w',
#   'colaboracion': ['Ana Castela',
#    'Jorge & Mateus',
#    'Maiara & Maraisa',
#    'Ana Castela',
#    'Jorge & Mateus'],
#   'subscriptores': '2.9M',
#   'views': 'No info',
#   'id': 176},
#  'Gustavo Mioto': {'idYTMusic': 'UCs9lddMff4X3DecjvGAgqsw',
#   'colaboracion': ['Mari Fernandez', 'Mari Fernandez'],
#   'subscriptores': '7M',
#   'views': 'No info',
#   'id': 177},
#  'Zé Felipe': {'idYTMusic': 'UCRIMRnwcEO-a7-o211fhNMw',
#   'colaboracion': ['Luan Pereira',
#    'Ana Castela',
#    'Luan Pereira',
#    'Ana Castela'],
#   'subscriptores': '8.13M',
#   'views': '2,735,788,435 views',
#   'id': 178},
#  'Felipe & Murillo': {'idYTMusic': 'UC8q_ILijGpVdBsa4H0Tf7PA',
#   'colaboracion': ['Ana Castela', 'Ana Castela'],
#   'subscriptores': '13K',
#   'views': 'No info',
#   'id': 179},
#  'Guilherme & Benuto': {'idYTMusic': 'UCNHnPxK_5yfprPSyYOQ2J0g',
#   'colaboracion': ['Matheus & Kauan',
#    'Xand Avião',
#    'Xand Avião',
#    'Matheus & Kauan'],
#   'subscriptores': '1.64M',
#   'views': '1,471,284,212 views',
#   'id': 180},
#  'Murilo Huff': {'idYTMusic': 'UC-g0dJZGCPLIb7yoFndqmRA',
#   'colaboracion': ['Maiara & Maraisa'],
#   'subscriptores': '1.38M',
#   'views': 'No info',
#   'id': 181},
#  'Jorge & Mateus': {'idYTMusic': 'UCf28WctYS7hBbDQSgDdS_7w',
#   'colaboracion': ['Matheus & Kauan',
#    'Hugo & Guilherme',
#    'Rionegro & Solimões',
#    'Matheus & Kauan'],
#   'subscriptores': '14.7M',
#   'views': '8,450,699,086 views',
#   'id': 182},
#  'Luan Santana': {'idYTMusic': 'UCeVDW-bGaWoUzn55fJY-sfQ',
#   'colaboracion': ['Henrique & Juliano'],
#   'subscriptores': '11.9M',
#   'views': '5,290,468,081 views',
#   'id': 183},
#  'Diego & Victor Hugo': {'idYTMusic': 'UCE705eB9XX_25xG_iOnImUg',
#   'colaboracion': ['Jorge & Mateus', 'Jorge & Mateus'],
#   'subscriptores': '2.84M',
#   'views': 'No info',
#   'id': 184},
#  'Gusttavo Lima': {'idYTMusic': 'UC1a6QMzU-em9TFB4OBsT52g',
#   'colaboracion': ['Hugo & Guilherme'],
#   'subscriptores': '19.6M',
#   'views': '12,763,294,228 views',
#   'id': 185},
#  'Bruno & Marrone': {'idYTMusic': 'UCoiH2CN6DEO2Tiit80XKX8w',
#   'colaboracion': ['Henrique & Juliano'],
#   'subscriptores': '5.9M',
#   'views': '3,585,419,912 views',
#   'id': 186},
#  'Paulo e Nathan': {'idYTMusic': 'UCet3bZ3DPitoyGaw0gmiE4g',
#   'colaboracion': ['Hugo & Guilherme'],
#   'subscriptores': '108K',
#   'views': 'No info',
#   'id': 187},
#  'Hugo & Guilherme': {'idYTMusic': 'UC86xOhUitK56NVSH1u-eldg',
#   'colaboracion': ['Tierry'],
#   'subscriptores': '1.89M',
#   'views': 'No info',
#   'id': 188},
#  'Mari Fernandez': {'idYTMusic': 'UCgdng0uA3fUklL7pE1zyrKg',
#   'colaboracion': ['Murilo Huff'],
#   'subscriptores': '1.78M',
#   'views': 'No info',
#   'id': 189},
#  'Wesley Safadão': {'idYTMusic': 'UClG_7_PRAIW6VeGCbeA2U0w',
#   'colaboracion': ['Deavele Santos'],
#   'subscriptores': '13.6M',
#   'views': '7,630,547,550 views',
#   'id': 190},
#  'nattan': {'idYTMusic': 'UC--PQbk41TJ2NVynu1GFU1A',
#   'colaboracion': ['Nivaldo Marques'],
#   'subscriptores': '1.55M',
#   'views': 'No info',
#   'id': 191},
#  'João Gomes': {'idYTMusic': 'UCAgLj3O_AeIqr9ZKfgZLj8w',
#   'colaboracion': ['Yara Tchê'],
#   'subscriptores': '3.9M',
#   'views': '1,364,923,982 views',
#   'id': 192},
#  'Orochi': {'idYTMusic': 'UCKr613dWPqkCDsHzqsDdxag',
#   'colaboracion': ['Mc Ryan SP',
#    'Oruam',
#    'Xamã',
#    'MC Daniel',
#    'BIN',
#    'Caio Passos'],
#   'subscriptores': '3.16M',
#   'views': 'No info',
#   'id': 193},
#  'Oruam': {'idYTMusic': 'UCPJ0y3GVshDXceFw-sqw88Q',
#   'colaboracion': ['Mainstreet'],
#   'subscriptores': '66.4K',
#   'views': 'No info',
#   'id': 194},
#  'Skeeter Beats': {'idYTMusic': 'UCR9TBQTbjdEA2MGQ5g3RevQ',
#   'colaboracion': ['Rô Rosa', 'Yago Oproprio'],
#   'subscriptores': '127',
#   'views': 'No info',
#   'id': 195},
#  'Lagum': {'idYTMusic': 'UC0WmQLDR5IwQzUp760ymc9A',
#   'colaboracion': ['Anavitória'],
#   'subscriptores': '778K',
#   'views': 'No info',
#   'id': 196},
#  'teto': {'idYTMusic': 'UCZYK0SevTVwrzdvDNrPEWtA',
#   'colaboracion': ['Felipe Amorim'],
#   'subscriptores': '16.2K',
#   'views': 'No info',
#   'id': 197},
#  'Xand Avião': {'idYTMusic': 'UCnVznkVigYrDMxqNhJ22Tnw',
#   'colaboracion': ['Kadu Martins'],
#   'subscriptores': '5.62M',
#   'views': 'No info',
#   'id': 198},
#  'PEDRO SAMPAIO': {'idYTMusic': 'UCrtlcOLqu8ARd0VXKz_TA3Q',
#   'colaboracion': ['Pabllo Vittar'],
#   'subscriptores': '3.93M',
#   'views': 'No info',
#   'id': 199},
#  'Pabllo Vittar': {'idYTMusic': 'UCmPnXSlj6y-NEfYLmRI2-7A',
#   'colaboracion': ['Gloria Groove'],
#   'subscriptores': '7.74M',
#   'views': '2,104,414,009 views',
#   'id': 200},
#  'Lexa': {'idYTMusic': 'UCxr0P-UHeApMcowSfaNA-PA',
#   'colaboracion': ['POCAH', 'Anitta'],
#   'subscriptores': '3.92M',
#   'views': '1,189,669,183 views',
#   'id': 201},
#  'Manu Gavassi': {'idYTMusic': 'UCiOU1yrq_x9PDruRct7p8mw',
#   'colaboracion': ['Gustavo Mioto'],
#   'subscriptores': '2.07M',
#   'views': '213,111,001 views',
#   'id': 202},
#  'Miami Sound Machine': {'idYTMusic': 'UC_RfleX8b6HxPrtrFvnpSWQ',
#   'colaboracion': ['Gloria Estefan'],
#   'subscriptores': '9.42K',
#   'views': '7,470,635 views',
#   'id': 203},
#  'Celia Cruz': {'idYTMusic': 'UCuDaqwAmogKMCUVn_z3wDTA',
#   'colaboracion': ['Tito Puente'],
#   'subscriptores': '316K',
#   'views': '351,937,639 views',
#   'id': 204},
#  'Daniela Darcourt': {'idYTMusic': 'UCNQB-0ylGx6pv2xGqBTTSsw',
#   'colaboracion': ['Ezio Oliva'],
#   'subscriptores': '796K',
#   'views': 'No info',
#   'id': 205},
#  'Gilberto Santa Rosa': {'idYTMusic': 'UCnrpYJUW8qhtKfkgbINJuiA',
#   'colaboracion': ['Willy Garcia'],
#   'subscriptores': '1.33M',
#   'views': '1,367,320,905 views',
#   'id': 206},
#  'India': {'idYTMusic': 'UCEdvRoGeWjuJr_VXaOCcVtw',
#   'colaboracion': ['Victor Manuelle'],
#   'subscriptores': '349K',
#   'views': '182,961,662 views',
#   'id': 207},
#  'Willie Colón': {'idYTMusic': 'UCZ7rjHAj_eNbsrKTFkBQbAQ',
#   'colaboracion': ['Héctor Lavoe'],
#   'subscriptores': '504K',
#   'views': '575,482,229 views',
#   'id': 208},
#  'Rubén Blades': {'idYTMusic': 'UCnkkieZOwsqTwV4rB_jENGw',
#   'colaboracion': ['Roberto Delgado & Orquesta', 'Carlos Vives'],
#   'subscriptores': '437K',
#   'views': '270,713,236 views',
#   'id': 209},
#  'Johnny Pacheco': {'idYTMusic': 'UCp32KspYOPOlLcAuCxyGNKg',
#   'colaboracion': ['Monguito "El Único" Santamaría', 'Celia Cruz'],
#   'subscriptores': '39.3K',
#   'views': 'No info',
#   'id': 210},
#  'Bobby Cruz': {'idYTMusic': 'UCFbqrxMsmJp3VqBoDIcsrsA',
#   'colaboracion': ['Ricardo "Richie" Ray'],
#   'subscriptores': '40.5K',
#   'views': '25,972,922 views',
#   'id': 211},
#  'Ala Jaza': {'idYTMusic': 'UCx4mI31AyOQVJ2t_ypYwAUw',
#   'colaboracion': ['Olga Tañon'],
#   'subscriptores': '759K',
#   'views': 'No info',
#   'id': 212},
#  'Rubby Perez': {'idYTMusic': 'UCxZIpfRkvGpWB4hy5qTMzew',
#   'colaboracion': ['Fernando Villalona', 'Toño Rosario', 'Romeo Santos'],
#   'subscriptores': '71.2K',
#   'views': 'No info',
#   'id': 213},
#  'Eddy Herrera': {'idYTMusic': 'UCRfNVEAGfGwsXi59RlU5dbg',
#   'colaboracion': ['Omar Enrique', 'Daniel Santacruz'],
#   'subscriptores': '306K',
#   'views': '274,519,475 views',
#   'id': 214},
#  'Proyecto Uno': {'idYTMusic': 'UChhGIorTwJk4D9ShYduTgaw',
#   'colaboracion': ['Gabriel'],
#   'subscriptores': '58.3K',
#   'views': '64,176,216 views',
#   'id': 215},
#  'Omega': {'idYTMusic': 'UCAJwa_1l4rHzBJyWbeBtGZw',
#   'colaboracion': ['Ozuna'],
#   'subscriptores': '315K',
#   'views': 'No info',
#   'id': 216},
#  'Elvis Crespo': {'idYTMusic': 'UC23tFg8bnVgRVQkLhSGElVw',
#   'colaboracion': ['Manny Cruz', 'Los Hermanos Rosario'],
#   'subscriptores': '1.11M',
#   'views': '911,375,723 views',
#   'id': 217},
#  'La Gran Manzana': {'idYTMusic': 'UCSTtOe0WUGTvQ4dQH3bN-gw',
#   'colaboracion': ['Victor Roque'],
#   'subscriptores': '2.48K',
#   'views': 'No info',
#   'id': 218},
#  'Raymix': {'idYTMusic': 'UCoccQa2mpLeXUrB0QkNQz6w',
#   'colaboracion': ['Chiquis', 'NZO'],
#   'subscriptores': '2.42M',
#   'views': '1,890,306,507 views',
#   'id': 219},
#  'La T y La M': {'idYTMusic': 'UC_HuyfhEyXeEc0zc4asMI6g',
#   'colaboracion': ['Ke Personajes'],
#   'subscriptores': '238K',
#   'views': 'No info',
#   'id': 220},
#  'DaCrewmbia': {'idYTMusic': 'UCww5VLNDHtezPy3rVNNNtXw',
#   'colaboracion': ['Agrupación Cariño'],
#   'subscriptores': '11',
#   'views': 'No info',
#   'id': 221},
#  'Abel Pintos': {'idYTMusic': 'UCaj_N7j2odeKoLlzN4jV1qA',
#   'colaboracion': ['Los Palmeras'],
#   'subscriptores': '1.48M',
#   'views': '1,483,727,847 views',
#   'id': 222},
#  'Play-N-Skillz': {'idYTMusic': 'UCX2yqJo9G5oJvw0leb3Ev5A',
#   'colaboracion': ['Becky G', 'Thalía', 'Chiquis', 'Luis Coronel'],
#   'subscriptores': '204K',
#   'views': '122,122,934 views',
#   'id': 223},
#  'Mexican Institute Of Sound': {'idYTMusic': 'UCfgF1FGpggXwz_XCWT8PN_g',
#   'colaboracion': ['Santa Fe Klan', 'Fidel Nadal'],
#   'subscriptores': '18.9K',
#   'views': '6,204,569 views',
#   'id': 224},
#  'Eliseo Herrera': {'idYTMusic': 'UC_UPHlr1vcglKqd38Wd_Gog',
#   'colaboracion': ['Los Cumbia Stars'],
#   'subscriptores': '720',
#   'views': 'No info',
#   'id': 225},
#  'Pato Machete': {'idYTMusic': 'UCgWVduNSS9sVKaFI8h_YqTg',
#   'colaboracion': ['Los Master Plus'],
#   'subscriptores': '46.8K',
#   'views': '10,123,774 views',
#   'id': 226},
#  'La Sonora Dinamita': {'idYTMusic': 'UCcZxKB31JHe6E298PPcJG7A',
#   'colaboracion': ['Banda El Recodo De Cruz Lizárraga', 'Santa Fe Klan'],
#   'subscriptores': '804K',
#   'views': '316,270,283 views',
#   'id': 227},
#  'Rochy RD': {'idYTMusic': 'UCTpb9vZ5hURZerNo80mh6RQ',
#   'colaboracion': ['Harryson', 'Tivi Gunz', 'Jonatan Burlon'],
#   'subscriptores': '4.69M',
#   'views': 'No info',
#   'id': 228},
#  'Tivi Gunz': {'idYTMusic': 'UCV5UwV8hyxXIujYsLVYvd5Q',
#   'colaboracion': ['Angel Dior',
#    'Young Gatillo',
#    'Treintisiete',
#    'Don Forty Five'],
#   'subscriptores': '557K',
#   'views': 'No info',
#   'id': 229},
#  'Chael Produciendo': {'idYTMusic': 'UCK9Js6zjAqvAEmlh5RyiTpA',
#   'colaboracion': ['El Alfa',
#    'Farruko',
#    'El Alfa',
#    'El Alfa',
#    'Braulio Fogon',
#    'T.Y.S',
#    'El Alfa',
#    'El Mayor Clasico',
#    'El Alfa'],
#   'subscriptores': '122K',
#   'views': 'No info',
#   'id': 230},
#  'Chimbala': {'idYTMusic': 'UCj36ACUuHAPPesaM_ydfrxw',
#   'colaboracion': ['Dowba Montana', 'Chucky73', 'Omega', 'Noriel'],
#   'subscriptores': '3.11M',
#   'views': '1,053,612,688 views',
#   'id': 231},
#  'Paulus Music': {'idYTMusic': 'UCVIfrBx2Yv7csHNHCM7-nbA',
#   'colaboracion': ['Tokischa', 'Yomel El Meloso'],
#   'subscriptores': '46',
#   'views': 'No info',
#   'id': 232},
#  'Farina': {'idYTMusic': 'UCNXvwbgr8tGszzqBjDClcxQ',
#   'colaboracion': ['El Alfa'],
#   'subscriptores': '2.53M',
#   'views': '740,893,918 views',
#   'id': 233},
#  'Jay Wheeler': {'idYTMusic': 'UC17u1K8tiqxxFhPMbM50ASA',
#   'colaboracion': ['El Alfa', 'DJ Nelson'],
#   'subscriptores': '4.82M',
#   'views': '2,771,251,802 views',
#   'id': 234},
#  'Imperio Record': {'idYTMusic': 'UC4HtCU-SgfH_PAQCVulS6Lw',
#   'colaboracion': ['Braulio Fogon'],
#   'subscriptores': '349',
#   'views': 'No info',
#   'id': 235},
#  'El Cherry Scom': {'idYTMusic': 'UCpnsxXva_hyqzvuJqQg_MHA',
#   'colaboracion': ['Tokischa',
#    'Haraca Kiko',
#    'El Panda 15',
#    'Shadow Blow',
#    'Dowba Montana'],
#   'subscriptores': '729K',
#   'views': 'No info',
#   'id': 236},
#  'El Futuro Fuera De Orbita': {'idYTMusic': 'UCjI8pt4uWXIjRSLWzXzcd9w',
#   'colaboracion': ['Harry Nach'],
#   'subscriptores': '332K',
#   'views': 'No info',
#   'id': 237},
#  'Dj Adoni': {'idYTMusic': 'UC9zfbD6eVR4j5ovoY8Ir9Ow',
#   'colaboracion': ['Lenny Tavárez',
#    'Bulin 47',
#    'Farruko',
#    'La Perversa',
#    'El Alfa'],
#   'subscriptores': '13.9K',
#   'views': 'No info',
#   'id': 238},
#  'Mark B': {'idYTMusic': 'UCUbUtoFC6ZNYmjm0FmIhD2g',
# ...
#   'views': '266,122,372 views',
#   'id': 522},
#  'NZO': {'idYTMusic': 'None',
#   'colaboracion': [],
#   'subscriptores': None,
#   'views': None,
#   'id': 523},
#  'Ke Personajes': {'idYTMusic': 'UCYJ_9Y3IoTbGZpU0TuQ8PPA',
#   'colaboracion': ['La T y La M'],
#   'subscriptores': '1.41M',
#   'views': 'No info',
#   'id': 524},
#  'Agrupación Cariño': {'idYTMusic': 'UCtV6jX-wOK7to2lhSKPQVMg',
#   'colaboracion': ['DaCrewmbia'],
#   'subscriptores': '7.15K',
#   'views': 'No info',
#   'id': 525},
#  'Los Palmeras': {'idYTMusic': 'UCp1U6alu7Y5BnjLZu2cfqmg',
#   'colaboracion': ['Abel Pintos'],
#   'subscriptores': '242K',
#   'views': 'No info',
#   'id': 526},
#  'Santa Fe Klan': {'idYTMusic': 'UC1t2O7UhGmJVT903LC4dEUA',
#   'colaboracion': ['Mexican Institute Of Sound', 'La Sonora Dinamita'],
#   'subscriptores': '10.1M',
#   'views': 'No info',
#   'id': 527},
#  'Fidel Nadal': {'idYTMusic': 'UCJ_bsibO3p86-iHH3ajKxgw',
#   'colaboracion': ['Mexican Institute Of Sound'],
#   'subscriptores': '22.3K',
#   'views': '6,360,424 views',
#   'id': 528},
#  'Los Cumbia Stars': {'idYTMusic': 'UC3koXa_yy1pExC8Z3DmIODg',
#   'colaboracion': ['Eliseo Herrera'],
#   'subscriptores': '9.36K',
#   'views': 'No info',
#   'id': 529},
#  'Luis Coronel': {'idYTMusic': 'UC9KGeOSI51Xe14GarhxaE6A',
#   'colaboracion': ['Play-N-Skillz'],
#   'subscriptores': '1.49M',
#   'views': '388,028,909 views',
#   'id': 530},
#  'Los Master Plus': {'idYTMusic': 'UC73-pfoiT2Ht9ox-H0fyo3Q',
#   'colaboracion': ['Pato Machete'],
#   'subscriptores': '2.84K',
#   'views': 'No info',
#   'id': 531},
#  'Banda El Recodo De Cruz Lizárraga': {'idYTMusic': 'UCqmicz9Sn9gih5SbUHRHZ6w',
#   'colaboracion': ['La Sonora Dinamita'],
#   'subscriptores': '2.63M',
#   'views': '2,761,230,483 views',
#   'id': 532},
#  'Harryson': {'idYTMusic': 'UC2ihX5uoblnN4wsA-ayIAAA',
#   'colaboracion': ['Rochy RD'],
#   'subscriptores': '112K',
#   'views': 'No info',
#   'id': 533},
#  'Angel Dior': {'idYTMusic': 'UCa5m6WrNdxNRbvY_LArD7Uw',
#   'colaboracion': ['Tivi Gunz'],
#   'subscriptores': '414K',
#   'views': 'No info',
#   'id': 534},
#  'Young Gatillo': {'idYTMusic': 'UCqyREMYfQxMRll2E0-DFDcg',
#   'colaboracion': ['Tivi Gunz'],
#   'subscriptores': '163K',
#   'views': '20,808,895 views',
#   'id': 535},
#  'Treintisiete': {'idYTMusic': 'UCf-VAsT81dyHR7TURcOQfcQ',
#   'colaboracion': ['Tokischa', 'Tivi Gunz'],
#   'subscriptores': '302K',
#   'views': 'No info',
#   'id': 536},
#  'Dowba Montana': {'idYTMusic': 'UC2Ggem3xUjMJR931ZVthMQg',
#   'colaboracion': ['Chimbala', 'El Cherry Scom', 'Mark B'],
#   'subscriptores': '635K',
#   'views': '151,367,853 views',
#   'id': 537},
#  'Chucky73': {'idYTMusic': 'UCqBydz3xCj4qX8Vds1vj_Yw',
#   'colaboracion': ['Chimbala', 'Fetti031'],
#   'subscriptores': '910K',
#   'views': 'No info',
#   'id': 538},
#  'Yomel El Meloso': {'idYTMusic': 'UCXpnwLMNGoghmQlbtIuiMqQ',
#   'colaboracion': ['Paulus Music'],
#   'subscriptores': '1.25M',
#   'views': 'No info',
#   'id': 539},
#  'Braulio Fogon': {'idYTMusic': 'UCUHeKrvQ35vs3yk3Y2Ivmag',
#   'colaboracion': ['Chael Produciendo',
#    'Imperio Record',
#    'Breyco En Producidera',
#    'French Montana'],
#   'subscriptores': '757K',
#   'views': 'No info',
#   'id': 540},
#  'Harry Nach': {'idYTMusic': 'UCO-eCC9qWjWdaDH1W3G9ZhA',
#   'colaboracion': ['El Futuro Fuera De Orbita'],
#   'subscriptores': '557K',
#   'views': 'No info',
#   'id': 541},
#  'Bulin 47': {'idYTMusic': 'None',
#   'colaboracion': [],
#   'subscriptores': None,
#   'views': None,
#   'id': 542},
#  'El Panda 15': {'idYTMusic': 'UC3jG5vgkjJ-3H-E0TdwyPiQ',
#   'colaboracion': ['El Cherry Scom'],
#   'subscriptores': '50.7K',
#   'views': 'No info',
#   'id': 543},
#  'Shadow Blow': {'idYTMusic': 'UCgbs2HqfNucMJzMhUWrr5TA',
#   'colaboracion': ['El Cherry Scom'],
#   'subscriptores': '652K',
#   'views': 'No info',
#   'id': 544},
#  'Secreto El Famoso Biberon': {'idYTMusic': 'UCRzrVBBwwgeVfR9eaVFlVIQ',
#   'colaboracion': ['Tokischa'],
#   'subscriptores': '3.28M',
#   'views': 'No info',
#   'id': 545},
#  'El Fecho Rd': {'idYTMusic': 'UCj8OfjueQS15zikAqqOGnSA',
#   'colaboracion': ['Chiki El De La Vaina'],
#   'subscriptores': '1.03M',
#   'views': 'No info',
#   'id': 546},
#  'La Perversa': {'idYTMusic': 'UCalwlLZB7DYtdcTIEpTGirQ',
#   'colaboracion': ['Dj Adoni', 'Ceky Vicini'],
#   'subscriptores': '805K',
#   'views': 'No info',
#   'id': 547},
#  'Don Forty Five': {'idYTMusic': 'UCwb9qpHXexGuAOJw-dAGkww',
#   'colaboracion': ['Tivi Gunz'],
#   'subscriptores': '13K',
#   'views': 'No info',
#   'id': 548},
#  'T.Y.S': {'idYTMusic': 'UCEeJQ_7WNGCggzFxlRwY6dw',
#   'colaboracion': ['Chael Produciendo'],
#   'subscriptores': '181K',
#   'views': '45,377,969 views',
#   'id': 549},
#  'Akapellah': {'idYTMusic': 'UCguwkFYfqM5V9tEjtUfsbjQ',
#   'colaboracion': ['Fetti031'],
#   'subscriptores': '1.41M',
#   'views': 'No info',
#   'id': 550},
#  'El Mayor Clasico': {'idYTMusic': 'UCOljex2KuBSCuPszyL1qWlA',
#   'colaboracion': ['Chael Produciendo'],
#   'subscriptores': '1.56M',
#   'views': 'No info',
#   'id': 551},
#  'El Productor de oro': {'idYTMusic': 'UCxdDdBWaydtrs5yQeE3gnFA',
#   'colaboracion': ['Ice P'],
#   'subscriptores': '1',
#   'views': 'No info',
#   'id': 552},
#  'Shootter Ledo': {'idYTMusic': 'UC1fsqiQvIoNQeTVEEA5xD8g',
#   'colaboracion': ['Boy Wonder CF'],
#   'subscriptores': '76',
#   'views': 'No info',
#   'id': 553},
#  'Jonatan Burlon': {'idYTMusic': 'UCFFal9JVwdW1dPs-BNVtJnw',
#   'colaboracion': ['Rochy RD'],
#   'subscriptores': '37.1K',
#   'views': '3,570,925 views',
#   'id': 554},
#  'Elvis Martinez': {'idYTMusic': 'UC4h9XqAOcX8oznh0JXLymfQ',
#   'colaboracion': ['Prince Royce'],
#   'subscriptores': '416K',
#   'views': '239,037,450 views',
#   'id': 555},
#  'Luis Vargas': {'idYTMusic': 'UChCP-Q1emDG1jv5iHdtRzdg',
#   'colaboracion': ['Henry Santos'],
#   'subscriptores': '198K',
#   'views': '132,888,648 views',
#   'id': 556},
#  'Yenddi': {'idYTMusic': 'UCRKdgiIDxc1TQ1PGh2YmY6Q',
#   'colaboracion': ['Zacarías Ferreíra'],
#   'subscriptores': '686',
#   'views': 'No info',
#   'id': 557},
#  '24 Horas': {'idYTMusic': 'None',
#   'colaboracion': [],
#   'subscriptores': None,
#   'views': None,
#   'id': 558},
#  'Monchy Capricho': {'idYTMusic': 'UCN7ZrapWAsiMIzVDo8MLMcQ',
#   'colaboracion': ['Alexandra'],
#   'subscriptores': '2.95K',
#   'views': 'No info',
#   'id': 559},
#  'DJ ABDO': {'idYTMusic': 'UCk-3J0MKsHPVWdR3Mp57Dzg',
#   'colaboracion': ['Mc Delux', 'Club Dz7'],
#   'subscriptores': '1.31K',
#   'views': 'No info',
#   'id': 560},
#  'Mc 2k': {'idYTMusic': 'UCiO5JtxCpBns0s4AyogQcTA',
#   'colaboracion': ['Dj Juninho Mpc'],
#   'subscriptores': '4.87K',
#   'views': 'No info',
#   'id': 561},
#  'MC PR': {'idYTMusic': 'UCNAeEUljS9-ZHwna23uMiqw',
#   'colaboracion': ['Dj Juninho Mpc'],
#   'subscriptores': '124K',
#   'views': 'No info',
#   'id': 562},
#  'Two Maloka': {'idYTMusic': 'UCEt30T7eohQrrxwVLVmXvyA',
#   'colaboracion': ['DJ Pernambuco'],
#   'subscriptores': '15.1K',
#   'views': 'No info',
#   'id': 563},
#  'MC DG': {'idYTMusic': 'UCGsOFlRJDp2guW_Gm9O-QfA',
#   'colaboracion': ['MC Gustta'],
#   'subscriptores': '5.15K',
#   'views': 'No info',
#   'id': 564},
#  'Mc Nando Dk': {'idYTMusic': 'UCz0kFzqCNvnPliNfI5NvWeQ',
#   'colaboracion': ['Jerry Smith'],
#   'subscriptores': '992',
#   'views': 'No info',
#   'id': 565},
#  'MC Guto VGS': {'idYTMusic': 'UC7xAsgLS8jSs6kNIyuqcceA',
#   'colaboracion': ['MC BN', 'MC BN'],
#   'subscriptores': '12.8K',
#   'views': 'No info',
#   'id': 566},
#  'DJ KL do ABC': {'idYTMusic': 'UCBQ0UWI5O3YA6vsYaAEVTOg',
#   'colaboracion': ['MC BN'],
#   'subscriptores': '255',
#   'views': 'No info',
#   'id': 567},
#  'MC Barone': {'idYTMusic': 'UC6snirf-iSSM4CQJUcT-csQ',
#   'colaboracion': ['MC Lan'],
#   'subscriptores': '5.64K',
#   'views': 'No info',
#   'id': 568},
#  'MC Hollywood': {'idYTMusic': 'UC1TJDizRa7hgzNuDTjgFyhA',
#   'colaboracion': ['MC Kevinho'],
#   'subscriptores': '126K',
#   'views': 'No info',
#   'id': 569},
#  'DJ KOSTA 22': {'idYTMusic': 'UCz6zNBbYBPxVgA993bV37gQ',
#   'colaboracion': ['Mc jhenny'],
#   'subscriptores': '300',
#   'views': 'No info',
#   'id': 570},
#  'MC Leléto': {'idYTMusic': 'UCl6MnM76oJeZMN3X4KNJleg',
#   'colaboracion': ['MC WM'],
#   'subscriptores': '353K',
#   'views': 'No info',
#   'id': 571},
#  'Os Cretinos': {'idYTMusic': 'UCsx8LW7HMjaIDYC_MPLRstw',
#   'colaboracion': ['MC WM'],
#   'subscriptores': '392K',
#   'views': 'No info',
#   'id': 572},
#  'MC 2Jhow': {'idYTMusic': 'UCdytVIeNmM8OLKYWtyiZ-vw',
#   'colaboracion': ['Rennan da Penha'],
#   'subscriptores': '20.6K',
#   'views': 'No info',
#   'id': 573},
#  'MC RANGEL': {'idYTMusic': 'UCAZAyCywmOzF5MUk4Dqq5Aw',
#   'colaboracion': ['Dj Kaio Lopes'],
#   'subscriptores': '1.32K',
#   'views': 'No info',
#   'id': 574},
#  'Mc J Mito': {'idYTMusic': 'UCM1QbOlxxC0u1I1b8_2LdXw',
#   'colaboracion': ['Dj Kaio Lopes'],
#   'subscriptores': '89.2K',
#   'views': 'No info',
#   'id': 575},
#  'Mc Ed': {'idYTMusic': 'UC-bom0_TRc_EJHWd54rETCA',
#   'colaboracion': ['Mc Charmosinho'],
#   'subscriptores': '9',
#   'views': 'No info',
#   'id': 576},
#  'Mc 7 Belo': {'idYTMusic': 'UCh-kHe6afscNsyP5Sj7udIg',
#   'colaboracion': ['DJ Arana'],
#   'subscriptores': '2.91K',
#   'views': 'No info',
#   'id': 577},
#  'MC LCKaiique': {'idYTMusic': 'UChC9hdo50Um4UT3xd2lMgHA',
#   'colaboracion': ['DJ Arana'],
#   'subscriptores': '2.1K',
#   'views': 'No info',
#   'id': 578},
#  'DJ Topo': {'idYTMusic': 'UCBsEbsC_PntTr48x_X6xlZg',
#   'colaboracion': ['MC Durrony'],
#   'subscriptores': '207K',
#   'views': 'No info',
#   'id': 579},
#  'Kyan': {'idYTMusic': 'None',
#   'colaboracion': [],
#   'subscriptores': None,
#   'views': None,
#   'id': 580},
#  'DJ Bruno Prado': {'idYTMusic': 'UCPpFWDvbZnh6RCgkKaUEa4w',
#   'colaboracion': ['MU540'],
#   'subscriptores': '19.7K',
#   'views': 'No info',
#   'id': 581},
#  'DJ Alex BNH': {'idYTMusic': 'UC__NUiQK94mobfrxZrPpj7g',
#   'colaboracion': ['FP do Trem Bala'],
#   'subscriptores': '39K',
#   'views': 'No info',
#   'id': 582},
#  'DJ Kley': {'idYTMusic': 'UCXAU0Sh9MYgK6E3HExR3QKQ',
#   'colaboracion': ['MC BN', 'MC BN'],
#   'subscriptores': '267',
#   'views': 'No info',
#   'id': 583},
#  'MC Neneco': {'idYTMusic': 'UC3J7QmvBrA0R2BVVcf3k3ZA',
#   'colaboracion': ['Rennan da Penha'],
#   'subscriptores': '128',
#   'views': 'No info',
#   'id': 584},
#  'Savanah': {'idYTMusic': 'UCzMzg8Rjq-cfwQJ7wt1hm1Q',
#   'colaboracion': ['Rennan da Penha'],
#   'subscriptores': '217',
#   'views': 'No info',
#   'id': 585},
#  'Dj Duarte': {'idYTMusic': 'UChx1BSGuI91UlYsgaXuoPPw',
#   'colaboracion': ['DJ TN Beat'],
#   'subscriptores': '63.5K',
#   'views': 'No info',
#   'id': 586},
#  'DJ TS': {'idYTMusic': 'UCShVJQBHPyzuf9VXl8JlQfA',
#   'colaboracion': ['DJ TN Beat'],
#   'subscriptores': '2.82K',
#   'views': 'No info',
#   'id': 587},
#  'bellagi': {'idYTMusic': 'UCamGzfqBkjYU060756qzguw',
#   'colaboracion': ['Isabely Thompson'],
#   'subscriptores': '374',
#   'views': 'No info',
#   'id': 588},
#  'Mc Mika': {'idYTMusic': 'UCkmWomM9-YqcSfiNCyTcVOA',
#   'colaboracion': ['Isabely Thompson'],
#   'subscriptores': '6.37K',
#   'views': 'No info',
#   'id': 589},
#  'DJ Abdo': {'idYTMusic': 'UCk-3J0MKsHPVWdR3Mp57Dzg',
#   'colaboracion': ['Mc Delux', 'MC Pipokinha', 'MC Pipokinha'],
#   'subscriptores': '1.31K',
#   'views': 'No info',
#   'id': 590},
#  'MC Saci': {'idYTMusic': 'UCMmPgIW_HFoGprj7NysFx-A',
#   'colaboracion': ['Dj Joao MDP', 'Dj rayan'],
#   'subscriptores': '13.3K',
#   'views': 'No info',
#   'id': 591},
#  'MC Faelzin': {'idYTMusic': 'UC3XhWRm7u8HI7O3rpGAdVuQ',
#   'colaboracion': ['Dj Joao MDP'],
#   'subscriptores': '987',
#   'views': 'No info',
#   'id': 592},
#  'Dj Serpinha': {'idYTMusic': 'UCby-p57hrzjfrKA0xijhZIQ',
#   'colaboracion': ['MC Teteu'],
#   'subscriptores': '7.89K',
#   'views': 'No info',
#   'id': 593},
#  'Maax Deejay': {'idYTMusic': 'UC0_3t9-CppT-9pjc0oXClwQ',
#   'colaboracion': ['Mc Koruja'],
#   'subscriptores': '88',
#   'views': 'No info',
#   'id': 594},
#  'Mc Anjim': {'idYTMusic': 'UCdJKZua9oH_Ok0n7CFvYcgQ',
#   'colaboracion': ['DJ VILÃO'],
#   'subscriptores': '93.7K',
#   'views': 'No info',
#   'id': 595},
#  'Dj JL O Único': {'idYTMusic': 'UCtHaQgktCC1w1ELY5LvY2yg',
#   'colaboracion': ['FP do Trem Bala'],
#   'subscriptores': '1.71K',
#   'views': 'No info',
#   'id': 596},
#  'DJ Pablo RB': {'idYTMusic': 'UCJlXwTuNo2cpt14U0BTGPJw',
#   'colaboracion': ['MC Nathan'],
#   'subscriptores': '1.94K',
#   'views': 'No info',
#   'id': 597},
#  'DJ Guih Da ZO': {'idYTMusic': 'UC3gnAlPB4ftWNvb76SXIVtQ',
#   'colaboracion': ['MC Delux'],
#   'subscriptores': '9.09K',
#   'views': 'No info',
#   'id': 598},
#  'DJ Kauan': {'idYTMusic': 'UCiGbyb4ZEZl52rUi1h23G1A',
#   'colaboracion': ['MC Menor MT'],
#   'subscriptores': '9',
#   'views': 'No info',
#   'id': 599},
#  'MC Hanan': {'idYTMusic': 'UCSKmzcEb1xXGw_V5Gk_mDYw',
#   'colaboracion': ['MC Pipokinha'],
#   'subscriptores': '114',
#   'views': 'No info',
#   'id': 600},
#  'MC Murilo MT': {'idYTMusic': 'UCsBAzU8RtOG-XSyZFRVP_Tg',
#   'colaboracion': ['MC Myres'],
#   'subscriptores': '74K',
#   'views': '29,188,183 views',
#   'id': 601},
#  'MC Yuri': {'idYTMusic': 'UC6q-lNODn3N3FBtDfQy6xJg',
#   'colaboracion': ['MC Myres'],
#   'subscriptores': '3.69K',
#   'views': 'No info',
#   'id': 602},
#  'Dj TG Beats': {'idYTMusic': 'UCnBbq3D0f2V6XoKD6fa7GsA',
#   'colaboracion': ['DJ Patrick Muniz'],
#   'subscriptores': '1.05K',
#   'views': 'No info',
#   'id': 603},
#  'MC Branquinha': {'idYTMusic': 'UCCG3RDgGByUiJxEMQTCDZQg',
#   'colaboracion': ['Mc Delux'],
#   'subscriptores': '112K',
#   'views': 'No info',
#   'id': 604},
#  'DJ Bill': {'idYTMusic': 'UCvqOUpTo_0xBmOwwc8Pz3oQ',
#   'colaboracion': ['MC RD'],
#   'subscriptores': '532',
#   'views': 'No info',
#   'id': 605},
#  'MC Garoto': {'idYTMusic': 'UCRghHpRqKFAmlDzlWsD3LqQ',
#   'colaboracion': ['DJ MACK'],
#   'subscriptores': '370',
#   'views': 'No info',
#   'id': 606},
#  'GORDÃO DO PC': {'idYTMusic': 'UCwXD8VV8nZ86jVKl_Flpw0Q',
#   'colaboracion': ['DJ MACK'],
#   'subscriptores': '113K',
#   'views': 'No info',
#   'id': 607},
#  'Dj Samuel Rodrigues': {'idYTMusic': 'UCgeFBXJneGo4gKjTt1-bXmw',
#   'colaboracion': ['Mc vh diniz, Mc Vitin Lc & Mc Anjim'],
#   'subscriptores': '210',
#   'views': 'No info',
#   'id': 608},
#  'DJ Yuri ZS': {'idYTMusic': 'UCCjojiwFp_IwnEyhANuq2Lg',
#   'colaboracion': ['Mc Gw'],
#   'subscriptores': '305',
#   'views': 'No info',
#   'id': 609},
#  'Lukkas': {'idYTMusic': 'UCWdLRxN-jeQMj8OC1LTKGNg',
#   'colaboracion': ['Ya Malb'],
#   'subscriptores': '34',
#   'views': 'No info',
#   'id': 610},
#  'JK NO BEAT': {'idYTMusic': 'UCEJQTQJi65bnJS5RgRbiJRQ',
#   'colaboracion': ['MC Zuka'],
#   'subscriptores': '21',
#   'views': 'No info',
#   'id': 611},
#  'dj cayoo': {'idYTMusic': 'UCIhXeaZzJOF5-vPAxUZPVyg',
#   'colaboracion': ['mc scar'],
#   'subscriptores': '17.2K',
#   'views': 'No info',
#   'id': 612},
#  'Dj Lemix': {'idYTMusic': 'UCS4paE2rksuNbT6PHSofpPw',
#   'colaboracion': ['MC Buret'],
#   'subscriptores': '679',
#   'views': 'No info',
#   'id': 613},
#  'MC Kitinho': {'idYTMusic': 'UCHnK0hxO3SV9GUZ9Ixx0AMw',
#   'colaboracion': ['MC BN'],
#   'subscriptores': '48.7K',
#   'views': 'No info',
#   'id': 614},
#  'Pet & Bobii': {'idYTMusic': 'UCVRDhav-IEeNd2f6Xm757Sw',
#   'colaboracion': ['Dj Douglinhas'],
#   'subscriptores': '257',
#   'views': 'No info',
#   'id': 615},
#  'Theus Costa': {'idYTMusic': 'UCZir0_S-7txH-YLS73jyeTQ',
#   'colaboracion': ['Bella Angel'],
#   'subscriptores': '466',
#   'views': 'No info',
#   'id': 616},
#  'Mc d20': {'idYTMusic': 'UCNWlhBAAHqixxW3oxbWeAiw',
#   'colaboracion': ['MC Talibã'],
#   'subscriptores': '97',
#   'views': 'No info',
#   'id': 617},
#  'Dj Gabriel Dutra': {'idYTMusic': 'UCuut22MsaDuSWdL379h4A2Q',
#   'colaboracion': ['Mc Danone'],
#   'subscriptores': '5.15K',
#   'views': 'No info',
#   'id': 618},
#  'DJ MAVICC': {'idYTMusic': 'UCyaLBspDqGIFOri-JdsjwXg',
#   'colaboracion': ['DJ Erik JP'],
#   'subscriptores': '3.15K',
#   'views': 'No info',
#   'id': 619},
#  'Mc Rodrigo do CN': {'idYTMusic': 'UCeXgvFRlfIgCuT4RIImPYGA',
#   'colaboracion': ['Dj rayan'],
#   'subscriptores': '26.5K',
#   'views': 'No info',
#   'id': 620},
#  'Mc Dricka': {'idYTMusic': 'UCGilQvQR6IiF02V47T3mYmg',
#   'colaboracion': ['Club Dz7'],
#   'subscriptores': '1.41M',
#   'views': '221,456,417 views',
#   'id': 621},
#  "Los Yonic's": {'idYTMusic': 'UCGjrreyBiWAztUpGtnEAbTw',
#   'colaboracion': ['Chico Che Chico'],
#   'subscriptores': '184K',
#   'views': '247,820,045 views',
#   'id': 622},
#  'Sofia Macchi': {'idYTMusic': 'UCw05UVFXBN5JFoGqbOsuNOA',
#   'colaboracion': ['Chico Che Chico'],
#   'subscriptores': '32.9K',
#   'views': 'No info',
#   'id': 623}}

# %% [markdown]
# Como resultado tenemos ya nuestra tabla de noodos completa

# %%
df = pd.DataFrame.from_dict(diccColabo, orient = "index",columns=['id','idYTMusic','colaboracion','subscriptores','views'])

df.to_csv('finished.csv')
df
# Out:
#                    id                 idYTMusic  \
# Quevedo             0  UC7PL9aor5qNRhvhWWVXyOqA
# Arcangel            1  UCVcAt8IIKIeubRSigcYXgtA
# Farruko             2  UC6QXZsAOOweLfhVPbqMyG4g
# Aitana              3  UCkyzcFsGWVYSUGaR7YB9OYQ
# Bizarrap            4  UCONiUl5u7y2bMaVZJcuRDEQ
# ...               ...                       ...
# DJ MAVICC         619  UCyaLBspDqGIFOri-JdsjwXg
# Mc Rodrigo do CN  620  UCeXgvFRlfIgCuT4RIImPYGA
# Mc Dricka         621  UCGilQvQR6IiF02V47T3mYmg
# Los Yonic's       622  UCGjrreyBiWAztUpGtnEAbTw
# Sofia Macchi      623  UCw05UVFXBN5JFoGqbOsuNOA
#
#                                                        colaboracion  \
# Quevedo           [Myke Towers, Bizarrap, Ovy On The Drums, Mora...
# Arcangel                                          [Bad Bunny, Sech]
# Farruko           [Omar Montes, Rauw Alejandro, Natti Natasha, J...
# Aitana                                                [Sangiovanni]
# Bizarrap                                                     [Duki]
# ...                                                             ...
# DJ MAVICC                                              [DJ Erik JP]
# Mc Rodrigo do CN                                         [Dj rayan]
# Mc Dricka                                                [Club Dz7]
# Los Yonic's                                       [Chico Che Chico]
# Sofia Macchi                                      [Chico Che Chico]
#
#                  subscriptores                views
# Quevedo                  1.12M    313,720,842 views
# Arcangel                 10.7M  4,800,073,660 views
# Farruko                  18.3M  8,941,155,292 views
# Aitana                   2.15M              No info
# Bizarrap                 16.6M  5,878,001,371 views
# ...                        ...                  ...
# DJ MAVICC                3.15K              No info
# Mc Rodrigo do CN         26.5K              No info
# Mc Dricka                1.41M    221,456,417 views
# Los Yonic's               184K    247,820,045 views
# Sofia Macchi             32.9K              No info
#
# [624 rows x 5 columns]

# %%
header = ['nombre','id','idYTMusic','colaboracion','subscriptores','views']

with open('nodos.csv','w',encoding='utf-8',newline='') as f:
    writer= csv.writer(f)
    writer.writerow(header)
    for i in diccColabo:
        writer.writerow([i,diccColabo[i]['id'],diccColabo[i]['idYTMusic'],
        diccColabo[i]['colaboracion'],diccColabo[i]['subscriptores'],diccColabo[i]['views']])

# %% [markdown]
# En este momento, abrimos un csv para escribir la información de las aristas.En nuestro caso se van a unir los nodos segun sus colaboraciones.Si el nodo A ha colaborado con B y C se lanzará una arista desde A hasta B y desde A hasta C.
# Tambien hemos añadido atributos complementarios para su posterior estudio en Gephi, como la duracion de la cancion en cuestión en la que colaboran, si la letra de la cancion tiene contenido explicito o no y la fecha de la publicación de la cancion en ytMusic.

# %%
header = ['artista', 'colaborador','duracion','explicito','fecha_publicacion','visitas']
writedicc = {}
with open('aristas.csv','w',encoding='utf-8',newline='') as f:
    writer= csv.writer(f)
    writer.writerow(header)
    iter=0
    repe=0
    for r in artistasAristas:
        for i in range(len(r)-1):
            fechaF=publicacion[iter]
            fecha=list(fechaF)
            fecha[4]='/'
            fecha[7]='/'
            fechaF = "".join(fecha)
            writer.writerow([r[0]['name'],r[i+1]['name'],duration[iter],explicit[iter],fechaF,vistas[iter]])
        iter=iter+1
            
      # iter=iter+1

# %% [markdown]
# Vamos a crear archivos para que gephi los pueda reconocer y podamos proceder analizarlo desde ahi

# %%
header = ['Id','Label','colaboracion','subscriptores','views']

with open('nodosGephi.csv','w',encoding='utf-8',newline='') as f:
    writer= csv.writer(f)
    writer.writerow(header)
    for i in diccColabo:
        writer.writerow([diccColabo[i]['id'],i,
        diccColabo[i]['colaboracion'],diccColabo[i]['subscriptores'],diccColabo[i]['views']])
        #writer.writerow([i,diccColabo[i]['colaboracion'],diccColabo[i]['subscriptores'],diccColabo[i]['views']])

# %%
header = ['Source', 'Target','duracion','explicito','visitas','fecha_publicacion']
writedicc = {}
with open('aristasGephi.csv','w',encoding='utf-8',newline='') as f:
    writer= csv.writer(f)
    writer.writerow(header)
    iter=0
    repe=0
    for r in artistasAristas:
        for i in range(len(r)-1):
            fechaF=publicacion[iter]
            fecha=list(fechaF)
            fecha[4]='/'
            fecha[7]='/'
            fechaF = "".join(fecha)
            writer.writerow([diccColabo[r[0]['name']]['id'],diccColabo[r[i+1]['name']]['id'],
            duration[iter],explicit[iter],vistas[iter],fechaF])
            #writer.writerow([r[0]['name'],r[i+1]['name'],duration[iter],explicit[iter],publicacion[iter],vistas[iter]])
        iter=iter+1

# %% [markdown]
# El resultado de esta red actual es el siguiente:

# %%
df = pd.read_csv('aristas.csv',names=['artista', 'colaborador','duracion','explicito','fecha_publicacion','visitas'])

G=nx.from_pandas_edgelist(df,'artista','colaborador')


plt.show() 
plt.figure(figsize=(13,10))
pos = nx.circular_layout(G)
nx.draw(G,pos,with_labels=True,alpha=0.7)
