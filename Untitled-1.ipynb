# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
import csv
#holawenasnoxes

# %% [markdown]
# Daaniiiiiiiiiiiiiiiiii     AQUI   poner brevemente que hace cada funcion

# %%
from ytmusicapi import YTMusic

yt = YTMusic()
#z8uyayN3RbE
searchMusic=yt.get_song("5g2hT4GmAGU")

#yt.get_artist("UCiY3z8HAGD6BlSNKVn2kSvQ")
search_results=yt.search("Barroso")
#search_results
searchPlay=yt.get_playlist("PL4fGSI1pDJn4jhQB4kb9M36dvVmJQPt4T")

searcArtist=yt.get_artist('UCI9q5A6SUN37p0gM01E1R4Q')

searchMusic=yt.get_song("5g2hT4GmAGU")

searchchar=yt.get_charts()
#searchchar
#searchPlay
searchMusic
#searcArtist
#search_results
# Out:
# {'playabilityStatus': {'status': 'OK',
#   'playableInEmbed': True,
#   'audioOnlyPlayability': {'audioOnlyPlayabilityRenderer': {'trackingParams': 'CCgQx2kiEwjiioPr1_n7AhX0GwYAHVdbDEk=',
#     'audioOnlyAvailability': 'FEATURE_AVAILABILITY_ALLOWED'}},
#   'liveStreamability': {'liveStreamabilityRenderer': {'videoId': '5g2hT4GmAGU',
#     'pollDelayMs': '15000',
#     'displayEndscreen': True}},
#   'miniplayer': {'miniplayerRenderer': {'playbackMode': 'PLAYBACK_MODE_ALLOW'}},
#   'contextParams': 'Q0FFU0FnZ0I='},
#  'streamingData': {'expiresInSeconds': '21540',
#   'formats': [{'itag': 18,
#     'mimeType': 'video/mp4; codecs="avc1.42001E, mp4a.40.2"',
#     'bitrate': 643197,
#     'width': 640,
#     'height': 360,
#     'lastModified': '1663947566281344',
#     'quality': 'medium',
#     'fps': 24,
#     'qualityLabel': '360p',
#     'projectionType': 'RECTANGULAR',
#     'audioQuality': 'AUDIO_QUALITY_LOW',
#     'approxDurationMs': '158987',
#     'audioSampleRate': '44100',
#     'audioChannels': 2,
#     'signatureCipher': 's=yy%3DAwet8aBQaUIqS8l2vgW7SVwy5B2_Dx-56kS%3DWOB8lLkAEiAS5caAfiE1MCKJ_XyCqX4pXMAOeXAkbS2AUG-Z_mxkzNAhIgRw8JQ0qObqOa&sp=sig&url=https://rr2---sn-gxqpgpn-h5ql.googlevideo.com/videoplayback%3Fexpire%3D1671062334%26ei%3D3g6aY-KjF_S3mLAP17axyAQ%26ip%3D147.96.60.89%26id%3Do-AD1kFiAvkqe7zRw26L-hwBFrn-Bs7xBsED8rq-samnFB%26itag%3D18%26source%3Dyoutube%26requiressl%3Dyes%26mh%3Dy8%26mm%3D31%252C29%26mn%3Dsn-gxqpgpn-h5ql%252Csn-h5q7knez%26ms%3Dau%252Crdu%26mv%3Dm%26mvi%3D2%26pl%3D17%26gcr%3Des%26initcwndbps%3D472500%26spc%3DzIddbDvRWL2_HbO6DTNEdJfV3RD7IIs%26vprv%3D1%26mime%3Dvideo%252Fmp4%26ns%3DLlKHjy-ISo3-FD_FgVOtfZAK%26cnr%3D14%26ratebypass%3Dyes%26dur%3D158.987%26lmt%3D1663947566281344%26mt%3D1671040424%26fvip%3D3%26fexp%3D24001373%252C24007246%26c%3DWEB_REMIX%26txp%3D4530434%26n%3DFDPfCrPMYjU86P%26sparams%3Dexpire%252Cei%252Cip%252Cid%252Citag%252Csource%252Crequiressl%252Cgcr%252Cspc%252Cvprv%252Cmime%252Cns%252Ccnr%252Cratebypass%252Cdur%252Clmt%26lsparams%3Dmh%252Cmm%252Cmn%252Cms%252Cmv%252Cmvi%252Cpl%252Cinitcwndbps%26lsig%3DAG3C_xAwRQIhAOSAiA_wo7qiWihf1EvWQIE7v4wbQlLh1Cm5TROblj2TAiAk4-G6Fsz_TCnNAG4VItglHubJRx5RVd86UjLHBt55Mw%253D%253D'}],
#   'adaptiveFormats': [{'itag': 313,
#     'mimeType': 'video/webm; codecs="vp9"',
#     'bitrate': 17897712,
#     'width': 3840,
#     'height': 2160,
#     'initRange': {'start': '0', 'end': '220'},
#     'indexRange': {'start': '221', 'end': '732'},
#     'lastModified': '1660183484358477',
#     'contentLength': '348588022',
#     'quality': 'hd2160',
#     'fps': 24,
#     'qualityLabel': '2160p',
#     'projectionType': 'RECTANGULAR',
#     'averageBitrate': 17548290,
#     'colorInfo': {'primaries': 'COLOR_PRIMARIES_BT709',
#      'transferCharacteristics': 'COLOR_TRANSFER_CHARACTERISTICS_BT709',
#      'matrixCoefficients': 'COLOR_MATRIX_COEFFICIENTS_BT709'},
#     'approxDurationMs': '158916',
#     'signatureCipher': 's=gg%3D%3DAxWZVihwzk16exiSrt9ARWJ4Zdtn2h-88l%3DyLAY77D9DQICshypG1ZKRcmIqDxHCz7R6jA4NUPjr-f_Q2Flv2eFs6LgIQRw8JQ0qOrqOV&sp=sig&url=https://rr2---sn-gxqpgpn-h5ql.googlevideo.com/videoplayback%3Fexpire%3D1671062334%26ei%3D3g6aY-KjF_S3mLAP17axyAQ%26ip%3D147.96.60.89%26id%3Do-AD1kFiAvkqe7zRw26L-hwBFrn-Bs7xBsED8rq-samnFB%26itag%3D313%26source%3Dyoutube%26requiressl%3Dyes%26mh%3Dy8%26mm%3D31%252C29%26mn%3Dsn-gxqpgpn-h5ql%252Csn-h5q7knez%26ms%3Dau%252Crdu%26mv%3Dm%26mvi%3D2%26pl%3D17%26gcr%3Des%26initcwndbps%3D472500%26spc%3DzIddbDvRWL2_HbO6DTNEdJfV3RD7IIs%26vprv%3D1%26mime%3Dvideo%252Fwebm%26ns%3DuT9t_HeTiPW76ogbpK8tq1sK%26gir%3Dyes%26clen%3D348588022%26dur%3D158.916%26lmt%3D1660183484358477%26mt%3D1671040424%26fvip%3D3%26keepalive%3Dyes%26fexp%3D24001373%252C24007246%26c%3DWEB_REMIX%26txp%3D453C434%26n%3DXtY3CXtLKAMt0E%26sparams%3Dexpire%252Cei%252Cip%252Cid%252Citag%252Csource%252Crequiressl%252Cgcr%252Cspc%252Cvprv%252Cmime%252Cns%252Cgir%252Cclen%252Cdur%252Clmt%26lsparams%3Dmh%252Cmm%252Cmn%252Cms%252Cmv%252Cmvi%252Cpl%252Cinitcwndbps%26lsig%3DAG3C_xAwRAIgIY8xbePhBKGAGngkrXd4iM7_RlW2LXSUnqFdc0OnAKwCIEYp7P3Cp5WOuspzxilSo6Yw1aQjTk3htDa9XxlTwpO_'},
#    {'itag': 271,
#     'mimeType': 'video/webm; codecs="vp9"',
#     'bitrate': 8902576,
#     'width': 2560,
#     'height': 1440,
#     'initRange': {'start': '0', 'end': '219'},
#     'indexRange': {'start': '220', 'end': '729'},
#     'lastModified': '1660183629244677',
#     'contentLength': '164438143',
#     'quality': 'hd1440',
#     'fps': 24,
#     'qualityLabel': '1440p',
#     'projectionType': 'RECTANGULAR',
#     'averageBitrate': 8277990,
#     'colorInfo': {'primaries': 'COLOR_PRIMARIES_BT709',
#      'transferCharacteristics': 'COLOR_TRANSFER_CHARACTERISTICS_BT709',
#      'matrixCoefficients': 'COLOR_MATRIX_COEFFICIENTS_BT709'},
#     'approxDurationMs': '158916',
#     'signatureCipher': 's=22XDxE5TLcE-mUl8zcenw_gxzKQ_4bXgUEIWYfX2xcOCCICgCEMmY8mvhAJCvZ9QrDapbAkZqRuL8DzrqDBvR3ab2KgIARw8JQ0qOLqOB&sp=sig&url=https://rr2---sn-gxqpgpn-h5ql.googlevideo.com/videoplayback%3Fexpire%3D1671062334%26ei%3D3g6aY-KjF_S3mLAP17axyAQ%26ip%3D147.96.60.89%26id%3Do-AD1kFiAvkqe7zRw26L-hwBFrn-Bs7xBsED8rq-samnFB%26itag%3D271%26source%3Dyoutube%26requiressl%3Dyes%26mh%3Dy8%26mm%3D31%252C29%26mn%3Dsn-gxqpgpn-h5ql%252Csn-h5q7knez%26ms%3Dau%252Crdu%26mv%3Dm%26mvi%3D2%26pl%3D17%26gcr%3Des%26initcwndbps%3D472500%26spc%3DzIddbDvRWL2_HbO6DTNEdJfV3RD7IIs%26vprv%3D1%26mime%3Dvideo%252Fwebm%26ns%3DuT9t_HeTiPW76ogbpK8tq1sK%26gir%3Dyes%26clen%3D164438143%26dur%3D158.916%26lmt%3D1660183629244677%26mt%3D1671040424%26fvip%3D3%26keepalive%3Dyes%26fexp%3D24001373%252C24007246%26c%3DWEB_REMIX%26txp%3D453C434%26n%3DXtY3CXtLKAMt0E%26sparams%3Dexpire%252Cei%252Cip%252Cid%252Citag%252Csource%252Crequiressl%252Cgcr%252Cspc%252Cvprv%252Cmime%252Cns%252Cgir%252Cclen%252Cdur%252Clmt%26lsparams%3Dmh%252Cmm%252Cmn%252Cms%252Cmv%252Cmvi%252Cpl%252Cinitcwndbps%26lsig%3DAG3C_xAwRgIhAOKskOok7EaJeHej7ij26DX1MR2hvtS9fnPGmWBwHVwrAiEAyS9VZrYv6Es66v2W66rGF_TsCBESVRRp8G9Tfg5O5e0%253D'},
#    {'itag': 137,
#     'mimeType': 'video/mp4; codecs="avc1.640028"',
#     'bitrate': 4361473,
#     'width': 1920,
#     'height': 1080,
#     'initRange': {'start': '0', 'end': '741'},
#     'indexRange': {'start': '742', 'end': '1121'},
#     'lastModified': '1660175585700594',
#     'contentLength': '80582210',
#     'quality': 'hd1080',
#     'fps': 24,
#     'qualityLabel': '1080p',
#     'projectionType': 'RECTANGULAR',
#     'averageBitrate': 4056593,
#     'approxDurationMs': '158916',
#     'signatureCipher': 's=ppziQUptkLhjPx_Zhm6ZE1w02S_3bV4GU-2IbYzrwsplFICw65yAVthxNmBgn_rIGZ7OeAMd_yW9DVGrLMBAlv4nnMgIARw8JQ0qO9qO0&sp=sig&url=https://rr2---sn-gxqpgpn-h5ql.googlevideo.com/videoplayback%3Fexpire%3D1671062334%26ei%3D3g6aY-KjF_S3mLAP17axyAQ%26ip%3D147.96.60.89%26id%3Do-AD1kFiAvkqe7zRw26L-hwBFrn-Bs7xBsED8rq-samnFB%26itag%3D137%26source%3Dyoutube%26requiressl%3Dyes%26mh%3Dy8%26mm%3D31%252C29%26mn%3Dsn-gxqpgpn-h5ql%252Csn-h5q7knez%26ms%3Dau%252Crdu%26mv%3Dm%26mvi%3D2%26pl%3D17%26gcr%3Des%26initcwndbps%3D472500%26spc%3DzIddbDvRWL2_HbO6DTNEdJfV3RD7IIs%26vprv%3D1%26mime%3Dvideo%252Fmp4%26ns%3DuT9t_HeTiPW76ogbpK8tq1sK%26gir%3Dyes%26clen%3D80582210%26dur%3D158.916%26lmt%3D1660175585700594%26mt%3D1671040424%26fvip%3D3%26keepalive%3Dyes%26fexp%3D24001373%252C24007246%26c%3DWEB_REMIX%26txp%3D453C434%26n%3DXtY3CXtLKAMt0E%26sparams%3Dexpire%252Cei%252Cip%252Cid%252Citag%252Csource%252Crequiressl%252Cgcr%252Cspc%252Cvprv%252Cmime%252Cns%252Cgir%252Cclen%252Cdur%252Clmt%26lsparams%3Dmh%252Cmm%252Cmn%252Cms%252Cmv%252Cmvi%252Cpl%252Cinitcwndbps%26lsig%3DAG3C_xAwRQIhANcyBds1QmlhUHVaYjMpmevn_xhwIc-bjmO-RI3UOX45AiBdflGnlXfhwzfvw7T7rTl9ywoQCjys72tKXJJ6YZdn7w%253D%253D'},
#    {'itag': 248,
#     'mimeType': 'video/webm; codecs="vp9"',
#     'bitrate': 3151037,
#     'width': 1920,
#     'height': 1080,
#     'initRange': {'start': '0', 'end': '219'},
#     'indexRange': {'start': '220', 'end': '719'},
#     'lastModified': '1660175714117218',
#     'contentLength': '34227119',
#     'quality': 'hd1080',
#     'fps': 24,
#     'qualityLabel': '1080p',
#     'projectionType': 'RECTANGULAR',
#     'averageBitrate': 1723029,
#     'colorInfo': {'primaries': 'COLOR_PRIMARIES_BT709',
#      'transferCharacteristics': 'COLOR_TRANSFER_CHARACTERISTICS_BT709',
#      'matrixCoefficients': 'COLOR_MATRIX_COEFFICIENTS_BT709'},
#     'approxDurationMs': '158916',
#     'signatureCipher': 's=bb%3D%3DQpBzI5c3namr7THkSTkltA9hyT4BESBV6a%3DqPI9KZgoBiAZ-C3gUvhiCz76IpVB8PUxEbA17qV2B435Oh57O0g8eNAhIQRw8JQ0qOBqO3&sp=sig&url=https://rr2---sn-gxqpgpn-h5ql.googlevideo.com/videoplayback%3Fexpire%3D1671062334%26ei%3D3g6aY-KjF_S3mLAP17axyAQ%26ip%3D147.96.60.89%26id%3Do-AD1kFiAvkqe7zRw26L-hwBFrn-Bs7xBsED8rq-samnFB%26itag%3D248%26source%3Dyoutube%26requiressl%3Dyes%26mh%3Dy8%26mm%3D31%252C29%26mn%3Dsn-gxqpgpn-h5ql%252Csn-h5q7knez%26ms%3Dau%252Crdu%26mv%3Dm%26mvi%3D2%26pl%3D17%26gcr%3Des%26initcwndbps%3D472500%26spc%3DzIddbDvRWL2_HbO6DTNEdJfV3RD7IIs%26vprv%3D1%26mime%3Dvideo%252Fwebm%26ns%3DuT9t_HeTiPW76ogbpK8tq1sK%26gir%3Dyes%26clen%3D34227119%26dur%3D158.916%26lmt%3D1660175714117218%26mt%3D1671040424%26fvip%3D3%26keepalive%3Dyes%26fexp%3D24001373%252C24007246%26c%3DWEB_REMIX%26txp%3D453E434%26n%3DXtY3CXtLKAMt0E%26sparams%3Dexpire%252Cei%252Cip%252Cid%252Citag%252Csource%252Crequiressl%252Cgcr%252Cspc%252Cvprv%252Cmime%252Cns%252Cgir%252Cclen%252Cdur%252Clmt%26lsparams%3Dmh%252Cmm%252Cmn%252Cms%252Cmv%252Cmvi%252Cpl%252Cinitcwndbps%26lsig%3DAG3C_xAwRgIhAPV3e-Ompspnfm7PPi_2fUH9kBLIN9IjAtqurrUirbkvAiEAxaAIwb3cujtC2Lhtel6UdGsKbxo0WMWencUpDp1yh38%253D'},
#    {'itag': 136,
#     'mimeType': 'video/mp4; codecs="avc1.4d401f"',
#     'bitrate': 1568787,
#     'width': 1280,
#     'height': 720,
#     'initRange': {'start': '0', 'end': '739'},
#     'indexRange': {'start': '740', 'end': '1119'},
#     'lastModified': '1660175621166403',
#     'contentLength': '23054275',
#     'quality': 'hd720',
#     'fps': 24,
#     'qualityLabel': '720p',
#     'projectionType': 'RECTANGULAR',
#     'averageBitrate': 1160576,
#     'approxDurationMs': '158916',
#     'signatureCipher': 's=XX%3D%3DgI-RjnJOmUx2CYJxGAiuxCgLToUlU7IO_N%3DGOfQm0u7BiAL5vBfAy2JwXbxEyLqdoyMpHA4qFLJ7VsF2eApjrmLnOAhIQRw8JQ0qO7qO6&sp=sig&url=https://rr2---sn-gxqpgpn-h5ql.googlevideo.com/videoplayback%3Fexpire%3D1671062334%26ei%3D3g6aY-KjF_S3mLAP17axyAQ%26ip%3D147.96.60.89%26id%3Do-AD1kFiAvkqe7zRw26L-hwBFrn-Bs7xBsED8rq-samnFB%26itag%3D136%26source%3Dyoutube%26requiressl%3Dyes%26mh%3Dy8%26mm%3D31%252C29%26mn%3Dsn-gxqpgpn-h5ql%252Csn-h5q7knez%26ms%3Dau%252Crdu%26mv%3Dm%26mvi%3D2%26pl%3D17%26gcr%3Des%26initcwndbps%3D472500%26spc%3DzIddbDvRWL2_HbO6DTNEdJfV3RD7IIs%26vprv%3D1%26mime%3Dvideo%252Fmp4%26ns%3DuT9t_HeTiPW76ogbpK8tq1sK%26gir%3Dyes%26clen%3D23054275%26dur%3D158.916%26lmt%3D1660175621166403%26mt%3D1671040424%26fvip%3D3%26keepalive%3Dyes%26fexp%3D24001373%252C24007246%26c%3DWEB_REMIX%26txp%3D453C434%26n%3DXtY3CXtLKAMt0E%26sparams%3Dexpire%252Cei%252Cip%252Cid%252Citag%252Csource%252Crequiressl%252Cgcr%252Cspc%252Cvprv%252Cmime%252Cns%252Cgir%252Cclen%252Cdur%252Clmt%26lsparams%3Dmh%252Cmm%252Cmn%252Cms%252Cmv%252Cmvi%252Cpl%252Cinitcwndbps%26lsig%3DAG3C_xAwRQIhANVDQ-U5pz0EBVFnxfNNRKL7AG90TZiTAORTuw6OHykhAiBngdRKGHx7QCcO5BMt7rfaEK9sKxJ4_3cbEhECGotrKg%253D%253D'},
#    {'itag': 247,
#     'mimeType': 'video/webm; codecs="vp9"',
#     'bitrate': 1936393,
#     'width': 1280,
#     'height': 720,
#     'initRange': {'start': '0', 'end': '219'},
#     'indexRange': {'start': '220', 'end': '709'},
#     'lastModified': '1660175923165582',
#     'contentLength': '20204365',
#     'quality': 'hd720',
#     'fps': 24,
#     'qualityLabel': '720p',
#     'projectionType': 'RECTANGULAR',
#     'averageBitrate': 1017109,
#     'colorInfo': {'primaries': 'COLOR_PRIMARIES_BT709',
#      'transferCharacteristics': 'COLOR_TRANSFER_CHARACTERISTICS_BT709',
#      'matrixCoefficients': 'COLOR_MATRIX_COEFFICIENTS_BT709'},
#     'approxDurationMs': '158916',
#     'signatureCipher': 's=55btd8rS-kINADVhveq06S2jzCydNdYAC4pBwNb3tTVDCICsdgttLI-uB5caBn1ia3bWgAtDjKJoQTh7G-4oapNo9egIARw8JQ0qOoqOy&sp=sig&url=https://rr2---sn-gxqpgpn-h5ql.googlevideo.com/videoplayback%3Fexpire%3D1671062334%26ei%3D3g6aY-KjF_S3mLAP17axyAQ%26ip%3D147.96.60.89%26id%3Do-AD1kFiAvkqe7zRw26L-hwBFrn-Bs7xBsED8rq-samnFB%26itag%3D247%26source%3Dyoutube%26requiressl%3Dyes%26mh%3Dy8%26mm%3D31%252C29%26mn%3Dsn-gxqpgpn-h5ql%252Csn-h5q7knez%26ms%3Dau%252Crdu%26mv%3Dm%26mvi%3D2%26pl%3D17%26gcr%3Des%26initcwndbps%3D472500%26spc%3DzIddbDvRWL2_HbO6DTNEdJfV3RD7IIs%26vprv%3D1%26mime%3Dvideo%252Fwebm%26ns%3DuT9t_HeTiPW76ogbpK8tq1sK%26gir%3Dyes%26clen%3D20204365%26dur%3D158.916%26lmt%3D1660175923165582%26mt%3D1671040424%26fvip%3D3%26keepalive%3Dyes%26fexp%3D24001373%252C24007246%26c%3DWEB_REMIX%26txp%3D453E434%26n%3DXtY3CXtLKAMt0E%26sparams%3Dexpire%252Cei%252Cip%252Cid%252Citag%252Csource%252Crequiressl%252Cgcr%252Cspc%252Cvprv%252Cmime%252Cns%252Cgir%252Cclen%252Cdur%252Clmt%26lsparams%3Dmh%252Cmm%252Cmn%252Cms%252Cmv%252Cmvi%252Cpl%252Cinitcwndbps%26lsig%3DAG3C_xAwRAIgRdiBhuu4PL8ouJgFEwcEiH0_ZvSKoV1eKSr0gaOdaakCIEwlIdosXyzw5gVWF4icyo9cnMXiTcd5s5GZNEobHXht'},
#    {'itag': 135,
#     'mimeType': 'video/mp4; codecs="avc1.4d401e"',
#     'bitrate': 1129994,
#     'width': 854,
#     'height': 480,
#     'initRange': {'start': '0', 'end': '740'},
#     'indexRange': {'start': '741', 'end': '1120'},
#     'lastModified': '1660175621332235',
#     'contentLength': '15792064',
#     'quality': 'large',
#     'fps': 24,
#     'qualityLabel': '480p',
#     'projectionType': 'RECTANGULAR',
#     'averageBitrate': 794989,
#     'approxDurationMs': '158916',
#     'signatureCipher': 's=SS4Z4ZnKTfPH4oFFekDBZ4HOAwW5B-OL3oL4dY4oEswxAIC8a5is9Kh_x7pBhu4fpiMY8AyoMx1EMPoBEinldDjMkdgIARw8JQ0qOEqOM&sp=sig&url=https://rr2---sn-gxqpgpn-h5ql.googlevideo.com/videoplayback%3Fexpire%3D1671062334%26ei%3D3g6aY-KjF_S3mLAP17axyAQ%26ip%3D147.96.60.89%26id%3Do-AD1kFiAvkqe7zRw26L-hwBFrn-Bs7xBsED8rq-samnFB%26itag%3D135%26source%3Dyoutube%26requiressl%3Dyes%26mh%3Dy8%26mm%3D31%252C29%26mn%3Dsn-gxqpgpn-h5ql%252Csn-h5q7knez%26ms%3Dau%252Crdu%26mv%3Dm%26mvi%3D2%26pl%3D17%26gcr%3Des%26initcwndbps%3D472500%26spc%3DzIddbDvRWL2_HbO6DTNEdJfV3RD7IIs%26vprv%3D1%26mime%3Dvideo%252Fmp4%26ns%3DuT9t_HeTiPW76ogbpK8tq1sK%26gir%3Dyes%26clen%3D15792064%26dur%3D158.916%26lmt%3D1660175621332235%26mt%3D1671040424%26fvip%3D3%26keepalive%3Dyes%26fexp%3D24001373%252C24007246%26c%3DWEB_REMIX%26txp%3D453C434%26n%3DXtY3CXtLKAMt0E%26sparams%3Dexpire%252Cei%252Cip%252Cid%252Citag%252Csource%252Crequiressl%252Cgcr%252Cspc%252Cvprv%252Cmime%252Cns%252Cgir%252Cclen%252Cdur%252Clmt%26lsparams%3Dmh%252Cmm%252Cmn%252Cms%252Cmv%252Cmvi%252Cpl%252Cinitcwndbps%26lsig%3DAG3C_xAwRQIhAPFKAY9nqDfCh5e6fMjewH1_q39eEn7MkJRC1zOG8OlxAiA5WV8YwqQineapqpmUj3ZoxhDYck9QBaCVnq526xNlSA%253D%253D'},
#    {'itag': 244,
#     'mimeType': 'video/webm; codecs="vp9"',
#     'bitrate': 980440,
#     'width': 854,
#     'height': 480,
#     'initRange': {'start': '0', 'end': '219'},
#     'indexRange': {'start': '220', 'end': '704'},
#     'lastModified': '1660175923010048',
#     'contentLength': '10229922',
#     'quality': 'large',
#     'fps': 24,
#     'qualityLabel': '480p',
#     'projectionType': 'RECTANGULAR',
#     'averageBitrate': 514985,
#     'colorInfo': {'primaries': 'COLOR_PRIMARIES_BT709',
#      'transferCharacteristics': 'COLOR_TRANSFER_CHARACTERISTICS_BT709',
#      'matrixCoefficients': 'COLOR_MATRIX_COEFFICIENTS_BT709'},
#     'approxDurationMs': '158916',
#     'signatureCipher': 's=pp%3D%3DQvQiDxu6w1vtUq-naBUaxshTfvQmKUmcM9%3D9PVAdwu8BiAKgvbZawdP8DcQhOk-nUtZBbAo_LFENomeErULch1qoNAhIQRw8JQ0qONqOo&sp=sig&url=https://rr2---sn-gxqpgpn-h5ql.googlevideo.com/videoplayback%3Fexpire%3D1671062334%26ei%3D3g6aY-KjF_S3mLAP17axyAQ%26ip%3D147.96.60.89%26id%3Do-AD1kFiAvkqe7zRw26L-hwBFrn-Bs7xBsED8rq-samnFB%26itag%3D244%26source%3Dyoutube%26requiressl%3Dyes%26mh%3Dy8%26mm%3D31%252C29%26mn%3Dsn-gxqpgpn-h5ql%252Csn-h5q7knez%26ms%3Dau%252Crdu%26mv%3Dm%26mvi%3D2%26pl%3D17%26gcr%3Des%26initcwndbps%3D472500%26spc%3DzIddbDvRWL2_HbO6DTNEdJfV3RD7IIs%26vprv%3D1%26mime%3Dvideo%252Fwebm%26ns%3DuT9t_HeTiPW76ogbpK8tq1sK%26gir%3Dyes%26clen%3D10229922%26dur%3D158.916%26lmt%3D1660175923010048%26mt%3D1671040424%26fvip%3D3%26keepalive%3Dyes%26fexp%3D24001373%252C24007246%26c%3DWEB_REMIX%26txp%3D453E434%26n%3DXtY3CXtLKAMt0E%26sparams%3Dexpire%252Cei%252Cip%252Cid%252Citag%252Csource%252Crequiressl%252Cgcr%252Cspc%252Cvprv%252Cmime%252Cns%252Cgir%252Cclen%252Cdur%252Clmt%26lsparams%3Dmh%252Cmm%252Cmn%252Cms%252Cmv%252Cmvi%252Cpl%252Cinitcwndbps%26lsig%3DAG3C_xAwRQIhAPyV5Nq8PM4ND33i_GoSxbpw6y4Vt_LQhS5tGgeclx2mAiB9ZQn82cNXKSekN5y0g9hBvMpvkRhBw483kVfrCmcmhQ%253D%253D'},
#    {'itag': 134,
#     'mimeType': 'video/mp4; codecs="avc1.4d401e"',
#     'bitrate': 632933,
#     'width': 640,
#     'height': 360,
#     'initRange': {'start': '0', 'end': '740'},
#     'indexRange': {'start': '741', 'end': '1120'},
#     'lastModified': '1660175621332592',
#     'contentLength': '10210750',
#     'quality': 'medium',
#     'fps': 24,
#     'qualityLabel': '360p',
#     'projectionType': 'RECTANGULAR',
#     'averageBitrate': 514019,
#     'highReplication': True,
#     'approxDurationMs': '158916',
#     'signatureCipher': 's=FF0DOFJSpB3sMAH2hkxw3cW29fPyVpms3AdvFj0xoZ29HICkKvQiYMVS6HKwOqTH53uF1Av3RNXKTx9GaTPDSm6yaQgIARw8JQ0qOKqOW&sp=sig&url=https://rr2---sn-gxqpgpn-h5ql.googlevideo.com/videoplayback%3Fexpire%3D1671062334%26ei%3D3g6aY-KjF_S3mLAP17axyAQ%26ip%3D147.96.60.89%26id%3Do-AD1kFiAvkqe7zRw26L-hwBFrn-Bs7xBsED8rq-samnFB%26itag%3D134%26source%3Dyoutube%26requiressl%3Dyes%26mh%3Dy8%26mm%3D31%252C29%26mn%3Dsn-gxqpgpn-h5ql%252Csn-h5q7knez%26ms%3Dau%252Crdu%26mv%3Dm%26mvi%3D2%26pl%3D17%26gcr%3Des%26initcwndbps%3D472500%26spc%3DzIddbDvRWL2_HbO6DTNEdJfV3RD7IIs%26vprv%3D1%26mime%3Dvideo%252Fmp4%26ns%3DuT9t_HeTiPW76ogbpK8tq1sK%26gir%3Dyes%26clen%3D10210750%26dur%3D158.916%26lmt%3D1660175621332592%26mt%3D1671040424%26fvip%3D3%26keepalive%3Dyes%26fexp%3D24001373%252C24007246%26c%3DWEB_REMIX%26txp%3D453C434%26n%3DXtY3CXtLKAMt0E%26sparams%3Dexpire%252Cei%252Cip%252Cid%252Citag%252Csource%252Crequiressl%252Cgcr%252Cspc%252Cvprv%252Cmime%252Cns%252Cgir%252Cclen%252Cdur%252Clmt%26lsparams%3Dmh%252Cmm%252Cmn%252Cms%252Cmv%252Cmvi%252Cpl%252Cinitcwndbps%26lsig%3DAG3C_xAwRQIhAIxwPTvYxPeThWkg2Yb2PVVexYiC-H1L2OQ0KmLJYdnqAiAY4U1BsF_dSw8k_R4lkc7qs0BX3u7x8Oci-rI0sh3duA%253D%253D'},
#    {'itag': 243,
#     'mimeType': 'video/webm; codecs="vp9"',
#     'bitrate': 497954,
#     'width': 640,
#     'height': 360,
#     'initRange': {'start': '0', 'end': '219'},
#     'indexRange': {'start': '220', 'end': '704'},
#     'lastModified': '1660175922830959',
#     'contentLength': '6866884',
#     'quality': 'medium',
#     'fps': 24,
#     'qualityLabel': '360p',
#     'projectionType': 'RECTANGULAR',
#     'averageBitrate': 345686,
#     'colorInfo': {'primaries': 'COLOR_PRIMARIES_BT709',
#      'transferCharacteristics': 'COLOR_TRANSFER_CHARACTERISTICS_BT709',
#      'matrixCoefficients': 'COLOR_MATRIX_COEFFICIENTS_BT709'},
#     'approxDurationMs': '158916',
#     'signatureCipher': 's=ooka9Ls4Gsxg_BrOwtRKvTHyG_AdkxaMacO2sxkTFcrzEIC4FktLjvlRpz7gaBzR7LC5GAuAHQGJEMGfil-MZMKIKegIARw8JQ0qOJqOD&sp=sig&url=https://rr2---sn-gxqpgpn-h5ql.googlevideo.com/videoplayback%3Fexpire%3D1671062334%26ei%3D3g6aY-KjF_S3mLAP17axyAQ%26ip%3D147.96.60.89%26id%3Do-AD1kFiAvkqe7zRw26L-hwBFrn-Bs7xBsED8rq-samnFB%26itag%3D243%26source%3Dyoutube%26requiressl%3Dyes%26mh%3Dy8%26mm%3D31%252C29%26mn%3Dsn-gxqpgpn-h5ql%252Csn-h5q7knez%26ms%3Dau%252Crdu%26mv%3Dm%26mvi%3D2%26pl%3D17%26gcr%3Des%26initcwndbps%3D472500%26spc%3DzIddbDvRWL2_HbO6DTNEdJfV3RD7IIs%26vprv%3D1%26mime%3Dvideo%252Fwebm%26ns%3DuT9t_HeTiPW76ogbpK8tq1sK%26gir%3Dyes%26clen%3D6866884%26dur%3D158.916%26lmt%3D1660175922830959%26mt%3D1671040424%26fvip%3D3%26keepalive%3Dyes%26fexp%3D24001373%252C24007246%26c%3DWEB_REMIX%26txp%3D453E434%26n%3DXtY3CXtLKAMt0E%26sparams%3Dexpire%252Cei%252Cip%252Cid%252Citag%252Csource%252Crequiressl%252Cgcr%252Cspc%252Cvprv%252Cmime%252Cns%252Cgir%252Cclen%252Cdur%252Clmt%26lsparams%3Dmh%252Cmm%252Cmn%252Cms%252Cmv%252Cmvi%252Cpl%252Cinitcwndbps%26lsig%3DAG3C_xAwRQIgM1CsfEfFZliTGM6nk9m8eIgB9j4PPqqiqVwaPJ_Tt8ACIQDlmlBNYb0cLGbsFTIiN9XncRjWNKrdjSZxTG7gUsXa0g%253D%253D'},
#    {'itag': 133,
#     'mimeType': 'video/mp4; codecs="avc1.4d4015"',
#     'bitrate': 245266,
#     'width': 426,
#     'height': 240,
#     'initRange': {'start': '0', 'end': '739'},
#     'indexRange': {'start': '740', 'end': '1119'},
#     'lastModified': '1660175621458939',
#     'contentLength': '4656413',
#     'quality': 'small',
#     'fps': 24,
#     'qualityLabel': '240p',
#     'projectionType': 'RECTANGULAR',
#     'averageBitrate': 234408,
#     'approxDurationMs': '158916',
#     'signatureCipher': 's=mm%3D%3DAVUc0pTQVfgP6EbtSTkMjranPrcMnRpACp%3DqBnPZoYnBiAxRUEjcYOrm9Yn0tOPHV7rn9AunkCm04o7PCmllHnhlNAhIQRw8JQ0qO0qOW&sp=sig&url=https://rr2---sn-gxqpgpn-h5ql.googlevideo.com/videoplayback%3Fexpire%3D1671062334%26ei%3D3g6aY-KjF_S3mLAP17axyAQ%26ip%3D147.96.60.89%26id%3Do-AD1kFiAvkqe7zRw26L-hwBFrn-Bs7xBsED8rq-samnFB%26itag%3D133%26source%3Dyoutube%26requiressl%3Dyes%26mh%3Dy8%26mm%3D31%252C29%26mn%3Dsn-gxqpgpn-h5ql%252Csn-h5q7knez%26ms%3Dau%252Crdu%26mv%3Dm%26mvi%3D2%26pl%3D17%26gcr%3Des%26initcwndbps%3D472500%26spc%3DzIddbDvRWL2_HbO6DTNEdJfV3RD7IIs%26vprv%3D1%26mime%3Dvideo%252Fmp4%26ns%3DuT9t_HeTiPW76ogbpK8tq1sK%26gir%3Dyes%26clen%3D4656413%26dur%3D158.916%26lmt%3D1660175621458939%26mt%3D1671040424%26fvip%3D3%26keepalive%3Dyes%26fexp%3D24001373%252C24007246%26c%3DWEB_REMIX%26txp%3D453C434%26n%3DXtY3CXtLKAMt0E%26sparams%3Dexpire%252Cei%252Cip%252Cid%252Citag%252Csource%252Crequiressl%252Cgcr%252Cspc%252Cvprv%252Cmime%252Cns%252Cgir%252Cclen%252Cdur%252Clmt%26lsparams%3Dmh%252Cmm%252Cmn%252Cms%252Cmv%252Cmvi%252Cpl%252Cinitcwndbps%26lsig%3DAG3C_xAwRQIgGqUPw4HEK5jx6NiUEkKeSBdbtK4jwPcT4JvBhKEibW0CIQCPP8Ji2B_x0lIsac0NzcikN9OOhx0RbFzAa51fms-UCA%253D%253D'},
#    {'itag': 242,
#     'mimeType': 'video/webm; codecs="vp9"',
#     'bitrate': 229544,
#     'width': 426,
#     'height': 240,
#     'initRange': {'start': '0', 'end': '218'},
#     'indexRange': {'start': '219', 'end': '702'},
#     'lastModified': '1660175922980003',
#     'contentLength': '2850920',
#     'quality': 'small',
#     'fps': 24,
#     'qualityLabel': '240p',
#     'projectionType': 'RECTANGULAR',
#     'averageBitrate': 143518,
#     'colorInfo': {'primaries': 'COLOR_PRIMARIES_BT709',
#      'transferCharacteristics': 'COLOR_TRANSFER_CHARACTERISTICS_BT709',
#      'matrixCoefficients': 'COLOR_MATRIX_COEFFICIENTS_BT709'},
#     'approxDurationMs': '158916',
#     'signatureCipher': 's=KK%3D%3DQ1u_HJ_SlTyDxmCXHhoaI1nJn1hIqPitVr%3DwhRe1EKoDQICEAQ0oKvAtegPpGWD-GN1cNAF486amGE3voJlYATNu1SgIQRw8JQ0qOmqOj&sp=sig&url=https://rr2---sn-gxqpgpn-h5ql.googlevideo.com/videoplayback%3Fexpire%3D1671062334%26ei%3D3g6aY-KjF_S3mLAP17axyAQ%26ip%3D147.96.60.89%26id%3Do-AD1kFiAvkqe7zRw26L-hwBFrn-Bs7xBsED8rq-samnFB%26itag%3D242%26source%3Dyoutube%26requiressl%3Dyes%26mh%3Dy8%26mm%3D31%252C29%26mn%3Dsn-gxqpgpn-h5ql%252Csn-h5q7knez%26ms%3Dau%252Crdu%26mv%3Dm%26mvi%3D2%26pl%3D17%26gcr%3Des%26initcwndbps%3D472500%26spc%3DzIddbDvRWL2_HbO6DTNEdJfV3RD7IIs%26vprv%3D1%26mime%3Dvideo%252Fwebm%26ns%3DuT9t_HeTiPW76ogbpK8tq1sK%26gir%3Dyes%26clen%3D2850920%26dur%3D158.916%26lmt%3D1660175922980003%26mt%3D1671040424%26fvip%3D3%26keepalive%3Dyes%26fexp%3D24001373%252C24007246%26c%3DWEB_REMIX%26txp%3D453E434%26n%3DXtY3CXtLKAMt0E%26sparams%3Dexpire%252Cei%252Cip%252Cid%252Citag%252Csource%252Crequiressl%252Cgcr%252Cspc%252Cvprv%252Cmime%252Cns%252Cgir%252Cclen%252Cdur%252Clmt%26lsparams%3Dmh%252Cmm%252Cmn%252Cms%252Cmv%252Cmvi%252Cpl%252Cinitcwndbps%26lsig%3DAG3C_xAwRQIgbbKACgw8skT1fL6TjUOuqmxTY4fINPkM-koN7rXD0JYCIQDzhvW-VLFEWq1y8_jY2I-8ZCJwT338cOv0g4yq2pXyMA%253D%253D'},
#    {'itag': 160,
#     'mimeType': 'video/mp4; codecs="avc1.4d400c"',
#     'bitrate': 110744,
#     'width': 256,
#     'height': 144,
#     'initRange': {'start': '0', 'end': '738'},
#     'indexRange': {'start': '739', 'end': '1118'},
#     'lastModified': '1660175621181999',
#     'contentLength': '2105504',
#     'quality': 'tiny',
#     'fps': 24,
#     'qualityLabel': '144p',
#     'projectionType': 'RECTANGULAR',
#     'averageBitrate': 105993,
#     'approxDurationMs': '158916',
#     'signatureCipher': 's=zz%3DoLFPe0Vmi0oc6Nb2wyIjlGrQ2zFx7cqnGHT%3D48DQer1AEiAo4jiqt403PDGwVC2FS26eMAABHYDLz2QxerNYyngPIMAhIgRw8JQ0qOzqOF&sp=sig&url=https://rr2---sn-gxqpgpn-h5ql.googlevideo.com/videoplayback%3Fexpire%3D1671062334%26ei%3D3g6aY-KjF_S3mLAP17axyAQ%26ip%3D147.96.60.89%26id%3Do-AD1kFiAvkqe7zRw26L-hwBFrn-Bs7xBsED8rq-samnFB%26itag%3D160%26source%3Dyoutube%26requiressl%3Dyes%26mh%3Dy8%26mm%3D31%252C29%26mn%3Dsn-gxqpgpn-h5ql%252Csn-h5q7knez%26ms%3Dau%252Crdu%26mv%3Dm%26mvi%3D2%26pl%3D17%26gcr%3Des%26initcwndbps%3D472500%26spc%3DzIddbDvRWL2_HbO6DTNEdJfV3RD7IIs%26vprv%3D1%26mime%3Dvideo%252Fmp4%26ns%3DuT9t_HeTiPW76ogbpK8tq1sK%26gir%3Dyes%26clen%3D2105504%26dur%3D158.916%26lmt%3D1660175621181999%26mt%3D1671040424%26fvip%3D3%26keepalive%3Dyes%26fexp%3D24001373%252C24007246%26c%3DWEB_REMIX%26txp%3D453C434%26n%3DXtY3CXtLKAMt0E%26sparams%3Dexpire%252Cei%252Cip%252Cid%252Citag%252Csource%252Crequiressl%252Cgcr%252Cspc%252Cvprv%252Cmime%252Cns%252Cgir%252Cclen%252Cdur%252Clmt%26lsparams%3Dmh%252Cmm%252Cmn%252Cms%252Cmv%252Cmvi%252Cpl%252Cinitcwndbps%26lsig%3DAG3C_xAwRgIhALEcq8FZRMYtZmZ7Vf8JHlAkuYDptqFl8l4fFdbA3s_QAiEAisqUh5v8C6qwSiYlAC0HkGixE37Br4bH_WMYmIDoAcM%253D'},
#    {'itag': 278,
#     'mimeType': 'video/webm; codecs="vp9"',
#     'bitrate': 112192,
#     'width': 256,
#     'height': 144,
#     'initRange': {'start': '0', 'end': '217'},
#     'indexRange': {'start': '218', 'end': '701'},
#     'lastModified': '1660175923376078',
#     'contentLength': '1474074',
#     'quality': 'tiny',
#     'fps': 24,
#     'qualityLabel': '144p',
#     'projectionType': 'RECTANGULAR',
#     'averageBitrate': 74206,
#     'colorInfo': {'primaries': 'COLOR_PRIMARIES_BT709',
#      'transferCharacteristics': 'COLOR_TRANSFER_CHARACTERISTICS_BT709',
#      'matrixCoefficients': 'COLOR_MATRIX_COEFFICIENTS_BT709'},
#     'approxDurationMs': '158916',
#     'signatureCipher': 's=ff%3D%3DwDqBq9jqkk2BMyUip4r0joehlowTStlyjJ%3DtG-DweNFCQICUGKxBnGVZFFu50NRQjdbWLAZFJ4bh2Yr9AFUl7LeZ2DgIQRw8JQ0qOhqOf&sp=sig&url=https://rr2---sn-gxqpgpn-h5ql.googlevideo.com/videoplayback%3Fexpire%3D1671062334%26ei%3D3g6aY-KjF_S3mLAP17axyAQ%26ip%3D147.96.60.89%26id%3Do-AD1kFiAvkqe7zRw26L-hwBFrn-Bs7xBsED8rq-samnFB%26itag%3D278%26source%3Dyoutube%26requiressl%3Dyes%26mh%3Dy8%26mm%3D31%252C29%26mn%3Dsn-gxqpgpn-h5ql%252Csn-h5q7knez%26ms%3Dau%252Crdu%26mv%3Dm%26mvi%3D2%26pl%3D17%26gcr%3Des%26initcwndbps%3D472500%26spc%3DzIddbDvRWL2_HbO6DTNEdJfV3RD7IIs%26vprv%3D1%26mime%3Dvideo%252Fwebm%26ns%3DuT9t_HeTiPW76ogbpK8tq1sK%26gir%3Dyes%26clen%3D1474074%26dur%3D158.916%26lmt%3D1660175923376078%26mt%3D1671040424%26fvip%3D3%26keepalive%3Dyes%26fexp%3D24001373%252C24007246%26c%3DWEB_REMIX%26txp%3D453E434%26n%3DXtY3CXtLKAMt0E%26sparams%3Dexpire%252Cei%252Cip%252Cid%252Citag%252Csource%252Crequiressl%252Cgcr%252Cspc%252Cvprv%252Cmime%252Cns%252Cgir%252Cclen%252Cdur%252Clmt%26lsparams%3Dmh%252Cmm%252Cmn%252Cms%252Cmv%252Cmvi%252Cpl%252Cinitcwndbps%26lsig%3DAG3C_xAwRgIhAKJne1jlXbWxRJ1WDvss0XKYB6D6lMDyyF6-0j1Px3xhAiEA6L52M-QWIYsL7HhrK-rmNgfTDLwtbMBSURnS7ep2vUo%253D'},
#    {'itag': 140,
#     'mimeType': 'audio/mp4; codecs="mp4a.40.2"',
#     'bitrate': 130561,
#     'initRange': {'start': '0', 'end': '631'},
#     'indexRange': {'start': '632', 'end': '855'},
#     'lastModified': '1660173424969987',
#     'contentLength': '2573700',
#     'quality': 'tiny',
#     'projectionType': 'RECTANGULAR',
#     'averageBitrate': 129504,
#     'highReplication': True,
#     'audioQuality': 'AUDIO_QUALITY_MEDIUM',
#     'approxDurationMs': '158987',
#     'audioSampleRate': '44100',
#     'audioChannels': 2,
#     'loudnessDb': -1.982748,
#     'signatureCipher': 's=33%3D%3Dwe1t6KY1KcTBwnbQ_ACeovwZ65dfyte8X4%3DXI64uNEmCQICIUKOcElWmNBeCQmJGa2M9yADdGIiFIErjdPr6fy_nzKgIQRw8JQ0qOFqOu&sp=sig&url=https://rr2---sn-gxqpgpn-h5ql.googlevideo.com/videoplayback%3Fexpire%3D1671062334%26ei%3D3g6aY-KjF_S3mLAP17axyAQ%26ip%3D147.96.60.89%26id%3Do-AD1kFiAvkqe7zRw26L-hwBFrn-Bs7xBsED8rq-samnFB%26itag%3D140%26source%3Dyoutube%26requiressl%3Dyes%26mh%3Dy8%26mm%3D31%252C29%26mn%3Dsn-gxqpgpn-h5ql%252Csn-h5q7knez%26ms%3Dau%252Crdu%26mv%3Dm%26mvi%3D2%26pl%3D17%26gcr%3Des%26initcwndbps%3D472500%26spc%3DzIddbDvRWL2_HbO6DTNEdJfV3RD7IIs%26vprv%3D1%26mime%3Daudio%252Fmp4%26ns%3DuT9t_HeTiPW76ogbpK8tq1sK%26gir%3Dyes%26clen%3D2573700%26dur%3D158.987%26lmt%3D1660173424969987%26mt%3D1671040424%26fvip%3D3%26keepalive%3Dyes%26fexp%3D24001373%252C24007246%26c%3DWEB_REMIX%26txp%3D4532434%26n%3DXtY3CXtLKAMt0E%26sparams%3Dexpire%252Cei%252Cip%252Cid%252Citag%252Csource%252Crequiressl%252Cgcr%252Cspc%252Cvprv%252Cmime%252Cns%252Cgir%252Cclen%252Cdur%252Clmt%26lsparams%3Dmh%252Cmm%252Cmn%252Cms%252Cmv%252Cmvi%252Cpl%252Cinitcwndbps%26lsig%3DAG3C_xAwRgIhAMBtSVk1toU4Cx44qWuhGGxT-5yY6T1lYs1GG-EiQ5svAiEAqALGrMouulrd1B0HZs1-rIzJceiQObkV_oVC2nIIFWk%253D'},
#    {'itag': 249,
#     'mimeType': 'audio/webm; codecs="opus"',
#     'bitrate': 59922,
#     'initRange': {'start': '0', 'end': '265'},
#     'indexRange': {'start': '266', 'end': '534'},
#     'lastModified': '1660173424616296',
#     'contentLength': '1103540',
#     'quality': 'tiny',
#     'projectionType': 'RECTANGULAR',
#     'averageBitrate': 55544,
#     'audioQuality': 'AUDIO_QUALITY_LOW',
#     'approxDurationMs': '158941',
#     'audioSampleRate': '48000',
#     'audioChannels': 2,
#     'loudnessDb': -1.9927473,
#     'signatureCipher': 's=WW%3D%3DQTKdsNKmXMfd6sJnt9pZQWPSYfEQ8YG4Wg%3DolxZLGdsDQICoD4ojuVBSfaODAsnb4Ur-GAhVmQMZj-Q4MdFqUu9OQPgIQRw8JQ0qOZqOW&sp=sig&url=https://rr2---sn-gxqpgpn-h5ql.googlevideo.com/videoplayback%3Fexpire%3D1671062334%26ei%3D3g6aY-KjF_S3mLAP17axyAQ%26ip%3D147.96.60.89%26id%3Do-AD1kFiAvkqe7zRw26L-hwBFrn-Bs7xBsED8rq-samnFB%26itag%3D249%26source%3Dyoutube%26requiressl%3Dyes%26mh%3Dy8%26mm%3D31%252C29%26mn%3Dsn-gxqpgpn-h5ql%252Csn-h5q7knez%26ms%3Dau%252Crdu%26mv%3Dm%26mvi%3D2%26pl%3D17%26gcr%3Des%26initcwndbps%3D472500%26spc%3DzIddbDvRWL2_HbO6DTNEdJfV3RD7IIs%26vprv%3D1%26mime%3Daudio%252Fwebm%26ns%3DuT9t_HeTiPW76ogbpK8tq1sK%26gir%3Dyes%26clen%3D1103540%26dur%3D158.941%26lmt%3D1660173424616296%26mt%3D1671040424%26fvip%3D3%26keepalive%3Dyes%26fexp%3D24001373%252C24007246%26c%3DWEB_REMIX%26txp%3D4532434%26n%3DXtY3CXtLKAMt0E%26sparams%3Dexpire%252Cei%252Cip%252Cid%252Citag%252Csource%252Crequiressl%252Cgcr%252Cspc%252Cvprv%252Cmime%252Cns%252Cgir%252Cclen%252Cdur%252Clmt%26lsparams%3Dmh%252Cmm%252Cmn%252Cms%252Cmv%252Cmvi%252Cpl%252Cinitcwndbps%26lsig%3DAG3C_xAwRQIhAPqsnouOU8r0MYiNOmIl14GrqxymOHjB5sELkLMaQrXAAiATdiNjpT1BCKwLf-MoUz2mU08aK3TMTWkW8LgdJceLoQ%253D%253D'},
#    {'itag': 250,
#     'mimeType': 'audio/webm; codecs="opus"',
#     'bitrate': 77385,
#     'initRange': {'start': '0', 'end': '265'},
#     'indexRange': {'start': '266', 'end': '534'},
#     'lastModified': '1660173424497972',
#     'contentLength': '1435300',
#     'quality': 'tiny',
#     'projectionType': 'RECTANGULAR',
#     'averageBitrate': 72243,
#     'audioQuality': 'AUDIO_QUALITY_LOW',
#     'approxDurationMs': '158941',
#     'audioSampleRate': '48000',
#     'audioChannels': 2,
#     'loudnessDb': -1.9927473,
#     'signatureCipher': 's=--%3D8DcM7UmfxqarLJqP-lS52oEH4n3pGtJ4OL0%3DbUwqy78AEiAPV9CALJn7sVGLHVrl8jTexxAuj6FhJ7rpjolQWcckTKAhIgRw8JQ0qOJqOJ&sp=sig&url=https://rr2---sn-gxqpgpn-h5ql.googlevideo.com/videoplayback%3Fexpire%3D1671062334%26ei%3D3g6aY-KjF_S3mLAP17axyAQ%26ip%3D147.96.60.89%26id%3Do-AD1kFiAvkqe7zRw26L-hwBFrn-Bs7xBsED8rq-samnFB%26itag%3D250%26source%3Dyoutube%26requiressl%3Dyes%26mh%3Dy8%26mm%3D31%252C29%26mn%3Dsn-gxqpgpn-h5ql%252Csn-h5q7knez%26ms%3Dau%252Crdu%26mv%3Dm%26mvi%3D2%26pl%3D17%26gcr%3Des%26initcwndbps%3D472500%26spc%3DzIddbDvRWL2_HbO6DTNEdJfV3RD7IIs%26vprv%3D1%26mime%3Daudio%252Fwebm%26ns%3DuT9t_HeTiPW76ogbpK8tq1sK%26gir%3Dyes%26clen%3D1435300%26dur%3D158.941%26lmt%3D1660173424497972%26mt%3D1671040424%26fvip%3D3%26keepalive%3Dyes%26fexp%3D24001373%252C24007246%26c%3DWEB_REMIX%26txp%3D4532434%26n%3DXtY3CXtLKAMt0E%26sparams%3Dexpire%252Cei%252Cip%252Cid%252Citag%252Csource%252Crequiressl%252Cgcr%252Cspc%252Cvprv%252Cmime%252Cns%252Cgir%252Cclen%252Cdur%252Clmt%26lsparams%3Dmh%252Cmm%252Cmn%252Cms%252Cmv%252Cmvi%252Cpl%252Cinitcwndbps%26lsig%3DAG3C_xAwRAIgUAvqGPyteJXdvqolQkucU-v0SgIfWAnZ2GTnlQEYUDgCIHWFwqQIpyn1YEUD0-WpYH4hMZ8rOe8ACa6kGs9_wQWu'},
#    {'itag': 251,
#     'mimeType': 'audio/webm; codecs="opus"',
#     'bitrate': 147687,
#     'initRange': {'start': '0', 'end': '265'},
#     'indexRange': {'start': '266', 'end': '534'},
#     'lastModified': '1660173424910073',
#     'contentLength': '2775063',
#     'quality': 'tiny',
#     'projectionType': 'RECTANGULAR',
#     'averageBitrate': 139677,
#     'audioQuality': 'AUDIO_QUALITY_MEDIUM',
#     'approxDurationMs': '158941',
#     'audioSampleRate': '48000',
#     'audioChannels': 2,
#     'loudnessDb': -1.9927473,
#     'signatureCipher': 's=XX%3DY0AMJhNzJU8qUJvMMElQOk0r9gYom7MnvIN%3DQ8YBgx8AEiAfRXrMYXPlKtv1Bqo5ADnYYsAhRN2_igaFoHdjgcE2wKAhIgRw8JQ0qOiqOq&sp=sig&url=https://rr2---sn-gxqpgpn-h5ql.googlevideo.com/videoplayback%3Fexpire%3D1671062334%26ei%3D3g6aY-KjF_S3mLAP17axyAQ%26ip%3D147.96.60.89%26id%3Do-AD1kFiAvkqe7zRw26L-hwBFrn-Bs7xBsED8rq-samnFB%26itag%3D251%26source%3Dyoutube%26requiressl%3Dyes%26mh%3Dy8%26mm%3D31%252C29%26mn%3Dsn-gxqpgpn-h5ql%252Csn-h5q7knez%26ms%3Dau%252Crdu%26mv%3Dm%26mvi%3D2%26pl%3D17%26gcr%3Des%26initcwndbps%3D472500%26spc%3DzIddbDvRWL2_HbO6DTNEdJfV3RD7IIs%26vprv%3D1%26mime%3Daudio%252Fwebm%26ns%3DuT9t_HeTiPW76ogbpK8tq1sK%26gir%3Dyes%26clen%3D2775063%26dur%3D158.941%26lmt%3D1660173424910073%26mt%3D1671040424%26fvip%3D3%26keepalive%3Dyes%26fexp%3D24001373%252C24007246%26c%3DWEB_REMIX%26txp%3D4532434%26n%3DXtY3CXtLKAMt0E%26sparams%3Dexpire%252Cei%252Cip%252Cid%252Citag%252Csource%252Crequiressl%252Cgcr%252Cspc%252Cvprv%252Cmime%252Cns%252Cgir%252Cclen%252Cdur%252Clmt%26lsparams%3Dmh%252Cmm%252Cmn%252Cms%252Cmv%252Cmvi%252Cpl%252Cinitcwndbps%26lsig%3DAG3C_xAwRgIhALv7WNwR55EDY0SMvLaWarn8TYKJIrCQ8RU3RywEOCM8AiEAma2ccPqdyj3yTgL6Cjjl5rshB80MiQmdkhjBzd_jwyQ%253D'}]},
#  'videoDetails': {'videoId': '5g2hT4GmAGU',
#   'title': 'DESPECHÁ',
#   'lengthSeconds': '159',
#   'channelId': 'UCy2bCk5KnIfjmWYFHMZcd5w',
#   'isOwnerViewing': False,
#   'isCrawlable': True,
#   'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/5g2hT4GmAGU/sddefault.jpg?sqp=-oaymwEWCJADEOEBIAQqCghqEJQEGHgg6AJIWg&rs=AOn4CLDabOMxAQAEoCKtUOWBF2L3Jo87Pg',
#      'width': 400,
#      'height': 225},
#     {'url': 'https://i.ytimg.com/vi/5g2hT4GmAGU/hq720.jpg?sqp=-oaymwEXCKAGEMIDIAQqCwjVARCqCBh4INgESFo&rs=AOn4CLDu1iU4bVHRfZO1Jk9kGWTcz4sC6A',
#      'width': 800,
#      'height': 450},
#     {'url': 'https://i.ytimg.com/vi/5g2hT4GmAGU/hq720.jpg?sqp=-oaymwEXCNUGEOADIAQqCwjVARCqCBh4INgESFo&rs=AOn4CLDgd-BRDqm6Dl1oBeKs_9gpV7Ji1w',
#      'width': 853,
#      'height': 480}]},
#   'allowRatings': True,
#   'viewCount': '215953779',
#   'author': 'ROSALÍA',
#   'isLowLatencyLiveStream': False,
#   'isPrivate': False,
#   'isUnpluggedCorpus': False,
#   'latencyClass': 'MDE_STREAM_OPTIMIZATIONS_RENDERER_LATENCY_NORMAL',
#   'musicVideoType': 'MUSIC_VIDEO_TYPE_OMV',
#   'isLiveContent': False},
#  'microformat': {'microformatDataRenderer': {'urlCanonical': 'https://music.youtube.com/watch?v=5g2hT4GmAGU',
#    'title': 'ROSALÍA - DESPECHÁ (Official Video) - YouTube Music',
#    'description': 'Official video for “DESPECHÁ” by ROSALÍA. Listen & Download “DESPECHÁ” out now: https://rosalia.lnk.to/DESPECHA Shop the official store: https://rosalia.ln...',
#    'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/5g2hT4GmAGU/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}]},
#    'siteName': 'YouTube Music',
#    'appName': 'YouTube Music',
#    'androidPackage': 'com.google.android.apps.youtube.music',
#    'iosAppStoreId': '1017492454',
#    'iosAppArguments': 'https://music.youtube.com/watch?v=5g2hT4GmAGU',
#    'ogType': 'video.other',
#    'urlApplinksIos': 'vnd.youtube.music://music.youtube.com/watch?v=5g2hT4GmAGU&feature=applinks',
#    'urlApplinksAndroid': 'vnd.youtube.music://music.youtube.com/watch?v=5g2hT4GmAGU&feature=applinks',
#    'urlTwitterIos': 'vnd.youtube.music://music.youtube.com/watch?v=5g2hT4GmAGU&feature=twitter-deep-link',
#    'urlTwitterAndroid': 'vnd.youtube.music://music.youtube.com/watch?v=5g2hT4GmAGU&feature=twitter-deep-link',
#    'twitterCardType': 'player',
#    'twitterSiteHandle': '@YouTubeMusic',
#    'schemaDotOrgType': 'http://schema.org/VideoObject',
#    'noindex': False,
#    'unlisted': False,
#    'paid': False,
#    'familySafe': True,
#    'tags': ['rosalia despecha',
#     'despecho',
#     'baby no me llames',
#     'bizcochito',
#     'motomami',
#     'saoko',
#     'candy',
#     'la fama',
#     'tiktok',
#     'summer songs',
#     'song of the summer',
#     'Columbia',
#     'DESPECHÁ',
#     'Latin Pop',
#     'ROSALÍA'],
#    'availableCountries': ['AD',
#     'AE',
#     'AF',
#     'AG',
#     'AI',
#     'AL',
#     'AM',
#     'AO',
#     'AQ',
#     'AR',
#     'AS',
#     'AT',
#     'AU',
#     'AW',
#     'AX',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BL',
#     'BM',
#     'BN',
#     'BO',
#     'BQ',
#     'BR',
#     'BS',
#     'BT',
#     'BV',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CC',
#     'CD',
#     'CF',
#     'CG',
#     'CH',
#     'CI',
#     'CK',
#     'CL',
#     'CM',
#     'CN',
#     'CO',
#     'CR',
#     'CU',
#     'CV',
#     'CW',
#     'CX',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'EH',
#     'ER',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FK',
#     'FM',
#     'FO',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GF',
#     'GG',
#     'GH',
#     'GI',
#     'GL',
#     'GM',
#     'GN',
#     'GP',
#     'GQ',
#     'GR',
#     'GS',
#     'GT',
#     'GU',
#     'GW',
#     'GY',
#     'HK',
#     'HM',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IM',
#     'IN',
#     'IO',
#     'IQ',
#     'IR',
#     'IS',
#     'IT',
#     'JE',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KP',
#     'KR',
#     'KW',
#     'KY',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MF',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MM',
#     'MN',
#     'MO',
#     'MP',
#     'MQ',
#     'MR',
#     'MS',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NC',
#     'NE',
#     'NF',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NU',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PF',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PM',
#     'PN',
#     'PR',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RE',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SD',
#     'SE',
#     'SG',
#     'SH',
#     'SI',
#     'SJ',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SO',
#     'SR',
#     'SS',
#     'ST',
#     'SV',
#     'SX',
#     'SY',
#     'SZ',
#     'TC',
#     'TD',
#     'TF',
#     'TG',
#     'TH',
#     'TJ',
#     'TK',
#     'TL',
#     'TM',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'UM',
#     'US',
#     'UY',
#     'UZ',
#     'VA',
#     'VC',
#     'VE',
#     'VG',
#     'VI',
#     'VN',
#     'VU',
#     'WF',
#     'WS',
#     'YE',
#     'YT',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'pageOwnerDetails': {'name': 'RosaliaVEVO',
#     'externalChannelId': 'UCy2bCk5KnIfjmWYFHMZcd5w',
#     'youtubeProfileUrl': 'http://www.youtube.com/channel/UCy2bCk5KnIfjmWYFHMZcd5w'},
#    'videoDetails': {'externalVideoId': '5g2hT4GmAGU',
#     'durationSeconds': '159',
#     'durationIso8601': 'PT2M39S'},
#    'linkAlternates': [{'hrefUrl': 'android-app://com.google.android.youtube/http/youtube.com/watch?v=5g2hT4GmAGU'},
#     {'hrefUrl': 'ios-app://544007664/http/youtube.com/watch?v=5g2hT4GmAGU'},
#     {'hrefUrl': 'https://www.youtube.com/oembed?format=json&url=https%3A%2F%2Fmusic.youtube.com%2Fwatch%3Fv%3D5g2hT4GmAGU',
#      'title': 'ROSALÍA - DESPECHÁ (Official Video)',
#      'alternateType': 'application/json+oembed'},
#     {'hrefUrl': 'https://www.youtube.com/oembed?format=xml&url=https%3A%2F%2Fmusic.youtube.com%2Fwatch%3Fv%3D5g2hT4GmAGU',
#      'title': 'ROSALÍA - DESPECHÁ (Official Video)',
#      'alternateType': 'text/xml+oembed'}],
#    'viewCount': '215953779',
#    'publishDate': '2022-08-10',
#    'category': 'Music',
#    'uploadDate': '2022-08-10'}}}

# %% [markdown]
# A continuación empezamos cargando un array con todos los artistas que aparecen en el array de playlist. Recorreremos el array de playlist y extraeremos los datos de dichas playlists con las funciones de la appi ya mencionadas. Probamos a meter los diccionarios que nos da la funcion
# "get_playlist" en un array llamado 'artistas' para empezar a jugar con ello.
# Nos dimos cuenta que filtrando por clave/valor del diccionario se podia ver muchos datos. En este caso filtramos por "tracks" donde nos enseña todas las canciones de las playlist con informacion relevante de ellas. Con esto conseguimos informacion de los artistas que participan en esa canción. Esta información la metemos en el array de artistas para dividir dos diccionarios: diccionario de solos (en los que solo participa un artista )y diccionario de colaboraciones (en el que participa más de uno)

# %% [markdown]
#
#
# ### Array de playlist
# * **BIZARRAP SESSIONS**  RDCLAK5uy_mEXMsobutX4itJVd6YaCodxMgUV-mMtNo
#
# * **TOP 100**   PL4fGSI1pDJn4jhQB4kb9M36dvVmJQPt4T

# %%
yt = YTMusic()
playlist=['RDCLAK5uy_mEXMsobutX4itJVd6YaCodxMgUV-mMtNo','PL4fGSI1pDJn4jhQB4kb9M36dvVmJQPt4T']

artistas = []
diccSolo= {}
diccSolo.clear()
colabos=[]

infoPlayList = []
for p in playlist:
     infoPlayList.append(yt.get_playlist(p))
     
#para rellenar artistas
for r in infoPlayList:
     for a in r['tracks']:
      artistas.append(a['artists'])

#for r in searchPlay['tracks']:
#     artistas.append(r['artists'])

for a in artistas:#cargamos el diccionario con los artistas que van a cantar solos
   for b in a:
    if(len(a)==1):
        diccSolo[b['name']]={'idYTMusic':b['id'],'colaboracion':[]}

# %%
diccColabo= {}
diccColabo.clear()

for a in artistas:#aqui cargamos solo artistas que han aparecido con colaboraciones en la playlist
  if(len(a)>1):
      diccColabo[a[0]['name']]={'idYTMusic':a[0]['id'],'colaboracion':[],'subscriptores':None,'views':None}

      #if(len(a)==2):
          #dicc[b['id']]={'name':b['name']}

# %% [markdown]
# Nos quedamos con el diccionario de colaboraciones para empezar nuestro análisis. Y empezamos a meter los atributos que nos vendran en el estudio. En este caso, recorriendo otra vez los artistas, sacaremos las colaboraciones de cada uno y la añadiremos

# %%
#c[1]['name']
for c in artistas:#aqui les metemos en colaboraciones sus feats
    if(len(c)>1):
      # print(c[i+1]['name'])--> funcion que recorre artistas de las colaboraciones
      #añadimos artistas a las colabos
           for i in range(len(c)-1):
            diccColabo[c[0]['name']]['colaboracion'].append(c[i+1]['name'])
#diccColabo

# %% [markdown]
# Al proseguir creando la red , nos dimos cuenta que un atributo que seria importante como el id de cada artista; algunas veces no salia. Aparecia como vacío y nos daba fallo al no poder mostrar nada. Esto era o bien porque no tienen canal creado dentro de esta plataforma o porque a veces la aplicación falla ocasionalmente. Por eso en este código buscamos estos espacios vacío, y los rellenamos usando otra funcion de la appi que nos proporciona tambien el id del artista: "search". En el caso de que no nos encuentre nada ponemos que no tiene canal creado.

# %%
#para quitar los artistas que no tiene id ytMusic(fallo de la api)

for a in diccColabo:
   if(diccColabo[a]['idYTMusic']==None):
     idsvacios=yt.search(a)
     if('browseId'not in idsvacios[0]):#VER SI TIENE  ['browseId'] , SI NO LO TIENE SE PONE NO CHANNEL, SI TIENE SE PONE LO QUE ESTA EN EL ELSE  
      diccColabo[a]['idYTMusic']='No Channel'
     else:
      diccColabo[a]['idYTMusic']=idsvacios[0]['browseId']
   
#diccColabo

# %%
#numeramos con ids 
i=0
for keys in diccColabo:
    diccColabo[keys]['id']=i
    i=i+1

# %% [markdown]
# Una vez bien creado las bases del csv, procedemos a rellenar la información de cada artista. En este caso meteremos sus visitas y sus suscriptores. Como resultado obtenemos el diccionario al completo con el que podremos crear el csv.

# %%
#sacamos artistas , del diccionario por su id, sacamos los que tienen canal,y metemos su info de vistas y subscriptores
infoartista=[]
infoSubscribers=[]
infoViews=[]
for a in diccColabo:
   infoartista.append(diccColabo[a]['idYTMusic'])
  
for r in infoartista:
   if(r!='No Channel'):
      artista=yt.get_artist(r)
      infoSubscribers.append(artista['subscribers'])
      infoViews.append(artista['views'])
i=0
for keys in diccColabo:
    if(diccColabo[keys]['idYTMusic']!='No Channel'):
      diccColabo[keys]['subscriptores']=infoSubscribers[i]
      diccColabo[keys]['views']=infoViews[i]
      i=i+1    

diccColabo
# Out:
# {'Bizarrap': {'idYTMusic': 'UCONiUl5u7y2bMaVZJcuRDEQ',
#   'colaboracion': ['Duki',
#    'Tiago PZK',
#    'Residente',
#    'Villano Antillano',
#    'Nicki Nicole',
#    'Trueno',
#    'Duki',
#    'Cazzu',
#    'Morad',
#    'Trueno',
#    'Ysy A',
#    'Chucky73',
#    'Bhavi',
#    'John C',
#    'Seven Kayne',
#    'Duki'],
#   'subscriptores': '16.6M',
#   'views': '5,834,438,304 views',
#   'id': 0},
#  'Quevedo': {'idYTMusic': 'UC7PL9aor5qNRhvhWWVXyOqA',
#   'colaboracion': ['Bizarrap',
#    'Bizarrap',
#    'Bad Gyal',
#    'Ovy On The Drums',
#    'Mora',
#    'Mora',
#    'Polima Westcoast'],
#   'subscriptores': '1.06M',
#   'views': '284,342,903 views',
#   'id': 1},
#  'L-Gante': {'idYTMusic': 'UCpmpQ_z2Id7bOFeNC9_WEvA',
#   'colaboracion': ['Bizarrap'],
#   'subscriptores': '3.22M',
#   'views': '1,319,373,137 views',
#   'id': 2},
#  'Nicky Jam': {'idYTMusic': 'UCMJ705HLB_EflTzWDAjcKSQ',
#   'colaboracion': ['Bizarrap'],
#   'subscriptores': '23.3M',
#   'views': '15,344,920,765 views',
#   'id': 3},
#  'Snow Tha Product': {'idYTMusic': 'UC75nukWj1GP0V62KVH7WvzQ',
#   'colaboracion': ['Bizarrap'],
#   'subscriptores': '1.97M',
#   'views': '353,008,752 views',
#   'id': 4},
#  'Ptazeta': {'idYTMusic': 'UCI9q5A6SUN37p0gM01E1R4Q',
#   'colaboracion': ['Bizarrap', 'Emilia', 'Aitana'],
#   'subscriptores': '380K',
#   'views': None,
#   'id': 5},
#  'Nathy Peluso': {'idYTMusic': 'UCkaQTGWajEjXlTEZ_649BVA',
#   'colaboracion': ['Bizarrap'],
#   'subscriptores': '1.37M',
#   'views': '421,793,337 views',
#   'id': 6},
#  'Eladio Carrion': {'idYTMusic': 'UC7YJ69rJ9qtVh6SjYFs4cGg',
#   'colaboracion': ['Bizarrap', 'Arcangel'],
#   'subscriptores': '3.19M',
#   'views': '1,751,081,651 views',
#   'id': 7},
#  'Alemán': {'idYTMusic': 'UC9qH_PzG3TpfJpsRt9VfKcA',
#   'colaboracion': ['Bizarrap'],
#   'subscriptores': '6.19M',
#   'views': '2,061,234,978 views',
#   'id': 8},
#  'dani': {'idYTMusic': 'UCd9LBR6-BX9kEYsAG1U2mZw',
#   'colaboracion': ['Bizarrap'],
#   'subscriptores': '4.14K',
#   'views': None,
#   'id': 9},
#  'Zaramay': {'idYTMusic': 'UC3l-zF0JLkdF6OMAtbQKAEA',
#   'colaboracion': ['Bizarrap'],
#   'subscriptores': '1.07M',
#   'views': None,
#   'id': 10},
#  'Anuel AA': {'idYTMusic': 'UCbBaYg2UToDaoOwo-R6xi4g',
#   'colaboracion': ['Bizarrap',
#    'Bryant Myers',
#    'MVSIS',
#    'Foreign Teck',
#    'Chris Jedi',
#    'Gaby Music'],
#   'subscriptores': '23.3M',
#   'views': '12,638,542,397 views',
#   'id': 11},
#  'Hot Plug Beats': {'idYTMusic': 'UC8Kso_Z_382RmA8WyCnTS8w',
#   'colaboracion': ['Frijo', 'Bizarrap'],
#   'subscriptores': '103',
#   'views': None,
#   'id': 12},
#  'Kiddo Toto': {'idYTMusic': 'UCjbaTRoB85rmL7lGybha2GQ',
#   'colaboracion': ['Bizarrap'],
#   'subscriptores': '275K',
#   'views': '28,129,228 views',
#   'id': 13},
#  'Arcangel': {'idYTMusic': 'UCVcAt8IIKIeubRSigcYXgtA',
#   'colaboracion': ['Bad Bunny',
#    'Duki',
#    'Bizarrap',
#    'Myke Towers',
#    'YOVNGCHIMI'],
#   'subscriptores': '10.6M',
#   'views': '4,723,378,205 views',
#   'id': 14},
#  'Farruko': {'idYTMusic': 'UC6QXZsAOOweLfhVPbqMyG4g',
#   'colaboracion': ['Omar Montes'],
#   'subscriptores': '18.3M',
#   'views': '8,900,707,044 views',
#   'id': 15},
#  'Rauw Alejandro': {'idYTMusic': 'UCw_m17sBd4GHxuK83-AZtuA',
#   'colaboracion': ['Baby Rasta', 'Lyanno', 'Brray'],
#   'subscriptores': '12.3M',
#   'views': '10,138,853,899 views',
#   'id': 16},
#  'Aitana': {'idYTMusic': 'UCkyzcFsGWVYSUGaR7YB9OYQ',
#   'colaboracion': ['Sangiovanni'],
#   'subscriptores': '2.14M',
#   'views': None,
#   'id': 17},
#  'Shakira': {'idYTMusic': 'UCo6JijJGA3IvIiPsawDK3Ww',
#   'colaboracion': ['Ozuna', 'Rauw Alejandro', 'Ozuna'],
#   'subscriptores': '39.2M',
#   'views': '24,990,210,238 views',
#   'id': 18},
#  'Melendi': {'idYTMusic': 'UCl4jq8XKq5X0ZL5p_xVMmZA',
#   'colaboracion': ['India Martínez'],
#   'subscriptores': '4.41M',
#   'views': '3,760,206,981 views',
#   'id': 19},
#  'Belinda': {'idYTMusic': 'UC8tw8d2POmc3Lt8t1bmgl9Q',
#   'colaboracion': ['Ana Mena'],
#   'subscriptores': '869K',
#   'views': '351,755,851 views',
#   'id': 20},
#  'Abraham Mateo': {'idYTMusic': 'UCql3y41dHUh9JoPHMedvCbQ',
#   'colaboracion': ['Ana Mena'],
#   'subscriptores': '4.62M',
#   'views': '1,817,376,514 views',
#   'id': 21},
#  'KAROL G': {'idYTMusic': 'UC7n3gWRN0vQzgiOKc51aZ4w',
#   'colaboracion': ['Maldy', 'Ovy On The Drums'],
#   'subscriptores': '28.7M',
#   'views': '15,344,553,181 views',
#   'id': 22},
#  'Sergio Ramos': {'idYTMusic': 'UC2MgeVTYErtkCzRMucgFyjQ',
#   'colaboracion': ['Niña Pastori', 'RedOne'],
#   'subscriptores': '555',
#   'views': '8,852 views',
#   'id': 23},
#  'Jairo deRemache': {'idYTMusic': 'UC0rxntgJfUecm5h_d6mY8eg',
#   'colaboracion': ['Farruquito', 'Omar Montes'],
#   'subscriptores': '193',
#   'views': None,
#   'id': 24},
#  'India Martínez': {'idYTMusic': 'UCJbpTwP22V6baVULM7-J4Bw',
#   'colaboracion': ['Andy Rivera'],
#   'subscriptores': '1.01M',
#   'views': '707,214,241 views',
#   'id': 25},
#  'Selena Gomez': {'idYTMusic': 'UCeBYRgPhy8kcRmIGQWKuqdQ',
#   'colaboracion': ['Rema'],
#   'subscriptores': '32M',
#   'views': '12,053,582,302 views',
#   'id': 26},
#  'Galvan Real': {'idYTMusic': 'UC0r04hp-02vxsjHBVlm4F3A',
#   'colaboracion': ['María Artés Lamorena'],
#   'subscriptores': '417K',
#   'views': None,
#   'id': 27},
#  'C. Tangana': {'idYTMusic': 'UCLuHOvsT_LbOGVjqmXudvBg',
#   'colaboracion': ['Omar Montes'],
#   'subscriptores': '2.23M',
#   'views': '1,370,899,035 views',
#   'id': 28},
#  'JC Reyes': {'idYTMusic': 'UCXGll6UzxbSdLO1_w7rP22g',
#   'colaboracion': ['Pablo Chill-E', 'Ecko'],
#   'subscriptores': '17.6K',
#   'views': None,
#   'id': 29},
#  'Zion & Lennox': {'idYTMusic': 'UC8U7wOw_Hd7ltvcWOWAp21g',
#   'colaboracion': ['Feid'],
#   'subscriptores': '3.38M',
#   'views': '2,795,135,464 views',
#   'id': 30},
#  'ROSALÍA': {'idYTMusic': 'UCeYz6rzUGhVwqxRM37FUo8w',
#   'colaboracion': ['Romeo Santos'],
#   'subscriptores': '9.96M',
#   'views': '4,668,229,051 views',
#   'id': 31},
#  'Kidd Keo': {'idYTMusic': 'UCv7W2bEmNY7yl9XxSsn3NvQ',
#   'colaboracion': ['TALE$'],
#   'subscriptores': '4.69M',
#   'views': None,
#   'id': 32},
#  'David Guetta': {'idYTMusic': 'UCh-4c1ZoBPNP1C8c-7iVvUQ',
#   'colaboracion': ['Bebe Rexha'],
#   'subscriptores': '24.8M',
#   'views': '16,569,755,189 views',
#   'id': 33},
#  'RVFV': {'idYTMusic': 'UCj6HoOP59UGegqUC-fu4Wlg',
#   'colaboracion': ['Duki'],
#   'subscriptores': '979K',
#   'views': None,
#   'id': 34},
#  'Cano': {'idYTMusic': 'UCumOUWYBPRw2pxGl7QGeiRw',
#   'colaboracion': ['El Jhota', 'Los del Control'],
#   'subscriptores': '181K',
#   'views': None,
#   'id': 35},
#  'Wiso Rivera': {'idYTMusic': 'UCwfvKaHqW4r64dOurVFzD9A',
#   'colaboracion': ['Cruz Cafuné', 'Juseph'],
#   'subscriptores': '174',
#   'views': None,
#   'id': 36},
#  'Subelo Neo': {'idYTMusic': 'UCYEfkGCYwm66_W3xj6zaD4Q',
#   'colaboracion': ['Rauw Alejandro'],
#   'subscriptores': '10',
#   'views': None,
#   'id': 37},
#  'Lola Indigo': {'idYTMusic': 'UCydg_dYqBrPZ4-X1MnxD37A',
#   'colaboracion': ['Maria Becerra'],
#   'subscriptores': '1.24M',
#   'views': '684,998,703 views',
#   'id': 38},
#  'RM': {'idYTMusic': 'UCJCAlMsCuld3v96t-9SffdA',
#   'colaboracion': ['조유진'],
#   'subscriptores': '1.4M',
#   'views': '31,162,948 views',
#   'id': 39},
#  'Feid': {'idYTMusic': 'UCc3e8O2V5_7OA300ursDyFQ',
#   'colaboracion': ['DJ Premier'],
#   'subscriptores': '3.64M',
#   'views': '3,106,850,451 views',
#   'id': 40},
#  'Kiddo': {'idYTMusic': 'UCVLS_HdJZUDE-4_Yzcd1vAA',
#   'colaboracion': ['Pepe : Vizio', 'Delaossa'],
#   'subscriptores': '102',
#   'views': None,
#   'id': 41},
#  'Beret': {'idYTMusic': 'UCz34FayZhwHJNdCLqhwVYaw',
#   'colaboracion': ['Estopa'],
#   'subscriptores': '4.56M',
#   'views': '1,447,092,808 views',
#   'id': 42},
#  'Sebastián Yatra': {'idYTMusic': 'UCXP8o4Xcws36pgpFNlGGBeg',
#   'colaboracion': ['Pablo Alborán'],
#   'subscriptores': '17.7M',
#   'views': '9,778,847,276 views',
#   'id': 43}}

# %%
df = pd.DataFrame.from_dict(diccColabo, orient = "index",columns=['id','idYTMusic','colaboracion','subscriptores','views'])
df.to_csv('finished.csv')
df
# Out:
#                   id                 idYTMusic  \
# Bizarrap           0  UCONiUl5u7y2bMaVZJcuRDEQ
# Quevedo            1  UC7PL9aor5qNRhvhWWVXyOqA
# L-Gante            2  UCpmpQ_z2Id7bOFeNC9_WEvA
# Nicky Jam          3  UCMJ705HLB_EflTzWDAjcKSQ
# Snow Tha Product   4  UC75nukWj1GP0V62KVH7WvzQ
# Ptazeta            5  UCI9q5A6SUN37p0gM01E1R4Q
# Nathy Peluso       6  UCkaQTGWajEjXlTEZ_649BVA
# Eladio Carrion     7  UC7YJ69rJ9qtVh6SjYFs4cGg
# Alemán             8  UC9qH_PzG3TpfJpsRt9VfKcA
# dani               9  UCd9LBR6-BX9kEYsAG1U2mZw
# Zaramay           10  UC3l-zF0JLkdF6OMAtbQKAEA
# Anuel AA          11  UCbBaYg2UToDaoOwo-R6xi4g
# Hot Plug Beats    12  UC8Kso_Z_382RmA8WyCnTS8w
# Kiddo Toto        13  UCjbaTRoB85rmL7lGybha2GQ
# Arcangel          14  UCVcAt8IIKIeubRSigcYXgtA
# Farruko           15  UC6QXZsAOOweLfhVPbqMyG4g
# Rauw Alejandro    16  UCw_m17sBd4GHxuK83-AZtuA
# Aitana            17  UCkyzcFsGWVYSUGaR7YB9OYQ
# Shakira           18  UCo6JijJGA3IvIiPsawDK3Ww
# Melendi           19  UCl4jq8XKq5X0ZL5p_xVMmZA
# Belinda           20  UC8tw8d2POmc3Lt8t1bmgl9Q
# Abraham Mateo     21  UCql3y41dHUh9JoPHMedvCbQ
# KAROL G           22  UC7n3gWRN0vQzgiOKc51aZ4w
# Sergio Ramos      23  UC2MgeVTYErtkCzRMucgFyjQ
# Jairo deRemache   24  UC0rxntgJfUecm5h_d6mY8eg
# India Martínez    25  UCJbpTwP22V6baVULM7-J4Bw
# Selena Gomez      26  UCeBYRgPhy8kcRmIGQWKuqdQ
# Galvan Real       27  UC0r04hp-02vxsjHBVlm4F3A
# C. Tangana        28  UCLuHOvsT_LbOGVjqmXudvBg
# JC Reyes          29  UCXGll6UzxbSdLO1_w7rP22g
# Zion & Lennox     30  UC8U7wOw_Hd7ltvcWOWAp21g
# ROSALÍA           31  UCeYz6rzUGhVwqxRM37FUo8w
# Kidd Keo          32  UCv7W2bEmNY7yl9XxSsn3NvQ
# David Guetta      33  UCh-4c1ZoBPNP1C8c-7iVvUQ
# RVFV              34  UCj6HoOP59UGegqUC-fu4Wlg
# Cano              35  UCumOUWYBPRw2pxGl7QGeiRw
# Wiso Rivera       36  UCwfvKaHqW4r64dOurVFzD9A
# Subelo Neo        37  UCYEfkGCYwm66_W3xj6zaD4Q
# Lola Indigo       38  UCydg_dYqBrPZ4-X1MnxD37A
# RM                39  UCJCAlMsCuld3v96t-9SffdA
# Feid              40  UCc3e8O2V5_7OA300ursDyFQ
# Kiddo             41  UCVLS_HdJZUDE-4_Yzcd1vAA
# Beret             42  UCz34FayZhwHJNdCLqhwVYaw
# Sebastián Yatra   43  UCXP8o4Xcws36pgpFNlGGBeg
#
#                                                        colaboracion  \
# Bizarrap          [Duki, Tiago PZK, Residente, Villano Antillano...
# Quevedo           [Bizarrap, Bizarrap, Bad Gyal, Ovy On The Drum...
# L-Gante                                                  [Bizarrap]
# Nicky Jam                                                [Bizarrap]
# Snow Tha Product                                         [Bizarrap]
# Ptazeta                                  [Bizarrap, Emilia, Aitana]
# Nathy Peluso                                             [Bizarrap]
# Eladio Carrion                                 [Bizarrap, Arcangel]
# Alemán                                                   [Bizarrap]
# dani                                                     [Bizarrap]
# Zaramay                                                  [Bizarrap]
# Anuel AA          [Bizarrap, Bryant Myers, MVSIS, Foreign Teck, ...
# Hot Plug Beats                                    [Frijo, Bizarrap]
# Kiddo Toto                                               [Bizarrap]
# Arcangel          [Bad Bunny, Duki, Bizarrap, Myke Towers, YOVNG...
# Farruko                                               [Omar Montes]
# Rauw Alejandro                          [Baby Rasta, Lyanno, Brray]
# Aitana                                                [Sangiovanni]
# Shakira                              [Ozuna, Rauw Alejandro, Ozuna]
# Melendi                                            [India Martínez]
# Belinda                                                  [Ana Mena]
# Abraham Mateo                                            [Ana Mena]
# KAROL G                                   [Maldy, Ovy On The Drums]
# Sergio Ramos                                 [Niña Pastori, RedOne]
# Jairo deRemache                           [Farruquito, Omar Montes]
# India Martínez                                        [Andy Rivera]
# Selena Gomez                                                 [Rema]
# Galvan Real                                  [María Artés Lamorena]
# C. Tangana                                            [Omar Montes]
# JC Reyes                                      [Pablo Chill-E, Ecko]
# Zion & Lennox                                                [Feid]
# ROSALÍA                                              [Romeo Santos]
# Kidd Keo                                                    [TALE$]
# David Guetta                                           [Bebe Rexha]
# RVFV                                                         [Duki]
# Cano                                    [El Jhota, Los del Control]
# Wiso Rivera                                   [Cruz Cafuné, Juseph]
# Subelo Neo                                         [Rauw Alejandro]
# Lola Indigo                                         [Maria Becerra]
# RM                                                            [조유진]
# Feid                                                   [DJ Premier]
# Kiddo                                      [Pepe : Vizio, Delaossa]
# Beret                                                      [Estopa]
# Sebastián Yatra                                     [Pablo Alborán]
#
#                  subscriptores                 views
# Bizarrap                 16.6M   5,834,438,304 views
# Quevedo                  1.06M     284,342,903 views
# L-Gante                  3.22M   1,319,373,137 views
# Nicky Jam                23.3M  15,344,920,765 views
# Snow Tha Product         1.97M     353,008,752 views
# Ptazeta                   380K                  None
# Nathy Peluso             1.37M     421,793,337 views
# Eladio Carrion           3.19M   1,751,081,651 views
# Alemán                   6.19M   2,061,234,978 views
# dani                     4.14K                  None
# Zaramay                  1.07M                  None
# Anuel AA                 23.3M  12,638,542,397 views
# Hot Plug Beats             103                  None
# Kiddo Toto                275K      28,129,228 views
# Arcangel                 10.6M   4,723,378,205 views
# Farruko                  18.3M   8,900,707,044 views
# Rauw Alejandro           12.3M  10,138,853,899 views
# Aitana                   2.14M                  None
# Shakira                  39.2M  24,990,210,238 views
# Melendi                  4.41M   3,760,206,981 views
# Belinda                   869K     351,755,851 views
# Abraham Mateo            4.62M   1,817,376,514 views
# KAROL G                  28.7M  15,344,553,181 views
# Sergio Ramos               555           8,852 views
# Jairo deRemache            193                  None
# India Martínez           1.01M     707,214,241 views
# Selena Gomez               32M  12,053,582,302 views
# Galvan Real               417K                  None
# C. Tangana               2.23M   1,370,899,035 views
# JC Reyes                 17.6K                  None
# Zion & Lennox            3.38M   2,795,135,464 views
# ROSALÍA                  9.96M   4,668,229,051 views
# Kidd Keo                 4.69M                  None
# David Guetta             24.8M  16,569,755,189 views
# RVFV                      979K                  None
# Cano                      181K                  None
# Wiso Rivera                174                  None
# Subelo Neo                  10                  None
# Lola Indigo              1.24M     684,998,703 views
# RM                        1.4M      31,162,948 views
# Feid                     3.64M   3,106,850,451 views
# Kiddo                      102                  None
# Beret                    4.56M   1,447,092,808 views
# Sebastián Yatra          17.7M   9,778,847,276 views

# %%
#para rellenar si es explicito  para artistas con colabos       
duration = []
explicit = []
publicacion=[]
videosIds=[]
artistasAristas=[]
for r in infoPlayList:
     for a in r['tracks']:
          if(len(a['artists'])>1):
            explicit.append(a['isExplicit'])

#para rellenar duracion seg   para artistas con colabos     
for r in infoPlayList:
     for a in r['tracks']:
           if(len(a['artists'])>1):
            duration.append(a['duration_seconds'])
#para los artistas del csv
for r in infoPlayList:
     for a in r['tracks']:
           if(len(a['artists'])>1):
            artistasAristas.append(a['artists'])


for r in infoPlayList:
     for a in r['tracks']:
           if(len(a['artists'])>1):
               searchMusic=yt.get_song(a['videoId'])
               publicacion.append(searchMusic['microformat']['microformatDataRenderer']['publishDate'])

# %% [markdown]
# En este momento, abrimos un csv para escribir la información de las aristas.En nuestro caso se van a unir los nodos segun sus colaboraciones.Si el nodo A ha colaborado con B y C se lanzará una arista desde A hasta B y desde A hasta C.
# Tambien hemos añadido atributos complementarios para su posterior estudio en Gephi, como la duracion de la cancion en cuestión en la que colaboran, si la letra de la cancion tiene contenido explicito o no y la fecha de la publicación de la cancion en ytMusic.

# %%
header = ['artista', 'colaboracion','duracion','explicito','fecha_publicacion']
writedicc = {}
with open('aristas.csv','w',encoding='utf-8',newline='') as f:
    writer= csv.writer(f)
    writer.writerow(header)
    iter=0
    repe=0
    for r in artistasAristas:
        for i in range(len(r)-1):
            writer.writerow([r[0]['name'],r[i+1]['name'],duration[iter],explicit[iter],publicacion[iter]])
        iter=iter+1
            
      # iter=iter+1

# %%
df = pd.read_csv('aristas.csv',names=['artista','colaboracion','repetidos','explicito','duracion'])

G=nx.from_pandas_edgelist(df,'artista','colaboracion')


plt.show() 
plt.figure(figsize=(13,10))
pos = nx.circular_layout(G)
nx.draw(G,pos,with_labels=True,alpha=0.7)
# Out:
# c:\Users\marco\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51312 (\N{HANGUL SYLLABLE JO}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\marco\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\marco\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51652 (\N{HANGUL SYLLABLE JIN}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\marco\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51312 (\N{HANGUL SYLLABLE JO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\marco\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\marco\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51652 (\N{HANGUL SYLLABLE JIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
