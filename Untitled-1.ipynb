# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
import csv

# %% [markdown]
# Los 100 vídeos musicales más populares en España

# %%
from ytmusicapi import YTMusic

yt = YTMusic()
#z8uyayN3RbE
searchMusic=yt.get_song("5g2hT4GmAGU")

#yt.get_artist("UCiY3z8HAGD6BlSNKVn2kSvQ")
search_results=yt.search("Barroso")
#search_results
searchPlay=yt.get_playlist("PL4fGSI1pDJn4jhQB4kb9M36dvVmJQPt4T")

searcArtist=yt.get_artist('UCMJ705HLB_EflTzWDAjcKSQ')

searchMusic=yt.get_song("5g2hT4GmAGU")
#searchPlay
#searchMusic
#searcArtist
#search_results

# %% [markdown]
# BIZARRAP SESSIONS     RDCLAK5uy_mEXMsobutX4itJVd6YaCodxMgUV-mMtNo
# TOP 100         PL4fGSI1pDJn4jhQB4kb9M36dvVmJQPt4T

# %%
yt = YTMusic()
playlist=['RDCLAK5uy_mEXMsobutX4itJVd6YaCodxMgUV-mMtNo','PL4fGSI1pDJn4jhQB4kb9M36dvVmJQPt4T']

artistas = []
ids=[]
diccSolo= {}
diccSolo.clear()
colabos=[]

infoPlayList = []
for p in playlist:
     infoPlayList.append(yt.get_playlist(p))

for r in infoPlayList:
     for a in r['tracks']:
      artistas.append(a['artists'])
          

#for r in searchPlay['tracks']:
#     artistas.append(r['artists'])


for a in artistas:#cargamos el diccionario con los artistas que van a cantar solos
   for b in a:
    if(len(a)==1):
        diccSolo[b['name']]={'idYTMusic':b['id'],'colaboracion':[]}

# %%
diccColabo= {}
diccColabo.clear()

for a in artistas:#aqui cargamos solo artistas que han aparecido con colaboraciones en la playlist
  if(len(a)>1):
      diccColabo[a[0]['name']]={'idYTMusic':a[0]['id'],'colaboracion':[],'subscriptores':None}

      #if(len(a)==2):
          #dicc[b['id']]={'name':b['name']}

# %%
#c[1]['name']
for c in artistas:#aqui les metemos en colaboraciones sus feats
    if(len(c)>1):
      # print(c[i+1]['name'])--> funcion que recorre artistas de las colaboraciones
      #añadimos artistas a las colabos
           for i in range(len(c)-1):
            diccColabo[c[0]['name']]['colaboracion'].append(c[i+1]['name'])
diccColabo
# Out:
# {'Bizarrap': {'idYTMusic': 'UCONiUl5u7y2bMaVZJcuRDEQ',
#   'colaboracion': ['Duki',
#    'Residente',
#    'Villano Antillano',
#    'Nicki Nicole',
#    'Trueno',
#    'Duki',
#    'Cazzu',
#    'Morad',
#    'Trueno',
#    'Ysy A',
#    'Chucky73',
#    'Bhavi',
#    'John C',
#    'Seven Kayne',
#    'Duki',
#    'Villano Antillano'],
#   'subscriptores': None},
#  'Quevedo': {'idYTMusic': 'UC7PL9aor5qNRhvhWWVXyOqA',
#   'colaboracion': ['Bizarrap', 'Bizarrap', 'Mora', 'Ovy On The Drums'],
#   'subscriptores': None},
#  'L-Gante': {'idYTMusic': 'UCpmpQ_z2Id7bOFeNC9_WEvA',
#   'colaboracion': ['Bizarrap'],
#   'subscriptores': None},
#  'Nicky Jam': {'idYTMusic': 'UCMJ705HLB_EflTzWDAjcKSQ',
#   'colaboracion': ['Bizarrap'],
#   'subscriptores': None},
#  'Snow Tha Product': {'idYTMusic': 'UC75nukWj1GP0V62KVH7WvzQ',
#   'colaboracion': ['Bizarrap'],
#   'subscriptores': None},
#  'Ptazeta': {'idYTMusic': 'UCI9q5A6SUN37p0gM01E1R4Q',
#   'colaboracion': ['Bizarrap', 'Emilia', 'Aitana'],
#   'subscriptores': None},
#  'Nathy Peluso': {'idYTMusic': 'UCkaQTGWajEjXlTEZ_649BVA',
#   'colaboracion': ['Bizarrap'],
#   'subscriptores': None},
#  'Eladio Carrion': {'idYTMusic': 'UC7YJ69rJ9qtVh6SjYFs4cGg',
#   'colaboracion': ['Bizarrap', 'Bizarrap'],
#   'subscriptores': None},
#  'Alemán': {'idYTMusic': 'UC9qH_PzG3TpfJpsRt9VfKcA',
#   'colaboracion': ['Bizarrap'],
#   'subscriptores': None},
#  'Dani Ribba': {'idYTMusic': 'UCwY3OSOlpPQSkheJWsbmNLA',
#   'colaboracion': ['Bizarrap'],
#   'subscriptores': None},
#  'Zaramay': {'idYTMusic': 'UC3l-zF0JLkdF6OMAtbQKAEA',
#   'colaboracion': ['Bizarrap'],
#   'subscriptores': None},
#  'Anuel AA': {'idYTMusic': 'UCbBaYg2UToDaoOwo-R6xi4g',
#   'colaboracion': ['Bizarrap',
#    'Bryant Myers',
#    'Casper Magico',
#    'Foreign Teck',
#    'Chris Jedi',
#    'Gaby Music'],
#   'subscriptores': None},
#  'Hot Plug Beats': {'idYTMusic': 'UC8Kso_Z_382RmA8WyCnTS8w',
#   'colaboracion': ['Frijo', 'Bizarrap'],
#   'subscriptores': None},
#  'Kiddo Toto': {'idYTMusic': 'UCjbaTRoB85rmL7lGybha2GQ',
#   'colaboracion': ['Bizarrap'],
#   'subscriptores': None},
#  'Rauw Alejandro': {'idYTMusic': 'UCw_m17sBd4GHxuK83-AZtuA',
#   'colaboracion': ['Baby Rasta', 'Lyanno', 'Brray'],
#   'subscriptores': None},
#  'Shakira': {'idYTMusic': 'UCo6JijJGA3IvIiPsawDK3Ww',
#   'colaboracion': ['Ozuna',
#    'Rauw Alejandro',
#    'Ozuna',
#    'Black Eyed Peas',
#    'David Guetta'],
#   'subscriptores': None},
#  'Aitana': {'idYTMusic': 'UCkyzcFsGWVYSUGaR7YB9OYQ',
#   'colaboracion': ['Sangiovanni'],
#   'subscriptores': None},
#  'KAROL G': {'idYTMusic': 'UC7n3gWRN0vQzgiOKc51aZ4w',
#   'colaboracion': ['Ovy On The Drums', 'Maldy'],
#   'subscriptores': None},
#  'Melendi': {'idYTMusic': 'UCl4jq8XKq5X0ZL5p_xVMmZA',
#   'colaboracion': ['India Martínez'],
#   'subscriptores': None},
#  'Wisin & Yandel': {'idYTMusic': None,
#   'colaboracion': ['Rosalia'],
#   'subscriptores': None},
#  'Abraham Mateo': {'idYTMusic': 'UCql3y41dHUh9JoPHMedvCbQ',
#   'colaboracion': ['Ana Mena'],
#   'subscriptores': None},
#  'Belinda': {'idYTMusic': 'UC8tw8d2POmc3Lt8t1bmgl9Q',
#   'colaboracion': ['Ana Mena'],
#   'subscriptores': None},
#  'India Martínez': {'idYTMusic': 'UCJbpTwP22V6baVULM7-J4Bw',
#   'colaboracion': ['Andy Rivera'],
#   'subscriptores': None},
#  'Jairo deRemache': {'idYTMusic': 'UC0rxntgJfUecm5h_d6mY8eg',
#   'colaboracion': ['Farruquito', 'Omar Montes'],
#   'subscriptores': None},
#  'Myke Towers': {'idYTMusic': 'UCYPsIfSIEwWcoynHBP5k1dg',
#   'colaboracion': ['Tiago PZK'],
#   'subscriptores': None},
#  'Jhayco': {'idYTMusic': 'UChZEzxer-QvRMbADJJGOMuQ',
#   'colaboracion': ['Mora', 'Feid', 'Sech'],
#   'subscriptores': None},
#  'JC Reyes': {'idYTMusic': 'UCXGll6UzxbSdLO1_w7rP22g',
#   'colaboracion': ['Pablo Chill-E', 'Ecko'],
#   'subscriptores': None},
#  'Sergio Ramos': {'idYTMusic': 'UC2MgeVTYErtkCzRMucgFyjQ',
#   'colaboracion': ['Niña Pastori', 'RedOne'],
#   'subscriptores': None},
#  'Selena Gomez': {'idYTMusic': 'UCeBYRgPhy8kcRmIGQWKuqdQ',
#   'colaboracion': ['Rema', 'Rema'],
#   'subscriptores': None},
#  'ROSALÍA': {'idYTMusic': 'UCeYz6rzUGhVwqxRM37FUo8w',
#   'colaboracion': ['Romeo Santos'],
#   'subscriptores': None},
#  'Barroso': {'idYTMusic': None,
#   'colaboracion': ['Dani MDR', 'Lorena Santos'],
#   'subscriptores': None},
#  'C. Tangana': {'idYTMusic': 'UCLuHOvsT_LbOGVjqmXudvBg',
#   'colaboracion': ['Omar Montes'],
#   'subscriptores': None},
#  'RVFV': {'idYTMusic': 'UCj6HoOP59UGegqUC-fu4Wlg',
#   'colaboracion': ['Duki'],
#   'subscriptores': None},
#  'Lola Indigo': {'idYTMusic': 'UCydg_dYqBrPZ4-X1MnxD37A',
#   'colaboracion': ['Maria Becerra'],
#   'subscriptores': None},
#  'Cano': {'idYTMusic': 'UCumOUWYBPRw2pxGl7QGeiRw',
#   'colaboracion': ['El Jhota', 'Los del Control'],
#   'subscriptores': None},
#  'Wiso Rivera': {'idYTMusic': 'UCwfvKaHqW4r64dOurVFzD9A',
#   'colaboracion': ['Cruz Cafuné', 'Juseph'],
#   'subscriptores': None},
#  'Paco Candela': {'idYTMusic': None,
#   'colaboracion': ['Andy & Lucas'],
#   'subscriptores': None},
#  'Sebastián Yatra': {'idYTMusic': 'UCXP8o4Xcws36pgpFNlGGBeg',
#   'colaboracion': ['Pablo Alborán'],
#   'subscriptores': None},
#  'Oliver Tree': {'idYTMusic': 'UCoOFEu6s0wk7CUljMh8wisw',
#   'colaboracion': ['Robin Schulz'],
#   'subscriptores': None},
#  'Darell': {'idYTMusic': 'UCVsfgFfzYNMJvcQLDYT7fHw',
#   'colaboracion': ['Omar Montes'],
#   'subscriptores': None},
#  'Mora': {'idYTMusic': 'UCgDpp8Ex8Yz6hhHjbl3W5mg',
#   'colaboracion': ['Feid'],
#   'subscriptores': None},
#  'Paulo Londra': {'idYTMusic': 'UCpH92jOmlMe71mRYEkp7riQ',
#   'colaboracion': ['LIT killah'],
#   'subscriptores': None}}

# %%
#para quitar los artistas que no tiene id ytMusic

for a in diccColabo:
    if(diccColabo[a]['idYTMusic']==None):
       idsvacios=yt.search(a)
       diccColabo[a]['idYTMusic']=idsvacios[0]['browseId']
#diccColabo

# %%
#numeramos con ids 
i=0
for keys in diccColabo:
    diccColabo[keys]['id']=i
    i=i+1

# %%
infoartista=[]
infoSubscribers=[]
for a in diccColabo:
   infoartista.append(diccColabo[a]['idYTMusic'])
  
for r in infoartista:
   artista=yt.get_artist(r)
   infoSubscribers.append(artista['subscribers'])
i=0
for keys in diccColabo:
    diccColabo[keys]['subscriptores']=infoSubscribers[i]
    i=i+1    

#diccColabo
# Out:
# {'Bizarrap': {'idYTMusic': 'UCONiUl5u7y2bMaVZJcuRDEQ',
#   'colaboracion': ['Duki',
#    'Residente',
#    'Villano Antillano',
#    'Nicki Nicole',
#    'Trueno',
#    'Duki',
#    'Cazzu',
#    'Morad',
#    'Trueno',
#    'Ysy A',
#    'Chucky73',
#    'Bhavi',
#    'John C',
#    'Seven Kayne',
#    'Duki',
#    'Villano Antillano'],
#   'subscriptores': '16.5M',
#   'id': 0},
#  'Quevedo': {'idYTMusic': 'UC7PL9aor5qNRhvhWWVXyOqA',
#   'colaboracion': ['Bizarrap', 'Bizarrap', 'Mora', 'Ovy On The Drums'],
#   'subscriptores': '1.03M',
#   'id': 1},
#  'L-Gante': {'idYTMusic': 'UCpmpQ_z2Id7bOFeNC9_WEvA',
#   'colaboracion': ['Bizarrap'],
#   'subscriptores': '3.2M',
#   'id': 2},
#  'Nicky Jam': {'idYTMusic': 'UCMJ705HLB_EflTzWDAjcKSQ',
#   'colaboracion': ['Bizarrap'],
#   'subscriptores': '23.3M',
#   'id': 3},
#  'Snow Tha Product': {'idYTMusic': 'UC75nukWj1GP0V62KVH7WvzQ',
#   'colaboracion': ['Bizarrap'],
#   'subscriptores': '1.97M',
#   'id': 4},
#  'Ptazeta': {'idYTMusic': 'UCI9q5A6SUN37p0gM01E1R4Q',
#   'colaboracion': ['Bizarrap', 'Emilia', 'Aitana'],
#   'subscriptores': '378K',
#   'id': 5},
#  'Nathy Peluso': {'idYTMusic': 'UCkaQTGWajEjXlTEZ_649BVA',
#   'colaboracion': ['Bizarrap'],
#   'subscriptores': '1.37M',
#   'id': 6},
#  'Eladio Carrion': {'idYTMusic': 'UC7YJ69rJ9qtVh6SjYFs4cGg',
#   'colaboracion': ['Bizarrap', 'Bizarrap'],
#   'subscriptores': '3.15M',
#   'id': 7},
#  'Alemán': {'idYTMusic': 'UC9qH_PzG3TpfJpsRt9VfKcA',
#   'colaboracion': ['Bizarrap'],
#   'subscriptores': '6.17M',
#   'id': 8},
#  'Dani Ribba': {'idYTMusic': 'UCwY3OSOlpPQSkheJWsbmNLA',
#   'colaboracion': ['Bizarrap'],
#   'subscriptores': '1.03M',
#   'id': 9},
#  'Zaramay': {'idYTMusic': 'UC3l-zF0JLkdF6OMAtbQKAEA',
#   'colaboracion': ['Bizarrap'],
#   'subscriptores': '1.07M',
#   'id': 10},
#  'Anuel AA': {'idYTMusic': 'UCbBaYg2UToDaoOwo-R6xi4g',
#   'colaboracion': ['Bizarrap',
#    'Bryant Myers',
#    'Casper Magico',
#    'Foreign Teck',
#    'Chris Jedi',
#    'Gaby Music'],
#   'subscriptores': '23.2M',
#   'id': 11},
#  'Hot Plug Beats': {'idYTMusic': 'UC8Kso_Z_382RmA8WyCnTS8w',
#   'colaboracion': ['Frijo', 'Bizarrap'],
#   'subscriptores': '104',
#   'id': 12},
#  'Kiddo Toto': {'idYTMusic': 'UCjbaTRoB85rmL7lGybha2GQ',
#   'colaboracion': ['Bizarrap'],
#   'subscriptores': '275K',
#   'id': 13},
#  'Rauw Alejandro': {'idYTMusic': 'UCw_m17sBd4GHxuK83-AZtuA',
#   'colaboracion': ['Baby Rasta', 'Lyanno', 'Brray'],
#   'subscriptores': '12.2M',
#   'id': 14},
#  'Shakira': {'idYTMusic': 'UCo6JijJGA3IvIiPsawDK3Ww',
#   'colaboracion': ['Ozuna',
#    'Rauw Alejandro',
#    'Ozuna',
#    'Black Eyed Peas',
#    'David Guetta'],
#   'subscriptores': '38.9M',
#   'id': 15},
#  'Aitana': {'idYTMusic': 'UCkyzcFsGWVYSUGaR7YB9OYQ',
#   'colaboracion': ['Sangiovanni'],
#   'subscriptores': '2.13M',
#   'id': 16},
#  'KAROL G': {'idYTMusic': 'UC7n3gWRN0vQzgiOKc51aZ4w',
#   'colaboracion': ['Ovy On The Drums', 'Maldy'],
#   'subscriptores': '28.6M',
#   'id': 17},
#  'Melendi': {'idYTMusic': 'UCl4jq8XKq5X0ZL5p_xVMmZA',
#   'colaboracion': ['India Martínez'],
#   'subscriptores': '4.4M',
#   'id': 18},
#  'Wisin & Yandel': {'idYTMusic': 'UCJ0-R-v3CaJNYMqfp9tivqA',
#   'colaboracion': ['Rosalia'],
#   'subscriptores': '6.99M',
#   'id': 19},
#  'Abraham Mateo': {'idYTMusic': 'UCql3y41dHUh9JoPHMedvCbQ',
#   'colaboracion': ['Ana Mena'],
#   'subscriptores': '4.62M',
#   'id': 20},
#  'Belinda': {'idYTMusic': 'UC8tw8d2POmc3Lt8t1bmgl9Q',
#   'colaboracion': ['Ana Mena'],
#   'subscriptores': '868K',
#   'id': 21},
#  'India Martínez': {'idYTMusic': 'UCJbpTwP22V6baVULM7-J4Bw',
#   'colaboracion': ['Andy Rivera'],
#   'subscriptores': '1M',
#   'id': 22},
#  'Jairo deRemache': {'idYTMusic': 'UC0rxntgJfUecm5h_d6mY8eg',
#   'colaboracion': ['Farruquito', 'Omar Montes'],
#   'subscriptores': '193',
#   'id': 23},
#  'Myke Towers': {'idYTMusic': 'UCYPsIfSIEwWcoynHBP5k1dg',
#   'colaboracion': ['Tiago PZK'],
#   'subscriptores': '9.55M',
#   'id': 24},
#  'Jhayco': {'idYTMusic': 'UChZEzxer-QvRMbADJJGOMuQ',
#   'colaboracion': ['Mora', 'Feid', 'Sech'],
#   'subscriptores': '4.73M',
#   'id': 25},
#  'JC Reyes': {'idYTMusic': 'UCXGll6UzxbSdLO1_w7rP22g',
#   'colaboracion': ['Pablo Chill-E', 'Ecko'],
#   'subscriptores': '17K',
#   'id': 26},
#  'Sergio Ramos': {'idYTMusic': 'UC2MgeVTYErtkCzRMucgFyjQ',
#   'colaboracion': ['Niña Pastori', 'RedOne'],
#   'subscriptores': '505',
#   'id': 27},
#  'Selena Gomez': {'idYTMusic': 'UCeBYRgPhy8kcRmIGQWKuqdQ',
#   'colaboracion': ['Rema', 'Rema'],
#   'subscriptores': '31.8M',
#   'id': 28},
#  'ROSALÍA': {'idYTMusic': 'UCeYz6rzUGhVwqxRM37FUo8w',
#   'colaboracion': ['Romeo Santos'],
#   'subscriptores': '9.92M',
#   'id': 29},
#  'Barroso': {'idYTMusic': 'UC1jVH0d6Eu8Sk521-VaxXxw',
#   'colaboracion': ['Dani MDR', 'Lorena Santos'],
#   'subscriptores': '78.3K',
#   'id': 30},
#  'C. Tangana': {'idYTMusic': 'UCLuHOvsT_LbOGVjqmXudvBg',
#   'colaboracion': ['Omar Montes'],
#   'subscriptores': '2.23M',
#   'id': 31},
#  'RVFV': {'idYTMusic': 'UCj6HoOP59UGegqUC-fu4Wlg',
#   'colaboracion': ['Duki'],
#   'subscriptores': '967K',
#   'id': 32},
#  'Lola Indigo': {'idYTMusic': 'UCydg_dYqBrPZ4-X1MnxD37A',
#   'colaboracion': ['Maria Becerra'],
#   'subscriptores': '1.23M',
#   'id': 33},
#  'Cano': {'idYTMusic': 'UCumOUWYBPRw2pxGl7QGeiRw',
#   'colaboracion': ['El Jhota', 'Los del Control'],
#   'subscriptores': '177K',
#   'id': 34},
#  'Wiso Rivera': {'idYTMusic': 'UCwfvKaHqW4r64dOurVFzD9A',
#   'colaboracion': ['Cruz Cafuné', 'Juseph'],
#   'subscriptores': '171',
#   'id': 35},
#  'Paco Candela': {'idYTMusic': 'UCBUw8Hip7C6BP8x-QrAaY9g',
#   'colaboracion': ['Andy & Lucas'],
#   'subscriptores': '63.7K',
#   'id': 36},
#  'Sebastián Yatra': {'idYTMusic': 'UCXP8o4Xcws36pgpFNlGGBeg',
#   'colaboracion': ['Pablo Alborán'],
#   'subscriptores': '17.7M',
#   'id': 37},
#  'Oliver Tree': {'idYTMusic': 'UCoOFEu6s0wk7CUljMh8wisw',
#   'colaboracion': ['Robin Schulz'],
#   'subscriptores': '4.14M',
#   'id': 38},
#  'Darell': {'idYTMusic': 'UCVsfgFfzYNMJvcQLDYT7fHw',
#   'colaboracion': ['Omar Montes'],
#   'subscriptores': '3.1M',
#   'id': 39},
#  'Mora': {'idYTMusic': 'UCgDpp8Ex8Yz6hhHjbl3W5mg',
#   'colaboracion': ['Feid'],
#   'subscriptores': '1.77M',
#   'id': 40},
#  'Paulo Londra': {'idYTMusic': 'UCpH92jOmlMe71mRYEkp7riQ',
#   'colaboracion': ['LIT killah'],
#   'subscriptores': '22.1M',
#   'id': 41}}

# %%
df = pd.DataFrame.from_dict(diccColabo, orient = "index",columns=['id','idYTMusic','colaboracion','subscriptores'])
df.to_csv('finished.csv')
df
# Out:
#                   id                 idYTMusic  \
# Bizarrap           0  UCONiUl5u7y2bMaVZJcuRDEQ
# Quevedo            1  UC7PL9aor5qNRhvhWWVXyOqA
# L-Gante            2  UCpmpQ_z2Id7bOFeNC9_WEvA
# Nicky Jam          3  UCMJ705HLB_EflTzWDAjcKSQ
# Snow Tha Product   4  UC75nukWj1GP0V62KVH7WvzQ
# Ptazeta            5  UCI9q5A6SUN37p0gM01E1R4Q
# Nathy Peluso       6  UCkaQTGWajEjXlTEZ_649BVA
# Eladio Carrion     7  UC7YJ69rJ9qtVh6SjYFs4cGg
# Alemán             8  UC9qH_PzG3TpfJpsRt9VfKcA
# Dani Ribba         9  UCwY3OSOlpPQSkheJWsbmNLA
# Zaramay           10  UC3l-zF0JLkdF6OMAtbQKAEA
# Anuel AA          11  UCbBaYg2UToDaoOwo-R6xi4g
# Hot Plug Beats    12  UC8Kso_Z_382RmA8WyCnTS8w
# Kiddo Toto        13  UCjbaTRoB85rmL7lGybha2GQ
# Rauw Alejandro    14  UCw_m17sBd4GHxuK83-AZtuA
# Shakira           15  UCo6JijJGA3IvIiPsawDK3Ww
# Aitana            16  UCkyzcFsGWVYSUGaR7YB9OYQ
# KAROL G           17  UC7n3gWRN0vQzgiOKc51aZ4w
# Melendi           18  UCl4jq8XKq5X0ZL5p_xVMmZA
# Wisin & Yandel    19  UCJ0-R-v3CaJNYMqfp9tivqA
# Abraham Mateo     20  UCql3y41dHUh9JoPHMedvCbQ
# Belinda           21  UC8tw8d2POmc3Lt8t1bmgl9Q
# India Martínez    22  UCJbpTwP22V6baVULM7-J4Bw
# Jairo deRemache   23  UC0rxntgJfUecm5h_d6mY8eg
# Myke Towers       24  UCYPsIfSIEwWcoynHBP5k1dg
# Jhayco            25  UChZEzxer-QvRMbADJJGOMuQ
# JC Reyes          26  UCXGll6UzxbSdLO1_w7rP22g
# Sergio Ramos      27  UC2MgeVTYErtkCzRMucgFyjQ
# Selena Gomez      28  UCeBYRgPhy8kcRmIGQWKuqdQ
# ROSALÍA           29  UCeYz6rzUGhVwqxRM37FUo8w
# Barroso           30  UC1jVH0d6Eu8Sk521-VaxXxw
# C. Tangana        31  UCLuHOvsT_LbOGVjqmXudvBg
# RVFV              32  UCj6HoOP59UGegqUC-fu4Wlg
# Lola Indigo       33  UCydg_dYqBrPZ4-X1MnxD37A
# Cano              34  UCumOUWYBPRw2pxGl7QGeiRw
# Wiso Rivera       35  UCwfvKaHqW4r64dOurVFzD9A
# Paco Candela      36  UCBUw8Hip7C6BP8x-QrAaY9g
# Sebastián Yatra   37  UCXP8o4Xcws36pgpFNlGGBeg
# Oliver Tree       38  UCoOFEu6s0wk7CUljMh8wisw
# Darell            39  UCVsfgFfzYNMJvcQLDYT7fHw
# Mora              40  UCgDpp8Ex8Yz6hhHjbl3W5mg
# Paulo Londra      41  UCpH92jOmlMe71mRYEkp7riQ
#
#                                                        colaboracion  \
# Bizarrap          [Duki, Residente, Villano Antillano, Nicki Nic...
# Quevedo                [Bizarrap, Bizarrap, Mora, Ovy On The Drums]
# L-Gante                                                  [Bizarrap]
# Nicky Jam                                                [Bizarrap]
# Snow Tha Product                                         [Bizarrap]
# Ptazeta                                  [Bizarrap, Emilia, Aitana]
# Nathy Peluso                                             [Bizarrap]
# Eladio Carrion                                 [Bizarrap, Bizarrap]
# Alemán                                                   [Bizarrap]
# Dani Ribba                                               [Bizarrap]
# Zaramay                                                  [Bizarrap]
# Anuel AA          [Bizarrap, Bryant Myers, Casper Magico, Foreig...
# Hot Plug Beats                                    [Frijo, Bizarrap]
# Kiddo Toto                                               [Bizarrap]
# Rauw Alejandro                          [Baby Rasta, Lyanno, Brray]
# Shakira           [Ozuna, Rauw Alejandro, Ozuna, Black Eyed Peas...
# Aitana                                                [Sangiovanni]
# KAROL G                                   [Ovy On The Drums, Maldy]
# Melendi                                            [India Martínez]
# Wisin & Yandel                                            [Rosalia]
# Abraham Mateo                                            [Ana Mena]
# Belinda                                                  [Ana Mena]
# India Martínez                                        [Andy Rivera]
# Jairo deRemache                           [Farruquito, Omar Montes]
# Myke Towers                                             [Tiago PZK]
# Jhayco                                           [Mora, Feid, Sech]
# JC Reyes                                      [Pablo Chill-E, Ecko]
# Sergio Ramos                                 [Niña Pastori, RedOne]
# Selena Gomez                                           [Rema, Rema]
# ROSALÍA                                              [Romeo Santos]
# Barroso                                   [Dani MDR, Lorena Santos]
# C. Tangana                                            [Omar Montes]
# RVFV                                                         [Duki]
# Lola Indigo                                         [Maria Becerra]
# Cano                                    [El Jhota, Los del Control]
# Wiso Rivera                                   [Cruz Cafuné, Juseph]
# Paco Candela                                         [Andy & Lucas]
# Sebastián Yatra                                     [Pablo Alborán]
# Oliver Tree                                          [Robin Schulz]
# Darell                                                [Omar Montes]
# Mora                                                         [Feid]
# Paulo Londra                                           [LIT killah]
#
#                  subscriptores
# Bizarrap                 16.5M
# Quevedo                  1.03M
# L-Gante                   3.2M
# Nicky Jam                23.3M
# Snow Tha Product         1.97M
# Ptazeta                   378K
# Nathy Peluso             1.37M
# Eladio Carrion           3.15M
# Alemán                   6.17M
# Dani Ribba               1.03M
# Zaramay                  1.07M
# Anuel AA                 23.2M
# Hot Plug Beats             104
# Kiddo Toto                275K
# Rauw Alejandro           12.2M
# Shakira                  38.9M
# Aitana                   2.13M
# KAROL G                  28.6M
# Melendi                   4.4M
# Wisin & Yandel           6.99M
# Abraham Mateo            4.62M
# Belinda                   868K
# India Martínez              1M
# Jairo deRemache            193
# Myke Towers              9.55M
# Jhayco                   4.73M
# JC Reyes                   17K
# Sergio Ramos               505
# Selena Gomez             31.8M
# ROSALÍA                  9.92M
# Barroso                  78.3K
# C. Tangana               2.23M
# RVFV                      967K
# Lola Indigo              1.23M
# Cano                      177K
# Wiso Rivera                171
# Paco Candela             63.7K
# Sebastián Yatra          17.7M
# Oliver Tree              4.14M
# Darell                    3.1M
# Mora                     1.77M
# Paulo Londra             22.1M

# %%
header = ['artista', 'colaboracion']

namedicc = {}
with open('aristas.csv','w',encoding='utf-8',newline='') as f:
    writer= csv.writer(f)
    writer.writerow(header)
    for i in diccColabo:
        nombre_relacionados = []
        #print("aaaaaaaaaaaaaaaaa")
        #print(i)
        for r in diccColabo[i]['colaboracion']:
            #print(r)
            writer.writerow([i,r])
        
    #namedicc[diccColabo[i]['id']]=nombre_relacionados


#with open('aristas.csv','w',encoding='utf-8',newline='') as f:
 #   writer= csv.writer(f)
  #  writer.writerow(header)
   # for i in namedicc:
    #    for item in namedicc[i]:
     #       writer.writerow([i,item])

# %%
df = pd.read_csv('aristas.csv',names=['artista','colaboracion'])

G=nx.from_pandas_edgelist(df,'artista','colaboracion')


plt.show() 
plt.figure(figsize=(13,10))
pos = nx.circular_layout(G)
nx.draw(G,pos,with_labels=True,alpha=0.7)

# %%
diccFinal= {}#EN PROCESO
diccFinal.clear()
for a in artistas:
   for b in a:
    if(len(a)>1):
           diccFinal[b['name']]={'idYTMusic':b['id'],'colaboracion':[]}
           for i in range(len(a)-1):
            diccFinal[a[0]['name']]['colaboracion'].append(a[i+1]['name'])
    elif(len(a)==1):
        diccFinal[b['name']]={'idYTMusic':b['id'],'colaboracion':[]}
#diccFinal

# %%
for a in artistas:
   ids.append(a[0]['id'])
