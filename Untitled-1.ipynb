# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
import csv
#holawenasnoxes

# %% [markdown]
# Daaniiiiiiiiiiiiiiiiii     AQUI   poner brevemente que hace cada funcion

# %%
from ytmusicapi import YTMusic

yt = YTMusic()
#z8uyayN3RbE
searchMusic=yt.get_song("5g2hT4GmAGU")

#yt.get_artist("UCiY3z8HAGD6BlSNKVn2kSvQ")
search_results=yt.search("Duki")
#search_results
searchPlay=yt.get_playlist("PL4fGSI1pDJn4jhQB4kb9M36dvVmJQPt4T")

searcArtist=yt.get_artist('UCI9q5A6SUN37p0gM01E1R4Q')

searchMusic=yt.get_song("-XiCucQ4RCU")

searchchar=yt.get_charts()
#searchchar
#searchPlay
#searchMusic
#searcArtist
#search_results

# %% [markdown]
# A continuación empezamos cargando un array con todos los artistas que aparecen en el array de playlist. Recorreremos el array de playlist y extraeremos los datos de dichas playlists con las funciones de la appi ya mencionadas. Probamos a meter los diccionarios que nos da la funcion
# "get_playlist" en un array llamado 'artistas' para empezar a jugar con ello.
# Nos dimos cuenta que filtrando por clave/valor del diccionario se podia ver muchos datos. En este caso filtramos por "tracks" donde nos enseña todas las canciones de las playlist con informacion relevante de ellas. Con esto conseguimos informacion de los artistas que participan en esa canción. Esta información la metemos en el array de artistas para dividir dos diccionarios: diccionario de solos (en los que solo participa un artista )y diccionario de colaboraciones (en el que participa más de uno)

# %% [markdown]
#
#
# ### Array de playlist
# * **BIZARRAP SESSIONS**  RDCLAK5uy_mEXMsobutX4itJVd6YaCodxMgUV-mMtNo
#
# * **TOP 100**   PL4fGSI1pDJn4jhQB4kb9M36dvVmJQPt4T
# * **Pon Reggaeton**       RDCLAK5uy_ll_3x-AJOymCxeODF09ZjyXg7b6m7OBqs
# * **Al Millon**        RDCLAK5uy_lOAAW-PX5XUed76iQefCxkOXd6m6ZvyiM
# * **Lo esencial del reggaetón**    RDCLAK5uy_mFaoBNPmTUVcY51UGFuAYedXv4kXuqg5M
# * **Hot Reggaeton** RDCLAK5uy_kV0Nh-OIcnh8LppyiFE4lhhWZEvaPQEOY
# * **Reggaeton Hits 2022** RDCLAK5uy_nCwpBIEzaxNFjFj4iWH5JzdwEuGUTCgFM
# * **Reggaeton Playlist - Best Reggaeton Songs** PLPPgknP7IOwXmkAE99CdZ2h4baKNEvzev
# * **Reggaeton 2022 Playlist & Latin Music 2022** PL6Go6XFhidEAac3TgkP8EfLF1bA1odl4e
# * **Top Reggaeton 2021 - 2022 Playlist - Best New Reggaeton Songs 2021 - 2022**    PLq3UZa7STrbpinnTs3HuJY_n49qHUu6Ho
# * **Top Reggaeton Playlist - Best Reggaeton Songs of All Time**    PLo3pNg0eiPc8rRO3XqFnl1Je2GTu7am-F
# * **REGGAETON ROMANTICO 2022/ MEJORES REGGAETONES 2022. Reggaeton nuevos mas tocados**   PL8cNgJdjBpTABXO7i8nrifUJWcHia392H
# * **Reggaeton para bailar**    PLPPgknP7IOwUmPZqVP6oj_K2YPfYdU2DV

# %%
yt = YTMusic()
playlist=['PL4fGSI1pDJn4jhQB4kb9M36dvVmJQPt4T','RDCLAK5uy_ll_3x-AJOymCxeODF09ZjyXg7b6m7OBqs',
'RDCLAK5uy_lOAAW-PX5XUed76iQefCxkOXd6m6ZvyiM','RDCLAK5uy_mFaoBNPmTUVcY51UGFuAYedXv4kXuqg5M',
'RDCLAK5uy_kV0Nh-OIcnh8LppyiFE4lhhWZEvaPQEOY','RDCLAK5uy_nCwpBIEzaxNFjFj4iWH5JzdwEuGUTCgFM',
'PLPPgknP7IOwXmkAE99CdZ2h4baKNEvzev','PL6Go6XFhidEAac3TgkP8EfLF1bA1odl4e','PLq3UZa7STrbpinnTs3HuJY_n49qHUu6Ho',
'PLo3pNg0eiPc8rRO3XqFnl1Je2GTu7am-F','PL8cNgJdjBpTABXO7i8nrifUJWcHia392H','PLPPgknP7IOwUmPZqVP6oj_K2YPfYdU2DV']

artistas = []
diccSolo= {}
diccSolo.clear()
colabos=[]

infoPlayList = []
for p in playlist:
     infoPlayList.append(yt.get_playlist(p))
     
#para rellenar artistas
for r in infoPlayList:
     for a in r['tracks']:
      artistas.append(a['artists'])

#for r in searchPlay['tracks']:
#     artistas.append(r['artists'])

for a in artistas:#cargamos el diccionario con los artistas que van a cantar solos
   for b in a:
    if(len(a)==1):
        diccSolo[b['name']]={'idYTMusic':b['id'],'colaboracion':[]}

# %%
diccColabo= {}
diccColabo.clear()

for a in artistas:#aqui cargamos solo artistas que han aparecido con colaboraciones en la playlist
  if(len(a)>1):
      diccColabo[a[0]['name']]={'idYTMusic':a[0]['id'],'colaboracion':[],'subscriptores':None,'views':None}

      #if(len(a)==2):
          #dicc[b['id']]={'name':b['name']}

# %% [markdown]
# Nos quedamos con el diccionario de colaboraciones para empezar nuestro análisis. Y empezamos a meter los atributos que nos vendran en el estudio. En este caso, recorriendo otra vez los artistas, sacaremos las colaboraciones de cada uno y la añadiremos

# %%
#c[1]['name']
for c in artistas:#aqui les metemos en colaboraciones sus feats
    if(len(c)>1):
      # print(c[i+1]['name'])--> funcion que recorre artistas de las colaboraciones
      #añadimos artistas a las colabos
           for i in range(len(c)-1):
            diccColabo[c[0]['name']]['colaboracion'].append(c[i+1]['name'])
#diccColabo

# %% [markdown]
# Al proseguir creando la red , nos dimos cuenta que un atributo que seria importante como el id de cada artista; algunas veces no salia. Aparecia como vacío y nos daba fallo al no poder mostrar nada. Esto era o bien porque no tienen canal creado dentro de esta plataforma o porque a veces la aplicación falla ocasionalmente. Por eso en este código buscamos estos espacios vacío, y los rellenamos usando otra funcion de la appi que nos proporciona tambien el id del artista: "search". En el caso de que no nos encuentre nada ponemos que no tiene canal creado.

# %%
#para quitar los artistas que no tiene id ytMusic(fallo de la api)

for a in diccColabo:
   if(diccColabo[a]['idYTMusic']==None):
     idsvacios=yt.search(a)
     if('browseId'not in idsvacios[0]):#VER SI TIENE  ['browseId'] , SI NO LO TIENE SE PONE NO CHANNEL, SI TIENE SE PONE LO QUE ESTA EN EL ELSE  
      diccColabo[a]['idYTMusic']='No Channel'
     else:
      diccColabo[a]['idYTMusic']=idsvacios[0]['browseId']
   
#diccColabo

# %%
#numeramos con ids 
i=0
for keys in diccColabo:
    diccColabo[keys]['id']=i
    i=i+1

# %% [markdown]
# Una vez bien creado las bases del csv, procedemos a rellenar la información de cada artista. En este caso meteremos sus visitas y sus suscriptores. Como resultado obtenemos el diccionario al completo con el que podremos crear el csv.

# %%
#sacamos artistas , del diccionario por su id, sacamos los que tienen canal,y metemos su info de vistas y subscriptores
infoartista=[]
infoSubscribers=[]
infoViews=[]
for a in diccColabo:
   infoartista.append(diccColabo[a]['idYTMusic'])
  
for r in infoartista:
   if(r!='No Channel'):
      artista=yt.get_artist(r)
      infoSubscribers.append(artista['subscribers'])
      if(artista['views']!=None):
         infoViews.append(artista['views'])
      else:
         infoViews.append("No info")
i=0
for keys in diccColabo:
    if(diccColabo[keys]['idYTMusic']!='No Channel'):
      diccColabo[keys]['subscriptores']=infoSubscribers[i]
      diccColabo[keys]['views']=infoViews[i]
      i=i+1

# %% [markdown]
# Con el diccionario obtenido arriba, tenemos colaboraciones completadas, pero no los nodos. El nodo a colabora con b y c, pero solo esta reconocido como nodo a , b y c no. Tenemos que crear nodos para los colaboradores tambien. Esta estructura nos viene bien para sacar los csv de aristas y de nodos para el análisis de gephi, porque solo tiene que tratar las colaboraciones una única vez. Es decir que va a tratar como 1 colaboración A-B. De la otra manera sería muy costoso porque trataría las colaboraciones 2 veces A-B y B-A

# %%
#para rellenar si es explicito  para artistas con colabos       
duration = []
explicit = []
publicacion=[]
vistas=[]
videosIds=[]
artistasAristas=[]
for r in infoPlayList:
     for a in r['tracks']:
          if(len(a['artists'])>1):
            explicit.append(a['isExplicit'])

#para rellenar duracion seg   para artistas con colabos     
for r in infoPlayList:
     for a in r['tracks']:
           if(len(a['artists'])>1):
            duration.append(a['duration_seconds'])
#para los artistas del csv
for r in infoPlayList:
     for a in r['tracks']:
           if(len(a['artists'])>1):
            artistasAristas.append(a['artists'])

#para las vistas de cada cancion
for r in infoPlayList:
     for a in r['tracks']:
           if(len(a['artists'])>1):
               searchMusic=yt.get_song(a['videoId'])
               publicacion.append(searchMusic['microformat']['microformatDataRenderer']['publishDate'])
               vistas.append(searchMusic['microformat']['microformatDataRenderer']['viewCount'])

# %% [markdown]
# Utilizamos la tabla de aristas para sacar los artistas que no han sido reconocidos como nodos y lo añadimos vacios

# %%
for r in artistasAristas:
   for i in range(len(r)-1):
        a=i+1
        if(r[a]['name'] not in diccColabo):
           diccColabo[r[a]['name']]={'idYTMusic':'None','colaboracion':[],'subscriptores':None,'views':None,'id':None}
           search_results=yt.search(r[a]['name'])
           
           if('browseId'in search_results[0]):
            if(search_results[0]['browseId'][0]=='U'):
               
                searcArtist=yt.get_artist(search_results[0]['browseId'])
                diccColabo[r[a]['name']]['idYTMusic']=search_results[0]['browseId']
                diccColabo[r[a]['name']]['subscriptores']=searcArtist['subscribers']
                if(searcArtist['views']==None):
                     diccColabo[r[a]['name']]['views']="No info"
                else:
                    diccColabo[r[a]['name']]['views']=searcArtist['views']
        
i=0
for keys in diccColabo:
    if(diccColabo[keys]['id']==None):
        diccColabo[keys]['id']=i
    i=i+1

# %% [markdown]
# Asi quedaría el diccionario definitivo

# %%
diccColabo
#FALTA  Y COLABOOOOOS
# Out:
# {'Arcangel': {'idYTMusic': 'UCVcAt8IIKIeubRSigcYXgtA',
#   'colaboracion': ['Bad Bunny', 'Bad Bunny', 'Sech'],
#   'subscriptores': '10.7M',
#   'views': '4,757,030,131 views',
#   'id': 0},
#  'Farruko': {'idYTMusic': 'UC6QXZsAOOweLfhVPbqMyG4g',
#   'colaboracion': ['Omar Montes',
#    'Rauw Alejandro',
#    'Natti Natasha',
#    'Justin Quiles',
#    'Sean Paul',
#    'Nicky Jam',
#    'Amenazzy',
#    'Don Omar',
#    'Myke Towers',
#    'Rvssian',
#    'J Balvin',
#    'Rauw Alejandro',
#    'Anuel AA',
#    'Zumbi',
#    'Rauw Alejandro',
#    'KEVVO',
#    'Chencho Corleone',
#    'Natti Natasha',
#    'Justin Quiles',
#    'Lenny Tavárez',
#    'Natti Natasha',
#    'Dalex',
#    'Rauw Alejandro',
#    'Nicky Jam',
#    'Amenazzy',
#    'Rvssian',
#    'J Balvin',
#    'Nicky Jam',
#    'Amenazzy'],
#   'subscriptores': '18.3M',
#   'views': '8,917,081,158 views',
#   'id': 1},
#  'Quevedo': {'idYTMusic': 'UC7PL9aor5qNRhvhWWVXyOqA',
#   'colaboracion': ['Bizarrap',
#    'Ovy On The Drums',
#    'Myke Towers',
#    'Mora',
#    'Bad Gyal',
#    'Mora',
#    'Polima Westcoast',
#    'Bizarrap',
#    'Myke Towers',
#    'Mora',
#    'Polima Westcoast',
#    'Bizarrap',
#    'De La Ghetto',
#    'Duki'],
#   'subscriptores': '1.1M',
#   'views': '296,360,104 views',
#   'id': 2},
#  'Bizarrap': {'idYTMusic': 'UCONiUl5u7y2bMaVZJcuRDEQ',
#   'colaboracion': ['Duki', 'Duki'],
#   'subscriptores': '16.6M',
#   'views': '5,849,808,044 views',
#   'id': 3},
#  'Aitana': {'idYTMusic': 'UCkyzcFsGWVYSUGaR7YB9OYQ',
#   'colaboracion': ['Sangiovanni'],
#   'subscriptores': '2.15M',
#   'views': 'No info',
#   'id': 4},
#  'Belinda': {'idYTMusic': 'UC8tw8d2POmc3Lt8t1bmgl9Q',
#   'colaboracion': ['Ana Mena', 'Ana Mena'],
#   'subscriptores': '870K',
#   'views': '352,382,429 views',
#   'id': 5},
#  'Melendi': {'idYTMusic': 'UCl4jq8XKq5X0ZL5p_xVMmZA',
#   'colaboracion': ['India Martínez'],
#   'subscriptores': '4.41M',
#   'views': '3,767,208,185 views',
#   'id': 6},
#  'Rauw Alejandro': {'idYTMusic': 'UCw_m17sBd4GHxuK83-AZtuA',
#   'colaboracion': ['Baby Rasta',
#    'Lyanno',
#    'Brray',
#    'Lyanno',
#    'Brray',
#    'Baby Rasta',
#    'Nio Garcia',
#    'Lenny Tavárez',
#    'Baby Rasta',
#    'Nio Garcia',
#    'Lenny Tavárez',
#    'Lyanno',
#    'Brray',
#    'Chencho Corleone',
#    'Mr. NaisGai',
#    'Lyanno',
#    'Brray',
#    'Chencho Corleone',
#    'Baby Rasta',
#    'Chencho Corleone',
#    'Lyanno',
#    'Brray',
#    'Álvaro Díaz',
#    'Baby Rasta',
#    'Chencho Corleone',
#    'Lyanno',
#    'Brray',
#    'Álvaro Díaz',
#    'Baby Rasta',
#    'Lyanno',
#    'Brray',
#    'Chencho Corleone',
#    'Chencho Corleone',
#    'Chencho Corleone',
#    'Chencho Corleone'],
#   'subscriptores': '12.3M',
#   'views': '10,178,787,164 views',
#   'id': 7},
#  'Anuel AA': {'idYTMusic': 'UCbBaYg2UToDaoOwo-R6xi4g',
#   'colaboracion': ['Jowell & Randy',
#    'De La Ghetto',
#    'Yailin la Mas Viral',
#    'MVSIS',
#    'David Guetta',
#    'Bryant Myers',
#    'Foreign Teck',
#    'Chris Jedi',
#    'Gaby Music',
#    'Jowell & Randy',
#    'De La Ghetto',
#    'Yailin la Mas Viral',
#    'Chris Jedi',
#    'Gaby Music',
#    'Jowell & Randy',
#    'De La Ghetto',
#    'Yailin la Mas Viral',
#    'Chris Jedi',
#    'Ñengo Flow',
#    'Chencho Corleone',
#    'Tainy',
#    'Ozuna',
#    'Chris Jedi',
#    'Ñengo Flow',
#    'Chencho Corleone',
#    'Rauw Alejandro',
#    'Daddy Yankee',
#    'Sech',
#    'Ozuna',
#    'Jowell & Randy',
#    'De La Ghetto',
#    'Yailin la Mas Viral',
#    'Chris Jedi',
#    'Ñengo Flow',
#    'Chencho Corleone',
#    'Chris Jedi',
#    'Gaby Music',
#    'Randy Nota Loca',
#    'Zion',
#    'Chris Jedi',
#    'Ñengo Flow',
#    'Chencho Corleone',
#    'Brytiago',
#    'Daddy Yankee',
#    'Darell',
#    'Ozuna',
#    'Daddy Yankee',
#    'Natti Natasha',
#    'Rauw Alejandro',
#    'Chris Jedi',
#    'Gaby Music',
#    'Chris Jedi',
#    'Ñengo Flow',
#    'Chencho Corleone',
#    'Rauw Alejandro',
#    'Rvssian',
#    'Juice WRLD',
#    'Ozuna',
#    'Tainy',
#    'Ozuna',
#    'Chris Jedi',
#    'Gaby Music',
#    'Tainy',
#    'Ozuna',
#    'Tainy',
#    'Ozuna',
#    'Daddy Yankee',
#    'Darell',
#    'Ozuna',
#    'Daddy Yankee'],
#   'subscriptores': '23.4M',
#   'views': '12,692,939,530 views',
#   'id': 8},
#  'Abraham Mateo': {'idYTMusic': 'UCql3y41dHUh9JoPHMedvCbQ',
#   'colaboracion': ['Ana Mena'],
#   'subscriptores': '4.63M',
#   'views': '1,819,667,437 views',
#   'id': 9},
#  'Shakira': {'idYTMusic': 'UCo6JijJGA3IvIiPsawDK3Ww',
#   'colaboracion': ['Ozuna',
#    'Rauw Alejandro',
#    'Ozuna',
#    'Ozuna',
#    'Ozuna',
#    'Rauw Alejandro',
#    'Anuel AA',
#    'Pedro Capó',
#    'Camilo',
#    'Maluma'],
#   'subscriptores': '39.3M',
#   'views': '25,051,014,029 views',
#   'id': 10},
#  'Emilia': {'idYTMusic': 'UCvXoAG_trv-m2pv5_1HVFvA',
#   'colaboracion': ['Ptazeta',
#    'Aitana',
#    'Ptazeta',
#    'Aitana',
#    'Ptazeta',
#    'Aitana'],
#   'subscriptores': '1.28M',
#   'views': '645,835,639 views',
#   'id': 11},
#  'KAROL G': {'idYTMusic': 'UC7n3gWRN0vQzgiOKc51aZ4w',
#   'colaboracion': ['Maldy',
#    'Ovy On The Drums',
#    'Ovy On The Drums',
#    'Maldy',
#    'Ovy On The Drums',
#    'Maldy',
#    'Maldy',
#    'Nicki Minaj',
#    'Anuel AA',
#    'Feid',
#    'Maldy',
#    'Maldy',
#    'Feid',
#    'Maldy',
#    'Anuel AA',
#    'Daddy Yankee',
#    'Anuel AA',
#    'Ovy On The Drums',
#    'Maldy',
#    'Feid',
#    'Nicki Minaj',
#    'Simone & Simaria',
#    'Anuel AA',
#    'Daddy Yankee',
#    'Nicki Minaj',
#    'Anuel AA',
#    'Mariah Angeliq ',
#    'Feid',
#    'Nicki Minaj',
#    'Anuel AA',
#    'Daddy Yankee',
#    'Anuel AA',
#    'Anuel AA',
#    'Daddy Yankee',
#    'Anuel AA',
#    'Anuel AA'],
#   'subscriptores': '28.7M',
#   'views': '15,391,322,780 views',
#   'id': 12},
#  'India Martínez': {'idYTMusic': 'UCJbpTwP22V6baVULM7-J4Bw',
#   'colaboracion': ['Andy Rivera'],
#   'subscriptores': '1.01M',
#   'views': '709,192,360 views',
#   'id': 13},
#  'Jairo deRemache': {'idYTMusic': 'UC0rxntgJfUecm5h_d6mY8eg',
#   'colaboracion': ['Farruquito', 'Omar Montes'],
#   'subscriptores': '193',
#   'views': 'No info',
#   'id': 14},
#  'Rema': {'idYTMusic': 'UCy6qn2oxmoXA4_gBA5Q7zPw',
#   'colaboracion': ['Selena Gomez'],
#   'subscriptores': '2.54M',
#   'views': '760,289,252 views',
#   'id': 15},
#  'Jhayco': {'idYTMusic': 'UChZEzxer-QvRMbADJJGOMuQ',
#   'colaboracion': ['Mora',
#    'Feid',
#    'Sech',
#    'Myke Towers',
#    'Feid',
#    'Sech',
#    'Myke Towers',
#    'Myke Towers',
#    'Anuel AA',
#    'Mora',
#    'Sech',
#    'Feid',
#    'Sech',
#    'Myke Towers',
#    'Myke Towers',
#    'Anuel AA',
#    'Anuel AA',
#    'Mora',
#    'Anuel AA'],
#   'subscriptores': '4.75M',
#   'views': '3,734,531,791 views',
#   'id': 16},
#  'Sergio Ramos': {'idYTMusic': 'UC2MgeVTYErtkCzRMucgFyjQ',
#   'colaboracion': ['Niña Pastori', 'RedOne'],
#   'subscriptores': '583',
#   'views': '8,984 views',
#   'id': 17},
#  'C. Tangana': {'idYTMusic': 'UCLuHOvsT_LbOGVjqmXudvBg',
#   'colaboracion': ['Omar Montes', 'Becky G', 'Becky G'],
#   'subscriptores': '2.23M',
#   'views': '1,373,657,757 views',
#   'id': 18},
#  'JC Reyes': {'idYTMusic': 'UCXGll6UzxbSdLO1_w7rP22g',
#   'colaboracion': ['Pablo Chill-E', 'Ecko', 'Pablo Chill-E', 'Ecko'],
#   'subscriptores': '17.7K',
#   'views': 'No info',
#   'id': 19},
#  'Galvan Real': {'idYTMusic': 'UC0r04hp-02vxsjHBVlm4F3A',
#   'colaboracion': ['María Artés Lamorena'],
#   'subscriptores': '418K',
#   'views': 'No info',
#   'id': 20},
#  'Nicki Minaj': {'idYTMusic': 'UCTTcTeAszDGxALRSMkJH9FQ',
#   'colaboracion': ['Maluma', 'Myriam Fares', 'FIFA Sound'],
#   'subscriptores': '25.1M',
#   'views': '9,740,024,406 views',
#   'id': 21},
#  'Cano': {'idYTMusic': 'UCumOUWYBPRw2pxGl7QGeiRw',
#   'colaboracion': ['El Jhota', 'Los del Control'],
#   'subscriptores': '181K',
#   'views': 'No info',
#   'id': 22},
#  'Kidd Keo': {'idYTMusic': 'UCv7W2bEmNY7yl9XxSsn3NvQ',
#   'colaboracion': ['TALE$'],
#   'subscriptores': '4.69M',
#   'views': 'No info',
#   'id': 23},
#  'David Guetta': {'idYTMusic': 'UCh-4c1ZoBPNP1C8c-7iVvUQ',
#   'colaboracion': ['Bebe Rexha'],
#   'subscriptores': '24.8M',
#   'views': '16,603,503,460 views',
#   'id': 24},
#  'ROSALÍA': {'idYTMusic': 'UCeYz6rzUGhVwqxRM37FUo8w',
#   'colaboracion': ['Romeo Santos', 'Romeo Santos', 'Romeo Santos'],
#   'subscriptores': '9.97M',
#   'views': '4,683,595,718 views',
#   'id': 25},
#  'Lola Indigo': {'idYTMusic': 'UCydg_dYqBrPZ4-X1MnxD37A',
#   'colaboracion': ['Maria Becerra'],
#   'subscriptores': '1.24M',
#   'views': '687,102,269 views',
#   'id': 26},
#  'Beret': {'idYTMusic': 'UCz34FayZhwHJNdCLqhwVYaw',
#   'colaboracion': ['Estopa'],
#   'subscriptores': '4.56M',
#   'views': '1,451,507,398 views',
#   'id': 27},
#  'RVFV': {'idYTMusic': 'UCj6HoOP59UGegqUC-fu4Wlg',
#   'colaboracion': ['Duki'],
#   'subscriptores': '981K',
#   'views': 'No info',
#   'id': 28},
#  'Wiso Rivera': {'idYTMusic': 'UCwfvKaHqW4r64dOurVFzD9A',
#   'colaboracion': ['Cruz Cafuné', 'Juseph'],
#   'subscriptores': '175',
#   'views': 'No info',
#   'id': 29},
#  'Oliver Tree': {'idYTMusic': 'UCoOFEu6s0wk7CUljMh8wisw',
#   'colaboracion': ['Robin Schulz'],
#   'subscriptores': '4.34M',
#   'views': '1,256,321,438 views',
#   'id': 30},
#  'Myke Towers': {'idYTMusic': 'UCYPsIfSIEwWcoynHBP5k1dg',
#   'colaboracion': ['Daddy Yankee',
#    'Daddy Yankee',
#    'Daddy Yankee',
#    'DJ Nelson',
#    'Jay Wheeler',
#    'Daddy Yankee',
#    'Tiago PZK',
#    'Tiago PZK',
#    'Juhn',
#    'DJ Nelson',
#    'Jay Wheeler'],
#   'subscriptores': '9.58M',
#   'views': 'No info',
#   'id': 31},
#  'Kiddo': {'idYTMusic': 'UCVLS_HdJZUDE-4_Yzcd1vAA',
#   'colaboracion': ['Pepe : Vizio', 'Delaossa'],
#   'subscriptores': '102',
#   'views': 'No info',
#   'id': 32},
#  'Subelo Neo': {'idYTMusic': 'UCYEfkGCYwm66_W3xj6zaD4Q',
#   'colaboracion': ['Rauw Alejandro'],
#   'subscriptores': '13',
#   'views': 'No info',
#   'id': 33},
#  'Mora': {'idYTMusic': 'UCgDpp8Ex8Yz6hhHjbl3W5mg',
#   'colaboracion': ['Feid',
#    'De La Ghetto',
#    'Feid',
#    'Sech',
#    'Feid',
#    'Bad Bunny',
#    'Sech',
#    'Feid',
#    'Bad Bunny',
#    'Bad Bunny',
#    'Sech'],
#   'subscriptores': '1.8M',
#   'views': '1,413,600,500 views',
#   'id': 34},
#  'Israel Fernández': {'idYTMusic': 'UCWSr_7vrGMRLRXfaX4cpa5A',
#   'colaboracion': ['Omar Montes'],
#   'subscriptores': '37.1K',
#   'views': 'No info',
#   'id': 35},
#  'Manuel Turizo': {'idYTMusic': 'UCfh2j2Dq-aSeLhzuPOsnhVg',
#   'colaboracion': ['Piso 21',
#    'Maria Becerra',
#    'Ozuna',
#    'Feid',
#    'Arcangel',
#    'Myke Towers',
#    'Rauw Alejandro',
#    'Ozuna',
#    'Mau y Ricky',
#    'Camilo',
#    'Anuel AA',
#    'Ozuna',
#    'Ozuna',
#    'Mau y Ricky',
#    'Camilo'],
#   'subscriptores': '9.09M',
#   'views': 'No info',
#   'id': 36},
#  'Wisin': {'idYTMusic': 'UCFVg6y3fZO7OVFbmoGfNdhQ',
#   'colaboracion': ['Jowell & Randy',
#    'Jowell & Randy',
#    'Nicky Jam',
#    'Jowell & Randy',
#    'Nicky Jam',
#    'Ozuna'],
#   'subscriptores': '7.41M',
#   'views': '6,130,364,005 views',
#   'id': 37},
#  'Ryan Castro': {'idYTMusic': 'UCDxiGGtBV3CQiE-NKLEFgUg',
#   'colaboracion': ['SOG', 'SOG', 'SOG', 'Feid', 'Feid', 'Blessd', 'Feid'],
#   'subscriptores': '2.34M',
#   'views': 'No info',
#   'id': 38},
#  'Cris Mj': {'idYTMusic': 'UCOykHV9q0qb0vrBsxO_5fkQ',
#   'colaboracion': ['Tiago PZK'],
#   'subscriptores': '1.53M',
#   'views': 'No info',
#   'id': 39},
#  'Standly': {'idYTMusic': 'UCmIeOVFFYF72643-4SspXWA',
#   'colaboracion': ['Stars Music Chile',
#    'Cris Mj',
#    'Stars Music Chile',
#    'Cris Mj',
#    'Stars Music Chile',
#    'Cris Mj',
#    'Stars Music Chile',
#    'Cris Mj'],
#   'subscriptores': '1.09M',
#   'views': 'No info',
#   'id': 40},
#  'Xyron': {'idYTMusic': 'UCq5W39BHJWSDbc_jLyvh_KQ',
#   'colaboracion': ['Nicky Jam', 'Rapeton Approved'],
#   'subscriptores': '1.23K',
#   'views': 'No info',
#   'id': 41},
#  'Natti Natasha': {'idYTMusic': 'UCqMwRUFZ6APDCsz61zEdhKQ',
#   'colaboracion': ['Maria Becerra',
#    'Ozuna',
#    'Maria Becerra',
#    'Becky G',
#    'Thalía',
#    'Maria Becerra',
#    'Ozuna',
#    'Thalía',
#    'Thalía',
#    'Daddy Yankee',
#    'Pitbull'],
#   'subscriptores': '12M',
#   'views': '7,577,828,884 views',
#   'id': 42},
#  'Yandel': {'idYTMusic': 'UCc1QpDE0iT0n6ZLckjflNHw',
#   'colaboracion': ['Tiago PZK',
#    'Arcangel',
#    'Arcangel',
#    'Tiago PZK',
#    'Rauw Alejandro',
#    'Anuel AA'],
#   'subscriptores': '5.44M',
#   'views': '3,798,981,231 views',
#   'id': 43},
#  'Pablo Chill-E': {'idYTMusic': 'UClixM-IgWBruYaGueMOruOg',
#   'colaboracion': ['Cris Mj', 'Harry Nach'],
#   'subscriptores': '991K',
#   'views': 'No info',
#   'id': 44},
#  'Zion & Lennox': {'idYTMusic': 'UC8U7wOw_Hd7ltvcWOWAp21g',
#   'colaboracion': ['Feid'],
#   'subscriptores': '3.39M',
#   'views': '2,802,344,916 views',
#   'id': 45},
#  'Blessd': {'idYTMusic': 'UC3vpYFFzqIzsXbMgneDTSeQ',
#   'colaboracion': ['De La Ghetto',
#    'Darell',
#    'De La Ghetto',
#    'Darell',
#    'De La Ghetto',
#    'Darell',
#    'Ryan Castro',
#    'Ryan Castro'],
#   'subscriptores': '2M',
#   'views': '1,417,212,662 views',
#   'id': 46},
#  'Fran C.': {'idYTMusic': 'UChKGa5uCEN3O9u0VNeDZ5yQ',
#   'colaboracion': ['Pablo Pesadilla',
#    'Polima Westcoast',
#    'Nickoog Clk',
#    'Pablo Pesadilla',
#    'Polima Westcoast',
#    'Nickoog Clk',
#    'Pablo Pesadilla',
#    'Polima Westcoast',
#    'Nickoog Clk'],
#   'subscriptores': '17.6K',
#   'views': 'No info',
#   'id': 47},
#  'Wisin & Yandel': {'idYTMusic': 'UCJ0-R-v3CaJNYMqfp9tivqA',
#   'colaboracion': ['Rauw Alejandro',
#    'Daddy Yankee',
#    'Natti Natasha',
#    'Daddy Yankee',
#    'Natti Natasha',
#    'Daddy Yankee',
#    'Daddy Yankee',
#    'Daddy Yankee'],
#   'subscriptores': '7.02M',
#   'views': '5,838,829,397 views',
#   'id': 48},
#  'De La Ghetto': {'idYTMusic': 'UCf3TsqO9Ysrw8k63aHg4O5A',
#   'colaboracion': ['Pailita',
#    'Polima Westcoast',
#    'Feid',
#    'Daddy Yankee',
#    'Ozuna',
#    'Rauw Alejandro',
#    'Pailita',
#    'Polima Westcoast',
#    'Feid',
#    'J Balvin'],
#   'subscriptores': '2.89M',
#   'views': '1,205,037,834 views',
#   'id': 49},
#  'Maluma': {'idYTMusic': 'UCtKIuEMDzPlUmPgdwBhiGcg',
#   'colaboracion': ['Chencho Corleone',
#    'Chencho Corleone',
#    'Chencho Corleone',
#    'Blessd',
#    'Chencho Corleone',
#    'Chencho Corleone',
#    'Chencho Corleone',
#    'Jennifer Lopez',
#    'GIMS',
#    'Becky G',
#    'Farina',
#    'J Balvin',
#    'Wisin',
#    'De La Ghetto',
#    'GIMS'],
#   'subscriptores': '28.9M',
#   'views': '20,255,933,637 views',
#   'id': 50},
#  'DJ Premier': {'idYTMusic': 'UCrWGuJPZpTT0UYL6NXQcBtA',
#   'colaboracion': ['Feid'],
#   'subscriptores': '163K',
#   'views': '12,705,984 views',
#   'id': 51},
#  'The Rudeboyz': {'idYTMusic': 'UCOGP7HlRV6GctAaZGGy0RSQ',
#   'colaboracion': ['Maluma', 'Adam Levine'],
#   'subscriptores': '90.2K',
#   'views': 'No info',
#   'id': 52},
#  'Trueno': {'idYTMusic': 'UCEPYn7xbzvQwL9C21evFGDg',
#   'colaboracion': ['Tiago PZK'],
#   'subscriptores': '5.86M',
#   'views': '1,376,011,149 views',
#   'id': 53},
#  'Ozuna': {'idYTMusic': 'UCKEFjh4JL-OyMI8z3h5Coaw',
#   'colaboracion': ['Tiago PZK',
#    'Karol G',
#    'Myke Towers',
#    'Tiago PZK',
#    'Tiago PZK',
#    'Tiago PZK',
#    'Sech',
#    'Tokischa',
#    'Karol G',
#    'Myke Towers',
#    'Camilo',
#    'Daddy Yankee',
#    'ROSALÍA'],
#   'subscriptores': '35.7M',
#   'views': '22,037,213,588 views',
#   'id': 54},
#  'Bad Bunny': {'idYTMusic': 'UCiY3z8HAGD6BlSNKVn2kSvQ',
#   'colaboracion': ['Jhay Cortez',
#    'J Balvin',
#    'Jhay Cortez',
#    'Tainy',
#    'Jowell & Randy',
#    'Ñengo Flow',
#    'J Balvin',
#    'Jhay Cortez',
#    'Daddy Yankee',
#    'Daddy Yankee',
#    'Jhay Cortez',
#    'Jowell & Randy',
#    'Ñengo Flow',
#    'J Balvin',
#    'Jhay Cortez',
#    'Farruko',
#    'Natti Natasha',
#    'ROSALÍA',
#    'Tainy',
#    'Sech',
#    'J Balvin',
#    'ROSALÍA',
#    'Jhay Cortez',
#    'Anuel AA',
#    'Dua Lipa',
#    'Tainy',
#    'J Balvin',
#    'Daddy Yankee',
#    'YAVIAH',
#    'J Balvin',
#    'Jhay Cortez',
#    'Tainy',
#    'J Balvin',
#    'J Balvin',
#    'Jhay Cortez',
#    'Jhay Cortez',
#    'Anuel AA',
#    'Jowell & Randy',
#    'Ñengo Flow',
#    'Tainy',
#    'ROSALÍA',
#    'Bomba Estéreo',
#    'J Balvin',
#    'Farruko',
#    'J Balvin',
#    'Jhay Cortez',
#    'Jhay Cortez',
#    'Jowell & Randy',
#    'Ñengo Flow',
#    'Jennifer Lopez',
#    'Wisin',
#    'Wisin & Yandel'],
#   'subscriptores': '44.8M',
#   'views': '27,499,680,353 views',
#   'id': 55},
#  'Becky G': {'idYTMusic': 'UC3UkDuAQjoRvTH7OEWm3cHQ',
#   'colaboracion': ['Natti Natasha',
#    'Paulo Londra',
#    'KAROL G',
#    'KAROL G',
#    'Paulo Londra',
#    'Natti Natasha',
#    'TINI',
#    'Anitta',
#    'KAROL G',
#    'Natti Natasha',
#    'Natti Natasha'],
#   'subscriptores': '20.7M',
#   'views': '9,948,885,530 views',
#   'id': 56},
#  'Maria Becerra': {'idYTMusic': 'UCyE23CF-5Be1FgN-VcFGg8A',
#   'colaboracion': ['J Balvin', 'Reik'],
#   'subscriptores': '3.83M',
#   'views': '1,828,319,014 views',
#   'id': 57},
#  'Dimelo Flow': {'idYTMusic': 'UCFc1GajMRv1jh4BIDj_n93g',
#   'colaboracion': ['Arcangel',
#    'Lenny Tavárez',
#    'Wisin',
#    'Dalex',
#    'Arcangel',
#    'Arcangel'],
#   'subscriptores': '664K',
#   'views': '357,743,270 views',
#   'id': 58},
#  'Crissin': {'idYTMusic': 'UC_Q2Ob7v-SlNlOiqHNrWQLw',
#   'colaboracion': ['Natan & Shander',
#    'Totoy El Frio',
#    'Natan & Shander',
#    'Totoy El Frio'],
#   'subscriptores': '15.4K',
#   'views': 'No info',
#   'id': 59},
#  'Lenny Tavárez': {'idYTMusic': 'UCpOtgk_uRB6PZK47wUXXlVQ',
#   'colaboracion': ['Blessd',
#    'Justin Quiles',
#    'Blessd',
#    'Justin Quiles',
#    'Blessd',
#    'Justin Quiles',
#    'Justin Quiles',
#    'Blessd',
#    'Justin Quiles',
#    'Dalex',
#    'Rauw Alejandro',
#    'Dalex',
#    'Brytiago'],
#   'subscriptores': '3.07M',
#   'views': '845,382,191 views',
#   'id': 60},
#  'Lunay': {'idYTMusic': 'UCPJQHfMDWwUdrKPkZfZNA0Q',
#   'colaboracion': ['Bad Bunny',
#    'Daddy Yankee',
#    'Lenny Tavárez',
#    'Boza',
#    'Juhn',
#    'Lenny Tavárez',
#    'Boza',
#    'Juhn',
#    'Bad Bunny',
#    'Daddy Yankee',
#    'Bad Bunny',
#    'Daddy Yankee',
#    'Bad Bunny',
#    'Daddy Yankee',
#    'Anuel AA',
#    'Ozuna',
#    'Bad Bunny',
#    'Daddy Yankee',
#    'Bad Bunny',
#    'Daddy Yankee'],
#   'subscriptores': '5.12M',
#   'views': '2,336,214,563 views',
#   'id': 61},
#  'J Balvin': {'idYTMusic': 'UCWw-Guyr5ul9B-d5kJlHMng',
#   'colaboracion': ['Sech',
#    'Daddy Yankee',
#    'Sech',
#    'Daddy Yankee',
#    'Zion & Lennox',
#    'Jowell & Randy',
#    'Ozuna',
#    'Chencho Corleone',
#    'Sech',
#    'Black Eyed Peas',
#    'Zion & Lennox',
#    'Zion & Lennox'],
#   'subscriptores': '33.8M',
#   'views': '22,113,531,860 views',
#   'id': 62},
#  'Nicky Jam': {'idYTMusic': 'UCMJ705HLB_EflTzWDAjcKSQ',
#   'colaboracion': ['Ozuna',
#    'Dalex',
#    'Justin Quiles',
#    'J Balvin',
#    'Ozuna',
#    'Anuel AA',
#    'J Balvin',
#    'Dalex',
#    'Justin Quiles',
#    'Sech',
#    'Mau y Ricky',
#    'Ozuna',
#    'J Balvin',
#    'Enrique Iglesias',
#    'Ozuna',
#    'Rauw Alejandro',
#    'Alex Sensation',
#    'J Balvin',
#    'Ozuna'],
#   'subscriptores': '23.3M',
#   'views': '15,356,942,730 views',
#   'id': 63},
#  'Nio Garcia': {'idYTMusic': 'UCSBeb5-yOlKqw1lS95ciqcA',
#   'colaboracion': ['Bad Bunny',
#    'J Balvin',
#    'Anuel AA',
#    'Myke Towers',
#    'Lenny Tavárez',
#    'Rauw Alejandro',
#    'Bad Bunny',
#    'J Balvin',
#    'Bad Bunny',
#    'J Balvin',
#    'Flow La Movie',
#    'Casper Magico',
#    'Bad Bunny',
#    'J Balvin'],
#   'subscriptores': '1.32M',
#   'views': 'No info',
#   'id': 64},
#  'Brytiago': {'idYTMusic': 'UCoEnXQjMHQX-5EEjhDMMXtQ',
#   'colaboracion': ['Darell'],
#   'subscriptores': '5.27M',
#   'views': '3,136,203,846 views',
#   'id': 65},
#  'Dalex': {'idYTMusic': 'UCXTtAAlWYj1RCVPZ-PYWoqA',
#   'colaboracion': ['Sech', 'Rich Music, Ltd'],
#   'subscriptores': '6.12M',
#   'views': '3,972,034,571 views',
#   'id': 66},
#  'Robi': {'idYTMusic': 'UCpjGA1q99cLKEvKlULb1Llw',
#   'colaboracion': ['Alejo', 'Feid', 'Alejo', 'Feid', 'Alejo', 'Feid'],
#   'subscriptores': '32.3K',
#   'views': 'No info',
#   'id': 67},
#  'Feid': {'idYTMusic': 'UCc3e8O2V5_7OA300ursDyFQ',
#   'colaboracion': ['Justin Quiles'],
#   'subscriptores': '3.67M',
#   'views': '3,146,131,966 views',
#   'id': 68},
#  'Los Legendarios': {'idYTMusic': 'UCu9edbv_LWcPQTOmP4FpOtg',
#   'colaboracion': ['Jhayco', 'Wisin', 'Myke Towers'],
#   'subscriptores': '54.3K',
#   'views': '162,663,319 views',
#   'id': 69},
#  'Aventura': {'idYTMusic': 'UCDaQK4nrsvz27YzufrhJfgg',
#   'colaboracion': ['Bad Bunny', 'Romeo Santos', 'Bad Bunny', 'Romeo Santos'],
#   'subscriptores': '6.11M',
#   'views': '6,613,289,257 views',
#   'id': 70},
#  'Young Miko': {'idYTMusic': 'UCJzwfOuHuaB6DuPfh6rrPoA',
#   'colaboracion': ['Vf7'],
#   'subscriptores': '6.65K',
#   'views': 'No info',
#   'id': 71},
#  'SOG': {'idYTMusic': 'UCfXiritC8HjvxbabC7hIJzA',
#   'colaboracion': ['Ryan Castro', 'Blessd'],
#   'subscriptores': '2.92K',
#   'views': 'No info',
#   'id': 72},
#  'Tainy': {'idYTMusic': 'UCeN6GRz4bN054slorYxms0w',
#   'colaboracion': ['Bad Bunny', 'Julieta Venegas', 'J Balvin', 'J Balvin'],
#   'subscriptores': '2.16M',
#   'views': '1,763,443,812 views',
#   'id': 73},
#  'Tiago PZK': {'idYTMusic': 'UCjYEamX786QxvyO527ezaaw',
#   'colaboracion': ['Trueno',
#    'Trueno',
#    'LIT killah',
#    'Maria Becerra',
#    'Nicki Nicole',
#    'Lit Killah'],
#   'subscriptores': '3.95M',
#   'views': '1,458,530,878 views',
#   'id': 74},
#  'Ovy On The Drums': {'idYTMusic': 'UCtfkGa4ie0BivwCPWCHalOw',
#   'colaboracion': ['Myke Towers', 'Blessd'],
#   'subscriptores': '1.08M',
#   'views': '643,288,035 views',
#   'id': 75},
#  'Sean Paul': {'idYTMusic': 'UCnCNNA05VZcH8wVJYtC-6ew',
#   'colaboracion': ['J Balvin', 'J Balvin', 'J Balvin'],
#   'subscriptores': '4.35M',
#   'views': '2,765,794,967 views',
#   'id': 76},
#  'DJ Luian': {'idYTMusic': 'UC5UPgDCYyAxG8Yjq-0I_xTw',
#   'colaboracion': ['Mambo Kingz',
#    'Nicky Jam',
#    'Anuel AA',
#    'Darell',
#    'Nicky Jam',
#    'Anuel AA',
#    'Darell',
#    'Mambo Kingz',
#    'Ozuna',
#    'Mambo Kingz'],
#   'subscriptores': '524K',
#   'views': 'No info',
#   'id': 77},
#  'Marc Anthony': {'idYTMusic': 'UC22hscWzcVvD_CEPiuaOIbQ',
#   'colaboracion': ['Will Smith', 'Bad Bunny'],
#   'subscriptores': '6.66M',
#   'views': '6,061,731,208 views',
#   'id': 78},
#  'Piso 21': {'idYTMusic': 'UCpe8GCklSIBcxULLHbhQwpQ',
#   'colaboracion': ['Micro TDH'],
#   'subscriptores': '7.56M',
#   'views': '6,634,294,146 views',
#   'id': 79},
#  'DJ Snake': {'idYTMusic': 'UC0c4bK_92XYr0YtASqqWOJg',
#   'colaboracion': ['J Balvin', 'Tyga', 'J Balvin', 'Tyga'],
#   'subscriptores': '23.8M',
#   'views': '7,964,211,366 views',
#   'id': 80},
#  'ChocQuibTown': {'idYTMusic': 'UCZq8jIlmIqSeb079Hr80BEw',
#   'colaboracion': ['Becky G', 'Farruko', 'Zion & Lennox'],
#   'subscriptores': '1.15M',
#   'views': '789,628,230 views',
#   'id': 81},
#  'Trumpmoney': {'idYTMusic': 'UCcOz_kTFH_rrLF47WVphoXQ',
#   'colaboracion': ['andres yuma', 'Vadi'],
#   'subscriptores': '111K',
#   'views': 'No info',
#   'id': 82},
#  'Almighty': {'idYTMusic': 'UCRDGcK3rFRn6VImxBUQVanA',
#   'colaboracion': ['Luar La L'],
#   'subscriptores': '3.1M',
#   'views': 'No info',
#   'id': 83},
#  'Randy': {'idYTMusic': 'UCq5lNggfaWwSiM_W032Ac5A',
#   'colaboracion': ['De La Ghetto', 'Cazzu'],
#   'subscriptores': '884K',
#   'views': 'No info',
#   'id': 84},
#  'Abhir Hathi': {'idYTMusic': 'UCYqIXahUqVJHiF_7Ca9kMDA',
#   'colaboracion': ['EL IMA'],
#   'subscriptores': '15.2K',
#   'views': 'No info',
#   'id': 85},
#  'Prince Royce': {'idYTMusic': 'UC1amDmVt3wHmB7zKpkmf3rg',
#   'colaboracion': ['Maria Becerra'],
#   'subscriptores': '10M',
#   'views': '5,856,145,025 views',
#   'id': 86},
#  'Ñejo': {'idYTMusic': 'UC73Rz2XUqTynb5plO5g1e_w',
#   'colaboracion': ['Ryan Castro', 'Andy Rivera'],
#   'subscriptores': '2.51M',
#   'views': 'No info',
#   'id': 87},
#  'Rei': {'idYTMusic': 'UCxj1FOny1CnD6_P5vIygG4w',
#   'colaboracion': ['Quevedo', 'BANDIDO', 'Duki'],
#   'subscriptores': '872K',
#   'views': 'No info',
#   'id': 88},
#  'Rusherking': {'idYTMusic': 'UC68p6YG34KOL19VezkzaLwA',
#   'colaboracion': ['Dread Mar I'],
#   'subscriptores': '2.11M',
#   'views': 'No info',
#   'id': 89},
#  'Tokischa': {'idYTMusic': 'UC7oLm1CnGj0JwTdlOnQTfGg',
#   'colaboracion': ['Anuel AA', 'Ñengo Flow'],
#   'subscriptores': '1.43M',
#   'views': '291,203,827 views',
#   'id': 90},
#  'Zhamira Zambrano': {'idYTMusic': 'UCGLtX9sThtyfV_pPhQy10SQ',
#   'colaboracion': ['Jay Wheeler'],
#   'subscriptores': '3.29K',
#   'views': 'No info',
#   'id': 91},
#  'Travis Scott': {'idYTMusic': 'UCf_gP4AMRSgAfyzbkeS9k4g',
#   'colaboracion': ['ROSALÍA'],
#   'subscriptores': '16.3M',
#   'views': '7,492,199,383 views',
#   'id': 92},
#  'Pedro Capó': {'idYTMusic': 'UCel_aU5VwTOSWlunrQ89UBQ',
#   'colaboracion': ['Camilo'],
#   'subscriptores': '6.77M',
#   'views': '3,375,403,919 views',
#   'id': 93},
#  'Karol G': {'idYTMusic': 'UC7n3gWRN0vQzgiOKc51aZ4w',
#   'colaboracion': ['Anuel AA'],
#   'subscriptores': '28.7M',
#   'views': '15,391,322,780 views',
#   'id': 94},
#  'El Alfa': {'idYTMusic': 'UCJMzvcg3QxvaTKfpaj57TyA',
#   'colaboracion': ['Darell', 'Noriel'],
#   'subscriptores': '8.56M',
#   'views': '4,139,484,442 views',
#   'id': 95},
#  'Sky Rompiendo': {'idYTMusic': 'UCSTtXdKn1Dmx28ufElKiaqQ',
#   'colaboracion': ['Myke Towers', 'Rauw Alejandro'],
#   'subscriptores': '359K',
#   'views': '178,364,323 views',
#   'id': 96},
#  'Luis Fonsi': {'idYTMusic': 'UCk91oFc2hY2CdHirU93baLg',
#   'colaboracion': ['Rauw Alejandro',
#    'Demi Lovato',
#    'Nicky Jam',
#    'Sebastián Yatra',
#    'Ozuna'],
#   'subscriptores': '31.2M',
#   'views': '14,736,470,380 views',
#   'id': 97},
#  'Chino & Nacho': {'idYTMusic': 'UCM0is5a5RHVKMcyN8Xs5dQw',
#   'colaboracion': ['Chyno Miranda', 'Nacho'],
#   'subscriptores': '4.8M',
#   'views': '4,165,774,958 views',
#   'id': 98},
#  'CNCO': {'idYTMusic': 'UCYkfG1iLz04t-X2WTsSO4Dw',
#   'colaboracion': ['Natti Natasha'],
#   'subscriptores': '11.9M',
#   'views': '7,030,430,338 views',
#   'id': 99},
#  'Reik': {'idYTMusic': 'UCJ3jO8eOeYGrKNJ-TmQoV3w',
#   'colaboracion': ['Morat', 'Maluma', 'Maluma'],
#   'subscriptores': '9.58M',
#   'views': '7,790,216,609 views',
#   'id': 100},
#  'Evaluna Montaner': {'idYTMusic': 'UCvPUs3Cm_Ioeihsy7ASXwLQ',
#   'colaboracion': ['Camilo'],
#   'subscriptores': '3.72M',
#   'views': '625,275,474 views',
#   'id': 101},
#  'Carlos Vives': {'idYTMusic': 'UC4mhBXLZXLSffhVsrSsTdCQ',
#   'colaboracion': ['Sebastián Yatra'],
#   'subscriptores': '5.71M',
#   'views': '5,143,172,072 views',
#   'id': 102},
#  'Sebastián Yatra': {'idYTMusic': 'UCXP8o4Xcws36pgpFNlGGBeg',
#   'colaboracion': ['Mau y Ricky', 'Mau y Ricky'],
#   'subscriptores': '17.7M',
#   'views': 'No info',
#   'id': 103},
#  'Chacal': {'idYTMusic': 'UCJt4IsSmUjqTaamhCJoKK_g',
#   'colaboracion': ['Lenier'],
#   'subscriptores': '441K',
#   'views': '263,409,677 views',
#   'id': 104},
#  'Kim Loaiza': {'idYTMusic': 'UCtGHTwNL20Y3fY9bumjHDOw',
#   'colaboracion': ['Ovy On The Drums'],
#   'subscriptores': '14.3M',
#   'views': '1,297,206,987 views',
#   'id': 105},
#  'Tiësto': {'idYTMusic': 'UC8VSaPhuiHkjobAgNpRqLIA',
#   'colaboracion': ['KAROL G'],
#   'subscriptores': '6.33M',
#   'views': '3,160,323,844 views',
#   'id': 106},
#  'Skrillex': {'idYTMusic': 'UCibXKvuw5PoJVmyZJ4qhDIw',
#   'colaboracion': ['J Balvin'],
#   'subscriptores': '20M',
#   'views': '6,411,841,314 views',
#   'id': 107},
#  'Sech': {'idYTMusic': 'UCXhOBsxGZ3TkeaYIW5LAHfA',
#   'colaboracion': ['Daddy Yankee'],
#   'subscriptores': '9.73M',
#   'views': '5,526,299,648 views',
#   'id': 108},
#  'Descemer Bueno': {'idYTMusic': 'UCp0C7rQ8oJ5sn_7_mDbub8A',
#   'colaboracion': ['Andra'],
#   'subscriptores': '135K',
#   'views': '86,729,544 views',
#   'id': 109},
#  'Kendo Kaponi': {'idYTMusic': 'UCLsG7r1pfUddC5VUI8Ero4g',
#   'colaboracion': ['Farruko', 'Anuel AA'],
#   'subscriptores': '1.33M',
#   'views': '341,175,099 views',
#   'id': 110},
#  'El Kamel': {'idYTMusic': 'UCPnWcazEV7QM0H7qBx6NVXg',
#   'colaboracion': ['Juaco'],
#   'subscriptores': '108K',
#   'views': 'No info',
#   'id': 111},
#  'Boy Wonder CF': {'idYTMusic': 'UC3IgJrS1IQIA94o27aKo-8Q',
#   'colaboracion': ['Bryant Myers', 'Baby Rasta', 'Cosculluela'],
#   'subscriptores': '18.8K',
#   'views': 'No info',
#   'id': 112},
#  'KHEA': {'idYTMusic': 'UCtdeqcj1VRfkxCZ427miDMQ',
#   'colaboracion': ['Eladio Carrion', 'Noriel', 'Eladio Carrion', 'Noriel'],
#   'subscriptores': '4.84M',
#   'views': '1,635,950,156 views',
#   'id': 113},
#  'Chyno Miranda': {'idYTMusic': 'UCKIxJ-kUSqhXUL5H-9brFcg',
#   'colaboracion': ['J Balvin'],
#   'subscriptores': '807K',
#   'views': '290,436,087 views',
#   'id': 114},
#  'Pacho El Antifeka': {'idYTMusic': 'UCAv5hmBopmA80uNfPOQ4uYg',
#   'colaboracion': ['Daddy Yankee'],
#   'subscriptores': '318K',
#   'views': 'No info',
#   'id': 115},
#  'Santana The Golden Boy': {'idYTMusic': 'UC41R6sIP1KOZqxLONheeIWQ',
#   'colaboracion': ['Amenazzy', 'Noriel'],
#   'subscriptores': '6.83K',
#   'views': 'No info',
#   'id': 116},
#  'Silvestre Dangond': {'idYTMusic': 'UCHgCGCFOoCaY6IB3nJC17Yg',
#   'colaboracion': ['Natti Natasha'],
#   'subscriptores': '5.66M',
#   'views': 'No info',
#   'id': 117},
#  'Greeicy': {'idYTMusic': 'UCkurR0SHjTh55G-or6U-5xg',
#   'colaboracion': ['Anitta'],
#   'subscriptores': '5.55M',
#   'views': 'No info',
#   'id': 118},
#  'Lalo Ebratt': {'idYTMusic': 'UCFKMn3pbbaDwC0tuURgh9Eg',
#   'colaboracion': ['Trapical'],
#   'subscriptores': '918K',
#   'views': '495,839,207 views',
#   'id': 119},
#  'Plan B': {'idYTMusic': 'UCptlL_RcC46JkGIcjkNspnA',
#   'colaboracion': ['Justin Quiles'],
#   'subscriptores': '5.57M',
#   'views': '3,828,208,568 views',
#   'id': 120},
#  'Omar Montes': {'idYTMusic': 'UC7ntHPjafLibUOIV1hxZO3w',
#   'colaboracion': [],
#   'subscriptores': '755K',
#   'views': '463,252,549 views',
#   'id': 121},
#  'Duki': {'idYTMusic': 'UCtLchRAZex11gn-ah1_1Pgw',
#   'colaboracion': [],
#   'subscriptores': '6.59M',
#   'views': '2,580,638,282 views',
#   'id': 122},
#  'Sangiovanni': {'idYTMusic': 'UC3P_YYlBJaBVV_MHcejbZQg',
#   'colaboracion': [],
#   'subscriptores': '679K',
#   'views': '375,064,512 views',
#   'id': 123},
#  'Ana Mena': {'idYTMusic': 'UCeZqJb8O79XPE0xjL6VxNqA',
#   'colaboracion': [],
#   'subscriptores': '978K',
#   'views': '504,942,121 views',
#   'id': 124},
#  'Baby Rasta': {'idYTMusic': 'UC-lKgl1QYyOS7eSIykTiJ9g',
#   'colaboracion': [],
#   'subscriptores': '561',
#   'views': 'No info',
#   'id': 125},
#  'Jowell & Randy': {'idYTMusic': 'UCN4NPml6D8Nf63UL-E-C8lA',
#   'colaboracion': [],
#   'subscriptores': '2.71M',
#   'views': '1,357,899,645 views',
#   'id': 126},
#  'Yailin la Mas Viral': {'idYTMusic': 'UCpMjO3rZM1xqn-s9HmtC_cA',
#   'colaboracion': [],
#   'subscriptores': '357K',
#   'views': '19,400,406 views',
#   'id': 127},
#  'Ptazeta': {'idYTMusic': 'UCI9q5A6SUN37p0gM01E1R4Q',
#   'colaboracion': [],
#   'subscriptores': '381K',
#   'views': 'No info',
#   'id': 128},
#  'Maldy': {'idYTMusic': 'UCsHl7m0iDLkZlOdPcKQN3Tg',
#   'colaboracion': [],
#   'subscriptores': '169K',
#   'views': '74,281,267 views',
#   'id': 129},
#  'Andy Rivera': {'idYTMusic': 'UCJR43lRCQY9oriyv3L1O3iA',
#   'colaboracion': [],
#   'subscriptores': '3.15M',
#   'views': '1,454,083,036 views',
#   'id': 130},
#  'Bad Gyal': {'idYTMusic': 'UC0jiPleafFjC3Z7L4VKLgAg',
#   'colaboracion': [],
#   'subscriptores': '793K',
#   'views': '475,086,326 views',
#   'id': 131},
#  'Farruquito': {'idYTMusic': 'None',
#   'colaboracion': [],
#   'subscriptores': None,
#   'views': None,
#   'id': 132},
#  'Selena Gomez': {'idYTMusic': 'UCeBYRgPhy8kcRmIGQWKuqdQ',
#   'colaboracion': [],
#   'subscriptores': '32M',
#   'views': '12,075,847,782 views',
#   'id': 133},
#  'Lyanno': {'idYTMusic': 'UCmI7GYyhkWc5MWS-x0h0yRQ',
#   'colaboracion': [],
#   'subscriptores': '1M',
#   'views': 'No info',
#   'id': 134},
#  'Brray': {'idYTMusic': 'UCzdbawqAXd7nW5H9wedLcXg',
#   'colaboracion': [],
#   'subscriptores': '201K',
#   'views': 'No info',
#   'id': 135},
#  'Polima Westcoast': {'idYTMusic': 'UCNcJAJvUKB7Z9o-wgQCPaqQ',
#   'colaboracion': [],
#   'subscriptores': '806K',
#   'views': '466,603,551 views',
#   'id': 136},
#  'MVSIS': {'idYTMusic': 'UCpk6J-Lg6cmksoQTirc1ucA',
#   'colaboracion': [],
#   'subscriptores': '66',
#   'views': 'No info',
#   'id': 137},
#  'Bryant Myers': {'idYTMusic': 'UCH-xlT-Cq4cNCGi54pqdwkg',
#   'colaboracion': [],
#   'subscriptores': '8.29M',
#   'views': '3,235,131,267 views',
#   'id': 138},
#  'Niña Pastori': {'idYTMusic': 'UC7r34gTXp2rBR9MH0IXB_iw',
#   'colaboracion': [],
#   'subscriptores': '376K',
#   'views': 'No info',
#   'id': 139},
#  'RedOne': {'idYTMusic': 'UCx67LAB_it2iESN6w1xUwIA',
#   'colaboracion': [],
#   'subscriptores': '1.31M',
#   'views': '333,773,912 views',
#   'id': 140},
#  'Ecko': {'idYTMusic': 'UC6b8Tteqvvbs0ReD2w9iiaA',
#   'colaboracion': [],
#   'subscriptores': '750',
#   'views': 'No info',
#   'id': 141},
#  'María Artés Lamorena': {'idYTMusic': 'UCIor0JghnFIMBOjfstqWPyg',
#   'colaboracion': [],
#   'subscriptores': '126K',
#   'views': 'No info',
#   'id': 142},
#  'Foreign Teck': {'idYTMusic': 'UC6R8VJBHXvKdsrRf1N1tj1Q',
#   'colaboracion': [],
#   'subscriptores': '186K',
#   'views': 'No info',
#   'id': 143},
#  'Myriam Fares': {'idYTMusic': 'UCUVvwGRr7LTeS_WfJ-VZlxQ',
#   'colaboracion': [],
#   'subscriptores': '2.06M',
#   'views': 'No info',
#   'id': 144},
#  'FIFA Sound': {'idYTMusic': 'UC65xtqPjYFI3VS21ULLaJOg',
#   'colaboracion': [],
#   'subscriptores': '772',
#   'views': 'No info',
#   'id': 145},
#  'El Jhota': {'idYTMusic': 'UClR2QAJa8OAPw5TSuJ-e-CA',
#   'colaboracion': [],
#   'subscriptores': '139K',
#   'views': 'No info',
#   'id': 146},
#  'Los del Control': {'idYTMusic': 'UCAYrx2AH-THEBcoFLvpTkBQ',
#   'colaboracion': [],
#   'subscriptores': '3.82K',
#   'views': 'No info',
#   'id': 147},
#  'TALE$': {'idYTMusic': 'UCPVMdfZvRcxs0Kiym1GCIjA',
#   'colaboracion': [],
#   'subscriptores': '23.9K',
#   'views': 'No info',
#   'id': 148},
#  'Bebe Rexha': {'idYTMusic': 'UChwSjx8SnvG6k96a9xqYw1g',
#   'colaboracion': [],
#   'subscriptores': '9.16M',
#   'views': '3,753,656,348 views',
#   'id': 149},
#  'Romeo Santos': {'idYTMusic': 'UCpB_98tUTs3zSiOxZuGPnOA',
#   'colaboracion': [],
#   'subscriptores': '20.1M',
#   'views': '15,828,341,028 views',
#   'id': 150},
#  'Estopa': {'idYTMusic': 'UCd25mqkTos06xFf1RP9qFJA',
#   'colaboracion': [],
#   'subscriptores': '646K',
#   'views': '734,193,382 views',
#   'id': 151},
#  'Cruz Cafuné': {'idYTMusic': 'UCdOIOrEjYYS42wLKAdGWTLQ',
#   'colaboracion': [],
#   'subscriptores': '144K',
#   'views': 'No info',
#   'id': 152},
#  'Juseph': {'idYTMusic': 'UCNavFbCUYI1Yyd8V7dU3MEw',
#   'colaboracion': [],
#   'subscriptores': '35.5K',
#   'views': 'No info',
#   'id': 153},
#  'Robin Schulz': {'idYTMusic': 'UCIpo9tfpIGXMzNQcZVWoXVw',
#   'colaboracion': [],
#   'subscriptores': '3.6M',
#   'views': '3,663,087,431 views',
#   'id': 154},
#  'Daddy Yankee': {'idYTMusic': 'UCXRloA7YFgCfd6sU2_Y12cA',
#   'colaboracion': [],
#   'subscriptores': '37.4M',
#   'views': '21,465,463,283 views',
#   'id': 155},
#  'Pepe : Vizio': {'idYTMusic': 'UCUyiOIWnGToRf7kmk_79gRg',
#   'colaboracion': [],
#   'subscriptores': '45.4K',
#   'views': 'No info',
#   'id': 156},
#  'Delaossa': {'idYTMusic': 'UCW6BH4lqss_NycLC1JUW2-A',
#   'colaboracion': [],
#   'subscriptores': '59.1K',
#   'views': 'No info',
#   'id': 157},
#  'Chris Jedi': {'idYTMusic': 'UCQN0qx3B0J5GWrG7SQyfWQw',
#   'colaboracion': [],
#   'subscriptores': '2.63M',
#   'views': '1,818,816,042 views',
#   'id': 158},
#  'Gaby Music': {'idYTMusic': 'UCVAtSz_69M2ULexewXFrB_g',
#   'colaboracion': [],
#   'subscriptores': '429',
#   'views': 'No info',
#   'id': 159},
#  'Stars Music Chile': {'idYTMusic': 'UC-5B4zAt_UIpqabGGnv7igg',
#   'colaboracion': [],
#   'subscriptores': '38.2K',
#   'views': 'No info',
#   'id': 160},
#  'Rapeton Approved': {'idYTMusic': 'UCveIOPVNOvIrKYZXNoNNIHA',
#   'colaboracion': [],
#   'subscriptores': '131',
#   'views': 'No info',
#   'id': 161},
#  'Harry Nach': {'idYTMusic': 'UCO-eCC9qWjWdaDH1W3G9ZhA',
#   'colaboracion': [],
#   'subscriptores': '552K',
#   'views': 'No info',
#   'id': 162},
#  'Darell': {'idYTMusic': 'UCVsfgFfzYNMJvcQLDYT7fHw',
#   'colaboracion': [],
#   'subscriptores': '3.11M',
#   'views': '1,187,303,625 views',
#   'id': 163},
#  'Pablo Pesadilla': {'idYTMusic': 'UCNHvdSM8DEzaQFkoYu-_cWg',
#   'colaboracion': [],
#   'subscriptores': '146K',
#   'views': 'No info',
#   'id': 164},
#  'Nickoog Clk': {'idYTMusic': 'UCKYuWm0fTnFQERqv-rBr9_w',
#   'colaboracion': [],
#   'subscriptores': '353K',
#   'views': 'No info',
#   'id': 165},
#  'Pailita': {'idYTMusic': 'UC5CrNkDJEiuV8GmqFlKKU0Q',
#   'colaboracion': [],
#   'subscriptores': '794K',
#   'views': 'No info',
#   'id': 166},
#  'Chencho Corleone': {'idYTMusic': 'UC4_xgMYQfEUnKTAuuys62JQ',
#   'colaboracion': [],
#   'subscriptores': '748K',
#   'views': '223,769,533 views',
#   'id': 167},
#  'Adam Levine': {'idYTMusic': 'UCi-kAl0YSpCJOt7Irwylx6A',
#   'colaboracion': [],
#   'subscriptores': '89.6K',
#   'views': '44,368,845 views',
#   'id': 168},
#  'Ñengo Flow': {'idYTMusic': 'UCeNt9djCuN7-Vr5J3kK_GkQ',
#   'colaboracion': [],
#   'subscriptores': '4.23M',
#   'views': '1,314,391,153 views',
#   'id': 169},
#  'Jhay Cortez': {'idYTMusic': 'UChZEzxer-QvRMbADJJGOMuQ',
#   'colaboracion': [],
#   'subscriptores': '4.75M',
#   'views': '3,734,531,791 views',
#   'id': 170},
#  'DJ Nelson': {'idYTMusic': 'UCkwiJQbXLRA5SQBW5-zpyPw',
#   'colaboracion': [],
#   'subscriptores': '1.3M',
#   'views': '904,619,997 views',
#   'id': 171},
#  'Jay Wheeler': {'idYTMusic': 'UC17u1K8tiqxxFhPMbM50ASA',
#   'colaboracion': [],
#   'subscriptores': '4.81M',
#   'views': '2,759,049,844 views',
#   'id': 172},
#  'Natan & Shander': {'idYTMusic': 'UCJqq8E9uhUCpPpH7x0GMydg',
#   'colaboracion': [],
#   'subscriptores': '24.7K',
#   'views': 'No info',
#   'id': 173},
#  'Totoy El Frio': {'idYTMusic': 'UC9IFHk6kGcjXXctFQQHUIow',
#   'colaboracion': [],
#   'subscriptores': '65K',
#   'views': '17,026,562 views',
#   'id': 174},
#  'Mr. NaisGai': {'idYTMusic': 'UCgH6ST4YytHJEXgb410e7og',
#   'colaboracion': [],
#   'subscriptores': '555',
#   'views': 'No info',
#   'id': 175},
#  'Justin Quiles': {'idYTMusic': 'UCAllAtIEaPeS-e65RgwMJMw',
#   'colaboracion': [],
#   'subscriptores': '4.51M',
#   'views': '3,803,268,245 views',
#   'id': 176},
#  'Paulo Londra': {'idYTMusic': 'UCpH92jOmlMe71mRYEkp7riQ',
#   'colaboracion': [],
#   'subscriptores': '22.1M',
#   'views': 'No info',
#   'id': 177},
#  'Rich Music, Ltd': {'idYTMusic': 'None',
#   'colaboracion': [],
#   'subscriptores': None,
#   'views': None,
#   'id': 178},
#  'Alejo': {'idYTMusic': 'UCMKvgX4kFL5yYFgS9wSOB0A',
#   'colaboracion': [],
#   'subscriptores': '14.8K',
#   'views': 'No info',
#   'id': 179},
#  'Boza': {'idYTMusic': 'None',
#   'colaboracion': [],
#   'subscriptores': None,
#   'views': None,
#   'id': 180},
#  'Juhn': {'idYTMusic': 'UCyk_J3-Nvv2ECz8kiVrZ5qQ',
#   'colaboracion': [],
#   'subscriptores': '1.27M',
#   'views': 'No info',
#   'id': 181},
#  'Randy Nota Loca': {'idYTMusic': 'UCKVLGFIIr8SkznqIic-HBdA',
#   'colaboracion': [],
#   'subscriptores': '195K',
#   'views': 'No info',
#   'id': 182},
#  'Zion': {'idYTMusic': 'None',
#   'colaboracion': [],
#   'subscriptores': None,
#   'views': None,
#   'id': 183},
#  'Vf7': {'idYTMusic': 'UC_CWZW3emYNvTPewmKCOsAA',
#   'colaboracion': [],
#   'subscriptores': '19.6K',
#   'views': 'No info',
#   'id': 184},
#  'Álvaro Díaz': {'idYTMusic': 'UCoHRmfxqEHTHoNTddLS3ErQ',
#   'colaboracion': [],
#   'subscriptores': '333K',
#   'views': 'No info',
#   'id': 185},
#  'Julieta Venegas': {'idYTMusic': 'UCvXTgH2KhTPYSgiKQ5JL70g',
#   'colaboracion': [],
#   'subscriptores': '1.42M',
#   'views': '1,134,309,795 views',
#   'id': 186},
#  'Amenazzy': {'idYTMusic': 'UCPPK-Pm1Ym23nWgxNbirxZA',
#   'colaboracion': [],
#   'subscriptores': '3.42M',
#   'views': '1,208,227,945 views',
#   'id': 187},
#  'Don Omar': {'idYTMusic': 'UCTrIOPtBeAN2E0R-sgU9JxA',
#   'colaboracion': [],
#   'subscriptores': '9.74M',
#   'views': '8,414,735,615 views',
#   'id': 188},
#  'Mambo Kingz': {'idYTMusic': 'UCVZLK2WQ4vzou3qtXS9n9ww',
#   'colaboracion': [],
#   'subscriptores': '137K',
#   'views': 'No info',
#   'id': 189},
#  'Will Smith': {'idYTMusic': 'UCdHscQsCBWSfcW50NjdJWkA',
#   'colaboracion': [],
#   'subscriptores': '104K',
#   'views': '141,897,351 views',
#   'id': 190},
#  'Thalía': {'idYTMusic': 'UCWwlelNu5JkcERFUT8VIOew',
#   'colaboracion': [],
#   'subscriptores': '7.3M',
#   'views': '5,274,667,497 views',
#   'id': 191},
#  'Micro TDH': {'idYTMusic': 'UCA9V9ETvzKWzYNeGqM7BSJQ',
#   'colaboracion': [],
#   'subscriptores': '3.72M',
#   'views': '1,470,447,543 views',
#   'id': 192},
#  'Tyga': {'idYTMusic': 'UC2-zLDHEP2rEkqwgutb2ctA',
#   'colaboracion': [],
#   'subscriptores': '11.2M',
#   'views': '5,422,085,514 views',
#   'id': 193},
#  'Rvssian': {'idYTMusic': 'UCNzGI8JyKXRgrgGIknRGalg',
#   'colaboracion': [],
#   'subscriptores': '28.2K',
#   'views': '76,797,214 views',
#   'id': 194},
#  'Mau y Ricky': {'idYTMusic': 'UCjdM1qBzGOeKgOmgybIuCtA',
#   'colaboracion': [],
#   'subscriptores': '4.15M',
#   'views': '2,625,014,929 views',
#   'id': 195},
#  'TINI': {'idYTMusic': 'UCBDXpukZYpWw54QCbEGdsZw',
#   'colaboracion': [],
#   'subscriptores': '7.96M',
#   'views': '3,861,928,308 views',
#   'id': 196},
#  'Anitta': {'idYTMusic': 'UCI99G32byWj1aH13pbxnTEw',
#   'colaboracion': [],
#   'subscriptores': '16.9M',
#   'views': '6,925,850,592 views',
#   'id': 197},
#  'andres yuma': {'idYTMusic': 'UCcGMHIKIFVWac1D4ODVuR-g',
#   'colaboracion': [],
#   'subscriptores': '0',
#   'views': 'No info',
#   'id': 198},
#  'Vadi': {'idYTMusic': 'None',
#   'colaboracion': [],
#   'subscriptores': None,
#   'views': None,
#   'id': 199},
#  'Luar La L': {'idYTMusic': 'UCStUThP2IprRPM9sw3pF48g',
#   'colaboracion': [],
#   'subscriptores': '500K',
#   'views': 'No info',
#   'id': 200},
#  'Cazzu': {'idYTMusic': 'UCXxxmrUKXeL095S9o9e5TDw',
#   'colaboracion': [],
#   'subscriptores': '5.28M',
#   'views': '1,839,918,985 views',
#   'id': 201},
#  'EL IMA': {'idYTMusic': 'UCkH_zaicOPTd1044FyrAybg',
#   'colaboracion': [],
#   'subscriptores': '6.41K',
#   'views': 'No info',
#   'id': 202},
#  'Dread Mar I': {'idYTMusic': 'UC_X1gYPv9eOW1CYIVEAX2hw',
#   'colaboracion': [],
#   'subscriptores': '5.29M',
#   'views': 'No info',
#   'id': 203},
#  'LIT killah': {'idYTMusic': 'UC1qoOeueDduCF1S6xnXYmqA',
#   'colaboracion': [],
#   'subscriptores': '5.62M',
#   'views': 'No info',
#   'id': 204},
#  'Nicki Nicole': {'idYTMusic': 'UCei_d3N_YJKny96V_5-dO9w',
#   'colaboracion': [],
#   'subscriptores': '4.29M',
#   'views': '1,015,138,608 views',
#   'id': 205},
#  'Camilo': {'idYTMusic': 'UC0l2FUrxXnO8XwR0eqb-Nsg',
#   'colaboracion': [],
#   'subscriptores': '15.6M',
#   'views': '6,362,328,757 views',
#   'id': 206},
#  'Dua Lipa': {'idYTMusic': 'UCzVb0SIXp9q9PeKCcFjsBtA',
#   'colaboracion': [],
#   'subscriptores': '21.3M',
#   'views': '10,459,880,531 views',
#   'id': 207},
#  'Noriel': {'idYTMusic': 'UCYWVGrOjgB0mJgMuy84vQxA',
#   'colaboracion': [],
#   'subscriptores': '5.03M',
#   'views': '1,712,150,842 views',
#   'id': 208},
#  'Jennifer Lopez': {'idYTMusic': 'UCXDcGa1H1axtr1wkxOR3hZQ',
#   'colaboracion': [],
#   'subscriptores': '15.9M',
#   'views': '9,789,937,390 views',
#   'id': 209},
#  'YAVIAH': {'idYTMusic': 'UCnrbNW0nwapPUZZTPv_KbBg',
#   'colaboracion': [],
#   'subscriptores': '33.2K',
#   'views': 'No info',
#   'id': 210},
#  'Nacho': {'idYTMusic': 'UCYJwsP1YmNv3Qm6HW7ozxBA',
#   'colaboracion': [],
#   'subscriptores': '5.73M',
#   'views': '2,891,482,475 views',
#   'id': 211},
#  'Simone & Simaria': {'idYTMusic': 'UCdr8B1Wj70vRx7qNz0HkKPw',
#   'colaboracion': [],
#   'subscriptores': '11.4M',
#   'views': '4,621,874,619 views',
#   'id': 212},
#  'Juice WRLD': {'idYTMusic': 'UCbn0GRdgsQtl9hlV-IqxFGg',
#   'colaboracion': [],
#   'subscriptores': '10.6M',
#   'views': '5,254,011,026 views',
#   'id': 213},
#  'Zumbi': {'idYTMusic': 'None',
#   'colaboracion': [],
#   'subscriptores': None,
#   'views': None,
#   'id': 214},
#  'Morat': {'idYTMusic': 'UCyZgGJiy9vum1xD7hXWG_rA',
#   'colaboracion': [],
#   'subscriptores': '6.56M',
#   'views': '4,681,551,216 views',
#   'id': 215},
#  'Flow La Movie': {'idYTMusic': 'UC95F-UDqrRZmrwozzczvawA',
#   'colaboracion': [],
#   'subscriptores': '5.96K',
#   'views': 'No info',
#   'id': 216},
#  'Casper Magico': {'idYTMusic': 'UCIAWcPYu4GWqyD2WhyenKBw',
#   'colaboracion': [],
#   'subscriptores': '55.8K',
#   'views': 'No info',
#   'id': 217},
#  'Black Eyed Peas': {'idYTMusic': 'UC7JGA3rY8kb0-Epuqenjkzw',
#   'colaboracion': [],
#   'subscriptores': '11.8M',
#   'views': '10,023,902,635 views',
#   'id': 218},
#  'GIMS': {'idYTMusic': 'UCanUjmTDohFr8OMpfk5xWBQ',
#   'colaboracion': [],
#   'subscriptores': '10.8M',
#   'views': '5,998,546,295 views',
#   'id': 219},
#  'KEVVO': {'idYTMusic': 'UCRNdAgK-Hwkl3PZmQFUnl1Q',
#   'colaboracion': [],
#   'subscriptores': '382K',
#   'views': '165,642,478 views',
#   'id': 220},
#  'Demi Lovato': {'idYTMusic': 'UCwem2sj-QUJCiWiPAo9JuAw',
#   'colaboracion': [],
#   'subscriptores': '17.8M',
#   'views': '6,660,099,909 views',
#   'id': 221},
#  'Enrique Iglesias': {'idYTMusic': 'UCD-0qTYqRd4t9re9AwRydnQ',
#   'colaboracion': [],
#   'subscriptores': '23.3M',
#   'views': '16,885,403,963 views',
#   'id': 222},
#  'Mariah Angeliq ': {'idYTMusic': 'UCbLTh4xcRBh49Psu-7MOXSQ',
#   'colaboracion': [],
#   'subscriptores': '1.12M',
#   'views': 'No info',
#   'id': 223},
#  'Lenier': {'idYTMusic': 'UCpEESy0SY7NiICeN0XgDdeA',
#   'colaboracion': [],
#   'subscriptores': '19.7K',
#   'views': 'No info',
#   'id': 224},
#  'Bomba Estéreo': {'idYTMusic': 'UCt7E5esO1UIPkZifW08r9hA',
#   'colaboracion': [],
#   'subscriptores': '1.87M',
#   'views': '1,057,427,057 views',
#   'id': 225},
#  'Lit Killah': {'idYTMusic': 'UC1qoOeueDduCF1S6xnXYmqA',
#   'colaboracion': [],
#   'subscriptores': '5.62M',
#   'views': 'No info',
#   'id': 226},
#  'BANDIDO': {'idYTMusic': 'None',
#   'colaboracion': [],
#   'subscriptores': None,
#   'views': None,
#   'id': 227},
#  'Farina': {'idYTMusic': 'UCNXvwbgr8tGszzqBjDClcxQ',
#   'colaboracion': [],
#   'subscriptores': '2.53M',
#   'views': '739,318,598 views',
#   'id': 228},
#  'Andra': {'idYTMusic': 'UCMHLzL4MdXUwC0ZpAR51WLA',
#   'colaboracion': [],
#   'subscriptores': '1.89M',
#   'views': '1,863,789,751 views',
#   'id': 229},
#  'Juaco': {'idYTMusic': 'UCKd4R_IF0UMe2KZBn_F5JZA',
#   'colaboracion': [],
#   'subscriptores': '56',
#   'views': 'No info',
#   'id': 230},
#  'Cosculluela': {'idYTMusic': 'UCDHhds5KLRgEyCIRF5zK4SA',
#   'colaboracion': [],
#   'subscriptores': '7.06M',
#   'views': '2,928,654,234 views',
#   'id': 231},
#  'Eladio Carrion': {'idYTMusic': 'UC7YJ69rJ9qtVh6SjYFs4cGg',
#   'colaboracion': [],
#   'subscriptores': '3.2M',
#   'views': '1,767,513,893 views',
#   'id': 232},
#  'Alex Sensation': {'idYTMusic': 'UCJ5rRzbngyC5hL71z7OvCLw',
#   'colaboracion': [],
#   'subscriptores': '1.46M',
#   'views': '1,029,763,675 views',
#   'id': 233},
#  'Trapical': {'idYTMusic': 'UCkV-TKWDLEANF3LYh8H4OcA',
#   'colaboracion': [],
#   'subscriptores': '35.4K',
#   'views': 'No info',
#   'id': 234},
#  'Pitbull': {'idYTMusic': 'UC03jIQv4WXBSHdr1DlCLYDw',
#   'colaboracion': [],
#   'subscriptores': '16M',
#   'views': '11,868,607,371 views',
#   'id': 235}}

# %% [markdown]
# Como resultado tenemos ya nuestra tabla de noodos completa

# %%
df = pd.DataFrame.from_dict(diccColabo, orient = "index",columns=['id','idYTMusic','colaboracion','subscriptores','views'])

df.to_csv('finished.csv')
df
# Out:
#                  id                 idYTMusic  \
# Arcangel          0  UCVcAt8IIKIeubRSigcYXgtA
# Farruko           1  UC6QXZsAOOweLfhVPbqMyG4g
# Quevedo           2  UC7PL9aor5qNRhvhWWVXyOqA
# Bizarrap          3  UCONiUl5u7y2bMaVZJcuRDEQ
# Aitana            4  UCkyzcFsGWVYSUGaR7YB9OYQ
# ...             ...                       ...
# Cosculluela     231  UCDHhds5KLRgEyCIRF5zK4SA
# Eladio Carrion  232  UC7YJ69rJ9qtVh6SjYFs4cGg
# Alex Sensation  233  UCJ5rRzbngyC5hL71z7OvCLw
# Trapical        234  UCkV-TKWDLEANF3LYh8H4OcA
# Pitbull         235  UC03jIQv4WXBSHdr1DlCLYDw
#
#                                                      colaboracion  \
# Arcangel                             [Bad Bunny, Bad Bunny, Sech]
# Farruko         [Omar Montes, Rauw Alejandro, Natti Natasha, J...
# Quevedo         [Bizarrap, Ovy On The Drums, Myke Towers, Mora...
# Bizarrap                                             [Duki, Duki]
# Aitana                                              [Sangiovanni]
# ...                                                           ...
# Cosculluela                                                    []
# Eladio Carrion                                                 []
# Alex Sensation                                                 []
# Trapical                                                       []
# Pitbull                                                        []
#
#                subscriptores                 views
# Arcangel               10.7M   4,757,030,131 views
# Farruko                18.3M   8,917,081,158 views
# Quevedo                 1.1M     296,360,104 views
# Bizarrap               16.6M   5,849,808,044 views
# Aitana                 2.15M               No info
# ...                      ...                   ...
# Cosculluela            7.06M   2,928,654,234 views
# Eladio Carrion          3.2M   1,767,513,893 views
# Alex Sensation         1.46M   1,029,763,675 views
# Trapical               35.4K               No info
# Pitbull                  16M  11,868,607,371 views
#
# [236 rows x 5 columns]

# %%
header = ['nombre','id','idYTMusic','colaboracion','subscriptores','views']

with open('nodos.csv','w',encoding='utf-8',newline='') as f:
    writer= csv.writer(f)
    writer.writerow(header)
    for i in diccColabo:
        writer.writerow([i,diccColabo[i]['id'],diccColabo[i]['idYTMusic'],
        diccColabo[i]['colaboracion'],diccColabo[i]['subscriptores'],diccColabo[i]['views']])

# %% [markdown]
# En este momento, abrimos un csv para escribir la información de las aristas.En nuestro caso se van a unir los nodos segun sus colaboraciones.Si el nodo A ha colaborado con B y C se lanzará una arista desde A hasta B y desde A hasta C.
# Tambien hemos añadido atributos complementarios para su posterior estudio en Gephi, como la duracion de la cancion en cuestión en la que colaboran, si la letra de la cancion tiene contenido explicito o no y la fecha de la publicación de la cancion en ytMusic.

# %%
header = ['artista', 'colaborador','duracion','explicito','fecha_publicacion','visitas']
writedicc = {}
with open('aristas.csv','w',encoding='utf-8',newline='') as f:
    writer= csv.writer(f)
    writer.writerow(header)
    iter=0
    repe=0
    for r in artistasAristas:
        for i in range(len(r)-1):
            fechaF=publicacion[iter]
            fecha=list(fechaF)
            fecha[4]='/'
            fecha[7]='/'
            fechaF = "".join(fecha)
            writer.writerow([r[0]['name'],r[i+1]['name'],duration[iter],explicit[iter],fechaF,vistas[iter]])
        iter=iter+1
            
      # iter=iter+1

# %% [markdown]
# Vamos a crear archivos para que gephi los pueda reconocer y podamos proceder analizarlo desde ahi

# %%
header = ['Id','Label','colaboracion','subscriptores','views']

with open('nodosGephi.csv','w',encoding='utf-8',newline='') as f:
    writer= csv.writer(f)
    writer.writerow(header)
    for i in diccColabo:
        writer.writerow([diccColabo[i]['id'],i,
        diccColabo[i]['colaboracion'],diccColabo[i]['subscriptores'],diccColabo[i]['views']])
        #writer.writerow([i,diccColabo[i]['colaboracion'],diccColabo[i]['subscriptores'],diccColabo[i]['views']])

# %%
header = ['Source', 'Target','duracion','explicito','visitas','fecha_publicacion']
writedicc = {}
with open('aristasGephi.csv','w',encoding='utf-8',newline='') as f:
    writer= csv.writer(f)
    writer.writerow(header)
    iter=0
    repe=0
    for r in artistasAristas:
        for i in range(len(r)-1):
            fechaF=publicacion[iter]
            fecha=list(fechaF)
            fecha[4]='/'
            fecha[7]='/'
            fechaF = "".join(fecha)
            writer.writerow([diccColabo[r[0]['name']]['id'],diccColabo[r[i+1]['name']]['id'],
            duration[iter],explicit[iter],vistas[iter],fechaF])
            #writer.writerow([r[0]['name'],r[i+1]['name'],duration[iter],explicit[iter],publicacion[iter],vistas[iter]])
        iter=iter+1

# %% [markdown]
# El resultado de esta red actual es el siguiente:

# %%
df = pd.read_csv('aristas.csv',names=['artista', 'colaborador','duracion','explicito','fecha_publicacion','visitas'])

G=nx.from_pandas_edgelist(df,'artista','colaborador')


plt.show() 
plt.figure(figsize=(13,10))
pos = nx.circular_layout(G)
nx.draw(G,pos,with_labels=True,alpha=0.7)
