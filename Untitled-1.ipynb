# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
import csv

# %% [markdown]
# Los 100 vídeos musicales más populares en España

# %%
from ytmusicapi import YTMusic

yt = YTMusic()
#z8uyayN3RbE
searchMusic=yt.get_song("5g2hT4GmAGU")

#yt.get_artist("UCiY3z8HAGD6BlSNKVn2kSvQ")
search_results=yt.search("Barroso")
#search_results
searchPlay=yt.get_playlist("PL4fGSI1pDJn4jhQB4kb9M36dvVmJQPt4T")

searcArtist=yt.get_artist('UCI9q5A6SUN37p0gM01E1R4Q')

searchMusic=yt.get_song("5g2hT4GmAGU")
#searchPlay
#searchMusic
#searcArtist
#search_results
# Out:
# {'description': None,
#  'views': None,
#  'name': 'Ptazeta',
#  'channelId': 'UCuEnnw70c_29Wh_jLIw6nyg',
#  'shuffleId': None,
#  'radioId': None,
#  'subscribers': '378K',
#  'subscribed': False,
#  'thumbnails': [{'url': 'https://lh3.googleusercontent.com/a-/ACNPEu9XyQ5jG7UKmlVOnS6D05nEZUK0XrDQdVBrybNdNA=w540-h225-l90-rj-dcLYWSri0H',
#    'width': 540,
#    'height': 225},
#   {'url': 'https://lh3.googleusercontent.com/a-/ACNPEu9XyQ5jG7UKmlVOnS6D05nEZUK0XrDQdVBrybNdNA=w816-h340-l90-rj-dcLYWSri0H',
#    'width': 816,
#    'height': 340},
#   {'url': 'https://lh3.googleusercontent.com/a-/ACNPEu9XyQ5jG7UKmlVOnS6D05nEZUK0XrDQdVBrybNdNA=w1440-h600-l90-rj-dcLYWSri0H',
#    'width': 1440,
#    'height': 600},
#   {'url': 'https://lh3.googleusercontent.com/a-/ACNPEu9XyQ5jG7UKmlVOnS6D05nEZUK0XrDQdVBrybNdNA=w1920-h800-l90-rj-dcLYWSri0H',
#    'width': 1920,
#    'height': 800},
#   {'url': 'https://lh3.googleusercontent.com/a-/ACNPEu9XyQ5jG7UKmlVOnS6D05nEZUK0XrDQdVBrybNdNA=w2400-h1000-l90-rj-dcLYWSri0H',
#    'width': 2400,
#    'height': 1000}],
#  'songs': {'browseId': 'VLOLAK5uy_ldonFB3ALIxeKQ-xnMP-9zpVTHGY2609E',
#   'results': [{'videoId': 'COn4oEzN3hY',
#     'title': 'Quieres',
#     'artists': [{'name': 'Aitana', 'id': 'UCkyzcFsGWVYSUGaR7YB9OYQ'},
#      {'name': 'Emilia', 'id': 'UCvXoAG_trv-m2pv5_1HVFvA'},
#      {'name': 'Ptazeta', 'id': 'UCI9q5A6SUN37p0gM01E1R4Q'}],
#     'album': {'name': 'Quieres', 'id': 'MPREb_Uv4v0EUS1ba'},
#     'likeStatus': 'INDIFFERENT',
#     'thumbnails': [{'url': 'https://lh3.googleusercontent.com/pvadqtyIYu7kmsUXmb4nD1-ohRabK_tFcj-L89gC3TAj89aeX7kEDi4yFwZrcPbLjch1lTZw423lKj5t=w60-h60-l90-rj',
#       'width': 60,
#       'height': 60},
#      {'url': 'https://lh3.googleusercontent.com/pvadqtyIYu7kmsUXmb4nD1-ohRabK_tFcj-L89gC3TAj89aeX7kEDi4yFwZrcPbLjch1lTZw423lKj5t=w120-h120-l90-rj',
#       'width': 120,
#       'height': 120}],
#     'isAvailable': True,
#     'isExplicit': False},
#    {'videoId': 'HMoBVoLEOiw',
#     'title': 'Ptazeta: Bzrp Music Sessions, Vol. 45',
#     'artists': [{'name': 'Bizarrap', 'id': 'UCONiUl5u7y2bMaVZJcuRDEQ'},
#      {'name': 'Ptazeta', 'id': 'UCI9q5A6SUN37p0gM01E1R4Q'}],
#     'album': {'name': 'Ptazeta: Bzrp Music Sessions, Vol. 45',
#      'id': 'MPREb_swfG4Fdq9dG'},
#     'likeStatus': 'INDIFFERENT',
#     'thumbnails': [{'url': 'https://lh3.googleusercontent.com/foCkBNYuwKvBfPJq4Y9szVzJuUoGte-pFGIBfOAhBvlv80s38b8p_pa0poWm03gyYNIzhpp6Ak3OnXiq=w60-h60-l90-rj',
#       'width': 60,
#       'height': 60},
#      {'url': 'https://lh3.googleusercontent.com/foCkBNYuwKvBfPJq4Y9szVzJuUoGte-pFGIBfOAhBvlv80s38b8p_pa0poWm03gyYNIzhpp6Ak3OnXiq=w120-h120-l90-rj',
#       'width': 120,
#       'height': 120}],
#     'isAvailable': True,
#     'isExplicit': False},
#    {'videoId': 'W3Cl_DAzSg0',
#     'title': 'Trakatá',
#     'artists': [{'name': 'Ptazeta', 'id': 'UCI9q5A6SUN37p0gM01E1R4Q'},
#      {'name': 'Farina', 'id': 'UCNXvwbgr8tGszzqBjDClcxQ'},
#      {'name': 'Juacko', 'id': 'UC1xacNInB8HMGe-zrF9FJyA'}],
#     'album': {'name': 'Trakatá', 'id': 'MPREb_wP4isL4aqTB'},
#     'likeStatus': 'INDIFFERENT',
#     'thumbnails': [{'url': 'https://lh3.googleusercontent.com/vgNV1sFb1WcPYiO1lohWcLx9hFC4Wm0ogsj7hDAj8FAByqyr7taXKkMdtqome7kC0xoCI0MrJUfClEOfug=w60-h60-l90-rj',
#       'width': 60,
#       'height': 60},
#      {'url': 'https://lh3.googleusercontent.com/vgNV1sFb1WcPYiO1lohWcLx9hFC4Wm0ogsj7hDAj8FAByqyr7taXKkMdtqome7kC0xoCI0MrJUfClEOfug=w120-h120-l90-rj',
#       'width': 120,
#       'height': 120}],
#     'isAvailable': True,
#     'isExplicit': False},
#    {'videoId': 'jzjvqfiiAEw',
#     'title': 'Mujerón',
#     'artists': [{'name': 'Ptazeta', 'id': 'UCI9q5A6SUN37p0gM01E1R4Q'},
#      {'name': 'Villano Antillano', 'id': 'UCPy0MALtfhQjfm6Jpk5T6FQ'}],
#     'album': {'name': 'Mujerón', 'id': 'MPREb_a5e26WqkvnH'},
#     'likeStatus': 'INDIFFERENT',
#     'thumbnails': [{'url': 'https://lh3.googleusercontent.com/vuCNiWsGuBlwyHlOhN8ReFLUebLxLNE3XtSlsIo2B0iG0nNclZlK6l7C_rC3Qzcmkgsl3fn9kBQQ-VKnqA=w60-h60-l90-rj',
#       'width': 60,
#       'height': 60},
#      {'url': 'https://lh3.googleusercontent.com/vuCNiWsGuBlwyHlOhN8ReFLUebLxLNE3XtSlsIo2B0iG0nNclZlK6l7C_rC3Qzcmkgsl3fn9kBQQ-VKnqA=w120-h120-l90-rj',
#       'width': 120,
#       'height': 120}],
#     'isAvailable': True,
#     'isExplicit': True},
#    {'videoId': 'GAcSK70W8As',
#     'title': 'Number One',
#     'artists': [{'name': 'Chema Rivas', 'id': 'UCjKxJEz7qbxn07e4_Mu5PAw'},
#      {'name': 'Ptazeta', 'id': 'UCI9q5A6SUN37p0gM01E1R4Q'}],
#     'album': {'name': 'Number One', 'id': 'MPREb_lPxUts6C5qP'},
#     'likeStatus': 'INDIFFERENT',
#     'thumbnails': [{'url': 'https://lh3.googleusercontent.com/M81-KIVKIU35aImJ6DjuH9WQocYh1P-CWCQtQa_zUrrLs3RmWNZGJnGR_shydpLQJERVnjL7Fkvmb2SUhA=w60-h60-l90-rj',
#       'width': 60,
#       'height': 60},
#      {'url': 'https://lh3.googleusercontent.com/M81-KIVKIU35aImJ6DjuH9WQocYh1P-CWCQtQa_zUrrLs3RmWNZGJnGR_shydpLQJERVnjL7Fkvmb2SUhA=w120-h120-l90-rj',
#       'width': 120,
#       'height': 120}],
#     'isAvailable': True,
#     'isExplicit': False}]},
#  'albums': {'browseId': None,
#   'results': [{'title': 'After Party en la Casa',
#     'year': '2022',
#     'browseId': 'MPREb_Q09GIbWunLb',
#     'thumbnails': [{'url': 'https://lh3.googleusercontent.com
name': 'Ptazeta', 'id': 'UCI9q5A6SUN37p0gM01E1R4Q'}],
#     'playlistId': 'OLAK5uy_kxQCXPETGxRC6gshhEBitA1KBuEMoHmMQ',
#     'thumbnails': [{'url': 'https://i.ytimg.com/vi/US9jKCfLnek/sddefault.jpg?sqp=-oaymwEWCJADEOEBIAQqCghqEJQEGHgg6AJIWg&rs=AMzJL3lnLb_cRHjcZyGzalgubwwljF39Iw',
#       'width': 400,
#       'height': 225},
#      {'url': 'https://i.ytimg.com/vi/US9jKCfLnek/hq720.jpg?sqp=-oaymwEXCKAGEMIDIAQqCwjVARCqCBh4INgESFo&rs=AMzJL3mVvTj6rpHbQ8MXvc10daUbP9abiA',
#       'width': 800,
#       'height': 450}],
#     'views': '38M'},
#    {'title': 'Mujerón',
#     'videoId': 'drmsUMIqN9k',
#     'artists': [{'name': 'Ptazeta', 'id': 'UCI9q5A6SUN37p0gM01E1R4Q'},
#      {'name': 'Villano Antillano', 'id': 'UCPy0MALtfhQjfm6Jpk5T6FQ'}],
#     'playlistId': 'OLAK5uy_kxQCXPETGxRC6gshhEBitA1KBuEMoHmMQ',
#     'thumbnails': [{'url': 'https://i.ytimg.com/vi/drmsUMIqN9k/sddefault.jpg?sqp=-oaymwEWCJADEOEBIAQqCghqEJQEGHgg6AJIWg&rs=AMzJL3mYQ7ky0vzbsdGu5rwWfLZyxUMlug',
#       'width': 400,
#       'height': 225},
#      {'url': 'https://i.ytimg.com/vi/drmsUMIqN9k/hq720.jpg?sqp=-oaymwEXCKAGEMIDIAQqCwjVARCqCBh4INgESFo&rs=AMzJL3krIDRqu3b362cGiBX1HFq0jiPPqw',
#       'width': 800,
#       'height': 450}],
#     'views': '2.9M'},
#    {'title': 'Mami',
#     'videoId': 'HMF2DPqWN5M',
#     'artists': [{'name': 'Juacko', 'id': 'UC1xacNInB8HMGe-zrF9FJyA'},
#      {'name': 'Ptazeta', 'id': 'UCI9q5A6SUN37p0gM01E1R4Q'}],
#     'playlistId': 'OLAK5uy_kxQCXPETGxRC6gshhEBitA1KBuEMoHmMQ',
#     'thumbnails': [{'url': 'https://i.ytimg.com/vi/HMF2DPqWN5M/sddefault.jpg?sqp=-oaymwEWCJADEOEBIAQqCghqEJQEGHgg6AJIWg&rs=AMzJL3n8rwTSv7pHjqK8Oib7478nPODvag',
#       'width': 400,
#       'height': 225},
#      {'url': 'https://i.ytimg.com/vi/HMF2DPqWN5M/hq720.jpg?sqp=-oaymwEXCKAGEMIDIAQqCwjVARCqCBh4INgESFo&rs=AMzJL3kgm0D7xMQRVF8sOgpn3dPQCMj-fQ',
#       'width': 800,
#       'height': 450}],
#     'views': '28M'},
#    {'title': 'Ri Ri',
#     'videoId': 'Ghd1RRBizOs',
#     'artists': [{'name': 'Ptazeta', 'id': 'UCI9q5A6SUN37p0gM01E1R4Q'}],
#     'playlistId': 'OLAK5uy_kxQCXPETGxRC6gshhEBitA1KBuEMoHmMQ',
#     'thumbnails': [{'url': 'https://i.ytimg.com/vi/Ghd1RRBizOs/sddefault.jpg?sqp=-oaymwEWCJADEOEBIAQqCghqEJQEGHgg6AJIWg&rs=AMzJL3lqhOCZM5JTCXrD1nwtDf7kh8M5IQ',
#       'width': 400,
#       'height': 225},
#      {'url': 'https://i.ytimg.com/vi/Ghd1RRBizOs/hq720.jpg?sqp=-oaymwEXCKAGEMIDIAQqCwjVARCqCBh4INgESFo&rs=AMzJL3lgauPLT6mKeTO6t5gHNX9YBI-6WA',
#       'width': 800,
#       'height': 450}],
#     'views': '3.5M'},
#    {'title': 'Ponte Pal XXX',
#     'videoId': 'fKzaU15y0ZE',
#     'artists': [{'name': 'Ptazeta', 'id': 'UCI9q5A6SUN37p0gM01E1R4Q'}],
#     'playlistId': 'OLAK5uy_kxQCXPETGxRC6gshhEBitA1KBuEMoHmMQ',
#     'thumbnails': [{'url': 'https://i.ytimg.com/vi/fKzaU15y0ZE/sddefault.jpg?sqp=-oaymwEWCJADEOEBIAQqCghqEJQEGHgg6AJIWg&rs=AMzJL3kVug30eI6fT7OFrUCEkUs8PnfEdQ',
#       'width': 400,
#       'height': 225},
#      {'url': 'https://i.ytimg.com/vi/fKzaU15y0ZE/hq720.jpg?sqp=-oaymwEXCKAGEMIDIAQqCwjVARCqCBh4INgESFo&rs=AMzJL3kJLry3JivaDiPNdV_GOTBMQkm96A',
#       'width': 800,
#       'height': 450}],
#     'views': '856K'},
#    {'title': 'Estoy Bien',
#     'videoId': 'xdjI8HjI9ss',
#     'artists': [{'name': 'Juacko', 'id': 'UC1xacNInB8HMGe-zrF9FJyA'},
#      {'name': 'Ptazeta', 'id': 'UCI9q5A6SUN37p0gM01E1R4Q'}],
#     'playlistId': 'OLAK5uy_kxQCXPETGxRC6gshhEBitA1KBuEMoHmMQ',
#     'thumbnails': [{'url': 'https://i.ytimg.com/vi/xdjI8HjI9ss/sddefault.jpg?sqp=-oaymwEWCJADEOEBIAQqCghqEJQEGHgg6AJIWg&rs=AMzJL3msqmEo26tB5YPSuLTJcDftXk574A',
#       'width': 400,
#       'height': 225},
#      {'url': 'https://i.ytimg.com/vi/xdjI8HjI9ss/hq720.jpg?sqp=-oaymwEXCKAGEMIDIAQqCwjVARCqCBh4INgESFo&rs=AMzJL3ll_G55ElrLfYuDWDZ8pdBB4mA71Q',
#       'width': 800,
#       'height': 450}],
#     'views': '2.7M'},
#    {'title': 'Ayer la vi',
#     'videoId': 'RqeVGzGX_50',
#     'artists': [{'name': 'Juacko', 'id': 'UC1xacNInB8HMGe-zrF9FJyA'},
#      {'name': 'Ptazeta', 'id': 'UCI9q5A6SUN37p0gM01E1R4Q'}],
#     'playlistId': 'OLAK5uy_kxQCXPETGxRC6gshhEBitA1KBuEMoHmMQ',
#     'thumbnails': [{'url': 'https://i.ytimg.com/vi/RqeVGzGX_50/sddefault.jpg?sqp=-oaymwEWCJADEOEBIAQqCghqEJQEGHgg6AJIWg&rs=AMzJL3lIKpAVN8HJq0QsxnMntci2PQEgpA',
#       'width': 400,
#       'height': 225},
#      {'url': 'https://i.ytimg.com/vi/RqeVGzGX_50/hq720.jpg?sqp=-oaymwEXCKAGEMIDIAQqCwjVARCqCBh4INgESFo&rs=AMzJL3mZXaJ0fpQSzkQEHvJJwwj9K67UEg',
#       'width': 800,
#       'height': 450}],
#     'views': '3.9M'},
#    {'title': 'Nena no me llores',
#     'videoId': 'VvY_vG8DUC4',
#     'artists': [{'name': 'Juacko', 'id': 'UC1xacNInB8HMGe-zrF9FJyA'},
#      {'name': 'Ptazeta', 'id': 'UCI9q5A6SUN37p0gM01E1R4Q
l90-rj',
#       'width': 226,
#       'height': 226},
#      {'url': 'https://lh3.googleusercontent.com/EelPpM7Q57Sab8x47LkuvFAfzawM1Au7b_SBFvVI-W_jwRO9pbaCqiT91nz7NYw7chzX_2Ymp-SHmhzt=w544-h544-p-l90-rj',
#       'width': 544,
#       'height': 544}]},
#    {'title': 'InnerCut',
#     'browseId': 'UCoRqW1wc2Gz600JnH4dUJGg',
#     'subscribers': '3.2K',
#     'thumbnails': [{'url': 'https://lh3.googleusercontent.com/a-/ACNPEu9HrY-VHYmzK2726KGBzZDqO1q78wxp4zqTlY7UOA=w226-h226-l90-rj-dcGUSecJ0J',
#       'width': 226,
#       'height': 226},
#      {'url': 'https://lh3.googleusercontent.com/a-/ACNPEu9HrY-VHYmzK2726KGBzZDqO1q78wxp4zqTlY7UOA=w544-h544-l90-rj-dcGUSecJ0J',
#       'width': 544,
#       'height': 544}]},
#    {'title': 'Nathy Peluso',
#     'browseId': 'UCkaQTGWajEjXlTEZ_649BVA',
#     'subscribers': '1.37M',
#     'thumbnails': [{'url': 'https://lh3.googleusercontent.com/a-/ACNPEu-jEp6dSnSLvY6AAaMba2v0UmySAH7qpNtsOehUQg=w226-h226-l90-rj',
#       'width': 226,
#       'height': 226},
#      {'url': 'https://lh3.googleusercontent.com/a-/ACNPEu-jEp6dSnSLvY6AAaMba2v0UmySAH7qpNtsOehUQg=w544-h544-l90-rj',
#       'width': 544,
#       'height': 544}]},
#    {'title': 'Jaime Lorente',
#     'browseId': 'UCR8uWjRA4X4SeTSZjl-OIUg',
#     'subscribers': '129K',
#     'thumbnails': [{'url': 'https://lh3.googleusercontent.com/a-/ACNPEu-YGePAROmFCBrg99O6L1238NMaGTFki6VMB4Jh=w226-h226-l90-rj',
#       'width': 226,
#       'height': 226},
#      {'url': 'https://lh3.googleusercontent.com/a-/ACNPEu-YGePAROmFCBrg99O6L1238NMaGTFki6VMB4Jh=w544-h544-l90-rj',
#       'width': 544,
#       'height': 544}]},
#    {'title': 'La Pantera',
#     'browseId': 'UCVcoqmzOo3QmzMdf8InN_Tw',
#     'subscribers': '144K',
#     'thumbnails': [{'url': 'https://lh3.googleusercontent.com/a-/ACNPEu-17VdZKNBMpPunyJ7B6s05wLeIn9GG-3imExVG=w226-h226-l90-rj-dcJWaY7aUI',
#       'width': 226,
#       'height': 226},
#      {'url': 'https://lh3.googleusercontent.com/a-/ACNPEu-17VdZKNBMpPunyJ7B6s05wLeIn9GG-3imExVG=w544-h544-l90-rj-dcJWaY7aUI',
#       'width': 544,
#       'height': 544}]},
#    {'title': 'Juseph',
#     'browseId': 'UCNavFbCUYI1Yyd8V7dU3MEw',
#     'subscribers': '34.7K',
#     'thumbnails': [{'url': 'https://lh3.googleusercontent.com/a-/ACNPEu_EWHcw75yTzojrQa6EBNUAMCeoN9pnygfw9XrH=w226-h226-l90-rj',
#       'width': 226,
#       'height': 226},
#      {'url': 'https://lh3.googleusercontent.com/a-/ACNPEu_EWHcw75yTzojrQa6EBNUAMCeoN9pnygfw9XrH=w544-h544-l90-rj',
#       'width': 544,
#       'height': 544}]}]}}

# %% [markdown]
# BIZARRAP SESSIONS     RDCLAK5uy_mEXMsobutX4itJVd6YaCodxMgUV-mMtNo
# TOP 100         PL4fGSI1pDJn4jhQB4kb9M36dvVmJQPt4T

# %%
yt = YTMusic()
playlist=['RDCLAK5uy_mEXMsobutX4itJVd6YaCodxMgUV-mMtNo','PL4fGSI1pDJn4jhQB4kb9M36dvVmJQPt4T']

artistas = []
ids=[]
diccSolo= {}
diccSolo.clear()
colabos=[]

infoPlayList = []
for p in playlist:
     infoPlayList.append(yt.get_playlist(p))

for r in infoPlayList:
     for a in r['tracks']:
      artistas.append(a['artists'])
          

#for r in searchPlay['tracks']:
#     artistas.append(r['artists'])


for a in artistas:#cargamos el diccionario con los artistas que van a cantar solos
   for b in a:
    if(len(a)==1):
        diccSolo[b['name']]={'idYTMusic':b['id'],'colaboracion':[]}

# %%
diccColabo= {}
diccColabo.clear()

for a in artistas:#aqui cargamos solo artistas que han aparecido con colaboraciones en la playlist
  if(len(a)>1):
      diccColabo[a[0]['name']]={'idYTMusic':a[0]['id'],'colaboracion':[],'subscriptores':None,'views':None}

      #if(len(a)==2):
          #dicc[b['id']]={'name':b['name']}

# %%
#c[1]['name']
for c in artistas:#aqui les metemos en colaboraciones sus feats
    if(len(c)>1):
      # print(c[i+1]['name'])--> funcion que recorre artistas de las colaboraciones
      #añadimos artistas a las colabos
           for i in range(len(c)-1):
            diccColabo[c[0]['name']]['colaboracion'].append(c[i+1]['name'])
#diccColabo

# %%
#para quitar los artistas que no tiene id ytMusic

for a in diccColabo:
   if(diccColabo[a]['idYTMusic']==None):
     idsvacios=yt.search(a)
     if('browseId'not in idsvacios[0]):#VER SI TIENE  ['browseId'] , SI NO LO TIENE SE PONE NO CHANNEL, SI TIENE SE PONE LO QUE ESTA EN EL ELSE  
      diccColabo[a]['idYTMusic']='No Channel'
     else:
      diccColabo[a]['idYTMusic']=idsvacios[0]['browseId']
   
#diccColabo

# %%
#numeramos con ids 
i=0
for keys in diccColabo:
    diccColabo[keys]['id']=i
    i=i+1

# %%
infoartista=[]
infoSubscribers=[]
infoViews=[]
for a in diccColabo:
   infoartista.append(diccColabo[a]['idYTMusic'])
  
for r in infoartista:
   if(r!='No Channel'):
      artista=yt.get_artist(r)
      infoSubscribers.append(artista['subscribers'])
      infoViews.append(artista['views'])
i=0
for keys in diccColabo:
    if(diccColabo[keys]['idYTMusic']!='No Channel'):
      diccColabo[keys]['subscriptores']=infoSubscribers[i]
      diccColabo[keys]['views']=infoViews[i]
      i=i+1    

diccColabo
# Out:
# {'Quevedo': {'idYTMusic': 'UC7PL9aor5qNRhvhWWVXyOqA',
#   'colaboracion': ['Bizarrap', 'Bizarrap', 'Mora', 'Ovy On The Drums'],
#   'subscriptores': '1.03M',
#   'views': '259,247,983 views',
#   'id': 0},
#  'L-Gante': {'idYTMusic': 'UCpmpQ_z2Id7bOFeNC9_WEvA',
#   'colaboracion': ['Bizarrap'],
#   'subscriptores': '3.2M',
#   'views': '1,308,970,468 views',
#   'id': 1},
#  'Nicky Jam': {'idYTMusic': 'UCMJ705HLB_EflTzWDAjcKSQ',
#   'colaboracion': ['Bizarrap'],
#   'subscriptores': '23.3M',
#   'views': '15,309,693,582 views',
#   'id': 2},
#  'Bizarrap': {'idYTMusic': 'UCONiUl5u7y2bMaVZJcuRDEQ',
#   'colaboracion': ['Residente',
#    'Villano Antillano',
#    'Nicki Nicole',
#    'Trueno',
#    'Duki',
#    'Cazzu',
#    'DANI',
#    'Morad',
#    'Trueno',
#    'Ysy A',
#    'Chucky73',
#    'Bhavi',
#    'John C',
#    'Seven Kayne',
#    'Villano Antillano'],
#   'subscriptores': '16.5M',
#   'views': '5,764,302,911 views',
#   'id': 3},
#  'Snow Tha Product': {'idYTMusic': 'UC75nukWj1GP0V62KVH7WvzQ',
#   'colaboracion': ['Bizarrap'],
#   'subscriptores': '1.97M',
#   'views': '350,462,838 views',
#   'id': 4},
#  'Ptazeta': {'idYTMusic': 'UCI9q5A6SUN37p0gM01E1R4Q',
#   'colaboracion': ['Bizarrap', 'Emilia', 'Aitana'],
#   'subscriptores': '378K',
#   'views': None,
#   'id': 5},
#  'Nathy Peluso': {'idYTMusic': 'UCkaQTGWajEjXlTEZ_649BVA',
#   'colaboracion': ['Bizarrap'],
#   'subscriptores': '1.37M',
#   'views': '418,636,529 views',
#   'id': 6},
#  'Eladio Carrion': {'idYTMusic': 'UC7YJ69rJ9qtVh6SjYFs4cGg',
#   'colaboracion': ['Bizarrap', 'Bizarrap'],
#   'subscriptores': '3.15M',
#   'views': '1,700,648,907 views',
#   'id': 7},
#  'Alemán': {'idYTMusic': 'UC9qH_PzG3TpfJpsRt9VfKcA',
#   'colaboracion': ['Bizarrap'],
#   'subscriptores': '6.18M',
#   'views': '2,042,179,126 views',
#   'id': 8},
#  'Zaramay': {'idYTMusic': 'UC3l-zF0JLkdF6OMAtbQKAEA',
#   'colaboracion': ['Bizarrap'],
#   'subscriptores': '1.07M',
#   'views': None,
#   'id': 9},
#  'Anuel AA': {'idYTMusic': 'UCbBaYg2UToDaoOwo-R6xi4g',
#   'colaboracion': ['Bizarrap',
#    'Bryant Myers',
#    'Casper Magico',
#    'Foreign Teck',
#    'Chris Jedi',
#    'Gaby Music'],
#   'subscriptores': '23.2M',
#   'views': '12,509,594,142 views',
#   'id': 10},
#  'Hot Plug Beats': {'idYTMusic': 'UC8Kso_Z_382RmA8WyCnTS8w',
#   'colaboracion': ['Frijo', 'Bizarrap'],
#   'subscriptores': '104',
#   'views': None,
#   'id': 11},
#  'Kiddo Toto': {'idYTMusic': 'UCjbaTRoB85rmL7lGybha2GQ',
#   'colaboracion': ['Bizarrap'],
#   'subscriptores': '275K',
#   'views': '27,988,646 views',
#   'id': 12},
#  'Rauw Alejandro': {'idYTMusic': 'UCw_m17sBd4GHxuK83-AZtuA',
#   'colaboracion': ['Baby Rasta', 'Lyanno', 'Brray'],
#   'subscriptores': '12.2M',
#   'views': '10,011,962,375 views',
#   'id': 13},
#  'Shakira': {'idYTMusic': 'UCo6JijJGA3IvIiPsawDK3Ww',
#   'colaboracion': ['Ozuna',
#    'Rauw Alejandro',
#    'Ozuna',
#    'Black Eyed Peas',
#    'David Guetta'],
#   'subscriptores': '38.9M',
#   'views': '24,853,910,045 views',
#   'id': 14},
#  'Aitana': {'idYTMusic': 'UCkyzcFsGWVYSUGaR7YB9OYQ',
#   'colaboracion': ['Sangiovanni'],
#   'subscriptores': '2.13M',
#   'views': '985,125,178 views',
#   'id': 15},
#  'KAROL G': {'idYTMusic': 'UC7n3gWRN0vQzgiOKc51aZ4w',
#   'colaboracion': ['Ovy On The Drums', 'Maldy'],
#   'subscriptores': '28.6M',
#   'views': '15,197,846,962 views',
#   'id': 16},
#  'Melendi': {'idYTMusic': 'UCl4jq8XKq5X0ZL5p_xVMmZA',
#   'colaboracion': ['India Martínez'],
#   'subscriptores': '4.4M',
#   'views': '3,738,929,441 views',
#   'id': 17},
#  'Wisin & Yandel': {'idYTMusic': 'UCJ0-R-v3CaJNYMqfp9tivqA',
#   'colaboracion': ['Rosalia'],
#   'subscriptores': '6.99M',
#   'views': '5,792,377,351 views',
#   'id': 18},
#  'Abraham Mateo': {'idYTMusic': 'UCql3y41dHUh9JoPHMedvCbQ',
#   'colaboracion': ['Ana Mena'],
#   'subscriptores': '4.62M',
#   'views': '1,810,429,832 views',
#   'id': 19},
#  'Belinda': {'idYTMusic': 'UC8tw8d2POmc3Lt8t1bmgl9Q',
#   'colaboracion': ['Ana Mena'],
#   'subscriptores': '868K',
#   'views': '349,838,357 views',
#   'id': 20},
#  'K y B': {'idYTMusic': 'No Channel',
#   'colaboracion': ['Beny Jr', 'Morad'],
#   'subscriptores': None,
#   'views': None,
#   'id': 21},
#  'India Martínez': {'idYTMusic': 'UCJbpTwP22V6baVULM7-J4Bw',
#   'colaboracion': ['Andy Rivera'],
#   'subscriptores': '1M',
#   'views': '700,760,215 views',
#   'id': 22},
#  'Jairo deRemache': {'idYTMusic': 'UC0rxntgJfUecm5h_d6mY8eg',
#   'colaboracion': ['Farruquito', 'Omar Montes'],
#   'subscriptores': '193',
#   'views': None,
#   'id': 23},
#  'Myke Towers': {'idYTMusic': 'UCYPsIfSIEwWcoynHBP5k1dg',
#   'colaboracion': ['Tiago PZK'],
#   'subscriptores': '9.55M',
#   'views': '6,489,046,884 views',
#   'id': 24},
#  'Jhayco': {'idYTMusic': 'UChZEzxer-QvRMbADJJGOMuQ',
#   'colaboracion': ['Mora', 'Feid', 'Sech'],
#   'subscriptores': '4.73M',
#   'views': '3,989,919,337 views',
#   'id': 25},
#  'JC Reyes': {'idYTMusic': 'UCXGll6UzxbSdLO1_w7rP22g',
#   'colaboracion': ['Pablo Chill-E', 'Ecko'],
#   'subscriptores': '17K',
#   'views': None,
#   'id': 26},
#  'Sergio Ramos': {'idYTMusic': 'UC2MgeVTYErtkCzRMucgFyjQ',
#   'colaboracion': ['Niña Pastori', 'RedOne'],
#   'subscriptores': '506',
#   'views': '8,438 views',
#   'id': 27},
#  'Selena Gomez': {'idYTMusic': 'UCeBYRgPhy8kcRmIGQWKuqdQ',
#   'colaboracion': ['Rema', 'Rema'],
#   'subscriptores': '31.8M',
#   'views': '11,989,010,534 views',
#   'id': 28},
#  'ROSALÍA': {'idYTMusic': 'UCeYz6rzUGhVwqxRM37FUo8w',
#   'colaboracion': ['Romeo Santos'],
#   'subscriptores': '9.92M',
#   'views': '4,617,326,172 views',
#   'id': 29},
#  'Barroso': {'idYTMusic': 'UC1jVH0d6Eu8Sk521-VaxXxw',
#   'colaboracion': ['Dani MDR', 'Lorena Santos'],
#   'subscriptores': '78.3K',
#   'views': None,
#   'id': 30},
#  'C. Tangana': {'idYTMusic': 'UCLuHOvsT_LbOGVjqmXudvBg',
#   'colaboracion': ['Omar Montes'],
#   'subscriptores': '2.23M',
#   'views': '1,362,117,586 views',
#   'id': 31},
#  'RVFV': {'idYTMusic': 'UCj6HoOP59UGegqUC-fu4Wlg',
#   'colaboracion': ['Duki'],
#   'subscriptores': '967K',
#   'views': None,
#   'id': 32},
#  'Lola Indigo': {'idYTMusic': 'UCydg_dYqBrPZ4-X1MnxD37A',
#   'colaboracion': ['Maria Becerra'],
#   'subscriptores': '1.23M',
#   'views': '678,406,693 views',
#   'id': 33},
#  'Cano': {'idYTMusic': 'UCumOUWYBPRw2pxGl7QGeiRw',
#   'colaboracion': ['El Jhota', 'Los del Control'],
#   'subscriptores': '177K',
#   'views': None,
#   'id': 34},
#  'Wiso Rivera': {'idYTMusic': 'UCwfvKaHqW4r64dOurVFzD9A',
#   'colaboracion': ['Cruz Cafuné', 'Juseph'],
#   'subscriptores': '171',
#   'views': None,
#   'id': 35},
#  'Paco Candela': {'idYTMusic': 'UCBUw8Hip7C6BP8x-QrAaY9g',
#   'colaboracion': ['Andy & Lucas'],
#   'subscriptores': '63.7K',
#   'views': None,
#   'id': 36},
#  'Sebastián Yatra': {'idYTMusic': 'UCXP8o4Xcws36pgpFNlGGBeg',
#   'colaboracion': ['Pablo Alborán'],
#   'subscriptores': '17.7M',
#   'views': '9,728,390,018 views',
#   'id': 37},
#  'MVSIS': {'idYTMusic': 'UCTqejquSMSCsmeIozQhKJsQ',
#   'colaboracion': ['Anuel AA'],
#   'subscriptores': '28',
#   'views': None,
#   'id': 38},
#  'Oliver Tree': {'idYTMusic': 'UCoOFEu6s0wk7CUljMh8wisw',
#   'colaboracion': ['Robin Schulz'],
#   'subscriptores': '4.14M',
#   'views': '1,169,268,654 views',
#   'id': 39},
#  'Darell': {'idYTMusic': 'UCVsfgFfzYNMJvcQLDYT7fHw',
#   'colaboracion': ['Omar Montes'],
#   'subscriptores': '3.1M',
#   'views': '1,174,085,786 views',
#   'id': 40},
#  'Mora': {'idYTMusic': 'UCgDpp8Ex8Yz6hhHjbl3W5mg',
#   'colaboracion': ['Feid'],
#   'subscriptores': '1.77M',
#   'views': '1,360,278,828 views',
#   'id': 41},
#  'Paulo Londra': {'idYTMusic': 'UCpH92jOmlMe71mRYEkp7riQ',
#   'colaboracion': ['LIT killah'],
#   'subscriptores': '22.1M',
#   'views': '7,409,917,487 views',
#   'id': 42}}

# %%
df = pd.DataFrame.from_dict(diccColabo, orient = "index",columns=['id','idYTMusic','colaboracion','subscriptores','views'])
df.to_csv('finished.csv')
df
# Out:
#                   id                 idYTMusic  \
# Quevedo            0  UC7PL9aor5qNRhvhWWVXyOqA
# L-Gante            1  UCpmpQ_z2Id7bOFeNC9_WEvA
# Nicky Jam          2  UCMJ705HLB_EflTzWDAjcKSQ
# Bizarrap           3  UCONiUl5u7y2bMaVZJcuRDEQ
# Snow Tha Product   4  UC75nukWj1GP0V62KVH7WvzQ
# Ptazeta            5  UCI9q5A6SUN37p0gM01E1R4Q
# Nathy Peluso       6  UCkaQTGWajEjXlTEZ_649BVA
# Eladio Carrion     7  UC7YJ69rJ9qtVh6SjYFs4cGg
# Alemán             8  UC9qH_PzG3TpfJpsRt9VfKcA
# Zaramay            9  UC3l-zF0JLkdF6OMAtbQKAEA
# Anuel AA          10  UCbBaYg2UToDaoOwo-R6xi4g
# Hot Plug Beats    11  UC8Kso_Z_382RmA8WyCnTS8w
# Kiddo Toto        12  UCjbaTRoB85rmL7lGybha2GQ
# Rauw Alejandro    13  UCw_m17sBd4GHxuK83-AZtuA
# Shakira           14  UCo6JijJGA3IvIiPsawDK3Ww
# Aitana            15  UCkyzcFsGWVYSUGaR7YB9OYQ
# KAROL G           16  UC7n3gWRN0vQzgiOKc51aZ4w
# Melendi           17  UCl4jq8XKq5X0ZL5p_xVMmZA
# Wisin & Yandel    18  UCJ0-R-v3CaJNYMqfp9tivqA
# Abraham Mateo     19  UCql3y41dHUh9JoPHMedvCbQ
# Belinda           20  UC8tw8d2POmc3Lt8t1bmgl9Q
# K y B             21                No Channel
# India Martínez    22  UCJbpTwP22V6baVULM7-J4Bw
# Jairo deRemache   23  UC0rxntgJfUecm5h_d6mY8eg
# Oliver Tree                                          [Robin Schulz]
# Darell                                                [Omar Montes]
# Mora                                                         [Feid]
# Paulo Londra                                           [LIT killah]
#
#                  subscriptores                 views
# Quevedo                  1.03M     259,247,983 views
# L-Gante                   3.2M   1,308,970,468 views
# Nicky Jam                23.3M  15,309,693,582 views
# Bizarrap                 16.5M   5,764,302,911 views
# Snow Tha Product         1.97M     350,462,838 views
# Ptazeta                   378K                  None
# Nathy Peluso             1.37M     418,636,529 views
# Eladio Carrion           3.15M   1,700,648,907 views
# Alemán                   6.18M   2,042,179,126 views
# Zaramay                  1.07M                  None
# Anuel AA                 23.2M  12,509,594,142 views
# Hot Plug Beats             104                  None
# Kiddo Toto                275K      27,988,646 views
# Rauw Alejandro           12.2M  10,011,962,375 views
# Shakira                  38.9M  24,853,910,045 views
# Aitana                   2.13M     985,125,178 views
# KAROL G                  28.6M  15,197,846,962 views
# Melendi                   4.4M   3,738,929,441 views
# Wisin & Yandel           6.99M   5,792,377,351 views
# Abraham Mateo            4.62M   1,810,429,832 views
# Belinda                   868K     349,838,357 views
# K y B                     None                  None
# India Martínez              1M     700,760,215 views
# Jairo deRemache            193                  None
# Myke Towers              9.55M   6,489,046,884 views
# Jhayco                   4.73M   3,989,919,337 views
# JC Reyes                   17K                  None
# Sergio Ramos               506           8,438 views
# Selena Gomez             31.8M  11,989,010,534 views
# ROSALÍA                  9.92M   4,617,326,172 views
# Barroso                  78.3K                  None
# C. Tangana               2.23M   1,362,117,586 views
# RVFV                      967K                  None
# Lola Indigo              1.23M     678,406,693 views
# Cano                      177K                  None
# Wiso Rivera                171                  None
# Paco Candela             63.7K                  None
# Sebastián Yatra          17.7M   9,728,390,018 views
# MVSIS                       28                  None
# Oliver Tree              4.14M   1,169,268,654 views
# Darell                    3.1M   1,174,085,786 views
# Mora                     1.77M   1,360,278,828 views
# Paulo Londra             22.1M   7,409,917,487 views

# %%
header = ['artista', 'colaboracion']

namedicc = {}
with open('aristas.csv','w',encoding='utf-8',newline='') as f:
    writer= csv.writer(f)
    writer.writerow(header)
    for i in diccColabo:
        nombre_relacionados = []
        #print("aaaaaaaaaaaaaaaaa")
        #print(i)
        for r in diccColabo[i]['colaboracion']:
            #print(r)
            writer.writerow([i,r])
        
    #namedicc[diccColabo[i]['id']]=nombre_relacionados


#with open('aristas.csv','w',encoding='utf-8',newline='') as f:
 #   writer= csv.writer(f)
  #  writer.writerow(header)
   # for i in namedicc:
    #    for item in namedicc[i]:
     #       writer.writerow([i,item])

# %%
df = pd.read_csv('aristas.csv',names=['artista','colaboracion'])

G=nx.from_pandas_edgelist(df,'artista','colaboracion')


plt.show() 
plt.figure(figsize=(13,10))
pos = nx.circular_layout(G)
nx.draw(G,pos,with_labels=True,alpha=0.7)

# %%
diccFinal= {}#EN PROCESO
diccFinal.clear()
for a in artistas:
   for b in a:
    if(len(a)>1):
           diccFinal[b['name']]={'idYTMusic':b['id'],'colaboracion':[]}
           for i in range(len(a)-1):
            diccFinal[a[0]['name']]['colaboracion'].append(a[i+1]['name'])
    elif(len(a)==1):
        diccFinal[b['name']]={'idYTMusic':b['id'],'colaboracion':[]}
#diccFinal

# %%
for a in artistas:
   ids.append(a[0]['id'])
